# %%
from Lattes import Lattes
from Lattes import Lattes
import os, glob
# Out:
# Importando Módulos
# Módulos Importados

# %%
# Out:
# Importing file D:/Lattes/Lattes_ZIP\0\0\Lattes_0000000403000690.zip
# Arquivo compactado lido no disco.
# Arquivo em XML salvo no disco.
# Arquivo em JSON salvo no disco.
# Saved id 0000000403000690 to disk.
# Importing file D:/Lattes/Lattes_ZIP\0\0\Lattes_0000002580990139.zip
# Arquivo compactado lido no disco.
# Arquivo em XML salvo no disco.
# Arquivo em JSON salvo no disco.
# Saved id 0000002580990139 to disk.
# Importing file D:/Lattes/Lattes_ZIP\0\0\Lattes_0000004258927645.zip
# Arquivo compactado lido no disco.
# Arquivo em XML salvo no disco.
# Arquivo em JSON salvo no disco.
# Saved id 0000004258927645 to disk.
# Importing file D:/Lattes/Lattes_ZIP\0\0\Lattes_0000005794097038.zip
# Arquivo compactado lido no disco.
# Arquivo em XML salvo no disco.
# Arquivo em JSON salvo no disco.
# Saved id 0000005794097038 to disk.
# Importing file D:/Lattes/Lattes_ZIP\0\0\Lattes_0000008565795348.zip
# Arquivo compactado lido no disco.
# Arquivo em XML salvo no disco.
# ...

# %%
lattes.json

# %%
        lattes = Lattes()

# %%
        lattes.read_zip_from_disk(filename='D:/Lattes/Lattes_ZIP/0/0/Lattes_0000000403000690.zip')
# Out:
# Arquivo compactado lido no disco.
# True

# %%
y='D:/Lattes/Lattes_ZIP/0/0/Lattes_0000000403000690.zip'

# %%
len(y[-20:-4])
# Out:
# 16

# %%
        lattes.get_xml()
# Out:
# True

# %%
lattes.json
# Out:
# OrderedDict([('CURRICULO-VITAE',
#               OrderedDict([('@SISTEMA-ORIGEM-XML', 'LATTES_OFFLINE'),
#                            ('@DATA-ATUALIZACAO', '29022008'),
#                            ('@HORA-ATUALIZACAO', '001941'),
#                            ('DADOS-GERAIS',
#                             OrderedDict([('@NOME-COMPLETO',
#                                           'Fernando Migliorini Tenório'),
#                                          ('@NOME-EM-CITACOES-BIBLIOGRAFICAS',
#                                           'TENÓRIO, F. M.'),
#                                          ('@NACIONALIDADE', 'B'),
#                                          ('@PAIS-DE-NASCIMENTO', 'Brasil'),
#                                          ('@UF-NASCIMENTO', 'PR'),
#                                          ('@CIDADE-NASCIMENTO', 'ARAPONGAS'),
#                                          ('@PERMISSAO-DE-DIVULGACAO', 'NAO'),
#                                          ('RESUMO-CV',
# ...

# %%
lattes.json['CURRICULO-VITAE']['@NUMERO-IDENTIFICADOR']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12244/3619558851.py in <module>
# ----> 1 lattes.json['CURRICULO-VITAE']['@NUMERO-IDENTIFICADOR']
#
# KeyError: '@NUMERO-IDENTIFICADOR'

# %%
lattes.save_xml_to_disk()
# Out:
# Arquivo em XML salvo no disco.
