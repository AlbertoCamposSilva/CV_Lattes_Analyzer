# %%
from Lattes import Lattes
from Indicadores import Indicadores

# %%
lattes = Lattes()
lattes.id = '6046697442527505'
lattes.read_zip_from_disk()
indicadores = Indicadores(lattes.xml)
indicadores.get_indicadores()
# Out:
# Arquivo compactado lido no disco.
# XML atualizado a partir do Lattes compactado.
#                  Id                                 Tipo   Ano
# 0  6046697442527505  Formação nível Superior - Graduação  1971
#                  Id                                 Tipo   Ano
# 0  6046697442527505  Formação nível Superior - Graduação  1973
#                  Id                                 Tipo   Ano
# 0  6046697442527505  Formação nível Superior - Graduação  1971
#                  Id                                      Tipo   Ano
# 0  6046697442527505  Formação nível Superior - Especialização  2002
#                  Id                                      Tipo   Ano
# 0  6046697442527505  Formação nível Superior - Especialização  1973
#                  Id                                      Tipo   Ano
# 0  6046697442527505  Formação nível Superior - Especialização  2001
#                  Id                                Tipo   Ano
# ...

# %%
print (Indicadores.indicadores)
# Out:
#                   Id                                               Tipo   Ano
# 0   0009812001660036                Formação nível Superior - Graduação  2003
# 0   0009812001660036                Formação nível Superior - Graduação  2003
# 0   0009812001660036          Formação nível Superior - Aperfeiçoamento  2007
# 0   0009812001660036          Formação nível Superior - Aperfeiçoamento  2004
# 0   0009812001660036                 Formação nível Superior - Mestrado  2015
# ..               ...                                                ...   ...
# 0   6046697442527505  produção Bibliográfica - Outra produção biblio...  2016
# 0   6046697442527505  produção Bibliográfica - Outra produção biblio...  2016
# 0   6046697442527505  produção Bibliográfica - Outra produção biblio...  2016
# 0   6046697442527505  produção Bibliográfica - Outra produção biblio...  2016
# 0   6046697442527505  produção Bibliográfica - Outra produção biblio...  1994
#
# [2108 rows x 3 columns]

# %%
for key in indicadores.lattes:
    print (key)
print('.')
print('.')
print('.')

print(indicadores.lattes)
# Out:
# AREA-DE-ATUACAO
# CURSO-TECNICO-PROFISSIONALIZANTE
# ENSINO-FUNDAMENTAL-PRIMEIRO-GRAU
# ENSINO-MEDIO-SEGUNDO-GRAU
# GRADUACAO
# APERFEICOAMENTO
# ESPECIALIZACAO
# MESTRADO
# MESTRADO-PROFISSIONALIZANTE
# DOUTORADO
# RESIDENCIA-MEDICA
# LIVRE-DOCENCIA
# POS-DOUTORADO
# VINCULOS
# DIRECAO-E-ADMINISTRACAO
# PESQUISA-E-DESENVOLVIMENTO
# ENSINO
# ESTAGIO
# SERVICO-TECNICO-ESPECIALIZADO
# EXTENSAO-UNIVERSITARIA
# TREINAMENTO-MINISTRADO
# OUTRA-ATIVIDADE-TECNICO-CIENTIFICA
# CONSELHO-COMISSAO-E-CONSULTORIA
# AREAS-DE-ATUACAO
# IDIOMA
# PREMIOS-TITULOS
# PARTICIPACAO-EM-PROJETO
# TRABALHOS-EM-EVENTOS
# ARTIGO-PUBLICADO
# ARTIGO-ACEITO-PARA-PUBLICACAO
# LIVRO-PUBLICADO-OU-ORGANIZADO
# TEXTO-EM-JORNAL-OU-REVISTA
# OUTRA-PRODUCAO-BIBLIOGRAFICA
# PARTITURA-MUSICAL
# .
# .
# .
# ...

# %%
indicadores.lattes['ARTIGO-PUBLICADO'][0]['TITULO-DO-ARTIGO']
# Out:
# 'Memória Salesiana na Missão dos Tachos'

# %%
teste = {'AREA-DE-ATUACAO': [('Grande Área', 'Área', 'Sub-Área', 'Especialidade'), ('CIENCIAS_HUMANAS', 'História', 'História do Brasil', 'História do Brasil Colônia Império'), ('CIENCIAS_HUMANAS', 'Educação', 'Ensino-Aprendizagem', 'Métodos e Técnicas de Ensino'), ('CIENCIAS_HUMANAS', 'História', 'História do Brasil', 'Patrimônio Cultural Território e Memória Local'), ('CIENCIAS_HUMANAS', 'Educação', 'Ensino-Aprendizagem', 'Metodologia da Pesquisa')]}

# %%
type (teste)
# Out:
# dict

# %%
type(indicadores.lattes)
# Out:
# dict
