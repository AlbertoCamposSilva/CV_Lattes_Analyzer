# %%
from Indicadores import Indicadores
from Lattes import Lattes

# %%
lattes = Lattes(id = '1600461423386842')
lattes.get_xml()
# Out:
# Data de atualização pega do Banco de dados: 2021-09-07 14:39:50+00:00
# Data de atualização pega via SOAP: 2021-09-07 14:39:50+00:00
# XML e JSON pegos do Banco de Dados.

# %%
indicadores = Indicadores(lattes.xml)

# %%
print(indicadores.indicador)
# Out:
# [('Id Lattes', 'Indicador', 'Descrição Indicador', 'Ano', 'Grande Área', 'Área', 'Sub-Área', 'Especialidade'), ('1600461423386842', 'FSG', 'Formação nível Superior - Graduação', '1974', 'Bacharelado em Física', None, None, None), ('1600461423386842', 'FSM', 'Formação nível Superior - Mestrado', '1977', 'CIENCIAS_EXATAS_E_DA_TERRA', '', 'Física da Matéria Condensada', ''), ('1600461423386842', 'FSD', 'Formação nível Superior - Doutorado', '1982', 'CIENCIAS_EXATAS_E_DA_TERRA', '', 'Física da Matéria Condensada', ''), ('1600461423386842', 'FSP', 'Formação nível Superior - Pós-Doutorado', '1985', 'CIENCIAS_EXATAS_E_DA_TERRA', '', 'Física da Matéria Condensada', 'Prop. Óticas e Espectrosc. da Mat. Condens; Outras Inter. da Mat. com Rad. e Part.'), ('1600461423386842', 'FSP', 'Formação nível Superior - Pós-Doutorado', '1992', 'CIENCIAS_EXATAS_E_DA_TERRA', '', 'Física da Matéria Condensada', ''), ('1600461423386842', 'FSP', 'Formação nível Superior - Pós-Doutorado', '1997', 'CIENCIAS_EXATAS
# ...

# %%
print(indicadores.graduacoes)
# Out:
# [{'SEQUENCIA-FORMACAO': '6', 'NIVEL': '1', 'TITULO-DO-TRABALHO-DE-CONCLUSAO-DE-CURSO': '', 'NOME-DO-ORIENTADOR': '', 'CODIGO-INSTITUICAO': '019200000005', 'NOME-INSTITUICAO': 'Universidade Federal do Rio Grande do Sul', 'CODIGO-ORGAO': '', 'NOME-ORGAO': '', 'CODIGO-CURSO': '90000000', 'NOME-CURSO': 'Bacharelado em Física', 'CODIGO-AREA-CURSO': '90000000', 'STATUS-DO-CURSO': 'CONCLUIDO', 'ANO-DE-INICIO': '1971', 'ANO-DE-CONCLUSAO': '1974', 'FLAG-BOLSA': 'NAO', 'CODIGO-AGENCIA-FINANCIADORA': '', 'NOME-AGENCIA': '', 'NUMERO-ID-ORIENTADOR': '', 'CODIGO-CURSO-CAPES': '', 'TITULO-DO-TRABALHO-DE-CONCLUSAO-DE-CURSO-INGLES': '', 'NOME-CURSO-INGLES': '', 'FORMACAO-ACADEMICA-TITULACAO': '', 'TIPO-GRADUACAO': '', 'CODIGO-INSTITUICAO-GRAD': '', 'NOME-INSTITUICAO-GRAD': '', 'CODIGO-INSTITUICAO-OUTRA-GRAD': '', 'NOME-INSTITUICAO-OUTRA-GRAD': '', 'NOME-ORIENTADOR-GRAD': ''}]
