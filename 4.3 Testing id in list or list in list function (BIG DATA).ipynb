# %%
import os, glob    
path = 'C:/downloads'
ids_em_zip = {}
for x in range(10):
    ids_em_zip[str(x)] = {}
    for y in range(10):
        ids_em_zip[str(x)][str(y)] = []

ids_em_json = []
linhas_lidas = 0

print('Carregando lista de ids em formato Arquivo zip já baixados.')
for x in os.walk(path):
    for y in glob.glob(os.path.join(x[0], '*.zip')):
         id_carga = y[y.find('Lattes_')+7:-4]
         ids_em_zip[str(id_carga[0])][str(id_carga[1])].append(id_carga)
# Out:
# Carregando lista de ids em formato Arquivo zip já baixados.

# %%
def list_in_big_list (lista1, lista2):
    temp_lista2 = {}
    num_keys = len(lista2) / 10
    for l in lista2:
        if
# Out:
# {'0': {'0': '0099997031842546',
#   '1': '0199998039712144',
#   '2': '0299999590287705',
#   '3': '0399999511595277',
#   '4': '0499999642879306',
#   '5': '0599988411848284',
#   '6': '0699995570509528',
#   '7': '0799990413452695',
#   '8': '0899992808968049',
#   '9': '0999998497706275'},
#  '1': {'0': '1099996963917718',
#   '1': '1199999681696667',
#   '2': '1299998730680380',
#   '3': '1399995601616126',
#   '4': '1499994860092947',
#   '5': '1599989594125312',
#   '6': '1699999698259799',
#   '7': '1799998336894001',
#   '8': '1899994465014135',
#   '9': '1999996403532229'},
#  '2': {'0': '2099998614904068',
#   '1': '2199999117212062',
#   '2': '2299999936131925',
#   '3': '2399991293300296',
#   '4': '2499989000728463',
#   '5': '2599995520818736',
#   '6': '2699996284387482',
#   '7': '2799995185656443',
#   '8': '2899996599823147',
#   '9': '2999999569645212'},
#  '3': {'0': '3099992866722194',
#   '1': '3199996350339027',
#   '2': '3299991368190713',
# ...

# %%
def list_in_big_list (value in list):
    list_lenformated_list
ids_em_zip = {}
for x in range(10):
    ids_em_zip[str(x)] = {}
    for y in range(10):
        ids_em_zip[str(x)][str(y)] = []

ids_em_json = []
linhas_lidas = 0

print('Carregando lista de ids em formato Arquivo zip já baixados.')
for x in os.walk(path):
    for y in glob.glob(os.path.join(x[0], '*.zip')):
         id_carga = y[y.find('Lattes_')+7:-4]
         ids_em_zip[str(id_carga[0])][str(id_carga[1])] = id_carga
