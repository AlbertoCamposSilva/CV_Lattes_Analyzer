# %%
from Carga import Carga
cg = Carga()
cg.atualiza_todos_os_indicadores (on_conflic_update = True, 
                                  pula_bd_indicadores = True, 
                                  pula_erros = False, 
                                  data_mínima_atualização_lattes = '2020-01-01', 
                                  de_all_lattes = True, 
                                  começando_com=[0,1,2,3,4],
                                  nível_mínimo = 4
                                 )
# Out:
# Carregando lista de Ids da tabela indicadores para pular
#
# Carregando lista de indicadores para importar da tabela Lattes do BD
#
# Carregando lista de indicadores para importar da tabela demanda_bruta do BD
#
# Carregando lista de indicadores para importar da tabela dados_pessoais do BD
#
# Retirando ids a exluir...
# Iniciando Importação.
# Importação iniciada em 11/03/2022, 08:54:48.
# 0.0% importados.
#
# Linhas por segundo lidas (total): 0.3
# 100 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 20/03/2022, 15:45:20
#
#
# ERRRO - Lattes não está carregado.874893640.
# Importação iniciada em 11/03/2022, 08:54:48.
# 0.1% importados.
#
# Linhas por segundo lidas (total): 0.4
# 200 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 20/03/2022, 11:25:14
#
#
# ERRRO - Lattes não está carregado.987041036.
# Importação iniciada em 11/03/2022, 08:54:48.
# 0.1% importados.
#
# Linhas por segundo lidas (total): 0.4
# 300 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 20/03/2022, 00:39:11
#
#
# Importação iniciada em 11/03/2022, 08:54:48.
# 0.1% importados.
#
# Linhas por segundo lidas (total): 0.4
# 400 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 22:14:14
#
#
# Importação iniciada em 11/03/2022, 08:54:48.
# 0.2% importados.
#
# Linhas por segundo lidas (total): 0.4
# 500 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 20/03/2022, 00:34:26
#
#
# Importação iniciada em 11/03/2022, 08:54:48.
# 0.2% importados.
#
# Linhas por segundo lidas (total): 0.4
# 600 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 23:46:17
#
#
# ERRRO - Lattes não está carregado.566171574.
# Importação iniciada em 11/03/2022, 08:54:48.
# 0.3% importados.
#
# Linhas por segundo lidas (total): 0.4
# 700 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 22:26:49
#
#
# Importação iniciada em 11/03/2022, 08:54:48.
# 0.3% importados.
#
# Linhas por segundo lidas (total): 0.4
# 800 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 20:04:59
#
#
# Importação iniciada em 11/03/2022, 08:54:48.
# 0.3% importados.
#
# Linhas por segundo lidas (total): 0.4
# 900 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 18:00:17
#
#
# ERRRO - Lattes não está carregado.128272857.
# Importação iniciada em 11/03/2022, 08:54:480.
# 0.4% importados.
#
# Linhas por segundo lidas (total): 0.4
# 1,000 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 16:40:01
#
#
# Importação iniciada em 11/03/2022, 08:54:484.
# 0.4% importados.
#
# Linhas por segundo lidas (total): 0.4
# 1,100 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 16:26:06
#
#
# Importação iniciada em 11/03/2022, 08:54:488.
# 0.4% importados.
#
# Linhas por segundo lidas (total): 0.4
# 1,200 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 16:43:20
#
#
# Importação iniciada em 11/03/2022, 08:54:485.
# 0.5% importados.
#
# Linhas por segundo lidas (total): 0.4
# 1,300 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 16:33:47
#
#
# ERRRO - Lattes não está carregado.9838807920.
# Importação iniciada em 11/03/2022, 08:54:489.
# 0.5% importados.
#
# Linhas por segundo lidas (total): 0.4
# 1,400 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 14:38:05
#
#
# ERRRO - Lattes não está carregado.6747671149.
# Importação iniciada em 11/03/2022, 08:54:486.
# 0.5% importados.
#
# Linhas por segundo lidas (total): 0.4
# 1,500 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 14:42:50
#
#
# Importação iniciada em 11/03/2022, 08:54:485.
# 0.6% importados.
#
# Linhas por segundo lidas (total): 0.4
# 1,600 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 15:29:46
#
#
# ERRRO - Lattes não está carregado.5485277418.
# Importação iniciada em 11/03/2022, 08:54:486.
# 0.6% importados.
#
# Linhas por segundo lidas (total): 0.4
# 1,700 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 15:56:48
#
#
# Importação iniciada em 11/03/2022, 08:54:482.
# 0.6% importados.
#
# Linhas por segundo lidas (total): 0.4
# 1,800 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 16:01:27
#
#
# Importação iniciada em 11/03/2022, 08:54:480.
# 0.7% importados.
#
# Linhas por segundo lidas (total): 0.4
# 1,900 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 15:51:08
#
#
# ERRRO - Lattes não está carregado.6782917639.
# Importação iniciada em 11/03/2022, 08:54:485.
# 0.7% importados.
#
# Linhas por segundo lidas (total): 0.4
# 2,000 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 16:06:19
#
#
# Importação iniciada em 11/03/2022, 08:54:484.
# 0.8% importados.
#
# Linhas por segundo lidas (total): 0.4
# 2,100 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 15:37:42
#
#
# ERRRO - Lattes não está carregado.6155145874.
# Importação iniciada em 11/03/2022, 08:54:487.
# 0.8% importados.
#
# Linhas por segundo lidas (total): 0.4
# 2,200 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 15:38:11
#
#
# Importação iniciada em 11/03/2022, 08:54:487.
# 0.8% importados.
#
# Linhas por segundo lidas (total): 0.4
# 2,300 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 15:25:37
#
#
# Importação iniciada em 11/03/2022, 08:54:489.
# 0.9% importados.
#
# Linhas por segundo lidas (total): 0.4
# 2,400 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 15:06:54
#
#
# Importação iniciada em 11/03/2022, 08:54:488.
# 0.9% importados.
#
# Linhas por segundo lidas (total): 0.4
# 2,500 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 15:53:55
#
#
# Importação iniciada em 11/03/2022, 08:54:486.
# 0.9% importados.
#
# Linhas por segundo lidas (total): 0.4
# 2,600 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 16:31:18
#
#
# Importação iniciada em 11/03/2022, 08:54:482.
# 1.0% importados.
#
# Linhas por segundo lidas (total): 0.4
# 2,700 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 17:01:46
#
#
# Importação iniciada em 11/03/2022, 08:54:486.
# 1.0% importados.
#
# Linhas por segundo lidas (total): 0.4
# 2,800 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 16:32:07
#
#
# Importação iniciada em 11/03/2022, 08:54:483.
# 1.0% importados.
#
# Linhas por segundo lidas (total): 0.4
# 2,900 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 17:07:04
#
#
# Importação iniciada em 11/03/2022, 08:54:488.
# 1.1% importados.
#
# Linhas por segundo lidas (total): 0.4
# 3,000 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 17:13:40
#
#
# Importação iniciada em 11/03/2022, 08:54:481.
# 1.1% importados.
#
# Linhas por segundo lidas (total): 0.4
# 3,100 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 17:03:33
#
#
# Importação iniciada em 11/03/2022, 08:54:482.
# 1.2% importados.
#
# Linhas por segundo lidas (total): 0.4
# 3,200 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 17:12:58
#
#
# ERRRO - Lattes não está carregado.3349227040.
# Importação iniciada em 11/03/2022, 08:54:487.
# 1.2% importados.
#
# Linhas por segundo lidas (total): 0.4
# 3,300 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 17:24:14
#
#
# Importação iniciada em 11/03/2022, 08:54:481.
# 1.2% importados.
#
# Linhas por segundo lidas (total): 0.4
# 3,400 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 17:28:41
#
#
# ERRRO - Lattes não está carregado.5751452532.
# ERRRO - Lattes não está carregado.9339500518.
# Importação iniciada em 11/03/2022, 08:54:489.
# 1.3% importados.
#
# Linhas por segundo lidas (total): 0.4
# 3,500 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 17:14:40
#
#
# Importação iniciada em 11/03/2022, 08:54:483.
# 1.3% importados.
#
# Linhas por segundo lidas (total): 0.4
# 3,600 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 17:25:46
#
#
# Importação iniciada em 11/03/2022, 08:54:488.
# 1.3% importados.
#
# Linhas por segundo lidas (total): 0.4
# 3,700 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 17:08:45
#
#
# ERRRO - Lattes não está carregado.8131000376.
# Importação iniciada em 11/03/2022, 08:54:482.
# 1.4% importados.
#
# Linhas por segundo lidas (total): 0.4
# 3,800 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 17:18:24
# Importação iniciada em 11/03/2022, 08:54:484.
# 1.4% importados.
#
# Linhas por segundo lidas (total): 0.4
# 3,900 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 17:43:33
#
#
# ERRRO - Lattes não está carregado.0307862606.
# ERRRO - Lattes não está carregado.7452722889.
# Importação iniciada em 11/03/2022, 08:54:486.
# 1.4% importados.
#
# Linhas por segundo lidas (total): 0.4
# 4,000 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 17:52:21
#
#
# Importação iniciada em 11/03/2022, 08:54:484.
# 1.5% importados.
#
# Linhas por segundo lidas (total): 0.4
# 4,100 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 18:15:51
#
#
# Importação iniciada em 11/03/2022, 08:54:481.
# 1.5% importados.
#
# Linhas por segundo lidas (total): 0.4
# 4,200 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 18:45:28
#
#
# ERRRO - Lattes não está carregado.5619262885.
# ERRRO - Lattes não está carregado.1542837629.
# ERRRO - Lattes não está carregado.1757190025.
# Importação iniciada em 11/03/2022, 08:54:488.
# 1.6% importados.
#
# Linhas por segundo lidas (total): 0.4
# 4,300 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 18:50:01
#
#
# Importação iniciada em 11/03/2022, 08:54:481.
# 1.6% importados.
#
# Linhas por segundo lidas (total): 0.4
# 4,400 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 19:19:56
#
#
# Importação iniciada em 11/03/2022, 08:54:484.
# 1.6% importados.
#
# Linhas por segundo lidas (total): 0.4
# 4,500 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 19:21:34
#
#
# Importação iniciada em 11/03/2022, 08:54:489.
# 1.7% importados.
#
# Linhas por segundo lidas (total): 0.4
# 4,600 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 20:12:37
#
#
# Importação iniciada em 11/03/2022, 08:54:480.
# 1.7% importados.
#
# Linhas por segundo lidas (total): 0.4
# 4,700 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 20:22:33
#
#
# Importação iniciada em 11/03/2022, 08:54:481.
# 1.7% importados.
#
# Linhas por segundo lidas (total): 0.4
# 4,800 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 20:20:05
#
#
# Importação iniciada em 11/03/2022, 08:54:480.
# 1.8% importados.
#
# Linhas por segundo lidas (total): 0.4
# 4,900 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 20:31:19
#
#
# Importação iniciada em 11/03/2022, 08:54:480.
# 1.8% importados.
#
# Linhas por segundo lidas (total): 0.4
# 5,000 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 20:36:31
#
#
# Importação iniciada em 11/03/2022, 08:54:485.
# 1.8% importados.
#
# Linhas por segundo lidas (total): 0.4
# 5,100 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 21:42:33
#
#
# Importação iniciada em 11/03/2022, 08:54:481.
# 1.9% importados.
#
# Linhas por segundo lidas (total): 0.4
# 5,200 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 22:39:55
#
#
# Importação iniciada em 11/03/2022, 08:54:480.
# 1.9% importados.
#
# Linhas por segundo lidas (total): 0.4
# 5,300 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 19/03/2022, 23:32:04
#
#
# Importação iniciada em 11/03/2022, 08:54:485.
# 1.9% importados.
#
# Linhas por segundo lidas (total): 0.4
# 5,400 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 20/03/2022, 00:13:41
#
#
# Importação iniciada em 11/03/2022, 08:54:488.
# 2.0% importados.
#
# Linhas por segundo lidas (total): 0.4
# 5,500 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 20/03/2022, 00:49:42
#
#
# ERRRO - Lattes não está carregado.2424687216.
# Importação iniciada em 11/03/2022, 08:54:489.
# 2.0% importados.
#
# Linhas por segundo lidas (total): 0.4
# 5,600 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 20/03/2022, 00:58:25
#
#
# Importação iniciada em 11/03/2022, 08:54:482.
# 2.1% importados.
#
# Linhas por segundo lidas (total): 0.4
# 5,700 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 20/03/2022, 01:05:18
#
#
# Importação iniciada em 11/03/2022, 08:54:485.
# 2.1% importados.
#
# Linhas por segundo lidas (total): 0.4
# 5,800 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 20/03/2022, 01:14:32
#
#
# Importação iniciada em 11/03/2022, 08:54:484.
# 2.1% importados.
#
# Linhas por segundo lidas (total): 0.4
# 5,900 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 20/03/2022, 01:40:59
#
#
# Importação iniciada em 11/03/2022, 08:54:485.
# 2.2% importados.
#
# Linhas por segundo lidas (total): 0.4
# 6,000 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 20/03/2022, 02:11:19
#
#
# Importação iniciada em 11/03/2022, 08:54:482.
# 2.2% importados.
#
# Linhas por segundo lidas (total): 0.4
# 6,100 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 20/03/2022, 02:34:52
#
#
# ERRRO - Lattes não está carregado.6000004371.
# Importação iniciada em 11/03/2022, 08:54:482.
# 2.2% importados.
#
# Linhas por segundo lidas (total): 0.4
# 6,200 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 20/03/2022, 03:01:27
#
#
# Importação iniciada em 11/03/2022, 08:54:484.
# 2.3% importados.
#
# Linhas por segundo lidas (total): 0.4
# 6,300 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 20/03/2022, 03:19:55
#
#
# ERRRO - Lattes não está carregado.8185505030.
# Importação iniciada em 11/03/2022, 08:54:482.
# 2.3% importados.
#
# Linhas por segundo lidas (total): 0.4
# 6,400 de 277,379
# Acabará em:
#     Cálculo considerando desde o início: 20/03/2022, 03:57:34
#
#
# 6433 / 277379. Importing id 2132414809153133.
