# %%
from Carga import Carga
cg = Carga(connect_to_bd = False)

# %%
cg.load_carga(
    pular_erros = False,
    pular_indicadores = False,
    pula_bd_lattes = False,
    pula_hd = True,                    
    de_bd_demanda_bruta = False,
    de_bd_dados_pessoais = False,
    de_dados_pessoais = False,
    de_carga = True,
    insere_no_bd = False,
    carga=r'C:\Users\albertos\CNPq\Lattes\Planilhas\Carga all_lattes\R358737.csv',
    log_file=r'C:\Users\albertos\CNPq\Lattes\Planilhas\Carga all_lattes\log.txt',
 )
# Out:
# _______  _        ______   _______  _______ _________ _______
# (  ___  )( \      (  ___ \ (  ____ \(  ____ )\__   __/(  ___  )
# | (   ) || (      | (   ) )| (    \/| (    )|   ) (   | (   ) |
# | (___) || |      | (__/ / | (__    | (____)|   | |   | |   | |
# |  ___  || |      |  __ (  |  __)   |     __)   | |   | |   | |
# | (   ) || |      | (  \ \ | (      | (\ (      | |   | |   | |
# | )   ( || (____/\| )___) )| (____/\| ) \ \__   | |   | (___) |
# |/     \|(_______/|/ \___/ (_______/|/   \__/   )_(   (_______)
#
#
#  _______  _______  _______  _______  _______  _______
# (  ____ \(  ___  )(       )(  ____ )(  ___  )(  ____ \
# | (    \/| (   ) || () () || (    )|| (   ) || (    \/
# | |      | (___) || || || || (____)|| |   | || (_____
# | |      |  ___  || |(_)| ||  _____)| |   | |(_____  )
# | |      | (   ) || |   | || (      | |   | |      ) |
# | (____/\| )   ( || )   ( || )      | (___) |/\____) |
# (_______/|/     \||/     \||/       (_______)\_______)
#
#
#
#  _____     ___    ______    _____     ___
# /  __ \   / _ \   | ___ \  |  __ \   / _ \
# | /  \/  / /_\ \  | |_/ /  | |  \/  / /_\ \
# | |      |  _  |  |    /   | | __   |  _  |
# | \__/\  | | | |  | |\ \   | |_\ \  | | | |
#  \____/  \_| |_/  \_| \_|   \____/  \_| |_/
#
#
# Criando diretórios temporários, se não existirem.
# Gerando lista de ids a atualizar indicadores
# Pegando lista de ids já salvos no HD.
#     296.4% completos.
#
# Carregando lista de IDs a importar pela carga de ids no SOAP
# Pulando primeiras linhas.
# Carregando ids a ler.
# Erro na linha 7379645: ['', 'COL', '16/09/2004', '', '', '05/01/2022']
# Erro na linha 7398983: ['', 'EUA', '02/03/2007', '', '', '05/01/2022']
#
# Retirando ids a exluir...
# Começando importação.
#
#
#  Há 1990959 arquivos a importar.
#
#
# Movendo arquivos do diretório temporário para o diretório permanente. do CNPq.
# Foram movidos 98 arquivos.
# Importação iniciada em 03/10/2022, 18:33:12
# 0.0% importados.
#
# Linhas por segundo lidas (total): 1.5
# 100 de 1,990,959
# 0 erros.
#
# Acabará em:
#     Cálculo considerando desde o início: 19/10/2022, 01:38:10
#
#
# Movendo arquivos do diretório temporário para o diretório permanente. do CNPq.
# Foram movidos 96 arquivos.
# Importação iniciada em 03/10/2022, 18:33:12
# 0.0% importados.
#
# Linhas por segundo lidas (total): 1.6
# 200 de 1,990,959
# 0 erros.
#
# Acabará em:
#     Cálculo considerando desde o início: 18/10/2022, 06:21:24
#
#
# Movendo arquivos do diretório temporário para o diretório permanente. do CNPq.
# Foram movidos 96 arquivos.
# Importação iniciada em 03/10/2022, 18:33:12
# 0.0% importados.
#
# Linhas por segundo lidas (total): 1.6
# 300 de 1,990,959
# 0 erros.
#
# Acabará em:
#     Cálculo considerando desde o início: 18/10/2022, 00:05:48
#
#
# Movendo arquivos do diretório temporário para o diretório permanente. do CNPq.
# Foram movidos 98 arquivos.
# Importação iniciada em 03/10/2022, 18:33:12
# 0.0% importados.
#
# Linhas por segundo lidas (total): 1.6
# 400 de 1,990,959
# 0 erros.
#
# Acabará em:
#     Cálculo considerando desde o início: 17/10/2022, 21:34:53
#
#
# Movendo arquivos do diretório temporário para o diretório permanente. do CNPq.
# Foram movidos 95 arquivos.
# Importação iniciada em 03/10/2022, 18:33:12
# 0.0% importados.
#
# Linhas por segundo lidas (total): 1.6
# 500 de 1,990,959
# 0 erros.
#
# Acabará em:
#     Cálculo considerando desde o início: 17/10/2022, 19:41:52
#
#
# Movendo arquivos do diretório temporário para o diretório permanente. do CNPq.
# Foram movidos 100 arquivos.
# Importação iniciada em 03/10/2022, 18:33:12
# 0.0% importados.
#
# Linhas por segundo lidas (total): 1.6
# 600 de 1,990,959
# 0 erros.
#
# Acabará em:
#     Cálculo considerando desde o início: 17/10/2022, 18:34:50
#
#
# Movendo arquivos do diretório temporário para o diretório permanente. do CNPq.
# Foram movidos 97 arquivos.
# Importação iniciada em 03/10/2022, 18:33:12
# 0.0% importados.
#
# Linhas por segundo lidas (total): 1.6
# 700 de 1,990,959
# 0 erros.
#
# Acabará em:
#     Cálculo considerando desde o início: 17/10/2022, 17:44:26
#
#
# Movendo arquivos do diretório temporário para o diretório permanente. do CNPq.
# Foram movidos 96 arquivos.
# Importação iniciada em 03/10/2022, 18:33:12
# 0.0% importados.
#
# Linhas por segundo lidas (total): 1.7
# 800 de 1,990,959
# 0 erros.
#
# Acabará em:
#     Cálculo considerando desde o início: 17/10/2022, 17:05:37
#
#
# Movendo arquivos do diretório temporário para o diretório permanente. do CNPq.
# Foram movidos 97 arquivos.
# Importação iniciada em 03/10/2022, 18:33:12
# 0.0% importados.
#
# Linhas por segundo lidas (total): 1.7
# 900 de 1,990,959
# 0 erros.
#
# Acabará em:
#     Cálculo considerando desde o início: 17/10/2022, 16:27:17
#
#
# Movendo arquivos do diretório temporário para o diretório permanente. do CNPq.
# Foram movidos 98 arquivos.
# Importação iniciada em 03/10/2022, 18:33:12
# 0.1% importados.
#
# Linhas por segundo lidas (total): 1.7
# 1,000 de 1,990,959
# 0 erros.
#
# Acabará em:
#     Cálculo considerando desde o início: 17/10/2022, 15:41:28
#
#
# Movendo arquivos do diretório temporário para o diretório permanente. do CNPq.
# Foram movidos 97 arquivos.
# Importação iniciada em 03/10/2022, 18:33:12
# 0.1% importados.
#
# Linhas por segundo lidas (total): 1.7
# 1,100 de 1,990,959
# 0 erros.
#
# Acabará em:
#     Cálculo considerando desde o início: 17/10/2022, 15:38:35
#
#
# Movendo arquivos do diretório temporário para o diretório permanente. do CNPq.
# Foram movidos 97 arquivos.
# Importação iniciada em 03/10/2022, 18:33:12
# 0.1% importados.
#
# Linhas por segundo lidas (total): 1.7
# 1,200 de 1,990,959
# 0 erros.
#
# Acabará em:
#     Cálculo considerando desde o início: 17/10/2022, 15:09:39
#
#
# Movendo arquivos do diretório temporário para o diretório permanente. do CNPq.
# Foram movidos 97 arquivos.
# Importação iniciada em 03/10/2022, 18:33:12
# 0.1% importados.
#
# Linhas por segundo lidas (total): 1.7
# 1,300 de 1,990,959
# 0 erros.
#
# Acabará em:
#     Cálculo considerando desde o início: 17/10/2022, 15:06:16
#
#
# Movendo arquivos do diretório temporário para o diretório permanente. do CNPq.
# Foram movidos 99 arquivos.
# Importação iniciada em 03/10/2022, 18:33:12
# 0.1% importados.
#
# Linhas por segundo lidas (total): 1.7
# 1,400 de 1,990,959
# 0 erros.
#
# Acabará em:
#     Cálculo considerando desde o início: 17/10/2022, 15:06:47
#
#
# Movendo arquivos do diretório temporário para o diretório permanente. do CNPq.
# Foram movidos 96 arquivos.
# Importação iniciada em 03/10/2022, 18:33:12
# 0.1% importados.
#
# Linhas por segundo lidas (total): 1.7
# 1,500 de 1,990,959
# 0 erros.
#
# Acabará em:
#     Cálculo considerando desde o início: 17/10/2022, 15
arquivos.
# Importação iniciada em 03/10/2022, 18:33:12
# 21.5% importados.
#
# Linhas por segundo lidas (total): 8.9
# 428,800 de 1,990,959
# 0 erros.
#
# Acabará em:
#     Cálculo considerando desde o início: 05/10/2022, 19:04:28
#
#
# Movendo arquivos do diretório temporário para o diretório permanente.
# Foram movidos 98 arquivos.
# Importação iniciada em 03/10/2022, 18:33:12
# 21.5% importados.
#
# Linhas por segundo lidas (total): 8.9
# 428,900 de 1,990,959
# 0 erros.
#
# Acabará em:
#     Cálculo considerando desde o início: 05/10/2022, 19:04:12
#
#
# Movendo arquivos do diretório temporário para o diretório permanente.
# Foram movidos 98 arquivos.
# Importação iniciada em 03/10/2022, 18:33:12
# 21.5% importados.
#
# Linhas por segundo lidas (total): 8.9
# 429,000 de 1,990,959
# 0 erros.
#
# Acabará em:
#     Cálculo considerando desde o início: 05/10/2022, 19:03:56
#
#
# Movendo arquivos do diretório temporário para o diretório permanente.
# Foram movidos 98 arquivos.
# Importação iniciada em 03/10/2022, 18:33:12
# 21.6% importados.
#
# Linhas por segundo lidas (total): 8.9
# 429,100 de 1,990,959
# 0 erros.
#
# Acabará em:
#     Cálculo considerando desde o início: 05/10/2022, 19:03:49
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13956/3178502605.py in <module>
# ----> 1 cg.load_carga(
#       2     pular_erros = False,
#       3     pular_indicadores = False,
#       4     pula_bd_lattes = False,
#       5     pula_hd = True,
#
# ~\CNPq\Lattes\Python\Carga.py in load_carga(self, carga, max, data_mínima_de_atualização, log_file, linhas_a_pular, tempo_a_esperar_em_horário_de_pico, insere_no_bd, num_imports_skip_before_log, show_import_messages, pular_erros, pular_indicadores, pula_bd_lattes, pula_hd, de_bd_demanda_bruta, de_bd_dados_pessoais, de_dados_pessoais, de_carga, começando_com)
#     832                 sys.stdout = open(os.devnull, "w")
#     833             lattes = Lattes(id = id, path = self.temp_path, auto_save_json_to_bd = False)
# --> 834             resposta = lattes.get_zip_from_SOAP()
#     835             # print(resposta, insere_no_bd, resposta == True and insere_no_bd == True)
#     836             if resposta == "Curriculo recuperado com sucesso!" and insere_no_bd == True:
#
# ~\CNPq\Lattes\Python\Lattes.py in get_zip_from_SOAP(self, id, set_auto_save, num_errors, path)
#      92             try:
#      93                 client = zeep.Client(wsdl=self.wsdl)
# ---> 94                 self.zip = client.service.getCurriculoCompactado(self.id)
#      95                 self.ocorrencia = client.service.getOcorrenciaCV(self.id)
#      96             except Exception as e:
#
# ~\Anaconda3\lib\site-packages\zeep\proxy.py in __call__(self, *args, **kwargs)
#      44             kwargs["_soapheaders"] = soap_headers
#      45
# ---> 46         return self._proxy._binding.send(
#      47             self._proxy._client,
#      48             self._proxy._binding_options,
#
# ~\Anaconda3\lib\site-packages\zeep\wsdl\bindings\soap.py in send(self, client, options, operation, args, kwargs)
#     125         )
#     126
# --> 127         response = client.transport.post_xml(options["address"], envelope, http_headers)
#     128
#     129         operation_obj = self.get(operation)
#
# ~\Anaconda3\lib\site-packages\zeep\transports.py in post_xml(self, address, envelope, headers)
#     105         """
#     106         message = etree_to_string(envelope)
# --> 107         return self.post(address, message, headers)
#     108
#     109     def load(self, url):
#
# ~\Anaconda3\lib\site-packages\zeep\transports.py in post(self, address, message, headers)
#      71             self.logger.debug("HTTP Post to %s:\n%s", address, log_message)
#      72
# ---> 73         response = self.session.post(
#      74             address, data=message, headers=headers, timeout=self.operation_timeout
#      75         )
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in post(self, url, data, json, **kwargs)
#     588         """
#     589
# --> 590         return self.request('POST', url, data=data, json=json, **kwargs)
#     591
#     592     def put(self, url, data=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1369         try:
#    1370             try:
# -> 1371                 response.begin()
#    1372             except ConnectionError:
#    1373                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
cg.carrega_lista_arquivos_no_HD (niveis=False)

# %%
cg.temp_path
