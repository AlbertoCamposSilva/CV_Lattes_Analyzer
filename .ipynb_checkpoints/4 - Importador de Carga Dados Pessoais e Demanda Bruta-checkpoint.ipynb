# %%
from Car import Lattes
Lattes.load_carga(max=300)
# Out:
# 0.0% importados (2 de 7429495) - Acabará em 04/02/2022, 19:35:18 - Importando Lattes:  1798100711476813
# File already existis
# 0.0% importados (3 de 7429495) - Acabará em 04/02/2022, 19:35:29 - Importando Lattes:  6716436953396086
# File already existis
# 0.0% importados (4 de 7429495) - Acabará em 04/02/2022, 19:36:42 - Importando Lattes:  1421040516626871
# File already existis
# 0.0% importados (5 de 7429495) - Acabará em 04/02/2022, 19:35:34 - Importando Lattes:  5038629344297105
# File already existis
# 0.0% importados (6 de 7429495) - Acabará em 04/02/2022, 19:35:37 - Importando Lattes:  3617080115725376
# File already existis
# 0.0% importados (7 de 7429495) - Acabará em 04/02/2022, 19:35:41 - Importando Lattes:  1748742727289800
# File already existis
# 0.0% importados (8 de 7429495) - Acabará em 04/02/2022, 19:35:39 - Importando Lattes:  4386732679544282
# File already existis
# ...
