# %%
from Carga import Carga
cg = Carga()
cg.atualiza_todos_os_indicadores (on_conflic_update = True, 
                                  pula_bd_indicadores = True, 
                                  pula_erros = False, 
                                  data_mínima_atualização_lattes = '2020-01-01', 
                                  de_all_lattes = True, 
                                  começando_com=[6],
                                 )
# Out:
# Carregando lista de Ids da tabela indicadores para pular
#
# Carregando lista de indicadores para importar da tabela Lattes do BD
#
# Carregando lista de indicadores para importar da tabela demanda_bruta do BD
#
# Carregando lista de indicadores para importar da tabela carga_dados_pessoais do BD
#
# Retirando ids a exluir...
# Iniciando Importação.
# Tentando recuperar Lattes compactado 6630375904580369 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6630375904580369
# Importação iniciada em 13/03/2022, 17:33:271.
# 0.0% importados.
#
# Linhas por segundo lidas (total): 9.7
# 400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:59:31
#
#
# Importação iniciada em 13/03/2022, 17:33:277.
# 0.0% importados.
#
# Linhas por segundo lidas (total): 8.4
# 700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 16:26:15
#
#
# Importação iniciada em 13/03/2022, 17:33:272.
# 0.1% importados.
#
# Linhas por segundo lidas (total): 9.1
# 800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 12:47:55
#
#
# Tentando recuperar Lattes compactado 6029484009354338 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6029484009354338
# Importação iniciada em 13/03/2022, 17:33:2773.
# 0.2% importados.
#
# Linhas por segundo lidas (total): 10.0
# 2,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:56:32
#
#
# Importação iniciada em 13/03/2022, 17:33:2715.
# 0.2% importados.
#
# Linhas por segundo lidas (total): 9.9
# 2,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:12:21
#
#
# Importação iniciada em 13/03/2022, 17:33:2767.
# 0.2% importados.
#
# Linhas por segundo lidas (total): 10.0
# 2,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:51:51
#
#
# Importação iniciada em 13/03/2022, 17:33:2777.
# 0.2% importados.
#
# Linhas por segundo lidas (total): 10.1
# 3,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:29:26
#
#
# Importação iniciada em 13/03/2022, 17:33:2740.
# 0.3% importados.
#
# Linhas por segundo lidas (total): 9.7
# 4,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:05:03
#
#
# Importação iniciada em 13/03/2022, 17:33:2788.
# 0.4% importados.
#
# Linhas por segundo lidas (total): 9.9
# 5,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:15:14
#
#
# Importação iniciada em 13/03/2022, 17:33:2789.
# 0.4% importados.
#
# Linhas por segundo lidas (total): 9.7
# 6,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:00:37
#
#
# Importação iniciada em 13/03/2022, 17:33:2725.
# 0.4% importados.
#
# Linhas por segundo lidas (total): 9.7
# 6,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:53:15
#
#
# Importação iniciada em 13/03/2022, 17:33:2747.
# 0.5% importados.
#
# Linhas por segundo lidas (total): 9.7
# 6,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:00:06
#
#
# Importação iniciada em 13/03/2022, 17:33:2762.
# 0.5% importados.
#
# Linhas por segundo lidas (total): 9.7
# 6,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:41:40
#
#
# Importação iniciada em 13/03/2022, 17:33:2787.
# 0.5% importados.
#
# Linhas por segundo lidas (total): 9.7
# 7,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:39:25
#
#
# Importação iniciada em 13/03/2022, 17:33:2760.
# 0.5% importados.
#
# Linhas por segundo lidas (total): 9.7
# 7,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:42:06
#
#
# Importação iniciada em 13/03/2022, 17:33:2777.
# 0.5% importados.
#
# Linhas por segundo lidas (total): 9.7
# 7,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:49:07
#
#
# Importação iniciada em 13/03/2022, 17:33:2734.
# 0.6% importados.
#
# Linhas por segundo lidas (total): 9.7
# 7,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:57:46
#
#
# Importação iniciada em 13/03/2022, 17:33:2769.
# 0.6% importados.
#
# Linhas por segundo lidas (total): 9.6
# 8,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:21:05
#
#
# Importação iniciada em 13/03/2022, 17:33:2787.
# 0.6% importados.
#
# Linhas por segundo lidas (total): 9.6
# 8,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:17:34
#
#
# Importação iniciada em 13/03/2022, 17:33:2712.
# 0.7% importados.
#
# Linhas por segundo lidas (total): 9.7
# 9,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:41:02
#
#
# Importação iniciada em 13/03/2022, 17:33:27758.
# 0.7% importados.
#
# Linhas por segundo lidas (total): 9.7
# 10,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:50:40
#
#
# Importação iniciada em 13/03/2022, 17:33:27843.
# 0.8% importados.
#
# Linhas por segundo lidas (total): 9.6
# 11,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:13:12
#
#
# Importação iniciada em 13/03/2022, 17:33:27327.
# 0.8% importados.
#
# Linhas por segundo lidas (total): 9.6
# 11,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:19:31
#
#
# Importação iniciada em 13/03/2022, 17:33:27868.
# 0.8% importados.
#
# Linhas por segundo lidas (total): 9.6
# 11,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:19:31
#
#
# Tentando recuperar Lattes compactado 6340671145987715 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Importação iniciada em 13/03/2022, 17:33:27708.
# 0.9% importados.
#
# Linhas por segundo lidas (total): 9.6
# 12,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:08:18
#
#
# Importação iniciada em 13/03/2022, 17:33:27716.
# 0.9% importados.
#
# Linhas por segundo lidas (total): 9.6
# 12,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:13:03
#
#
# Importação iniciada em 13/03/2022, 17:33:27563.
# 0.9% importados.
#
# Linhas por segundo lidas (total): 9.6
# 12,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:05:28
#
#
# Tentando recuperar Lattes compactado 6922029225434488 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6922029225434488
# Importação iniciada em 13/03/2022, 17:33:27086.
# 1.1% importados.
#
# Linhas por segundo lidas (total): 9.7
# 15,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:23:28
#
#
# Tentando recuperar Lattes compactado 6734882032818394 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6734882032818394
# Tentando recuperar Lattes compactado 6501432814014618 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6501432814014618
# Importação iniciada em 13/03/2022, 17:33:27122.
# 1.3% importados.
#
# Linhas por segundo lidas (total): 9.8
# 18,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:17:12
#
#
# Importação iniciada em 13/03/2022, 17:33:27278.
# 1.4% importados.
#
# Linhas por segundo lidas (total): 9.7
# 19,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:21:01
#
#
# Importação iniciada em 13/03/2022, 17:33:27794.
# 1.4% importados.
#
# Linhas por segundo lidas (total): 9.7
# 20,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:17:54
#
#
# Importação iniciada em 13/03/2022, 17:33:27669.
# 1.5% importados.
#
# Linhas por segundo lidas (total): 9.8
# 21,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:59:36
#
#
# Tentando recuperar Lattes compactado 6050107448075588 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6050107448075588
# Tentando recuperar Lattes compactado 6495271624864309 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Importação iniciada em 13/03/2022, 17:33:27285.
# 1.6% importados.
#
# Linhas por segundo lidas (total): 9.9
# 23,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:42:26
#
#
# Importação iniciada em 13/03/2022, 17:33:27865.
# 1.7% importados.
#
# Linhas por segundo lidas (total): 9.9
# 23,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:29:29
# Tentando recuperar Lattes compactado 6437574596920803 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6437574596920803
# Importação iniciada em 13/03/2022, 17:33:27001.
# 1.8% importados.
#
# Linhas por segundo lidas (total): 10.1
# 25,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:50:58
#
#
# Importação iniciada em 13/03/2022, 17:33:27924.
# 1.9% importados.
#
# Linhas por segundo lidas (total): 10.1
# 26,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:40:57
#
#
# Importação iniciada em 13/03/2022, 17:33:27742.
# 2.1% importados.
#
# Linhas por segundo lidas (total): 10.2
# 29,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:26:33
#
#
# Importação iniciada em 13/03/2022, 17:33:27147.
# 2.1% importados.
#
# Linhas por segundo lidas (total): 10.2
# 29,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:10:22
#
#
# Importação iniciada em 13/03/2022, 17:33:27514.
# 2.2% importados.
#
# Linhas por segundo lidas (total): 10.3
# 30,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:57:42
#
#
# Importação iniciada em 13/03/2022, 17:33:27909.
# 2.2% importados.
#
# Linhas por segundo lidas (total): 10.3
# 31,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:56:59
#
#
# Tentando recuperar Lattes compactado 6567352496620616 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6567352496620616
# Importação iniciada em 13/03/2022, 17:33:27157.
# 2.3% importados.
#
# Linhas por segundo lidas (total): 10.3
# 33,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:39:09
#
#
# Importação iniciada em 13/03/2022, 17:33:27765.
# 2.5% importados.
#
# Linhas por segundo lidas (total): 10.3
# 35,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:43:02
#
#
# Importação iniciada em 13/03/2022, 17:33:27517.
# 2.7% importados.
#
# Linhas por segundo lidas (total): 10.3
# 37,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:50:38
#
#
# Importação iniciada em 13/03/2022, 17:33:27769.
# 2.7% importados.
#
# Linhas por segundo lidas (total): 10.2
# 38,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:52:17
#
#
# Importação iniciada em 13/03/2022, 17:33:27138.
# 2.7% importados.
#
# Linhas por segundo lidas (total): 10.2
# 38,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:50:20
#
#
# Importação iniciada em 13/03/2022, 17:33:27422.
# 2.8% importados.
#
# Linhas por segundo lidas (total): 10.2
# 39,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:50:34
#
#
# Importação iniciada em 13/03/2022, 17:33:27380.
# 2.8% importados.
#
# Linhas por segundo lidas (total): 10.2
# 39,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:48:28
#
#
# Tentando recuperar Lattes compactado 6972274666189236 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6972274666189236
# Importação iniciada em 13/03/2022, 17:33:27474.
# 2.9% importados.
#
# Linhas por segundo lidas (total): 10.2
# 40,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:50:16
#
#
# Importação iniciada em 13/03/2022, 17:33:27383.
# 3.1% importados.
#
# Linhas por segundo lidas (total): 10.2
# 43,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:47:06
#
#
# Importação iniciada em 13/03/2022, 17:33:27918.
# 3.1% importados.
#
# Linhas por segundo lidas (total): 10.2
# 44,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:54:11
#
#
# Importação iniciada em 13/03/2022, 17:33:27542.
# 3.2% importados.
#
# Linhas por segundo lidas (total): 10.1
# 45,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:13:49
#
#
# Importação iniciada em 13/03/2022, 17:33:27013.
# 3.2% importados.
#
# Linhas por segundo lidas (total): 10.1
# 45,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:18:30
#
#
# Importação iniciada em 13/03/2022, 17:33:27570.
# 3.2% importados.
#
# Linhas por segundo lidas (total): 10.0
# 45,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:23:55
#
#
# Importação iniciada em 13/03/2022, 17:33:27718.
# 3.2% importados.
#
# Linhas por segundo lidas (total): 10.0
# 45,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:24:03
#
#
# Importação iniciada em 13/03/2022, 17:33:27976.
# 3.3% importados.
#
# Linhas por segundo lidas (total): 10.1
# 46,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:17:44
#
#
# Importação iniciada em 13/03/2022, 17:33:27289.
# 3.3% importados.
#
# Linhas por segundo lidas (total): 10.1
# 46,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:17:30
#
#
# Importação iniciada em 13/03/2022, 17:33:27795.
# 3.4% importados.
#
# Linhas por segundo lidas (total): 10.1
# 47,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:08:56
#
#
# Importação iniciada em 13/03/2022, 17:33:27918.
# 3.4% importados.
#
# Linhas por segundo lidas (total): 10.1
# 47,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:09:43
#
#
# Importação iniciada em 13/03/2022, 17:33:27017.
# 3.5% importados.
#
# Linhas por segundo lidas (total): 10.1
# 48,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:03:15
#
#
# Importação iniciada em 13/03/2022, 17:33:27664.
# 3.5% importados.
#
# Linhas por segundo lidas (total): 10.1
# 49,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:05:19
#
#
# Tentando recuperar Lattes compactado 6319731383064095 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6319731383064095
# Importação iniciada em 13/03/2022, 17:33:27456.
# 3.5% importados.
#
# Linhas por segundo lidas (total): 10.1
# 50,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:55:29
#
#
# Importação iniciada em 13/03/2022, 17:33:27792.
# 3.6% importados.
#
# Linhas por segundo lidas (total): 10.2
# 50,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:50:37
#
#
# Importação iniciada em 13/03/2022, 17:33:27929.
# 3.6% importados.
#
# Linhas por segundo lidas (total): 10.2
# 50,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:50:25
#
#
# Importação iniciada em 13/03/2022, 17:33:27487.
# 3.6% importados.
#
# Linhas por segundo lidas (total): 10.1
# 51,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:54:52
#
#
# Importação iniciada em 13/03/2022, 17:33:27212.
# 3.7% importados.
#
# Linhas por segundo lidas (total): 10.2
# 51,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:43:45
#
#
# Importação iniciada em 13/03/2022, 17:33:27332.
# 3.8% importados.
#
# Linhas por segundo lidas (total): 10.2
# 54,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:31:07
#
#
# Importação iniciada em 13/03/2022, 17:33:27559.
# 3.9% importados.
#
# Linhas por segundo lidas (total): 10.2
# 54,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:31:29
#
#
# Tentando recuperar Lattes compactado 6314404881915699 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6314404881915699
# Importação iniciada em 13/03/2022, 17:33:27054.
# 3.9% importados.
#
# Linhas por segundo lidas (total): 10.2
# 55,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:25:55
#
#
# Importação iniciada em 13/03/2022, 17:33:27161.
# 4.0% importados.
#
# Linhas por segundo lidas (total): 10.2
# 56,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:28:08
#
#
# Tentando recuperar Lattes compactado 6140063764053360 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6140063764053360
# Importação iniciada em 13/03/2022, 17:33:27351.
# 4.1% importados.
#
# Linhas por segundo lidas (total): 10.2
# 57,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:22:02
# Tentando recuperar Lattes compactado 6704434991951149 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6704434991951149
# Importação iniciada em 13/03/2022, 17:33:27293.
# 4.3% importados.
#
# Linhas por segundo lidas (total): 10.3
# 60,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:00:24
#
#
# Importação iniciada em 13/03/2022, 17:33:27944.
# 4.3% importados.
#
# Linhas por segundo lidas (total): 10.4
# 61,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:50:44
#
#
# Importação iniciada em 13/03/2022, 17:33:27347.
# 4.4% importados.
#
# Linhas por segundo lidas (total): 10.3
# 61,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:51:21
#
#
# Importação iniciada em 13/03/2022, 17:33:27882.
# 4.4% importados.
#
# Linhas por segundo lidas (total): 10.4
# 62,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:46:27
#
#
# Importação iniciada em 13/03/2022, 17:33:27609.
# 4.4% importados.
#
# Linhas por segundo lidas (total): 10.3
# 62,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:49:27
#
#
# Importação iniciada em 13/03/2022, 17:33:27909.
# 4.4% importados.
#
# Linhas por segundo lidas (total): 10.3
# 62,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:49:21
#
#
# Importação iniciada em 13/03/2022, 17:33:27296.
# 4.5% importados.
#
# Linhas por segundo lidas (total): 10.4
# 64,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:44:55
#
#
# Importação iniciada em 13/03/2022, 17:33:27535.
# 4.6% importados.
#
# Linhas por segundo lidas (total): 10.4
# 65,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:42:25
#
#
# Tentando recuperar Lattes compactado 6930043629400459 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6930043629400459
# Importação iniciada em 13/03/2022, 17:33:27026.
# 4.6% importados.
#
# Linhas por segundo lidas (total): 10.4
# 65,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:43:35
#
#
# Importação iniciada em 13/03/2022, 17:33:27173.
# 4.8% importados.
#
# Linhas por segundo lidas (total): 10.3
# 67,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:45:19
#
#
# Importação iniciada em 13/03/2022, 17:33:27180.
# 4.8% importados.
#
# Linhas por segundo lidas (total): 10.3
# 67,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:44:53
#
#
# Importação iniciada em 13/03/2022, 17:33:27056.
# 4.8% importados.
#
# Linhas por segundo lidas (total): 10.3
# 68,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:43:27
#
#
# Importação iniciada em 13/03/2022, 17:33:27055.
# 4.9% importados.
#
# Linhas por segundo lidas (total): 10.3
# 68,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:44:59
#
#
# Importação iniciada em 13/03/2022, 17:33:27333.
# 4.9% importados.
#
# Linhas por segundo lidas (total): 10.3
# 69,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:44:48
#
#
# Importação iniciada em 13/03/2022, 17:33:27859.
# 5.0% importados.
#
# Linhas por segundo lidas (total): 10.3
# 70,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:43:00
#
#
# Importação iniciada em 13/03/2022, 17:33:27736.
# 5.0% importados.
#
# Linhas por segundo lidas (total): 10.3
# 70,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:38:18
#
#
# Importação iniciada em 13/03/2022, 17:33:27506.
# 5.0% importados.
#
# Linhas por segundo lidas (total): 10.3
# 71,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:35:27
#
#
# Importação iniciada em 13/03/2022, 17:33:27524.
# 5.1% importados.
#
# Linhas por segundo lidas (total): 10.3
# 71,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:38:45
#
#
# Importação iniciada em 13/03/2022, 17:33:27209.
# 5.2% importados.
#
# Linhas por segundo lidas (total): 10.3
# 72,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:37:58
#
#
# Importação iniciada em 13/03/2022, 17:33:27585.
# 5.2% importados.
#
# Linhas por segundo lidas (total): 10.3
# 74,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:40:31
#
#
# Importação iniciada em 13/03/2022, 17:33:27339.
# 5.5% importados.
#
# Linhas por segundo lidas (total): 10.3
# 77,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:29:49
#
#
# Importação iniciada em 13/03/2022, 17:33:27290.
# 5.5% importados.
#
# Linhas por segundo lidas (total): 10.3
# 77,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:31:03
#
#
# Importação iniciada em 13/03/2022, 17:33:27900.
# 5.5% importados.
#
# Linhas por segundo lidas (total): 10.3
# 78,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:28:09
#
#
# Importação iniciada em 13/03/2022, 17:33:27313.
# 5.6% importados.
#
# Linhas por segundo lidas (total): 10.3
# 78,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:30:09
#
#
# Importação iniciada em 13/03/2022, 17:33:27351.
# 5.6% importados.
#
# Linhas por segundo lidas (total): 10.3
# 79,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:31:32
#
#
# Importação iniciada em 13/03/2022, 17:33:27966.
# 5.6% importados.
#
# Linhas por segundo lidas (total): 10.3
# 79,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:29:52
#
#
# Importação iniciada em 13/03/2022, 17:33:27829.
# 5.7% importados.
#
# Linhas por segundo lidas (total): 10.3
# 80,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:27:26
#
#
# Tentando recuperar Lattes compactado 6344465535055889 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6344465535055889
# Importação iniciada em 13/03/2022, 17:33:27688.
# 5.7% importados.
#
# Linhas por segundo lidas (total): 10.3
# 80,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:27:26
#
#
# Importação iniciada em 13/03/2022, 17:33:27345.
# 5.7% importados.
#
# Linhas por segundo lidas (total): 10.3
# 81,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:25:25
#
#
# Importação iniciada em 13/03/2022, 17:33:27524.
# 5.9% importados.
#
# Linhas por segundo lidas (total): 10.3
# 83,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:20:11
#
#
# Importação iniciada em 13/03/2022, 17:33:27841.
# 5.9% importados.
#
# Linhas por segundo lidas (total): 10.3
# 84,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:16:21
#
#
# Importação iniciada em 13/03/2022, 17:33:27702.
# 6.1% importados.
#
# Linhas por segundo lidas (total): 10.4
# 85,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:10:54
#
#
# Tentando recuperar Lattes compactado 6658552344675640 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6658552344675640
# Tentando recuperar Lattes compactado 6016973292621471 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6016973292621471
# Importação iniciada em 13/03/2022, 17:33:27405.
# 6.4% importados.
#
# Linhas por segundo lidas (total): 10.4
# 89,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:58:25
#
#
# Importação iniciada em 13/03/2022, 17:33:27684.
# 6.4% importados.
#
# Linhas por segundo lidas (total): 10.4
# 91,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:55:06
#
#
# Tentando recuperar Lattes compactado 6690768218848379 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6690768218848379
# Importação iniciada em 13/03/2022, 17:33:27245.
# 6.7% importados.
#
# Linhas por segundo lidas (total): 10.4
# 94,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:43:38
#
#
# Tentando recuperar Lattes compactado 6967493852817120 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6967493852817120
# Importação iniciada em 13/03/2022, 17:33:27298.
# 6.9% importados.
#
# Linhas por segundo lidas (total): 10.4
# 97,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:45:19
#
#
# Importação iniciada em 13/03/2022, 17:33:27188.
# 6.9% importados.
#
# Linhas por segundo lidas (total): 10.4
# 97,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:46:23
#
#
# Importação iniciada em 13/03/2022, 17:33:27435.
# 7.0% importados.
#
# Linhas por segundo lidas (total): 10.4
# 98,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:44:37
#
#
# Importação iniciada em 13/03/2022, 17:33:27654.
# 7.0% importados.
#
# Linhas por segundo lidas (total): 10.4
# 98,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:42:59
#
#
# Importação iniciada em 13/03/2022, 17:33:27071.
# 7.0% importados.
#
# Linhas por segundo lidas (total): 10.4
# 99,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:42:10
#
#
# Tentando recuperar Lattes compactado 6897724436575931 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6897724436575931
# Importação iniciada em 13/03/2022, 17:33:272348.
# 7.2% importados.
#
# Linhas por segundo lidas (total): 10.4
# 101,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:32:10
#
#
# Importação iniciada em 13/03/2022, 17:33:277758.
# 7.2% importados.
#
# Linhas por segundo lidas (total): 10.4
# 101,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:33:06
#
#
# Importação iniciada em 13/03/2022, 17:33:279832.
# 7.2% importados.
#
# Linhas por segundo lidas (total): 10.4
# 102,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:33:21
#
#
# Tentando recuperar Lattes compactado 6137236901641805 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6137236901641805
# Importação iniciada em 13/03/2022, 17:33:278162.
# 7.3% importados.
#
# Linhas por segundo lidas (total): 10.4
# 103,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:28:25
#
#
# Importação iniciada em 13/03/2022, 17:33:275732.
# 7.3% importados.
#
# Linhas por segundo lidas (total): 10.4
# 103,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:26:12
#
#
# Importação iniciada em 13/03/2022, 17:33:270873.
# 7.4% importados.
#
# Linhas por segundo lidas (total): 10.4
# 105,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:25:34
#
#
# Importação iniciada em 13/03/2022, 17:33:271279.
# 7.5% importados.
#
# Linhas por segundo lidas (total): 10.4
# 105,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:28:18
#
#
# Importação iniciada em 13/03/2022, 17:33:279770.
# 7.6% importados.
#
# Linhas por segundo lidas (total): 10.4
# 107,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:24:04
#
#
# Importação iniciada em 13/03/2022, 17:33:272737.
# 7.7% importados.
#
# Linhas por segundo lidas (total): 10.4
# 108,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:24:39
#
#
# Importação iniciada em 13/03/2022, 17:33:277318.
# 7.7% importados.
#
# Linhas por segundo lidas (total): 10.4
# 108,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:24:23
#
#
# Importação iniciada em 13/03/2022, 17:33:275764.
# 7.7% importados.
#
# Linhas por segundo lidas (total): 10.4
# 108,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:26:39
#
#
# Tentando recuperar Lattes compactado 6896231481383882 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6896231481383882
# Importação iniciada em 13/03/2022, 17:33:278945.
# 7.8% importados.
#
# Linhas por segundo lidas (total): 10.4
# 110,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:30:08
#
#
# Importação iniciada em 13/03/2022, 17:33:275128.
# 7.8% importados.
#
# Linhas por segundo lidas (total): 10.4
# 110,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:30:44
#
#
# Importação iniciada em 13/03/2022, 17:33:275796.
# 7.9% importados.
#
# Linhas por segundo lidas (total): 10.4
# 111,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:28:56
#
#
# Importação iniciada em 13/03/2022, 17:33:278068.
# 7.9% importados.
#
# Linhas por segundo lidas (total): 10.4
# 111,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:25:19
#
#
# Importação iniciada em 13/03/2022, 17:33:272230.
# 8.0% importados.
#
# Linhas por segundo lidas (total): 10.4
# 112,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:22:26
#
#
# Importação iniciada em 13/03/2022, 17:33:271077.
# 8.0% importados.
#
# Linhas por segundo lidas (total): 10.4
# 112,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:21:09
#
#
# Importação iniciada em 13/03/2022, 17:33:277127.
# 8.2% importados.
#
# Linhas por segundo lidas (total): 10.4
# 115,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:11:03
#
#
# Importação iniciada em 13/03/2022, 17:33:271531.
# 8.2% importados.
#
# Linhas por segundo lidas (total): 10.4
# 116,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:09:22
#
#
# Importação iniciada em 13/03/2022, 17:33:277387.
# 8.4% importados.
#
# Linhas por segundo lidas (total): 10.5
# 118,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:58:45
#
#
# Importação iniciada em 13/03/2022, 17:33:279219.
# 8.4% importados.
#
# Linhas por segundo lidas (total): 10.5
# 118,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:58:03
#
#
# Importação iniciada em 13/03/2022, 17:33:272073.
# 8.4% importados.
#
# Linhas por segundo lidas (total): 10.4
# 119,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:58:33
#
#
# Tentando recuperar Lattes compactado 6371892176734660 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6371892176734660
# Importação iniciada em 13/03/2022, 17:33:274620.
# 8.5% importados.
#
# Linhas por segundo lidas (total): 10.5
# 120,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:54:04
#
#
# Importação iniciada em 13/03/2022, 17:33:277982.
# 8.6% importados.
#
# Linhas por segundo lidas (total): 10.5
# 121,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:52:30
#
#
# Importação iniciada em 13/03/2022, 17:33:272051.
# 8.6% importados.
#
# Linhas por segundo lidas (total): 10.5
# 121,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:52:23
#
#
# Importação iniciada em 13/03/2022, 17:33:273673.
# 8.7% importados.
#
# Linhas por segundo lidas (total): 10.5
# 122,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:45:45
#
#
# Tentando recuperar Lattes compactado 6144884373474638 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6144884373474638
# Importação iniciada em 13/03/2022, 17:33:271300.
# 8.8% importados.
#
# Linhas por segundo lidas (total): 10.5
# 124,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:45:21
#
#
# Importação iniciada em 13/03/2022, 17:33:277907.
# 8.9% importados.
#
# Linhas por segundo lidas (total): 10.5
# 125,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:44:03
#
#
# Tentando recuperar Lattes compactado 6958924449731847 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6958924449731847
# Importação iniciada em 13/03/2022, 17:33:277727.
# 9.0% importados.
#
# Linhas por segundo lidas (total): 10.5
# 127,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:41:01
#
#
# Tentando recuperar Lattes compactado 6472776036063047 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6472776036063047
# Importação iniciada em 13/03/2022, 17:33:275104.
# 9.1% importados.
#
# Linhas por segundo lidas (total): 10.5
# 128,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:40:03
# Importação iniciada em 13/03/2022, 17:33:275521.
# 9.3% importados.
#
# Linhas por segundo lidas (total): 10.5
# 130,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:37:49
#
#
# Tentando recuperar Lattes compactado 6694647047879401 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6694647047879401
# Importação iniciada em 13/03/2022, 17:33:270201.
# 9.4% importados.
#
# Linhas por segundo lidas (total): 10.5
# 132,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:32:04
#
#
# Importação iniciada em 13/03/2022, 17:33:273568.
# 9.4% importados.
#
# Linhas por segundo lidas (total): 10.5
# 133,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:31:32
#
#
# Importação iniciada em 13/03/2022, 17:33:274604.
# 9.5% importados.
#
# Linhas por segundo lidas (total): 10.5
# 133,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:31:07
#
#
# Importação iniciada em 13/03/2022, 17:33:276825.
# 9.5% importados.
#
# Linhas por segundo lidas (total): 10.5
# 133,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:30:13
#
#
# Tentando recuperar Lattes compactado 6579032276810875 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6579032276810875
# Importação iniciada em 13/03/2022, 17:33:270915.
# 9.6% importados.
#
# Linhas por segundo lidas (total): 10.5
# 136,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:26:15
#
#
# Importação iniciada em 13/03/2022, 17:33:279292.
# 9.6% importados.
#
# Linhas por segundo lidas (total): 10.5
# 136,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:25:51
#
#
# Importação iniciada em 13/03/2022, 17:33:275290.
# 9.9% importados.
#
# Linhas por segundo lidas (total): 10.5
# 140,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:13:34
#
#
# Importação iniciada em 13/03/2022, 17:33:277214.
# 10.0% importados.
#
# Linhas por segundo lidas (total): 10.5
# 141,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:09:22
#
#
# Tentando recuperar Lattes compactado 6501165117736306 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6501165117736306
# Importação iniciada em 13/03/2022, 17:33:279312.
# 10.0% importados.
#
# Linhas por segundo lidas (total): 10.5
# 141,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:09:32
#
#
# Importação iniciada em 13/03/2022, 17:33:277413.
# 10.0% importados.
#
# Linhas por segundo lidas (total): 10.5
# 141,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:08:39
#
#
# Tentando recuperar Lattes compactado 6587744961636774 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6587744961636774
# Importação iniciada em 13/03/2022, 17:33:278803.
# 10.2% importados.
#
# Linhas por segundo lidas (total): 10.5
# 144,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:59:05
#
#
# Importação iniciada em 13/03/2022, 17:33:278847.
# 10.3% importados.
#
# Linhas por segundo lidas (total): 10.5
# 145,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:59:20
#
#
# Importação iniciada em 13/03/2022, 17:33:274061.
# 10.3% importados.
#
# Linhas por segundo lidas (total): 10.5
# 145,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:59:22
#
#
# Importação iniciada em 13/03/2022, 17:33:271554.
# 10.4% importados.
#
# Linhas por segundo lidas (total): 10.5
# 146,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:58:36
#
#
# Importação iniciada em 13/03/2022, 17:33:272349.
# 10.5% importados.
#
# Linhas por segundo lidas (total): 10.5
# 147,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:55:38
#
#
# Tentando recuperar Lattes compactado 6076176969893498 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6076176969893498
# Tentando recuperar Lattes compactado 6201549807977089 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6201549807977089
# Importação iniciada em 13/03/2022, 17:33:274233.
# 10.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 149,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:49:46
#
#
# Tentando recuperar Lattes compactado 6104254652461901 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6104254652461901
# Tentando recuperar Lattes compactado 6108257909900860 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6108257909900860
# Importação iniciada em 13/03/2022, 17:33:271294.
# 10.8% importados.
#
# Linhas por segundo lidas (total): 10.6
# 152,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:40:45
#
#
# Importação iniciada em 13/03/2022, 17:33:277173.
# 10.8% importados.
#
# Linhas por segundo lidas (total): 10.6
# 152,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:39:47
#
#
# Tentando recuperar Lattes compactado 6619705979252507 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6619705979252507
# Tentando recuperar Lattes compactado 6781056461173913 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6781056461173913
# Tentando recuperar Lattes compactado 6831170493512800 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6831170493512800
# Tentando recuperar Lattes compactado 6296090894516999 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6296090894516999
# Importação iniciada em 13/03/2022, 17:33:270543.
# 11.1% importados.
#
# Linhas por segundo lidas (total): 10.6
# 157,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:26:23
#
#
# Importação iniciada em 13/03/2022, 17:33:275210.
# 11.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 158,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:24:01
#
#
# Importação iniciada em 13/03/2022, 17:33:270830.
# 11.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 158,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:21:54
#
#
# Importação iniciada em 13/03/2022, 17:33:271621.
# 11.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 160,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:16:35
#
#
# Importação iniciada em 13/03/2022, 17:33:272912.
# 11.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 161,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:15:38
#
#
# Importação iniciada em 13/03/2022, 17:33:270974.
# 11.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 161,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:15:05
#
#
# Importação iniciada em 13/03/2022, 17:33:270015.
# 11.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 163,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:10:41
#
#
# Importação iniciada em 13/03/2022, 17:33:271925.
# 11.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 163,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:09:38
#
#
# Tentando recuperar Lattes compactado 6398934365953616 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Importação iniciada em 13/03/2022, 17:33:274886.
# 11.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 164,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:10:11
#
#
# Importação iniciada em 13/03/2022, 17:33:276223.
# 11.8% importados.
#
# Linhas por segundo lidas (total): 10.7
# 166,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:05:28
#
#
# Importação iniciada em 13/03/2022, 17:33:273705.
# 11.9% importados.
#
# Linhas por segundo lidas (total): 10.7
# 168,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:00:10
# Importação iniciada em 13/03/2022, 17:33:276559.
# 12.0% importados.
#
# Linhas por segundo lidas (total): 10.7
# 169,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:56:49
#
#
# Importação iniciada em 13/03/2022, 17:33:279058.
# 12.0% importados.
#
# Linhas por segundo lidas (total): 10.7
# 169,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:57:29
#
#
# Importação iniciada em 13/03/2022, 17:33:276097.
# 12.1% importados.
#
# Linhas por segundo lidas (total): 10.7
# 171,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:50:50
#
#
# Tentando recuperar Lattes compactado 6572997971917311 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6572997971917311
# Importação iniciada em 13/03/2022, 17:33:275089.
# 12.3% importados.
#
# Linhas por segundo lidas (total): 10.7
# 174,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:43:14
#
#
# Importação iniciada em 13/03/2022, 17:33:275624.
# 12.4% importados.
#
# Linhas por segundo lidas (total): 10.7
# 175,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:39:13
#
#
# Tentando recuperar Lattes compactado 6490820114351512 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6490820114351512
# Importação iniciada em 13/03/2022, 17:33:270057.
# 12.5% importados.
#
# Linhas por segundo lidas (total): 10.7
# 177,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:34:29
#
#
# Importação iniciada em 13/03/2022, 17:33:279732.
# 12.6% importados.
#
# Linhas por segundo lidas (total): 10.7
# 177,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:33:52
#
#
# Importação iniciada em 13/03/2022, 17:33:271362.
# 12.6% importados.
#
# Linhas por segundo lidas (total): 10.7
# 177,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:34:21
#
#
# Importação iniciada em 13/03/2022, 17:33:273578.
# 12.6% importados.
#
# Linhas por segundo lidas (total): 10.7
# 178,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:33:27
#
#
# Importação iniciada em 13/03/2022, 17:33:277694.
# 12.6% importados.
#
# Linhas por segundo lidas (total): 10.7
# 178,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:33:46
#
#
# Importação iniciada em 13/03/2022, 17:33:272183.
# 12.9% importados.
#
# Linhas por segundo lidas (total): 10.7
# 181,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:29:05
#
#
# Tentando recuperar Lattes compactado 6760019681236117 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6760019681236117
# Importação iniciada em 13/03/2022, 17:33:276028.
# 13.3% importados.
#
# Linhas por segundo lidas (total): 10.7
# 187,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:15:21
#
#
# Importação iniciada em 13/03/2022, 17:33:277994.
# 13.3% importados.
#
# Linhas por segundo lidas (total): 10.7
# 187,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:15:37
#
#
# Tentando recuperar Lattes compactado 6790003584543589 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6790003584543589
# Importação iniciada em 13/03/2022, 17:33:272922.
# 13.3% importados.
#
# Linhas por segundo lidas (total): 10.7
# 187,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:15:07
#
#
# Importação iniciada em 13/03/2022, 17:33:271211.
# 13.3% importados.
#
# Linhas por segundo lidas (total): 10.7
# 188,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:15:07
#
#
# Importação iniciada em 13/03/2022, 17:33:272965.
# 13.5% importados.
#
# Linhas por segundo lidas (total): 10.7
# 190,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:10:36
#
#
# Importação iniciada em 13/03/2022, 17:33:278169.
# 13.5% importados.
#
# Linhas por segundo lidas (total): 10.7
# 191,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:09:17
#
#
# Importação iniciada em 13/03/2022, 17:33:274632.
# 13.7% importados.
#
# Linhas por segundo lidas (total): 10.8
# 193,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:01:58
#
#
# Importação iniciada em 13/03/2022, 17:33:271192.
# 13.7% importados.
#
# Linhas por segundo lidas (total): 10.8
# 194,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:00:47
#
#
# Importação iniciada em 13/03/2022, 17:33:273620.
# 13.7% importados.
#
# Linhas por segundo lidas (total): 10.8
# 194,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:00:44
#
#
# Tentando recuperar Lattes compactado 6963719508562485 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Importação iniciada em 13/03/2022, 17:33:277227.
# 13.8% importados.
#
# Linhas por segundo lidas (total): 10.8
# 194,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:00:59
#
#
# Importação iniciada em 13/03/2022, 17:33:276638.
# 13.9% importados.
#
# Linhas por segundo lidas (total): 10.8
# 196,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:55:56
#
#
# Tentando recuperar Lattes compactado 6535084620917866 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6535084620917866
# Importação iniciada em 13/03/2022, 17:33:277138.
# 14.0% importados.
#
# Linhas por segundo lidas (total): 10.8
# 198,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:51:09
#
#
# Importação iniciada em 13/03/2022, 17:33:273604.
# 14.0% importados.
#
# Linhas por segundo lidas (total): 10.8
# 198,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:51:22
#
#
# Importação iniciada em 13/03/2022, 17:33:278298.
# 14.2% importados.
#
# Linhas por segundo lidas (total): 10.8
# 200,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:47:15
#
#
# Importação iniciada em 13/03/2022, 17:33:276071.
# 14.4% importados.
#
# Linhas por segundo lidas (total): 10.8
# 202,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:40:59
#
#
# Importação iniciada em 13/03/2022, 17:33:274638.
# 14.4% importados.
#
# Linhas por segundo lidas (total): 10.8
# 203,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:40:27
#
#
# Importação iniciada em 13/03/2022, 17:33:274199.
# 14.4% importados.
#
# Linhas por segundo lidas (total): 10.8
# 203,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:38:31
#
#
# Importação iniciada em 13/03/2022, 17:33:272675.
# 14.5% importados.
#
# Linhas por segundo lidas (total): 10.8
# 204,800 de 1,413,665
# Acabará em:
# ...
#
#
# Importação iniciada em 13/03/2022, 17:33:278818.
# 44.4% importados.
#
# Linhas por segundo lidas (total): 11.0
# 627,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:26:30
#
#
# Importação iniciada em 13/03/2022, 17:33:274665.
# 44.5% importados.
#
# Linhas por segundo lidas (total): 11.0
# 629,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:27:22
#
#
# Importação iniciada em 13/03/2022, 17:33:270401.
# 44.5% importados.
#
# Linhas por segundo lidas (total): 11.0
# 629,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:27:00
#
#
# Importação iniciada em 13/03/2022, 17:33:272569.
# 44.5% importados.
#
# Linhas por segundo lidas (total): 10.9
# 629,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:27:21
#
#
# Importação iniciada em 13/03/2022, 17:33:279773.
# 44.7% importados.
#
# Linhas por segundo lidas (total): 10.9
# 631,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:28:00
#
#
# Importação iniciada em 13/03/2022, 17:33:276432.
# 44.7% importados.
#
# Linhas por segundo lidas (total): 10.9
# 631,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:28:08
#
#
# Importação iniciada em 13/03/2022, 17:33:275945.
# 45.0% importados.
#
# Linhas por segundo lidas (total): 10.9
# 635,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:26:08
#
#
# Tentando recuperar Lattes compactado 6100010694016363 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6100010694016363
# Importação iniciada em 13/03/2022, 17:33:278964.
# 45.1% importados.
#
# Linhas por segundo lidas (total): 10.9
# 637,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:25:41
#
#
# Importação iniciada em 13/03/2022, 17:33:278320.
# 45.1% importados.
#
# Linhas por segundo lidas (total): 10.9
# 637,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:25:24
#
#
# Importação iniciada em 13/03/2022, 17:33:271283.
# 45.2% importados.
#
# Linhas por segundo lidas (total): 10.8
# 638,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:23:53
#
#
# Importação iniciada em 13/03/2022, 17:33:271744.
# 45.3% importados.
#
# Linhas por segundo lidas (total): 10.8
# 640,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:21:44
#
#
# Importação iniciada em 13/03/2022, 17:33:277843.
# 45.3% importados.
#
# Linhas por segundo lidas (total): 10.8
# 640,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:20:56
#
#
# Importação iniciada em 13/03/2022, 17:33:274768.
# 45.3% importados.
#
# Linhas por segundo lidas (total): 10.8
# 641,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:20:42
#
#
# Tentando recuperar Lattes compactado 6004307421433560 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6004307421433560
# Importação iniciada em 13/03/2022, 17:33:270206.
# 45.5% importados.
#
# Linhas por segundo lidas (total): 10.8
# 643,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:17:16
#
#
# Importação iniciada em 13/03/2022, 17:33:277076.
# 45.6% importados.
#
# Linhas por segundo lidas (total): 10.8
# 644,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:17:07
#
#
# Importação iniciada em 13/03/2022, 17:33:278696.
# 45.6% importados.
#
# Linhas por segundo lidas (total): 10.8
# 644,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:16:51
#
#
# Importação iniciada em 13/03/2022, 17:33:276802.
# 45.6% importados.
#
# Linhas por segundo lidas (total): 10.8
# 644,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:16:19
#
#
# Importação iniciada em 13/03/2022, 17:33:276328.
# 45.7% importados.
#
# Linhas por segundo lidas (total): 10.8
# 645,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:15:14
#
#
# Importação iniciada em 13/03/2022, 17:33:274910.
# 45.7% importados.
#
# Linhas por segundo lidas (total): 10.8
# 645,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:15:23
#
#
# Importação iniciada em 13/03/2022, 17:33:273278.
# 45.8% importados.
#
# Linhas por segundo lidas (total): 10.8
# 647,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:13:46
#
#
# Tentando recuperar Lattes compactado 6529044789961062 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6529044789961062
# Importação iniciada em 13/03/2022, 17:33:270432.
# 46.0% importados.
#
# Linhas por segundo lidas (total): 10.8
# 649,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:10:11
#
#
# Importação iniciada em 13/03/2022, 17:33:271754.
# 46.0% importados.
#
# Linhas por segundo lidas (total): 10.8
# 650,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:09:48
#
#
# Importação iniciada em 13/03/2022, 17:33:277454.
# 46.0% importados.
#
# Linhas por segundo lidas (total): 10.8
# 650,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:09:00
# Importação iniciada em 13/03/2022, 17:33:278836.
# 46.1% importados.
#
# Linhas por segundo lidas (total): 10.8
# 651,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:08:06
#
#
# Importação iniciada em 13/03/2022, 17:33:270449.
# 46.1% importados.
#
# Linhas por segundo lidas (total): 10.8
# 651,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:07:50
#
#
# Importação iniciada em 13/03/2022, 17:33:278445.
# 46.1% importados.
#
# Linhas por segundo lidas (total): 10.8
# 652,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:07:29
#
#
# Importação iniciada em 13/03/2022, 17:33:275137.
# 46.2% importados.
#
# Linhas por segundo lidas (total): 10.8
# 652,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:06:40
#
#
# Tentando recuperar Lattes compactado 6624636053688856 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6624636053688856
# Tentando recuperar Lattes compactado 6667758239563438 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6667758239563438
# Importação iniciada em 13/03/2022, 17:33:277017.
# 46.3% importados.
#
# Linhas por segundo lidas (total): 10.8
# 654,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:06:12
#
#
# Importação iniciada em 13/03/2022, 17:33:271383.
# 46.3% importados.
#
# Linhas por segundo lidas (total): 10.8
# 654,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:05:58
#
#
# Importação iniciada em 13/03/2022, 17:33:272242.
# 46.4% importados.
#
# Linhas por segundo lidas (total): 10.8
# 655,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:05:56
#
#
# Importação iniciada em 13/03/2022, 17:33:271515.
# 46.4% importados.
#
# Linhas por segundo lidas (total): 10.8
# 655,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:05:39
#
#
# Importação iniciada em 13/03/2022, 17:33:277619.
# 46.4% importados.
#
# Linhas por segundo lidas (total): 10.8
# 656,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:05:24
#
#
# Importação iniciada em 13/03/2022, 17:33:274900.
# 46.4% importados.
#
# Linhas por segundo lidas (total): 10.8
# 656,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:04:44
#
#
# Tentando recuperar Lattes compactado 6463028672154866 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6463028672154866
# Importação iniciada em 13/03/2022, 17:33:278148.
# 46.5% importados.
#
# Linhas por segundo lidas (total): 10.8
# 657,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:04:30
#
#
# Importação iniciada em 13/03/2022, 17:33:273766.
# 46.6% importados.
#
# Linhas por segundo lidas (total): 10.8
# 658,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:04:10
#
#
# Importação iniciada em 13/03/2022, 17:33:276648.
# 46.7% importados.
#
# Linhas por segundo lidas (total): 10.7
# 659,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:04:44
#
#
# Importação iniciada em 13/03/2022, 17:33:274545.
# 46.7% importados.
#
# Linhas por segundo lidas (total): 10.7
# 660,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:05:48
#
#
# Importação iniciada em 13/03/2022, 17:33:275376.
# 46.9% importados.
#
# Linhas por segundo lidas (total): 10.7
# 662,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:07:18
#
#
# Importação iniciada em 13/03/2022, 17:33:276101.
# 46.9% importados.
#
# Linhas por segundo lidas (total): 10.7
# 663,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:07:27
#
#
# Importação iniciada em 13/03/2022, 17:33:270817.
# 46.9% importados.
#
# Linhas por segundo lidas (total): 10.7
# 663,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:07:29
#
#
# Importação iniciada em 13/03/2022, 17:33:270164.
# 46.9% importados.
#
# Linhas por segundo lidas (total): 10.7
# 663,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:07:27
#
#
# Tentando recuperar Lattes compactado 6544683048560388 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6544683048560388
# Importação iniciada em 13/03/2022, 17:33:277286.
# 47.0% importados.
#
# Linhas por segundo lidas (total): 10.6
# 664,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:07:07
#
#
# Importação iniciada em 13/03/2022, 17:33:273692.
# 47.0% importados.
#
# Linhas por segundo lidas (total): 10.6
# 664,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:07:28
#
#
# Importação iniciada em 13/03/2022, 17:33:279998.
# 47.0% importados.
#
# Linhas por segundo lidas (total): 10.6
# 664,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:07:29
#
#
# Tentando recuperar Lattes compactado 6070243075070641 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6070243075070641
# Importação iniciada em 13/03/2022, 17:33:278616.
# 47.1% importados.
#
# Linhas por segundo lidas (total): 10.6
# 665,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:07:22
#
#
# Importação iniciada em 13/03/2022, 17:33:275033.
# 47.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 667,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:07:27
#
#
# Importação iniciada em 13/03/2022, 17:33:279162.
# 47.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 668,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:06:50
#
#
# Importação iniciada em 13/03/2022, 17:33:279873.
# 47.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 668,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:06:39
#
#
# Importação iniciada em 13/03/2022, 17:33:270597.
# 47.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 668,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:06:28
#
#
# Importação iniciada em 13/03/2022, 17:33:271552.
# 47.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 669,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:05:40
#
#
# Importação iniciada em 13/03/2022, 17:33:271482.
# 47.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 673,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:03:19
#
#
# Importação iniciada em 13/03/2022, 17:33:274580.
# 47.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 673,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:03:03
#
#
# Importação iniciada em 13/03/2022, 17:33:274370.
# 47.7% importados.
#
# Linhas por segundo lidas (total): 10.5
# 674,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:02:15
#
#
# Importação iniciada em 13/03/2022, 17:33:275437.
# 47.7% importados.
#
# Linhas por segundo lidas (total): 10.5
# 675,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 13:01:43
#
#
# Importação iniciada em 13/03/2022, 17:33:270792.
# 48.0% importados.
#
# Linhas por segundo lidas (total): 10.5
# 678,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 12:56:44
#
#
# Tentando recuperar Lattes compactado 6567184149998311 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6567184149998311
# Importação iniciada em 13/03/2022, 17:33:270292.
# 48.1% importados.
#
# Linhas por segundo lidas (total): 10.5
# 680,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 12:54:47
#
#
# 680465 / 1413665. Importing id 6853196325536402.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16088/153155580.py in <module>
#       1 from Carga import Carga
#       2 cg = Carga()
# ----> 3 cg.atualiza_todos_os_indicadores (on_conflic_update = True,
#       4                                   pula_bd_indicadores = True,
#       5                                   pula_erros = False,
#
# ~\CNPq\Lattes\Python\Carga.py in atualiza_todos_os_indicadores(self, path, log_file, max, de_hd, de_bd_lattes, de_all_lattes, de_bd_demanda_bruta, de_carga_dados_pessoais, pula_bd_indicadores, pula_erros, data_mínima_atualização_lattes, show_import_messages, num_imports_skip_before_log, começando_com, on_conflic_update, nível_mínimo)
#    1015             #         t.join()
#    1016             #     list_threads = []
# -> 1017             atualiza_indicador (id, on_conflic_update = on_conflic_update)
#    1018             if num%num_imports_skip_before_log == 0:
#    1019                 segundos_por_linha = (datetime.now() - tempo_inicio)/num_imports_skip_before_log
#
# ~\CNPq\Lattes\Python\Carga.py in atualiza_indicador(id, on_conflic_update)
#     995         def atualiza_indicador (id, on_conflic_update = False):
#     996             ind = Indicadores (id = id)
# --> 997             ind.atualiza(on_conflic_update=on_conflic_update)
#     998             del ind
#     999
#
# ~\CNPq\Lattes\Python\Indicadores.py in wrap(*args, **kw)
#      58         def wrap(*args, **kw):
#      59             if args[0].show_execution_time: ts = datetime.now()
# ---> 60             result = f(*args, **kw)
#      61             if args[0].show_execution_time:
#      62                 te = datetime.now()
#
# ~\CNPq\Lattes\Python\Indicadores.py in atualiza(self, indicadores, palavras_chave, areas_conhecimento, publicações, dados_pessoais, on_conflic_update)
#     444                 print ('ERRRO - Não foi possível carregar Áreas do Conhecimento. ID:', self.id)
#     445             else:
# --> 446                 self.salva_areas_do_conhecimento_no_bd(on_conflic_update = on_conflic_update)
#     447         if publicações:
#     448             if not self.get_publicações():
#
# ~\CNPq\Lattes\Python\Indicadores.py in wrap(*args, **kw)
#      58         def wrap(*args, **kw):
#      59             if args[0].show_execution_time: ts = datetime.now()
# ---> 60             result = f(*args, **kw)
#      61             if args[0].show_execution_time:
#      62                 te = datetime.now()
#
# ~\CNPq\Lattes\Python\Indicadores.py in salva_areas_do_conhecimento_no_bd(self, on_conflic_update)
#     300         insert into public."areas_conhecimento" (id, tipo, area) VALUES \n''' + args_str + '''
#     301         ON CONFLICT (id, tipo, area) DO NOTHING'''
# --> 302         sql = self.db.cursor.mogrify(sql, (self.id,))
#     303         if self.show_sql: print (sql)
#     304         self.db.execute(sql)
#
# ValueError: unsupported format character ' ' (0x20) at index 432

# %%
from Indicadores import Indicadores

# %%
ind = Indicadores(id = '6853196325536402', show_sql = True)

# %%
ind.atualiza()
# Out:
# b'\n                delete from public."indicadores" where id = \'6853196325536402\';\n                insert into public."indicadores"\n                    (id, ano, path, tipo, qty)\n                VALUES (\'6853196325536402\',2003,\'["CURRICULO-VITAE", "DADOS-GERAIS", "FORMACAO-ACADEMICA-TITULACAO", "GRADUACAO", 0, "@ANO-DE-INICIO"]\',\'@ANO-DE-INICIO GRADUACAO \',1),(\'6853196325536402\',2004,\'["CURRICULO-VITAE", "DADOS-GERAIS", "FORMACAO-ACADEMICA-TITULACAO", "GRADUACAO", 0, "@ANO-DE-CONCLUSAO"]\',\'@ANO-DE-CONCLUSAO GRADUACAO \',1),(\'6853196325536402\',2005,\'["CURRICULO-VITAE", "DADOS-GERAIS", "FORMACAO-ACADEMICA-TITULACAO", "GRADUACAO", 1, "@ANO-DE-INICIO"]\',\'@ANO-DE-INICIO GRADUACAO \',1),(\'6853196325536402\',2008,\'["CURRICULO-VITAE", "DADOS-GERAIS", "FORMACAO-ACADEMICA-TITULACAO", "GRADUACAO", 1, "@ANO-DE-CONCLUSAO"]\',\'@ANO-DE-CONCLUSAO GRADUACAO \',1),(\'6853196325536402\',2006,\'["CURRICULO-VITAE", "DADOS-GERAIS", "FORMACAO-ACADEMICA-TITULACAO", "ESPECIALIZACAO", "@ANO-DE-INICIO"]\',\'@ANO-DE-INICIO ESPECIALIZACAO \',1),(\'6853196325536402\',2008,\'["CURRICULO-VITAE", "DADOS-GERAIS", "FORMACAO-ACADEMICA-TITULACAO", "ESPECIALIZACAO", "@ANO-DE-CONCLUSAO"]\',\'@ANO-DE-CONCLUSAO ESPECIALIZACAO \',1),(\'6853196325536402\',2013,\'["CURRICULO-VITAE", "DADOS-GERAIS", "FORMACAO-ACADEMICA-TITULACAO", "MESTRADO", "@ANO-DE-INICIO"]\',\'@ANO-DE-INICIO MESTRADO \',1),(\'6853196325536402\',2009,\'["CURRICULO-VITAE", "DADOS-GERAIS", "ATUACOES-PROFISSIONAIS", "ATUACAO-PROFISSIONAL", 0, "VINCULOS", "@ANO-INICIO"]\',\'@ANO-INICIO VINCULOS \',1),(\'6853196325536402\',2012,\'["CURRICULO-VITAE", "DADOS-GERAIS", "ATUACOES-PROFISSIONAIS", "ATUACAO-PROFISSIONAL", 0, "VINCULOS", "@ANO-FIM"]\',\'@ANO-FIM VINCULOS \',1),(\'6853196325536402\',2010,\'["CURRICULO-VITAE", "DADOS-GERAIS", "ATUACOES-PROFISSIONAIS", "ATUACAO-PROFISSIONAL", 1, "VINCULOS", "@ANO-INICIO"]\',\'@ANO-INICIO VINCULOS \',1),(\'6853196325536402\',2010,\'["CURRICULO-VITAE", "DADOS-GERAIS", "ATUACOES-PROFISSIONAIS", "ATUACAO-PROFISSIONAL", 2, "VINCULOS", "@ANO-INICIO"]\',\'@ANO-INICIO VINCULOS \',1),(\'6853196325536402\',2013,\'["CURRICULO-VITAE", "DADOS-GERAIS", "ATUACOES-PROFISSIONAIS", "ATUACAO-PROFISSIONAL", 2, "VINCULOS", "@ANO-FIM"]\',\'@ANO-FIM VINCULOS \',1),(\'6853196325536402\',2011,\'["CURRICULO-VITAE", "DADOS-GERAIS", "ATUACOES-PROFISSIONAIS", "ATUACAO-PROFISSIONAL", 3, "VINCULOS", "@ANO-INICIO"]\',\'@ANO-INICIO VINCULOS \',1),(\'6853196325536402\',2014,\'["CURRICULO-VITAE", "DADOS-GERAIS", "ATUACOES-PROFISSIONAIS", "ATUACAO-PROFISSIONAL", 3, "VINCULOS", "@ANO-FIM"]\',\'@ANO-FIM VINCULOS \',1),(\'6853196325536402\',2011,\'["CURRICULO-VITAE", "DADOS-GERAIS", "ATUACOES-PROFISSIONAIS", "ATUACAO-PROFISSIONAL", 4, "VINCULOS", "@ANO-INICIO"]\',\'@ANO-INICIO VINCULOS \',1),(\'6853196325536402\',2015,\'["CURRICULO-VITAE", "DADOS-GERAIS", "ATUACOES-PROFISSIONAIS", "ATUACAO-PROFISSIONAL", 4, "VINCULOS", "@ANO-FIM"]\',\'@ANO-FIM VINCULOS \',1),(\'6853196325536402\',2010,\'["CURRICULO-VITAE", "DADOS-GERAIS", "ATUACOES-PROFISSIONAIS", "ATUACAO-PROFISSIONAL", 5, "VINCULOS", "@ANO-INICIO"]\',\'@ANO-INICIO VINCULOS \',1),(\'6853196325536402\',2014,\'["CURRICULO-VITAE", "DADOS-GERAIS", "ATUACOES-PROFISSIONAIS", "ATUACAO-PROFISSIONAL", 5, "VINCULOS", "@ANO-FIM"]\',\'@ANO-FIM VINCULOS \',1),(\'6853196325536402\',2008,\'["CURRICULO-VITAE", "DADOS-GERAIS", "ATUACOES-PROFISSIONAIS", "ATUACAO-PROFISSIONAL", 6, "VINCULOS", "@ANO-INICIO"]\',\'@ANO-INICIO VINCULOS \',1),(\'6853196325536402\',2014,\'["CURRICULO-VITAE", "DADOS-GERAIS", "ATUACOES-PROFISSIONAIS", "ATUACAO-PROFISSIONAL", 7, "VINCULOS", "@ANO-INICIO"]\',\'@ANO-INICIO VINCULOS \',1),(\'6853196325536402\',2012,\'["CURRICULO-VITAE", "DADOS-GERAIS", "ATUACOES-PROFISSIONAIS", "ATUACAO-PROFISSIONAL", 8, "VINCULOS", "@ANO-INICIO"]\',\'@ANO-INICIO VINCULOS \',1),(\'6853196325536402\',2010,\'["CURRICULO-VITAE", "DADOS-GERAIS", "ATUACOES-PROFISSIONAIS", "ATUACAO-PROFISSIONAL", 9, "VINCULOS", "@ANO-INICIO"]\',\'@ANO-INICIO VINCULOS ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16088/1838741963.py in <module>
# ----> 1 ind.atualiza()
#
# ~\CNPq\Lattes\Python\Indicadores.py in wrap(*args, **kw)
#      58         def wrap(*args, **kw):
#      59             if args[0].show_execution_time: ts = datetime.now()
# ---> 60             result = f(*args, **kw)
#      61             if args[0].show_execution_time:
#      62                 te = datetime.now()
#
# ~\CNPq\Lattes\Python\Indicadores.py in atualiza(self, indicadores, palavras_chave, areas_conhecimento, publicações, dados_pessoais, on_conflic_update)
#     444                 print ('ERRRO - Não foi possível carregar Áreas do Conhecimento. ID:', self.id)
#     445             else:
# --> 446                 self.salva_areas_do_conhecimento_no_bd(on_conflic_update = on_conflic_update)
#     447         if publicações:
#     448             if not self.get_publicações():
#
# ~\CNPq\Lattes\Python\Indicadores.py in wrap(*args, **kw)
#      58         def wrap(*args, **kw):
#      59             if args[0].show_execution_time: ts = datetime.now()
# ---> 60             result = f(*args, **kw)
#      61             if args[0].show_execution_time:
#      62                 te = datetime.now()
#
# ~\CNPq\Lattes\Python\Indicadores.py in salva_areas_do_conhecimento_no_bd(self, on_conflic_update)
#     300         insert into public."areas_conhecimento" (id, tipo, area) VALUES \n''' + args_str + '''
#     301         ON CONFLICT (id, tipo, area) DO NOTHING'''
# --> 302         sql = self.db.cursor.mogrify(sql, (self.id,))
#     303         if self.show_sql: print (sql)
#     304         self.db.execute(sql)
#
# ValueError: unsupported format character ' ' (0x20) at index 432

# %%
ind.get_areas_conhecimento()
# Out:
# True
