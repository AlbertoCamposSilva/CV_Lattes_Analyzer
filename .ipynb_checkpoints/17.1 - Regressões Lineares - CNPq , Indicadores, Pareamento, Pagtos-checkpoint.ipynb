# %%
from datetime import datetime

print('Início em: ', datetime.now())
print('Importações Iniciais')

from Regressao import Regressao
reg = Regressao()

print('Fim: ', datetime.now())
# Out:
# Início em:  2023-04-29 10:41:59.260945
# Importações Iniciais
# Fim:  2023-04-29 10:42:06.774456

# %%
reg.path = ''
reg.variável_dependente = 'qty_2019'
reg.variáveis_independentes = ['qty_2013', 'porcent_pagos', 'C(nome)']
reg.confianças = [0.01, 0.05]
reg.indicador = 'Artigo Publicado'
reg.ano_início = 2014
reg.best_r2 = False
reg.pareamento = True
reg.capes = False
reg.cnpq = True
reg.nenhum = True
reg.ambos = False
reg.preenche_todos_ids = False
reg.verbose = False
reg.drop_not_significant = False

#reg.faz_apenas_os_indicadores = ['Conclusão de Ensino Médio']

# %%
Regressao.pd = reg.pega_tabela_para_regressão()
# Out:
# Carregando indicadores na memória. Início em:  2023-04-29 10:42:06.821098
# Fim em:  2023-04-29 10:43:04.983801

# %%
reg.faz_regressões()
# Out:
# Iniciado em 2023-04-25 20:56:31.548539.
# 0/128. Fazendo: Conclusão de Doutorado.
# 1/128. 0.8% feitos. Fazendo: Conclusão de Curso de Curta Duração. Acabará em 25/04/23 20:57:10. O Último demorou: 0:00:00.258002.
# 2/128. 1.6% feitos. Fazendo: Conclusão de Graduação. Acabará em 25/04/23 20:57:03. O Último demorou: 0:00:00.194000.
# 3/128. 2.3% feitos. Fazendo: Conclusão de Mestrado. Acabará em 25/04/23 20:57:07. O Último demorou: 0:00:00.335998.
# 4/128. 3.1% feitos. Fazendo: Início de Doutorado. Acabará em 25/04/23 20:57:08. O Último demorou: 0:00:00.309998.
# 5/128. 3.9% feitos. Fazendo: Início de Curso de Curta Duração. Acabará em 25/04/23 20:57:13. O Último demorou: 0:00:00.491997.
# 6/128. 4.7% feitos. Fazendo: Início de Graduação. Acabará em 25/04/23 20:57:12. O Último demorou: 0:00:00.262002.
# 7/128. 5.5% feitos. Fazendo: Início de Mestrado. Acabará em 25/04/23 20:57:17. O Último demorou: 0:00:00.631999.
# 8/128. 6.2% feitos. Fazendo: Início de Pós-Doutorado. Acabará em 25/04/23 20:57:15. O Último demorou: 0:00:00.188003.
# 9/128. 7.0% feitos. Fazendo: Obtenção do Título de Doutorado. Acabará em 25/04/23 20:57:13. O Último demorou: 0:00:00.213996.
# 10/128. 7.8% feitos. Fazendo: Obtenção do Título de Metrado. Acabará em 25/04/23 20:57:12. O Último demorou: 0:00:00.278003.
# 11/128. 8.6% feitos. Fazendo: Trabalho em Evento. Acabará em 25/04/23 20:57:11. O Último demorou: 0:00:00.228999.
# 12/128. 9.4% feitos. Fazendo: Artigo Publicado. Acabará em 25/04/23 20:57:10. O Último demorou: 0:00:00.178579.
# 13/128. 10.2% feitos. Fazendo: Trabalho em Eventos. Acabará em 25/04/23 20:57:08. O Último demorou: 0:00:00.122003.
# 14/128. 10.9% feitos. Fazendo: Fim de Estágio. Acabará em 25/04/23 20:57:08. O Último demorou: 0:00:00.286001.
# 15/128. 11.7% feitos. Fazendo: Fim de Atividade de Pesquisa e Desenvolvimento. Acabará em 25/04/23 20:57:06. O Último demorou: 0:00:00.086998.
# 16/128. 12.5% feitos. Fazendo: Fim de Vínculo Empregatício ou Funcional. Acabará em 25/04/23 20:57:05. O Último demorou: 0:00:00.177006.
# 17/128. 13.3% feitos. Fazendo: Início de Atividade de Ensino. Acabará em 25/04/23 20:57:05. O Último demorou: 0:00:00.245993.
# 18/128. 14.1% feitos. Fazendo: Início de Estágio. Acabará em 25/04/23 20:57:05. O Último demorou: 0:00:00.177003.
# 19/128. 14.8% feitos. Fazendo: Início de Atividade de Pesquisa e Desenvolvimento. Acabará em 25/04/23 20:57:05. O Último demorou: 0:00:00.257996.
# 20/128. 15.6% feitos. Fazendo: Início de Vínculo Empregatício ou Funcional. Acabará em 25/04/23 20:57:04. O Último demorou: 0:00:00.125999.
# 21/128. 16.4% feitos. Fazendo: Apresentação de Trabalho Técnico. Acabará em 25/04/23 20:57:03. O Último demorou: 0:00:00.118999.
# 22/128. 17.2% feitos. Fazendo: Publicação de Capítulo de Livro. Acabará em 25/04/23 20:57:03. O Último demorou: 0:00:00.260989.
# 23/128. 18.0% feitos. Fazendo: Livro Publicado ou Organizado. Acabará em 25/04/23 20:57:03. O Último demorou: 0:00:00.178001.
# 24/128. 18.8% feitos. Fazendo: Outras Orientações Concluídas. Acabará em 25/04/23 20:57:02. O Último demorou: 0:00:00.174000.
# 25/128. 19.5% feitos. Fazendo: Participação em Congresso. Acabará em 25/04/23 20:57:02. O Último demorou: 0:00:00.121071.
# 26/128. 20.3% feitos. Fazendo: Participação em Seminário. Acabará em 25/04/23 20:57:01. O Último demorou: 0:00:00.108000.
# 27/128. 21.1% feitos. Fazendo: Participação em Simpósio. Acabará em 25/04/23 20:57:00. O Último demorou: 0:00:00.074524.
# 28/128. 21.9% feitos. Fazendo: Prêmio ou Título Recebido. Acabará em 25/04/23 20:57:00. O Último demorou: 0:00:00.110999.
# 29/128. 22.7% feitos. Fazendo: Conclusão de Outra Formação Complementar. Acabará em 25/04/23 20:57:00. O Último demorou: 0:00:00.209997.
# 30/128. 23.4% feitos. Fazendo: Início de Outra Formação Complementar. Acabará em 25/04/23 20:57:00. O Último demorou: 0:00:00.208003.
# 31/128. 24.2% feitos. Fazendo: Organização de Evento. Acabará em 25/04/23 20:56:59. O Último demorou: 0:00:00.120997.
# 32/128. 25.0% feitos. Fazendo: Outras Participações em Congressos. Acabará em 25/04/23 20:56:59. O Último demorou: 0:00:00.233001.
# 33/128. 25.8% feitos. Fazendo: Participação em Banca de Graduação. Acabará em 25/04/23 20:56:59. O Último demorou: 0:00:00.192002.
# 34/128. 26.6% feitos. Fazendo: Conclusão de Especialização. Acabará em 25/04/23 20:56:59. O Último demorou: 0:00:00.257999.
# 35/128. 27.3% feitos. Fazendo: Conclusão de Extensão Universitária. Acabará em 25/04/23 20:56:59. O Último demorou: 0:00:00.161000.
# 36/128. 28.1% feitos. Fazendo: Início de Especialização. Acabará em 25/04/23 20:56:59. O Último demorou: 0:00:00.153001.
# 37/128. 28.9% feitos. Fazendo: Início de Extensão Universitária. Acabará em 25/04/23 20:56:58. O Último demorou: 0:00:00.132003.
# 38/128. 29.7% feitos. Fazendo: Fim de Atividade de Ensino. Acabará em 25/04/23 20:56:59. O Último demorou: 0:00:00.261031.
# 39/128. 30.5% feitos. Fazendo: Fim de Participação em Projeto. Acabará em 25/04/23 20:56:58. O Último demorou: 0:00:00.177003.
# 40/128. 31.2% feitos. Fazendo: Fim de Projeto de Pesquisa. Acabará em 25/04/23 20:56:58. O Último demorou: 0:00:00.183001.
# 41/128. 32.0% feitos. Fazendo: Início de Participação em Projeto. Acabará em 25/04/23 20:56:59. O Último demorou: 0:00:00.246995.
# 42/128. 32.8% feitos. Fazendo: Início de Projeto de Pesquisa. Acabará em 25/04/23 20:56:58. O Último demorou: 0:00:00.108045.
# 43/128. 33.6% feitos. Fazendo: Ministério de Curso de Curta Duração. Acabará em 25/04/23 20:56:58. O Último demorou: 0:00:00.218001.
# 44/128. 34.4% feitos. Fazendo: Desenvolvimento de Material Didático ou Instrucional. Acabará em 25/04/23 20:56:58. O Último demorou: 0:00:00.279004.
# 45/128. 35.2% feitos. Fazendo: Outra produção Técnica. Acabará em 25/04/23 20:56:58. O Último demorou: 0:00:00.085998.
# 46/128. 35.9% feitos. Fazendo: Outras Participações de Bancas Julgadoras. Acabará em 25/04/23 20:56:58. O Último demorou: 0:00:00.150995.
# 47/128. 36.7% feitos. Fazendo: Participação em Encontro. Acabará em 25/04/23 20:56:58. O Último demorou: 0:00:00.206002.
# 48/128. 37.5% feitos. Fazendo: Participação em Exposição. Acabará em 25/04/23 20:56:58. O Último demorou: 0:00:00.125002.
# 49/128. 38.3% feitos. Fazendo: Publicação de Prefácio ou Posfácio. Acabará em 25/04/23 20:56:57. O Último demorou: 0:00:00.153998.
# 50/128. 39.1% feitos. Fazendo: Programa de Rádio ou TV. Acabará em 25/04/23 20:56:57. O Último demorou: 0:00:00.124002.
# 51/128. 39.8% feitos. Fazendo: Mídia Social, websiteou Blog. Acabará em 25/04/23 20:56:57. O Último demorou: 0:00:00.094998.
# 52/128. 40.6% feitos. Fazendo: Participação em Banca de Aperfeiçoamento ou Especialização. Acabará em 25/04/23 20:56:57. O Último demorou: 0:00:00.171002.
# 53/128. 41.4% feitos. Fazendo: Participação em Banca de Exame de Qualificação. Acabará em 25/04/23 20:56:57. O Último demorou: 0:00:00.087002.
# 54/128. 42.2% feitos. Fazendo: Participação em Banca de Mestrado. Acabará em 25/04/23 20:56:57. O Último demorou: 0:00:00.167996.
# 55/128. 43.0% feitos. Fazendo: Participação em Oficina. Acabará em 25/04/23 20:56:57. O Último demorou: 0:00:00.211248.
# 56/128. 43.8% feitos. Fazendo: Produção de Trabalho Técnico. Acabará em 25/04/23 20:56:57. O Último demorou: 0:00:00.158752.
# 57/128. 44.5% feitos. Fazendo: Conclusão de Ensino Médio. Acabará em 25/04/23 20:56:57. O Último demorou: 0:00:00.281004.
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1804: RuntimeWarning: divide by zero encountered in double_scalars
#   return self.mse_model/self.mse_resid
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1804: RuntimeWarning: divide by zero encountered in double_scalars
#   return self.mse_model/self.mse_resid
# Erro, regressão usou o Intercept mesmo com -1 na fórmula. Continuando.
# Erro, regressão usou o Intercept mesmo com -1 na fórmula. Continuando.
# 58/128. 45.3% feitos. Fazendo: Início de Ensino Médio. Acabará em 25/04/23 20:56:57. O Último demorou: 0:00:00.479996.
# 59/128. 46.1% feitos. Fazendo: Artigo Aceito para Publicação. Acabará em 25/04/23 20:56:57. O Último demorou: 0:00:00.160003.
# 60/128. 46.9% feitos. Fazendo: Participação em Banca Julgadora para Concurso Público. Acabará em 25/04/23 20:56:57. O Último demorou: 0:00:00.188000.
# 61/128. 47.7% feitos. Fazendo: Orientação em Andamento de Graduação. Acabará em 25/04/23 20:56:57. O Último demorou: 0:00:00.122003.
# 62/128. 48.4% feitos. Fazendo: Produção Bibliográfica. Acabará em 25/04/23 20:56:57. O Último demorou: 0:00:00.109998.
# 63/128. 49.2% feitos. Fazendo: Participação em Banca de Doutorado. Acabará em 25/04/23 20:56:57. O Último demorou: 0:00:00.126000.
# 64/128. 50.0% feitos. Fazendo: Produção de Relatório de Pesquisa. Acabará em 25/04/23 20:56:57. O Último demorou: 0:00:00.118001.
# 65/128. 50.8% feitos. Fazendo: Fim de Atividade de Serviço Técnico-Especializado. Acabará em 25/04/23 20:56:56. O Último demorou: 0:00:00.086027.
# 66/128. 51.6% feitos. Fazendo: Início de Atividade de Serviço Técnico-Especializado. Acabará em 25/04/23 20:56:56. O Último demorou: 0:00:00.062974.
# 67/128. 52.3% feitos. Fazendo: Conclusão de Curso Técnico/Profissionalizante. Acabará em 25/04/23 20:56:56. O Último demorou: 0:00:00.146000.
# 68/128. 53.1% feitos. Fazendo: Início de Curso Técnico/Profissionalizante. Acabará em 25/04/23 20:56:56. O Último demorou: 0:00:00.083997.
# 69/128. 53.9% feitos. Fazendo: Texto em Jornal ou Revista. Acabará em 25/04/23 20:56:56. O Último demorou: 0:00:00.082000.
# 70/128. 54.7% feitos. Fazendo: Orientação Concluída de Doutorado. Acabará em 25/04/23 20:56:55. O Último demorou: 0:00:00.066000.
# 71/128. 55.5% feitos. Fazendo: Orientação Concluída de Mestrado. Acabará em 25/04/23 20:56:55. O Último demorou: 0:00:00.096003.
# 72/128. 56.2% feitos. Fazendo: Tradução. Acabará em 25/04/23 20:56:55. O Último demorou: 0:00:00.074207.
# 73/128. 57.0% feitos. Fazendo: Produção de Artes Visuais. Acabará em 25/04/23 20:56:55. O Último demorou: 0:00:00.067793.
# 74/128. 57.8% feitos. Fazendo: Produção - Demais Trabalhos. Acabará em 25/04/23 20:56:55. O Último demorou: 0:00:00.082996.
# 75/128. 58.6% feitos. Fazendo: Produção Artística ou Cultural. Acabará em 25/04/23 20:56:55. O Último demorou: 0:00:00.259522.
# 76/128. 59.4% feitos. Fazendo: Início de Atividade de Direção ou Administração. Acabará em 25/04/23 20:56:55. O Último demorou: 0:00:00.120009.
# 77/128. 60.2% feitos. Fazendo: Fim de Extensão Universitária. Acabará em 25/04/23 20:56:54. O Último demorou: 0:00:00.111806.
# 78/128. 60.9% feitos. Fazendo: Fim de Outra Atividade Técnico/Científica. Acabará em 25/04/23 20:56:54. O Último demorou: 0:00:00.064992.
# 79/128. 61.7% feitos. Fazendo: Início de Outra Atividade Técnico/Científica. Acabará em 25/04/23 20:56:54. O Último demorou: 0:00:00.071001.
# 80/128. 62.5% feitos. Fazendo: Fim de Participação em Conselho, Comissão ou Consultoria. Acabará em 25/04/23 20:56:54. O Último demorou: 0:00:00.076998.
# 81/128. 63.3% feitos. Fazendo: Início de Atividade de Conselho, Comissão ou Consultoria. Acabará em 25/04/23 20:56:54. O Último demorou: 0:00:00.075002.
# 82/128. 64.1% feitos. Fazendo: Orientação em Andamento de Mestrado. Acabará em 25/04/23 20:56:54. O Último demorou: 0:00:00.069522.
# 83/128. 64.8% feitos. Fazendo: Orientação em Andamento de Iniciação Científica. Acabará em 25/04/23 20:56:53. O Último demorou: 0:00:00.090998.
# 84/128. 65.6% feitos. Fazendo: Participação em Feira. Acabará em 25/04/23 20:56:53. O Último demorou: 0:00:00.113997.
# 85/128. 66.4% feitos. Fazendo: Patente Registrada. Acabará em 25/04/23 20:56:53. O Último demorou: 0:00:00.077001.
# 86/128. 67.2% feitos. Fazendo: Conclusão de Aperfeiçoamento. Acabará em 25/04/23 20:56:53. O Último demorou: 0:00:00.077057.
# 87/128. 68.0% feitos. Fazendo: Início de Aperfeiçoamento. Acabará em 25/04/23 20:56:53. O Último demorou: 0:00:00.125996.
# 88/128. 68.8% feitos. Fazendo: Editoração. Acabará em 25/04/23 20:56:53. O Último demorou: 0:00:00.063000.
# 89/128. 69.5% feitos. Fazendo: Orientação em Andamento de Aperfeiçoamento ou Especialização. Acabará em 25/04/23 20:56:53. O Último demorou: 0:00:00.088999.
# 90/128. 70.3% feitos. Fazendo: Conclusão de Ensino Fundamental. Acabará em 25/04/23 20:56:53. O Último demorou: 0:00:00.079001.
# 91/128. 71.1% feitos. Fazendo: Início de Ensino Fundamental. Acabará em 25/04/23 20:56:52. O Último demorou: 0:00:00.069001.
# 92/128. 71.9% feitos. Fazendo: Participação em Banca Julgadora para Avaliação de Cursos. Acabará em 25/04/23 20:56:52. O Último demorou: 0:00:00.070998.
# 93/128. 72.7% feitos. Fazendo: Fim de Participação em Direção ou Administração. Acabará em 25/04/23 20:56:52. O Último demorou: 0:00:00.161002.
# 94/128. 73.4% feitos. Fazendo: Conclusão de MBA. Acabará em 25/04/23 20:56:52. O Último demorou: 0:00:00.132999.
# 95/128. 74.2% feitos. Fazendo: Início de MBA. Acabará em 25/04/23 20:56:52. O Último demorou: 0:00:00.068002.
# 96/128. 75.0% feitos. Fazendo: Outras Orientações em Andamento. Acabará em 25/04/23 20:56:52. O Último demorou: 0:00:00.059000.
# 97/128. 75.8% feitos. Fazendo: Produção de Software. Acabará em 25/04/23 20:56:52. O Último demorou: 0:00:00.070001.
# 98/128. 76.6% feitos. Fazendo: Orientação em Andamento de Doutorado. Acabará em 25/04/23 20:56:52. O Último demorou: 0:00:00.088999.
# 99/128. 77.3% feitos. Fazendo: Conclusão de Residência Médica. Acabará em 25/04/23 20:56:52. O Último demorou: 0:00:00.122999.
# 100/128. 78.1% feitos. Fazendo: Início de Residência Médica. Acabará em 25/04/23 20:56:52. O Último demorou: 0:00:00.144021.
# 101/128. 78.9% feitos. Fazendo: Conclusão de Mestrado Profissionalizante. Acabará em 25/04/23 20:56:52. O Último demorou: 0:00:00.121998.
# 102/128. 79.7% feitos. Fazendo: Início de Mestrado Profissionalizante. Acabará em 25/04/23 20:56:52. O Último demorou: 0:00:00.063000.
# 103/128. 80.5% feitos. Fazendo: Obtenção do Título de Mestrado Profissionalizante. Acabará em 25/04/23 20:56:51. O Último demorou: 0:00:00.070999.
# 104/128. 81.2% feitos. Fazendo: Treinamento Ministrado. Acabará em 25/04/23 20:56:51. O Último demorou: 0:00:00.108001.
# 105/128. 82.0% feitos. Fazendo: Início de Ministério de Treinamento. Acabará em 25/04/23 20:56:51. O Último demorou: 0:00:00.061002.
# 106/128. 82.8% feitos. Fazendo: Participação em Olimpíada. Acabará em 25/04/23 20:56:51. O Último demorou: 0:00:00.059999.
# 107/128. 83.6% feitos. Fazendo: Conclusão de Pós-Doutorado. Acabará em 25/04/23 20:56:51. O Último demorou: 0:00:00.057000.
# 108/128. 84.4% feitos. Fazendo: Produção de Artes Cênicas. Acabará em 25/04/23 20:56:51. O Último demorou: 0:00:00.114997.
# 109/128. 85.2% feitos. Fazendo: Música. Acabará em 25/04/23 20:56:51. O Último demorou: 0:00:00.140999.
# 110/128. 85.9% feitos. Fazendo: Desenvolvimento de Marca. Acabará em 25/04/23 20:56:51. O Último demorou: 0:00:00.140002.
# 111/128. 86.7% feitos. Fazendo: Produção Técnica - Produto Tecnológico. Acabará em 25/04/23 20:56:51. O Último demorou: 0:00:00.098004.
# 112/128. 87.5% feitos. Fazendo: Orientação em Andamento de Pós-Doutorado. Acabará em 25/04/23 20:56:51. O Último demorou: 0:00:00.071994.
# 113/128. 88.3% feitos. Fazendo: Participação em Banca Julgadora para Professor Titular. Acabará em 25/04/23 20:56:51. O Último demorou: 0:00:00.092003.
# 114/128. 89.1% feitos. Fazendo: Produção de Carta, Mapa ou Similar. Acabará em 25/04/23 20:56:51. O Último demorou: 0:00:00.062001.
# 115/128. 89.8% feitos. Fazendo: Produção Técnica - Processos ou Técnicas. Acabará em 25/04/23 20:56:51. O Último demorou: 0:00:00.124998.
# 116/128. 90.6% feitos. Fazendo: Produção  de Obra Musical. Acabará em 25/04/23 20:56:50. O Último demorou: 0:00:00.087001.
# 117/128. 91.4% feitos. Fazendo: Publicação de Partitura Musical. Acabará em 25/04/23 20:56:50. O Último demorou: 0:00:00.159012.
# 118/128. 92.2% feitos. Fazendo: Maquete. Acabará em 25/04/23 20:56:51. O Último demorou: 0:00:00.218988.
# 119/128. 93.0% feitos. Fazendo: Participação em Banca Julgadora para Livre Docência. Acabará em 25/04/23 20:56:51. O Último demorou: 0:00:00.202997.
# 120/128. 93.8% feitos. Fazendo: Obtenção do Título de Livre Docência. Acabará em 25/04/23 20:56:51. O Último demorou: 0:00:00.186003.
# 121/128. 94.5% feitos. Fazendo: Orientação Concluída de Pós-Doutorado. Acabará em 25/04/23 20:56:51. O Último demorou: 0:00:00.100003.
# 122/128. 95.3% feitos. Fazendo: Solicitação de Cultivar Registrada. Acabará em 25/04/23 20:56:51. O Último demorou: 0:00:00.091997.
# 123/128. 96.1% feitos. Fazendo: Manutenção de Obra Artística. Acabará em 25/04/23 20:56:50. O Último demorou: 0:00:00.110000.
# 124/128. 96.9% feitos. Fazendo: Outras participações em Banca. Acabará em 25/04/23 20:56:50. O Último demorou: 0:00:00.126001.
# 125/128. 97.7% feitos. Fazendo: Desenvolvimento de Desenho Industrial. Acabará em 25/04/23 20:56:50. O Último demorou: 0:00:00.090995.
# 126/128. 98.4% feitos. Fazendo: Solicitação de Cultivar protegida. Acabará em 25/04/23 20:56:50. O Último demorou: 0:00:00.095001.
# 127/128. 99.2% feitos. Fazendo: Obtenção do Título de MBA. Acabará em 25/04/23 20:56:50. O Último demorou: 0:00:00.108001.
# [{'Indicador': 'Conclusão de Doutorado',
#   'Erro': False,
#   'Prob (F-statistic)': 4.636947697223378e-05,
#   'Parâmetros': Intercept    0.974850
#   qty_2014     0.291817
#   dtype: float64,
#   'P>|t|': Intercept    0.000000
#   qty_2014     0.000046
#   dtype: float64,
#   'Standard Error': Intercept    0.004129
#   qty_2014     0.071573
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.000223 -0.000223
#   qty_2014   -0.000223  0.066889,
#   'Number of observations n.': 4508.0,
#   'R2 ajustado': 0.003454515468901742,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c31967ee0>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Conclusão de Doutorado',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Conclusão de Curso de Curta Duração',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept    1.175437
#   qty_2014     1.177665
#   dtype: float64,
#   'P>|t|': Intercept    1.057411e-28
#   qty_2014     0.000000e+00
#   dtype: float64,
#   'Standard Error': Intercept    0.104811
#   qty_2014     0.010711
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.000494 -0.000033
#   qty_2014   -0.000033  0.000005,
#   'Number of observations n.': 3506.0,
#   'R2 ajustado': 0.7752148228777322,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c56f7db50>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Conclusão de Curso de Curta Duração',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Conclusão de Graduação',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': qty_2014    1.028146
#   dtype: float64,
#   'P>|t|': qty_2014    0.0
#   dtype: float64,
#   'Standard Error': qty_2014    0.002285
#   dtype: float64,
#   'Covariância entre os pasrâmetros':           qty_2014
#   qty_2014  0.000134,
#   'Number of observations n.': 4700.0,
#   'R2 ajustado': 0.9773075306534833,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c7367a370>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Conclusão de Graduação',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Conclusão de Mestrado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept    0.351674
#   qty_2014     0.660068
#   dtype: float64,
#   'P>|t|': Intercept    1.075462e-264
#   qty_2014      0.000000e+00
#   dtype: float64,
#   'Standard Error': Intercept    0.009442
#   qty_2014     0.009292
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.010884 -0.010601
#   qty_2014   -0.010601  0.010542,
#   'Number of observations n.': 4471.0,
#   'R2 ajustado': 0.5302026932195296,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c73668f10>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Conclusão de Mestrado',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Doutorado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': qty_2014    1.030026
#   dtype: float64,
#   'P>|t|': qty_2014    0.0
#   dtype: float64,
#   'Standard Error': qty_2014    0.002522
#   dtype: float64,
#   'Covariância entre os pasrâmetros':           qty_2014
#   qty_2014  0.000203,
#   'Number of observations n.': 4836.0,
#   'R2 ajustado': 0.971829131723425,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c56f7d820>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Início de Doutorado',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Curso de Curta Duração',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept    1.176543
#   qty_2014     1.177666
#   dtype: float64,
#   'P>|t|': Intercept    1.047785e-28
#   qty_2014     0.000000e+00
#   dtype: float64,
#   'Standard Error': Intercept    0.104904
#   qty_2014     0.010709
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.000494 -0.000033
#   qty_2014   -0.000033  0.000005,
#   'Number of observations n.': 3512.0,
#   'R2 ajustado': 0.7749942165146178,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c73668220>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Início de Curso de Curta Duração',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Graduação',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': qty_2014    1.036938
#   dtype: float64,
#   'P>|t|': qty_2014    0.0
#   dtype: float64,
#   'Standard Error': qty_2014    0.002442
#   dtype: float64,
#   'Covariância entre os pasrâmetros':           qty_2014
#   qty_2014  0.000127,
#   'Number of observations n.': 4711.0,
#   'R2 ajustado': 0.974540045243592,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c73640a00>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Início de Graduação',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Mestrado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept    0.073655
#   qty_2014     0.930806
#   dtype: float64,
#   'P>|t|': Intercept    5.221309e-26
#   qty_2014     0.000000e+00
#   dtype: float64,
#   'Standard Error': Intercept    0.006940
#   qty_2014     0.006796
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.013858 -0.013461
#   qty_2014   -0.013461  0.013289,
#   'Number of observations n.': 4486.0,
#   'R2 ajustado': 0.8070530245661764,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c56f4a790>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Início de Mestrado',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Pós-Doutorado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.001364305718045183,
#   'Parâmetros': Intercept          0.909004
#   porcent_pagos    179.950810
#   dtype: float64,
#   'P>|t|': Intercept        4.475271e-205
#   porcent_pagos     1.364306e-03
#   dtype: float64,
#   'Standard Error': Intercept         0.023798
#   porcent_pagos    56.056650
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  porcent_pagos
#   Intercept       0.001649      -2.632217
#   porcent_pagos  -2.632217    9147.682864,
#   'Number of observations n.': 1122.0,
#   'R2 ajustado': 0.008232402324529597,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c56f42e50>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Início de Pós-Doutorado',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Obtenção do Título de Doutorado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.04765170758888014,
#   'Parâmetros': Intercept    0.965525
#   qty_2014     0.284475
#   dtype: float64,
#   'P>|t|': Intercept    0.000000
#   qty_2014     0.047652
#   dtype: float64,
#   'Standard Error': Intercept    0.004323
#   qty_2014     0.143601
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.000227 -0.000227
#   qty_2014   -0.000227  0.250227,
#   'Number of observations n.': 4413.0,
#   'R2 ajustado': 0.000662393362286462,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c6b8e7cd0>,
#   'Confiança': 0.05,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Obtenção do Título de Doutorado',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Obtenção do Título de Metrado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept    0.561703
#   qty_2014     0.452349
#   dtype: float64,
#   'P>|t|': Intercept    0.0
#   qty_2014     0.0
#   dtype: float64,
#   'Standard Error': Intercept    0.009355
#   qty_2014     0.009272
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.009176 -0.008983
#   qty_2014   -0.008983  0.009013,
#   'Number of observations n.': 4468.0,
#   'R2 ajustado': 0.3475287711569597,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c736403d0>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Obtenção do Título de Metrado',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Trabalho em Evento',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept    2.415528
#   qty_2014     1.319612
#   dtype: float64,
#   'P>|t|': Intercept    2.483784e-49
#   qty_2014     0.000000e+00
#   dtype: float64,
#   'Standard Error': Intercept    0.161277
#   qty_2014     0.009359
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.000436 -0.000016
#   qty_2014   -0.000016  0.000001,
#   'Number of observations n.': 3842.0,
#   'R2 ajustado': 0.8380827922836495,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c6b8e7a30>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Trabalho em Evento',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Artigo Publicado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept           2.478063
#   qty_2014            1.800903
#   porcent_pagos    1534.649467
#   dtype: float64,
#   'P>|t|': Intercept        4.559430e-93
#   qty_2014         0.000000e+00
#   porcent_pagos    1.153528e-07
#   dtype: float64,
#   'Standard Error': Intercept          0.118044
#   qty_2014           0.022858
#   porcent_pagos    289.009710
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000478 -0.000044      -0.594665
#   qty_2014       -0.000044  0.000018      -0.002571
#   porcent_pagos  -0.594665 -0.002571    2863.866118,
#   'Number of observations n.': 4148.0,
#   'R2 ajustado': 0.600890325095812,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c01b7fc70>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Artigo Publicado',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Trabalho em Eventos',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept    2.472857
#   qty_2014     1.321447
#   dtype: float64,
#   'P>|t|': Intercept    1.493525e-50
#   qty_2014     0.000000e+00
#   dtype: float64,
#   'Standard Error': Intercept    0.162971
#   qty_2014     0.009352
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.000437 -0.000016
#   qty_2014   -0.000016  0.000001,
#   'Number of observations n.': 3851.0,
#   'R2 ajustado': 0.8383274136389562,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c6b8e7b80>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Trabalho em Eventos',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Fim de Estágio',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept    0.193852
#   qty_2014     1.021965
#   dtype: float64,
#   'P>|t|': Intercept    0.000002
#   qty_2014     0.000000
#   dtype: float64,
#   'Standard Error': Intercept    0.040315
#   qty_2014     0.013225
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.002836 -0.000679
#   qty_2014   -0.000679  0.000305,
#   'Number of observations n.': 754.0,
#   'R2 ajustado': 0.8880088893914869,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c01b7f490>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Fim de Estágio',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Fim de Atividade de Pesquisa e Desenvolvimento',
#   'Erro': False,
#   'Prob (F-statistic)': 4.188428593917821e-191,
#   'Parâmetros': Intercept    0.723333
#   qty_2014     0.926319
#   dtype: float64,
#   'P>|t|': Intercept     6.568950e-60
#   qty_2014     4.188429e-191
#   dtype: float64,
#   'Standard Error': Intercept    0.039773
#   qty_2014     0.021536
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.002709 -0.000957
#   qty_2014   -0.000957  0.000794,
#   'Number of observations n.': 643.0,
#   'R2 ajustado': 0.7422738021326407,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c56f74c10>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Fim de Atividade de Pesquisa e Desenvolvimento',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Fim de Vínculo Empregatício ou Funcional',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept    1.176471
#   qty_2014     1.189356
#   dtype: float64,
#   'P>|t|': Intercept    5.243129e-72
#   qty_2014     0.000000e+00
#   dtype: float64,
#   'Standard Error': Intercept    0.064384
#   qty_2014     0.009573
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.000568 -0.000066
#   qty_2014   -0.000066  0.000013,
#   'Number of observations n.': 4494.0,
#   'R2 ajustado': 0.7745176028161053,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c01b41970>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Fim de Vínculo Empregatício ou Funcional',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Atividade de Ensino',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept    2.590987
#   qty_2014     1.164683
#   dtype: float64,
#   'P>|t|': Intercept    2.141221e-63
#   qty_2014     0.000000e+00
#   dtype: float64,
#   'Standard Error': Intercept    0.147436
#   qty_2014     0.020953
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.000813 -0.000057
#   qty_2014   -0.000057  0.000016,
#   'Number of observations n.': 1616.0,
#   'R2 ajustado': 0.6566461751783521,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c01b519d0>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Início de Atividade de Ensino',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Estágio',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept    0.207486
#   qty_2014     1.021156
#   dtype: float64,
#   'P>|t|': Intercept    7.437021e-07
#   qty_2014     0.000000e+00
#   dtype: float64,
#   'Standard Error': Intercept    0.041575
#   qty_2014     0.013700
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.002741 -0.000657
#   qty_2014   -0.000657  0.000298,
#   'Number of observations n.': 775.0,
#   'R2 ajustado': 0.8777007338021487,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c01b5c370>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Início de Estágio',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Atividade de Pesquisa e Desenvolvimento',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept    0.609455
#   qty_2014     0.934413
#   dtype: float64,
#   'P>|t|': Intercept    3.762636e-66
#   qty_2014     0.000000e+00
#   dtype: float64,
#   'Standard Error': Intercept    0.033310
#   qty_2014     0.015808
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.001726 -0.000590
#   qty_2014   -0.000590  0.000389,
#   'Number of observations n.': 1202.0,
#   'R2 ajustado': 0.7441429769444385,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c7366d3a0>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Início de Atividade de Pesquisa e Desenvolvimento',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Vínculo Empregatício ou Funcional',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept           1.041442
#   qty_2014            1.278928
#   porcent_pagos    1537.792494
#   dtype: float64,
#   'P>|t|': Intercept        1.075755e-21
#   qty_2014         0.000000e+00
#   porcent_pagos    4.132705e-13
#   dtype: float64,
#   'Standard Error': Intercept          0.108295
#   qty_2014           0.012172
#   porcent_pagos    211.470710
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000702 -0.000059      -0.529950
#   qty_2014       -0.000059  0.000009       0.002556
#   porcent_pagos  -0.529950  0.002556    2675.323044,
#   'Number of observations n.': 4695.0,
#   'R2 ajustado': 0.7021999879578767,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c01b6c610>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Início de Vínculo Empregatício ou Funcional',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Apresentação de Trabalho Técnico',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept    2.496401
#   qty_2014     1.290430
#   dtype: float64,
#   'P>|t|': Intercept    1.504556e-86
#   qty_2014     0.000000e+00
#   dtype: float64,
#   'Standard Error': Intercept    0.123593
#   qty_2014     0.010475
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.000425 -0.000023
#   qty_2014   -0.000023  0.000003,
#   'Number of observations n.': 4084.0,
#   'R2 ajustado': 0.7879888688258316,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c01b5bee0>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Apresentação de Trabalho Técnico',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Publicação de Capítulo de Livro',
#   'Erro': False,
#   'Prob (F-statistic)': 5.233347839473432e-286,
#   'Parâmetros': Intercept    1.386859
#   qty_2014     1.337327
#   dtype: float64,
#   'P>|t|': Intercept     4.597665e-77
#   qty_2014     5.233348e-286
#   dtype: float64,
#   'Standard Error': Intercept    0.071704
#   qty_2014     0.031629
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.000572 -0.000113
#   qty_2014   -0.000113  0.000111,
#   'Number of observations n.': 2188.0,
#   'R2 ajustado': 0.44963584221889297,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c01b42b50>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Publicação de Capítulo de Livro',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Livro Publicado ou Organizado',
#   'Erro': False,
#   'Prob (F-statistic)': 1.7873430560758186e-191,
#   'Parâmetros': Intercept    0.803703
#   qty_2014     1.562667
#   dtype: float64,
#   'P>|t|': Intercept     5.513911e-29
#   qty_2014     1.787343e-191
#   dtype: float64,
#   'Standard Error': Intercept    0.069960
#   qty_2014     0.043221
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.001080 -0.000291
#   qty_2014   -0.000291  0.000412,
#   'Number of observations n.': 1145.0,
#   'R2 ajustado': 0.5331020754679721,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c01b69c40>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Livro Publicado ou Organizado',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Outras Orientações Concluídas',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept           5.929152
#   qty_2014            1.109965
#   porcent_pagos   -2520.712925
#   dtype: float64,
#   'P>|t|': Intercept        1.231782e-73
#   qty_2014         0.000000e+00
#   porcent_pagos    6.406338e-03
#   dtype: float64,
#   'Standard Error': Intercept          0.315505
#   qty_2014           0.019249
#   porcent_pagos    923.808327
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000734 -0.000017      -1.233681
#   qty_2014       -0.000017  0.000003       0.014896
#   porcent_pagos  -1.233681  0.014896    6296.042355,
#   'Number of observations n.': 2414.0,
#   'R2 ajustado': 0.5856161412763607,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c01b7a130>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Outras Orientações Concluídas',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Participação em Congresso',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept          1.254699
#   qty_2014           1.179327
#   porcent_pagos    593.438432
#   dtype: float64,
#   'P>|t|': Intercept        1.737064e-57
#   qty_2014         0.000000e+00
#   porcent_pagos    4.547373e-04
#   dtype: float64,
#   'Standard Error': Intercept          0.077256
#   qty_2014           0.010284
#   porcent_pagos    169.118354
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000635 -0.000053      -0.660717
#   qty_2014       -0.000053  0.000011       0.005536
#   porcent_pagos  -0.660717  0.005536    3041.587391,
#   'Number of observations n.': 3996.0,
#   'R2 ajustado': 0.7669599153520335,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c01b42340>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Participação em Congresso',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Participação em Seminário',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept    0.592785
#   qty_2014     1.154962
#   dtype: float64,
#   'P>|t|': Intercept    4.437267e-24
#   qty_2014     0.000000e+00
#   dtype: float64,
#   'Standard Error': Intercept    0.058068
#   qty_2014     0.011017
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept    0.00062 -0.000080
#   qty_2014    -0.00008  0.000022,
#   'Number of observations n.': 3031.0,
#   'R2 ajustado': 0.783860327291201,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c01b5bb50>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Participação em Seminário',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Participação em Simpósio',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept    0.777732
#   qty_2014     1.093501
#   dtype: float64,
#   'P>|t|': Intercept    9.211514e-84
#   qty_2014     0.000000e+00
#   dtype: float64,
#   'Standard Error': Intercept    0.038888
#   qty_2014     0.010561
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.000625 -0.000118
#   qty_2014   -0.000118  0.000046,
#   'Number of observations n.': 3085.0,
#   'R2 ajustado': 0.7765898765518946,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c01577a00>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Participação em Simpósio',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Prêmio ou Título Recebido',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept    0.898079
#   qty_2014     1.180665
#   dtype: float64,
#   'P>|t|': Intercept    3.927727e-59
#   qty_2014     0.000000e+00
#   dtype: float64,
#   'Standard Error': Intercept    0.053931
#   qty_2014     0.016968
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.000661 -0.000131
#   qty_2014   -0.000131  0.000065,
#   'Number of observations n.': 2505.0,
#   'R2 ajustado': 0.6590632487456951,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c01577b80>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Prêmio ou Título Recebido',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Conclusão de Outra Formação Complementar',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept    0.506615
#   qty_2014     1.101261
#   dtype: float64,
#   'P>|t|': Intercept    9.516530e-26
#   qty_2014     0.000000e+00
#   dtype: float64,
#   'Standard Error': Intercept    0.047726
#   qty_2014     0.009211
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.000618 -0.000067
#   qty_2014   -0.000067  0.000023,
#   'Number of observations n.': 2370.0,
#   'R2 ajustado': 0.8578289064762505,
# ...
#   dtype: float64,
#   'Covariância entre os pasrâmetros':           qty_2014
#   qty_2014  0.000004,
#   'Number of observations n.': 66.0,
#   'R2 ajustado': 0.9707738396767482,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c609a1c40>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Música',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Desenvolvimento de Marca',
#   'Erro': False,
#   'Prob (F-statistic)': 0.007283035221840664,
#   'Parâmetros': Intercept    0.897059
#   qty_2014     0.382353
#   dtype: float64,
#   'P>|t|': Intercept    8.451825e-09
#   qty_2014     7.283035e-03
#   dtype: float64,
#   'Standard Error': Intercept    0.089385
#   qty_2014     0.126410
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.073529 -0.058824
#   qty_2014   -0.058824  0.147059,
#   'Number of observations n.': 20.0,
#   'R2 ajustado': 0.30015509028470144,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c6f357850>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Desenvolvimento de Marca',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Produção Técnica - Produto Tecnológico',
#   'Erro': False,
#   'Prob (F-statistic)': 6.50518083106166e-11,
#   'Parâmetros': Intercept    0.994303
#   qty_2014     0.887348
#   dtype: float64,
#   'P>|t|': Intercept    1.024551e-03
#   qty_2014     6.505181e-11
#   dtype: float64,
#   'Standard Error': Intercept    0.292342
#   qty_2014     0.118781
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.015718 -0.003311
#   qty_2014   -0.003311  0.002595,
#   'Number of observations n.': 87.0,
#   'R2 ajustado': 0.3892392159599587,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c6b89c040>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Produção Técnica - Produto Tecnológico',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Orientação em Andamento de Pós-Doutorado',
#   'Erro': True,
#   'Prob (F-statistic)': None,
#   'Parâmetros': None,
#   'P>|t|': None,
#   'Standard Error': None,
#   'Covariância entre os pasrâmetros': None,
#   'Number of observations n.': None,
#   'R2 ajustado': None,
#   'Modelo': None,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Orientação em Andamento de Pós-Doutorado',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Participação em Banca Julgadora para Professor Titular',
#   'Erro': False,
#   'Prob (F-statistic)': 1.9992815678861186e-33,
#   'Parâmetros': Intercept    0.993276
#   qty_2014     0.937555
#   dtype: float64,
#   'P>|t|': Intercept    9.357695e-06
#   qty_2014     1.999282e-33
#   dtype: float64,
#   'Standard Error': Intercept    0.208658
#   qty_2014     0.043810
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.018940 -0.002197
#   qty_2014   -0.002197  0.000835,
#   'Number of observations n.': 76.0,
#   'R2 ajustado': 0.8590175731508524,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c60989370>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Participação em Banca Julgadora para Professor Titular',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Produção de Carta, Mapa ou Similar',
#   'Erro': False,
#   'Prob (F-statistic)': 1.0902411606403089e-23,
#   'Parâmetros': qty_2014    1.385705
#   dtype: float64,
#   'P>|t|': qty_2014    1.090241e-23
#   dtype: float64,
#   'Standard Error': qty_2014    0.061099
#   dtype: float64,
#   'Covariância entre os pasrâmetros':           qty_2014
#   qty_2014  0.000337,
#   'Number of observations n.': 39.0,
#   'R2 ajustado': 0.929393991541789,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c60991070>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Produção de Carta, Mapa ou Similar',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Produção Técnica - Processos ou Técnicas',
#   'Erro': False,
#   'Prob (F-statistic)': 1.9217104239564634e-07,
#   'Parâmetros': Intercept    1.152078
#   qty_2014     0.737598
#   dtype: float64,
#   'P>|t|': Intercept    1.381254e-05
#   qty_2014     1.921710e-07
#   dtype: float64,
#   'Standard Error': Intercept    0.243666
#   qty_2014     0.125629
#   dtype: float64,
#   'Covariância entre os pasrâmetros':            Intercept  qty_2014
#   Intercept   0.022697 -0.006416
#   qty_2014   -0.006416  0.006033,
#   'Number of observations n.': 63.0,
#   'R2 ajustado': 0.3505896433568201,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c60987af0>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Produção Técnica - Processos ou Técnicas',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Produção  de Obra Musical',
#   'Erro': False,
#   'Prob (F-statistic)': 2.064308093929744e-24,
#   'Parâmetros': qty_2014    1.173347
#   dtype: float64,
#   'P>|t|': qty_2014    2.064308e-24
#   dtype: float64,
#   'Standard Error': qty_2014    0.039285
#   dtype: float64,
#   'Covariância entre os pasrâmetros':           qty_2014
#   qty_2014  0.000207,
#   'Number of observations n.': 32.0,
#   'R2 ajustado': 0.9653326306603469,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c6b889fa0>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Produção  de Obra Musical',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Publicação de Partitura Musical',
#   'Erro': False,
#   'Prob (F-statistic)': 3.051288612392426e-07,
#   'Parâmetros': qty_2014    1.205551
#   dtype: float64,
#   'P>|t|': qty_2014    3.051289e-07
#   dtype: float64,
#   'Standard Error': qty_2014    0.077989
#   dtype: float64,
#   'Covariância entre os pasrâmetros':           qty_2014
#   qty_2014  0.000402,
#   'Number of observations n.': 9.0,
#   'R2 ajustado': 0.9635554848986139,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c609bce80>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Publicação de Partitura Musical',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Maquete',
#   'Erro': False,
#   'Prob (F-statistic)': 1.1755761902317804e-05,
#   'Parâmetros': qty_2014    1.105263
#   dtype: float64,
#   'P>|t|': qty_2014    0.000012
#   dtype: float64,
#   'Standard Error': qty_2014    0.127721
#   dtype: float64,
#   'Covariância entre os pasrâmetros':           qty_2014
#   qty_2014  0.052632,
#   'Number of observations n.': 10.0,
#   'R2 ajustado': 0.8807917228969862,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c609b7730>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Maquete',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Participação em Banca Julgadora para Livre Docência',
#   'Erro': False,
#   'Prob (F-statistic)': 0.00013723151307164805,
#   'Parâmetros': qty_2014    1.329412
#   dtype: float64,
#   'P>|t|': qty_2014    0.000137
#   dtype: float64,
#   'Standard Error': qty_2014    0.233037
#   dtype: float64,
#   'Covariância entre os pasrâmetros':           qty_2014
#   qty_2014  0.003922,
#   'Number of observations n.': 12.0,
#   'R2 ajustado': 0.7244153563732141,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c5ec98d90>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Participação em Banca Julgadora para Livre Docência',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Obtenção do Título de Livre Docência',
#   'Erro': True,
#   'Prob (F-statistic)': None,
#   'Parâmetros': None,
#   'P>|t|': None,
#   'Standard Error': None,
#   'Covariância entre os pasrâmetros': None,
#   'Number of observations n.': None,
#   'R2 ajustado': None,
#   'Modelo': None,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Obtenção do Título de Livre Docência',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Orientação Concluída de Pós-Doutorado',
#   'Erro': True,
#   'Prob (F-statistic)': None,
#   'Parâmetros': None,
#   'P>|t|': None,
#   'Standard Error': None,
#   'Covariância entre os pasrâmetros': None,
#   'Number of observations n.': None,
#   'R2 ajustado': None,
#   'Modelo': None,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Orientação Concluída de Pós-Doutorado',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Solicitação de Cultivar Registrada',
#   'Erro': True,
#   'Prob (F-statistic)': None,
#   'Parâmetros': None,
#   'P>|t|': None,
#   'Standard Error': None,
#   'Covariância entre os pasrâmetros': None,
#   'Number of observations n.': None,
#   'R2 ajustado': None,
#   'Modelo': None,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Solicitação de Cultivar Registrada',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Manutenção de Obra Artística',
#   'Erro': False,
#   'Prob (F-statistic)': 1.5331185768011307e-18,
#   'Parâmetros': qty_2014    1.043449
#   dtype: float64,
#   'P>|t|': qty_2014    1.533119e-18
#   dtype: float64,
#   'Standard Error': qty_2014    0.011182
#   dtype: float64,
#   'Covariância entre os pasrâmetros':           qty_2014
#   qty_2014  0.000066,
#   'Number of observations n.': 13.0,
#   'R2 ajustado': 0.9985091635208413,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x26c6099e100>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Manutenção de Obra Artística',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Outras participações em Banca',
#   'Erro': True,
#   'Prob (F-statistic)': None,
#   'Parâmetros': None,
#   'P>|t|': None,
#   'Standard Error': None,
#   'Covariância entre os pasrâmetros': None,
#   'Number of observations n.': None,
#   'R2 ajustado': None,
#   'Modelo': None,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Outras participações em Banca',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Desenvolvimento de Desenho Industrial',
#   'Erro': True,
#   'Prob (F-statistic)': None,
#   'Parâmetros': None,
#   'P>|t|': None,
#   'Standard Error': None,
#   'Covariância entre os pasrâmetros': None,
#   'Number of observations n.': None,
#   'R2 ajustado': None,
#   'Modelo': None,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Desenvolvimento de Desenho Industrial',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Solicitação de Cultivar protegida',
#   'Erro': True,
#   'Prob (F-statistic)': None,
#   'Parâmetros': None,
#   'P>|t|': None,
#   'Standard Error': None,
#   'Covariância entre os pasrâmetros': None,
#   'Number of observations n.': None,
#   'R2 ajustado': None,
#   'Modelo': None,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Solicitação de Cultivar protegida',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Obtenção do Título de MBA',
#   'Erro': True,
#   'Prob (F-statistic)': None,
#   'Parâmetros': None,
#   'P>|t|': None,
#   'Standard Error': None,
#   'Covariância entre os pasrâmetros': None,
#   'Number of observations n.': None,
#   'R2 ajustado': None,
#   'Modelo': None,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Obtenção do Título de MBA',
#    'ano_início': 2014,
#    'best_r2': True,
#    'pareamento': True,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}}]

# %%
reg.salva_regressões_csv()
