# %%
from datetime import datetime

print('Início em: ', datetime.now())
print('Importações Iniciais')

from Regressao import Regressao
reg = Regressao()

print('Fim: ', datetime.now())
# Out:
# Início em:  2023-04-30 09:50:16.209383
# Importações Iniciais
# Fim:  2023-04-30 09:50:25.633064

# %%
reg.path = ''
reg.variável_dependente = 'qty_2019'
reg.variáveis_independentes = ['qty_2013', 'C(grupo)']
reg.confianças = [0.01, 0.05]
reg.indicador = 'Artigo Publicado'
reg.ano_início = 2013
reg.best_r2 = True
reg.pareamento = True
reg.capes = True
reg.cnpq = True
reg.nenhum = True
reg.ambos = False
reg.preenche_todos_ids = False
reg.verbose = False
reg.drop_not_significant = True

#reg.faz_apenas_os_indicadores = ['Conclusão de Ensino Médio']

# %%
Regressao.pd = reg.pega_tabela_para_regressão()
# Out:
# Carregando indicadores na memória. Início em:  2023-04-30 09:50:25.735988
# Fim em:  2023-04-30 09:51:26.046511

# %% [markdown]
# dados = reg.pd.loc[reg.pd.nome == reg.indicador]
# reg.variáveis_independentes = ['porcent_pagos']
# reg.regressão(dt=dados)

# %%
reg.faz_regressões()
# Out:
# Iniciado em 2023-04-26 18:13:08.299927.
# 0/128. Fazendo: Prêmio ou Título Recebido.
# 1/128. 0.8% feitos. Fazendo: Conclusão de Curso Técnico/Profissionalizante. Acabará em 26/04/23 18:13:47. O Último demorou: 0:00:00.264004.
# 2/128. 1.6% feitos. Fazendo: Conclusão de Doutorado. Acabará em 26/04/23 18:13:44. O Último demorou: 0:00:00.253999.
# 3/128. 2.3% feitos. Fazendo: Conclusão de Curso de Curta Duração. Acabará em 26/04/23 18:13:46. O Último demorou: 0:00:00.330996.
# 4/128. 3.1% feitos. Fazendo: Conclusão de Extensão Universitária. Acabará em 26/04/23 18:13:45. O Último demorou: 0:00:00.259634.
# 5/128. 3.9% feitos. Fazendo: Conclusão de Graduação. Acabará em 26/04/23 18:13:42. O Último demorou: 0:00:00.189367.
# 6/128. 4.7% feitos. Fazendo: Conclusão de Mestrado. Acabará em 26/04/23 18:13:42. O Último demorou: 0:00:00.232999.
# 7/128. 5.5% feitos. Fazendo: Conclusão de Outra Formação Complementar. Acabará em 26/04/23 18:13:40. O Último demorou: 0:00:00.180001.
# ...

# %%
reg.salva_regressões_csv()
