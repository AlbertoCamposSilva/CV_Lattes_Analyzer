# %%
print('Inicializando Variáveis do Programa')

ano_início = 2014
ano_fim = 2020
confiança = 0.01
# Out:
# Inicializando Variáveis do Programa

# %%
from datetime import datetime
print('Início em: ', datetime.now())

print('Importações Iniciais')

from tkinter import NONE
from Lattes import Lattes
from Carga import Carga
from Database import Database
import psycopg2, pickle
import pandas, os, math
import statsmodels.api as sm
from urllib.parse import urlencode
from psycopg2.extensions import AsIs
from Carga import Carga
from pandas import pandas as pd
import numpy as np
import Database
import json
import locale
import pylab
from scipy import stats
from scipy.stats import norm, skewnorm, shapiro, kstest
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

print('Fim: ', datetime.now())
# Out:
# Início em:  2023-04-21 15:56:58.151521
# Importações Iniciais
# Fim:  2023-04-21 15:57:02.607905

# %%
#Carregar arquivo na memória
print('Carregando indicadores na memória. Início em: ', datetime.now())

db = Database.Database('CNPq')
engine = Carga.db_engine()
dt = pd.read_sql('''
select * from financiamentos_doutorandos_2014
inner join indicadores_doutorado
on indicadores_doutorado.id = financiamentos_doutorandos_2014.id
''', engine)
print(f'dt.size: {dt.size}')

print('Término em: ', datetime.now())
# Out:
# Carregando indicadores na memória. Início em:  2023-04-21 15:57:02.620873
# dt.size: 12911456
# Término em:  2023-04-21 15:57:11.634480

# %%
## Normalizando as Tabelas

print('Realizando normalização da tabela. Início em: ', datetime.now())

dt['bool_cnpq'] = dt['pagtos'].map(lambda pagtos: 1 if pagtos > 0 else 0)
dt['bool_capes'] = dt['capes'].map(lambda capes: 1 if capes == True else 0)
dt['const'] = 1
dt = dt.loc[:,~dt.columns.duplicated()]


#Preenchendo Nan com zeros nos indicadores
dt.qty_2012 = dt.qty_2012.fillna(0)
dt.qty_2013 = dt.qty_2013.fillna(0)
dt.qty_2014 = dt.qty_2014.fillna(0)
dt.qty_2015 = dt.qty_2015.fillna(0)
dt.qty_2016 = dt.qty_2016.fillna(0)
dt.qty_2017 = dt.qty_2017.fillna(0)
dt.qty_2018 = dt.qty_2018.fillna(0)
dt.qty_2019 = dt.qty_2019.fillna(0)
dt.capes = dt.capes.fillna(0)
dt.pagtos = dt.pagtos.fillna(0)
dt.bool_cnpq = dt.bool_cnpq.fillna(0)
dt.bool_capes = dt.bool_capes.fillna(0)

num_ids = len(dt.id.unique())

print('Fim em: ', datetime.now())
# Out:
# Realizando normalização da tabela. Início em:  2023-04-21 15:57:11.660288
# Fim em:  2023-04-21 15:57:12.606310

# %%
def regressão(X,y):
    try:
        # OLS vem de Ordinary Least Squares e o método fit irá treinar o modelo
        reg = sm.OLS(y, X).fit()
        # mostrando as estatísticas do modelo
        #reg.summary()
        
        
        
        #guardando a regressão na memória

        result = {
                'Indicador': indicador,
                'Erro': False,
                'Prob (F-statistic)':reg.f_pvalue, 
                'Parâmetros': reg.params, 
                "P>|t|":reg.pvalues, 
                'Standard Error': reg.bse, 
                "Covariância entre os pasrâmetros": reg.normalized_cov_params, 
                'Number of observations n.': reg.nobs, 
                "R2 ajustado": reg.rsquared_adj, 
                "Modelo":reg.model,
            }
    except:
        result = {
                'Indicador': indicador,
                'Erro': True,
                'Prob (F-statistic)':None, 
                'Parâmetros': None, 
                "P>|t|":None, 
                'Standard Error': None, 
                "Covariância entre os pasrâmetros": None, 
                'Number of observations n.': None, 
                "R2 ajustado": None, 
                "Modelo": None,
            }
    return result

# %%
def regressão_com_confiança (X,y,confiança = 0.05): 
    result = regressão(X,y)
    #print(result)
    while result['Erro'] == False and result['P>|t|'].max() > confiança:
        X = X.drop(columns=result['P>|t|'].idxmax())
        result = regressão(X,y)
        #print(result)
    if result['Erro'] == False and result['Prob (F-statistic)'] < confiança and result['P>|t|'].max() < confiança:
        result['Confiança'] = confiança
        return result
    else:
        result['Confiança'] = 'Erro'
    return result

# %%
## inicializando variáveis
lista_regressões = []
tempo_início = datetime.now()
feitos = 0
print(f'Iniciado em {tempo_início}.')
Impacto = []

#pegando lista de todos os indicadores
todos_indicadores = dt.indicador_tipo.unique()

#iterando sobre cada indicador
número_total = len(todos_indicadores)
for indicador in todos_indicadores:
    
    #Realizando previsão de término
    if not feitos == 0:
        porcentagem_já_feita = (feitos/número_total)
        tempo_passado = datetime.now() - tempo_início
        tempo_por_id = tempo_passado / feitos
        tempo_restante = (número_total - feitos) * tempo_por_id
        tempo_em_que_vai_acabar = datetime.now() + tempo_restante
        print(f'{feitos}/{número_total}. {porcentagem_já_feita * 100}% feitos. Fazendo indicador: {indicador}. Acabará em {tempo_em_que_vai_acabar}. O Último demorou: {datetime.now() - tempo_último}.')
    else:
        print(f'{feitos}/{número_total}. Fazendo id: {indicador}.')
    feitos += 1
    tempo_último = datetime.now()

    #Realizando a regressão
    dados = dt.loc[dt.indicador_tipo==indicador]
    X = dados[['const','qty_2014', 'bool_cnpq','bool_capes']]
    y = dados[['qty_2019']]
    lista_confianças = (0.01, 0.05)
    for confiança in lista_confianças:
        result = regressão_com_confiança(X,y, confiança)
        if not result['Confiança'] == 'Erro':
            break

    
    if not result['Erro'] and not result['Confiança'] == 'Erro':
        if not 'bool_cnpq' in result['Parâmetros'] :
            result['Parâmetros']['bool_cnpq'] = 0
        if not 'bool_capes' in result['Parâmetros'] :
            result['Parâmetros']['bool_capes'] = 0
        if not 'const' in result['Parâmetros'] :
            result['Parâmetros']['const'] = 0   
        if not 'qty_2014' in result['Parâmetros'] :
            result['Parâmetros']['qty_2014'] = 0         

        temp = {
            'Indicador': indicador,
            'Tamanho Amostra:': len(dados),
            'R2 ajustado': result['R2 ajustado'],
            'Confiança': result['Confiança'],
            'alfa': result['Parâmetros']['const'],
            'qty_2014': result['Parâmetros']['qty_2014'],
            'amostra_qty_2014': len(dados.loc[dados.bool_capes == 0].loc[dados.bool_cnpq == 0]),
            'bool_capes': result['Parâmetros']['bool_capes'],
            'amostra_capes': len(dados.loc[dados.bool_capes == 1]),
            'Impacto CAPES': result['Parâmetros']['bool_capes'] * len(dados.loc[dados.bool_capes == 1]),
            'bool_cnpq': result['Parâmetros']['bool_cnpq'],
            'amostra_cnpq': len(dados.loc[dados.bool_cnpq == 1]),
            'Impacto CNPq': result['Parâmetros']['bool_cnpq'] * len(dados.loc[dados.bool_cnpq == 1]),
            }
        Impacto.append(temp)
  
    lista_regressões.append(result)
# Out:
# Iniciado em 2023-04-21 17:23:38.949824.
# 0/133. Fazendo id: @ANO-DA-PREMIACAO PREMIO-TITULO .
# 1/133. 0.7518796992481203% feitos. Fazendo indicador: @ANO-DE-CONCLUSA
anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1804: RuntimeWarning: divide by zero encountered in double_scalars
#   return self.mse_model/self.mse_resid
# 122/133. 91.72932330827066% feitos. Fazendo indicador: @ANO BANCA-JULGADORA-PARA-LIVRE-DOCENCIA . Acabará em 2023-04-21 17:23:58.034734. O Último demorou: 0:00:00.111003.
# 123/133. 92.4812030075188% feitos. Fazendo indicador: @ANO-DA-OBRA DETALHAMENTO-DE-MANUTENCAO-DE-OBRA-ARTISTICA . Acabará em 2023-04-21 17:23:57.986617. O Último demorou: 0:00:00.098999.
# 124/133. 93.23308270676691% feitos. Fazendo indicador: @ANO MANUTENCAO-DE-OBRA-ARTISTICA . Acabará em 2023-04-21 17:23:57.957510. O Último demorou: 0:00:00.115998.
# 125/133. 93.98496240601504% feitos. Fazendo indicador: @ANO-SOLICITACAO CULTIVAR-PROTEGIDA . Acabará em 2023-04-21 17:23:57.910791. O Último demorou: 0:00:00.098005.
# 126/133. 94.73684210526315% feitos. Fazendo indicador: @ANO MAQUETE . Acabará em 2023-04-21 17:23:57.856932. O Último demorou: 0:00:00.091540.
# 127/133. 95.48872180451127% feitos. Fazendo indicador: @ANO PARTITURA-MUSICAL . Acabará em 2023-04-21 17:23:57.841534. O Último demorou: 0:00:00.125539.
# 128/133. 96.2406015037594% feitos. Fazendo indicador: @ANO OUTRAS-PARTICIPACOES-EM-BANCA . Acabará em 2023-04-21 17:23:57.788499. O Último demorou: 0:00:00.091003.
# 129/133. 96.99248120300751% feitos. Fazendo indicador: @ANO CURSO-DE-CURTA-DURACAO . Acabará em 2023-04-21 17:23:57.747623. O Último demorou: 0:00:00.101996.
# 130/133. 97.74436090225564% feitos. Fazendo indicador: @ANO ORIENTACOES-CONCLUIDAS-PARA-POS-DOUTORADO . Acabará em 2023-04-21 17:23:57.683859. O Último demorou: 0:00:00.079013.
# 131/133. 98.49624060150376% feitos. Fazendo indicador: @ANO-DE-OBTENCAO-DO-TITULO LIVRE-DOCENCIA . Acabará em 2023-04-21 17:23:57.620041. O Último demorou: 0:00:00.077997.
# 132/133. 99.24812030075188% feitos. Fazendo indicador: @ANO-DESENVOLVIMENTO TOPOGRAFIA-DE-CIRCUITO-INTEGRADO . Acabará em 2023-04-21 17:23:57.570424. O Último demorou: 0:00:00.091134.
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1728: RuntimeWarning: invalid value encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1728: RuntimeWarning: invalid value encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss

# %%
'bool_cnpq' in result['Parâmetros'] and result['Parâmetros']['bool_cnpq'] > 0
# Out:
# False

# %%
with open('Regressões dos Doutorandos 2014 com CAPES e CNPq.pickle', 'wb') as f:
   pickle.dump(lista_regressões, f)

# %%
regressões = pd.DataFrame(lista_regressões)

# %%
regressões = pd.concat([regressões, regressões['Parâmetros'].apply(pd.Series), regressões['P>|t|'].apply(pd.Series), regressões['Standard Error'].apply(pd.Series)], axis=1)

# %%
regressões.to_excel('Regressões dos Doutorandos 2014 com CAPES e CNPq.xlsx')

# %%
valor_total_cnpq =  dt[['id', 'pagtos']].loc[dt['pagtos']>0].drop_duplicates().sum().pagtos

# %%
impacto = pd.DataFrame(Impacto)
impacto.to_excel('Impacto dos Doutorandos 2014 com CAPES e CNPq.xlsx')

# %%
Impacto
# Out:
# [{'Indicador': '@ANO-DA-PREMIACAO PREMIO-TITULO ',
#   'Tamanho Amostra:': 11803,
#   'R2 ajustado': 0.7430071221948016,
#   'Confiança': 0.01,
#   'alfa': 0.9583460365480547,
#   'qty_2014': 1.1546906407468522,
#   'bool_capes': 0.15119187979772208,
#   'amostra_capes': 4725,
#   'Impacto CAPES': 714.3816320442369,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 1620,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-CONCLUSAO DOUTORADO ',
#   'Tamanho Amostra:': 20342,
#   'R2 ajustado': 0.005364984093886416,
#   'Confiança': 0.01,
#   'alfa': 0.9768634001284979,
#   'qty_2014': 0.3333427739627717,
#   'bool_capes': 0.02072608423101608,
#   'amostra_capes': 8459,
#   'Impacto CAPES': 175.32194651016502,
#   'bool_cnpq': 0.019494896091660763,
#   'amostra_cnpq': 2701,
#   'Impacto CNPq': 52.655714343575724},
#  {'Indicador': '@ANO-DE-CONCLUSAO ESPECIALIZACAO ',
#   'Tamanho Amostra:': 8760,
#   'R2 ajustado': 0.7457703544100749,
#   'Confiança': 0.01,
#   'alfa': 0.28489074297137124,
#   'qty_2014': 0.9179307691635472,
#   'bool_capes': 0.0,
#   'amostra_capes': 2911,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 602,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-CONCLUSAO GRADUACAO ',
#   'Tamanho Amostra:': 20959,
#   'R2 ajustado': 0.8273780502669379,
#   'Confiança': 0.01,
#   'alfa': 0.011699546674458546,
#   'qty_2014': 1.0192347020503523,
#   'bool_capes': 0.01356771475022995,
#   'amostra_capes': 8595,
#   'Impacto CAPES': 116.61450827822641,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 2771,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-CONCLUSAO MESTRADO ',
#   'Tamanho Amostra:': 19984,
#   'R2 ajustado': 0.6595575831953584,
#   'Confiança': 0.01,
#   'alfa': 0.22219137283162552,
#   'qty_2014': 0.7903424625112789,
#   'bool_capes': -0.005826535220276781,
#   'amostra_capes': 8329,
#   'Impacto CAPES': -48.52921184968531,
#   'bool_cnpq': -0.0046348605187956134,
#   'amostra_cnpq': 2690,
#   'Impacto CNPq': -12.4677747955602},
#  {'Indicador': '@ANO-DE-INICIO DOUTORADO ',
#   'Tamanho Amostra:': 21250,
#   'R2 ajustado': 0.9756665960618359,
#   'Confiança': 0.01,
#   'alfa': 0.0,
#   'qty_2014': 1.0240020786644675,
#   'bool_capes': 0.0,
#   'amostra_capes': 8647,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.01122370543592487,
#   'amostra_cnpq': 2790,
#   'Impacto CNPq': 31.314138166230386},
#  {'Indicador': '@ANO-DE-INICIO ESPECIALIZACAO ',
#   'Tamanho Amostra:': 9172,
#   'R2 ajustado': 0.7358842331002157,
#   'Confiança': 0.01,
#   'alfa': 0.30511400789776144,
#   'qty_2014': 0.9248389138810937,
#   'bool_capes': 0.0,
#   'amostra_capes': 3112,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 654,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-INICIO GRADUACAO ',
#   'Tamanho Amostra:': 20992,
#   'R2 ajustado': 0.9694960534004788,
#   'Confiança': 0.01,
#   'alfa': 0.0,
#   'qty_2014': 1.0361806844306936,
#   'bool_capes': 0.015908744940610835,
#   'amostra_capes': 8611,
#   'Impacto CAPES': 136.9902026835999,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 2779,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-INICIO MESTRADO ',
#   'Tamanho Amostra:': 20041,
#   'R2 ajustado': 0.8369828381622739,
#   'Confiança': 0.01,
#   'alfa': 0.05143051157577157,
#   'qty_2014': 0.9538855851955654,
#   'bool_capes': -0.002672989882525746,
#   'amostra_capes': 8351,
#   'Impacto CAPES': -22.322138508972504,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 2694,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-OBTENCAO-DO-TITULO DOUTORADO ',
#   'Tamanho Amostra:': 20045,
#   'R2 ajustado': 0.0022368717364252833,
#   'Confiança': 0.01,
#   'alfa': 0.9689684049646147,
#   'qty_2014': 0.2488564800253303,
#   'bool_capes': 0.022527122190695067,
#   'amostra_capes': 8398,
#   'Impacto CAPES': 189.18277215745718,
#   'bool_cnpq': 0.017048912899661362,
#   'amostra_cnpq': 2675,
#   'Impacto CNPq': 45.605842006594145},
#  {'Indicador': '@ANO-DE-OBTENCAO-DO-TITULO MESTRADO ',
#   'Tamanho Amostra:': 19971,
#   'R2 ajustado': 0.5086154326712176,
#   'Confiança': 0.01,
#   'alfa': 0.38776334629175724,
#   'qty_2014': 0.6261182955180389,
#   'bool_capes': -0.004718556609242047,
#   'amostra_capes': 8333,
#   'Impacto CAPES': -39.319732224813976,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 2686,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-REALIZACAO DETALHAMENTO-DO-TRABALHO ',
#   'Tamanho Amostra:': 18582,
#   'R2 ajustado': 0.8127963836090566,
#   'Confiança': 0.01,
#   'alfa': 2.633312175083169,
#   'qty_2014': 1.2998543202688682,
#   'bool_capes': 0.598016343189757,
#   'amostra_capes': 7810,
#   'Impacto CAPES': 4670.507640312003,
#   'bool_cnpq': 0.5458897365133026,
#   'amostra_cnpq': 2452,
#   'Impacto CNPq': 1338.521633930618},
#  {'Indicador': '@ANO-DO-ARTIGO ARTIGO-PUBLICADO ',
#   'Tamanho Amostra:': 19536,
#   'R2 ajustado': 0.5896439520695183,
#   'Confiança': 0.01,
#   'alfa': 2.6250679691126253,
#   'qty_2014': 1.5354971630601195,
#   'bool_capes': 1.2817252459446844,
#   'amostra_capes': 8196,
#   'Impacto CAPES': 10505.020115762632,
#   'bool_cnpq': 1.5299519277011477,
#   'amostra_cnpq': 2660,
#   'Impacto CNPq': 4069.672127685053},
#  {'Indicador': '@ANO-DO-TRABALHO TRABALHO-EM-EVENTOS ',
#   'Tamanho Amostra:': 18617,
#   'R2 ajustado': 0.8143413384069209,
#   'Confiança': 0.01,
#   'alfa': 2.6770935310661557,
#   'qty_2014': 1.2995036971339862,
#   'bool_capes': 0.6340948254290744,
#   'amostra_capes': 7827,
#   'Impacto CAPES': 4963.060198633365,
#   'bool_cnpq': 0.616647412972521,
#   'amostra_cnpq': 2456,
#   'Impacto CNPq': 1514.4860462605116},
#  {'Indicador': '@ANO-FIM DIRECAO-E-ADMINISTRACAO ',
#   'Tamanho Amostra:': 3401,
#   'R2 ajustado': 0.7300877410500132,
#   'Confiança': 0.01,
#   'alfa': 0.5695480881763134,
#   'qty_2014': 1.0024754964515277,
#   'bool_capes': 0.0,
#   'amostra_capes': 978,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 229,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-FIM ENSINO ',
#   'Tamanho Amostra:': 8253,
#   'R2 ajustado': 0.7951931997320963,
#   'Confiança': 0.01,
#   'alfa': 1.543720630300637,
#   'qty_2014': 1.2259703687626708,
#   'bool_capes': 1.1110453895757335,
#   'amostra_capes': 3107,
#   'Impacto CAPES': 3452.018025411804,
#   'bool_cnpq': 1.1572100432677632,
#   'amostra_cnpq': 933,
#   'Impacto CNPq': 1079.676970368823},
#  {'Indicador': '@ANO-FIM EXTENSAO-UNIVERSITARIA ',
#   'Tamanho Amostra:': 2711,
#   'R2 ajustado': 0.7987054797047922,
#   'Confiança': 0.01,
#   'alfa': 0.42082553904053577,
#   'qty_2014': 1.0514748874931272,
#   'bool_capes': 0.0,
#   'amostra_capes': 1017,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 295,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-FIM SERVICO-TECNICO-ESPECIALIZADO ',
#   'Tamanho Amostra:': 2387,
#   'R2 ajustado': 0.9693454651187065,
#   'Confiança': 0.01,
#   'alfa': 0.18839744307974932,
#   'qty_2014': 1.0070804660272683,
#   'bool_capes': 0.08774982593576262,
#   'amostra_capes': 698,
#   'Impacto CAPES': 61.24937850316231,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 178,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-FIM TREINAMENTO-MINISTRADO ',
#   'Tamanho Amostra:': 775,
#   'R2 ajustado': 0.8848403525174647,
#   'Confiança': 0.01,
#   'alfa': 0.29794854431208884,
#   'qty_2014': 0.9699087504615224,
#   'bool_capes': 0.0,
#   'amostra_capes': 247,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 52,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-FIM VINCULOS ',
#   'Tamanho Amostra:': 20386,
#   'R2 ajustado': 0.8027231198584404,
#   'Confiança': 0.01,
#   'alfa': 0.9539461644785279,
#   'qty_2014': 1.1897753710544894,
#   'bool_capes': 0.5827046950551223,
#   'amostra_capes': 8430,
#   'Impacto CAPES': 4912.200579314682,
#   'bool_cnpq': 0.48072792250705887,
#   'amostra_cnpq': 2684,
#   'Impacto CNPq': 1290.273744008946},
#  {'Indicador': '@ANO-INICIO DIRECAO-E-ADMINISTRACAO ',
#   'Tamanho Amostra:': 4357,
#   'R2 ajustado': 0.7880597557018448,
#   'Confiança': 0.01,
#   'alfa': 0.6703807789852495,
#   'qty_2014': 0.9921156325172853,
#   'bool_capes': 0.15945145594943905,
#   'amostra_capes': 1290,
#   'Impacto CAPES': 205.69237817477637,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 345,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-INICIO ENSINO ',
#   'Tamanho Amostra:': 9606,
#   'R2 ajustado': 0.7926422759376435,
#   'Confiança': 0.01,
#   'alfa': 1.4952623126249658,
#   'qty_2014': 1.2112583747446017,
#   'bool_capes': 1.4215808267329197,
#   'amostra_capes': 3532,
#   'Impacto CAPES': 5021.023480020673,
#   'bool_cnpq': 1.3418334432302275,
#   'amostra_cnpq': 1071,
#   'Impacto CNPq': 1437.1036176995735},
#  {'Indicador': '@ANO-INICIO EXTENSAO-UNIVERSITARIA ',
#   'Tamanho Amostra:': 3251,
#   'R2 ajustado': 0.798509592299989,
#   'Confiança': 0.01,
#   'alfa': 0.5038556912966666,
#   'qty_2014': 1.0415256698581339,
#   'bool_capes': 0.0,
#   'amostra_capes': 1216,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 341,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-INICIO SERVICO-TECNICO-ESPECIALIZADO ',
#   'Tamanho Amostra:': 2790,
#   'R2 ajustado': 0.9699863491314742,
#   'Confiança': 0.01,
#   'alfa': 0.16009216087484013,
#   'qty_2014': 1.0068662376870536,
#   'bool_capes': 0.09785382126993919,
#   'amostra_capes': 800,
#   'Impacto CAPES': 78.28305701595136,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 197,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-INICIO TREINAMENTO-MINISTRADO ',
#   'Tamanho Amostra:': 874,
#   'R2 ajustado': 0.8930696926185993,
#   'Confiança': 0.01,
#   'alfa': 0.29942081559219813,
#   'qty_2014': 0.9692201056715668,
#   'bool_capes': 0.0,
#   'amostra_capes': 274,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 56,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-INICIO VINCULOS ',
#   'Tamanho Amostra:': 21036,
#   'R2 ajustado': 0.7519341978632261,
#   'Confiança': 0.01,
#   'alfa': 0.8615258420927594,
#   'qty_2014': 1.2632738661349139,
#   'bool_capes': 1.071440275356256,
#   'amostra_capes': 8576,
#   'Impacto CAPES': 9188.671801455252,
#   'bool_cnpq': 1.2232288703845007,
#   'amostra_cnpq': 2745,
#   'Impacto CNPq': 3357.7632492054545},
#  {'Indicador': '@ANO APRESENTACAO-DE-TRABALHO ',
#   'Tamanho Amostra:': 19231,
#   'R2 ajustado': 0.7936107885892241,
#   'Confiança': 0.01,
#   'alfa': 2.685663574101211,
#   'qty_2014': 1.3153752282462152,
#   'bool_capes': 0.38569976567736763,
#   'amostra_capes': 7990,
#   'Impacto CAPES': 3081.7411277621673,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 2520,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO DEMAIS-TRABALHOS ',
#   'Tamanho Amostra:': 1258,
#   'R2 ajustado': 0.9915165727266722,
#   'Confiança': 0.01,
#   'alfa': 0.08392780980339332,
#   'qty_2014': 1.0038202327573602,
#   'bool_capes': 0.0,
#   'amostra_capes': 376,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.28438373901167485,
#   'amostra_cnpq': 74,
#   'Impacto CNPq': 21.04439668686394},
#  {'Indicador': '@ANO ORGANIZACAO-DE-EVENTO ',
#   'Tamanho Amostra:': 14546,
#   'R2 ajustado': 0.7948236237852305,
#   'Confiança': 0.01,
#   'alfa': 1.1112438323834786,
#   'qty_2014': 1.2471064487949983,
#   'bool_capes': 0.0,
#   'amostra_capes': 6069,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 1769,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO OUTRAS-ORIENTACOES-CONCLUIDAS ',
#   'Tamanho Amostra:': 12966,
#   'R2 ajustado': 0.7858313293431719,
#   'Confiança': 0.01,
#   'alfa': 5.949908749903953,
#   'qty_2014': 1.2295118046429052,
#   'bool_capes': -0.6209990346066645,
#   'amostra_capes': 4907,
#   'Impacto CAPES': -3047.242262814903,
#   'bool_cnpq': -1.1592823524272342,
#   'amostra_cnpq': 1419,
#   'Impacto CNPq': -1645.0216580942454},
#  {'Indicador': '@ANO PARTICIPACAO-EM-BANCA-DE-GRADUACAO ',
#   'Tamanho Amostra:': 13602,
#   'R2 ajustado': 0.7858715879981797,
#   'Confiança': 0.01,
#   'alfa': 5.586910243951985,
#   'qty_2014': 1.1985625826101105,
#   'bool_capes': -0.579731845374704,
#   'amostra_capes': 5528,
#   'Impacto CAPES': -3204.757641231364,
#   'bool_cnpq': -1.1613929822472746,
#   'amostra_cnpq': 1546,
#   'Impacto CNPq': -1795.5135505542864},
#  {'Indicador': '@ANO PARTICIPACAO-EM-CONGRESSO ',
#   'Tamanho Amostra:': 19113,
#   'R2 ajustado': 0.8392557005456517,
#   'Confiança': 0.01,
#   'alfa': 1.3822424619112665,
#   'qty_2014': 1.1927285066777105,
#   'bool_capes': 0.0,
#   'amostra_capes': 7953,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 2554,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO PARTICIPACAO-EM-ENCONTRO ',
#   'Tamanho Amostra:': 16606,
#   'R2 ajustado': 0.8758509986283505,
#   'Confiança': 0.01,
#   'alfa': 0.6879134587351794,
#   'qty_2014': 1.14721845702002,
#   'bool_capes': 0.0,
#   'amostra_capes': 6847,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 2064,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO PARTICIPACAO-EM-OFICINA ',
#   'Tamanho Amostra:': 8068,
#   'R2 ajustado': 0.8146670250867981,
#   'Confiança': 0.01,
#   'alfa': 0.5632564246539327,
#   'qty_2014': 1.031492968134133,
#   'bool_capes': 0.0,
#   'amostra_capes': 3164,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 890,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO PARTICIPACAO-EM-SEMINARIO ',
#   'Tamanho Amostra:': 15346,
#   'R2 ajustado': 0.8364918569516911,
#   'Confiança': 0.01,
#   'alfa': 0.5523755344628498,
#   'qty_2014': 1.2058197023849326,
#   'bool_capes': 0.0,
#   'amostra_capes': 6264,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 1831,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-CONCLUSAO FORMACAO-COMPLEMENTAR-CURSO-DE-CURTA-DURACAO ',
#   'Tamanho Amostra:': 16849,
#   'R2 ajustado': 0.8090745478332682,
#   'Confiança': 0.01,
#   'alfa': 1.3703526379967608,
#   'qty_2014': 1.1399703573338078,
#   'bool_capes': 0.0,
#   'amostra_capes': 7074,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 2155,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-INICIO FORMACAO-COMPLEMENTAR-CURSO-DE-CURTA-DURACAO ',
#   'Tamanho Amostra:': 16872,
#   'R2 ajustado': 0.8087996489291329,
#   'Confiança': 0.01,
#   'alfa': 1.3760876080450362,
#   'qty_2014': 1.1404238135539044,
#   'bool_capes': 0.0,
#   'amostra_capes': 7084,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 2157,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-INICIO POS-DOUTORADO ',
#   'Tamanho Amostra:': 4422,
#   'R2 ajustado': 0.018318558314224243,
#   'Confiança': 0.01,
#   'alfa': 0.8138885166117016,
#   'qty_2014': 0.49320731802375584,
#   'bool_capes': 0.09229786004610105,
#   'amostra_capes': 2282,
#   'Impacto CAPES': 210.6237166252026,
#   'bool_cnpq': 0.19793383558397792,
#   'amostra_cnpq': 967,
#   'Impacto CNPq': 191.40201900970666},
#  {'Indicador': '@ANO-FIM ESTAGIO ',
#   'Tamanho Amostra:': 4040,
#   'R2 ajustado': 0.8855686749734634,
#   'Confiança': 0.01,
#   'alfa': 0.1442782117245407,
#   'qty_2014': 1.0110133668848578,
#   'bool_capes': 0.17845553772900774,
#   'amostra_capes': 1716,
#   'Impacto CAPES': 306.2297027429773,
#   'bool_cnpq': 0.10237683160977955,
#   'amostra_cnpq': 561,
#   'Impacto CNPq': 57.43340253308633},
#  {'Indicador': '@ANO-FIM PESQUISA-E-DESENVOLVIMENTO ',
#   'Tamanho Amostra:': 3572,
#   'R2 ajustado': 0.7427522937439319,
#   'Confiança': 0.01,
#   'alfa': 0.5915933190920821,
#   'qty_2014': 0.9442540598563202,
#   'bool_capes': 0.14116872048957396,
#   'amostra_capes': 1548,
#   'Impacto CAPES': 218.5291793178605,
#   'bool_cnpq': 0.20338138264861094,
#   'amostra_cnpq': 513,
#   'Impacto CNPq': 104.33464929873742},
#  {'Indicador': '@ANO-INICIO ESTAGIO ',
#   'Tamanho Amostra:': 4207,
#   'R2 ajustado': 0.8865329732449284,
#   'Confiança': 0.01,
#   'alfa': 0.13583061501086258,
#   'qty_2014': 1.015078475413616,
#   'bool_capes': 0.17126688156334868,
#   'amostra_capes': 1779,
#   'Impacto CAPES': 304.6837823011973,
#   'bool_cnpq': 0.10918624117026718,
#   'amostra_cnpq': 575,
#   'Impacto CNPq': 62.782088672903626},
#  {'Indicador': '@ANO-INICIO PESQUISA-E-DESENVOLVIMENTO ',
#   'Tamanho Amostra:': 7220,
#   'R2 ajustado': 0.7508107034456928,
#   'Confiança': 0.01,
#   'alfa': 0.5322392172359336,
#   'qty_2014': 0.9619517434507592,
#   'bool_capes': 0.05416398891462712,
#   'amostra_capes': 2949,
#   'Impacto CAPES': 159.7296033092354,
#   'bool_cnpq': 0.08310416080683913,
#   'amostra_cnpq': 903,
#   'Impacto CNPq': 75.04305720857573},
#  {'Indicador': '@ANO CAPITULO-DE-LIVRO-PUBLICADO ',
#   'Tamanho Amostra:': 11642,
#   'R2 ajustado': 0.5299333341703016,
#   'Confiança': 0.01,
#   'alfa': 1.640138124461143,
#   'qty_2014': 1.3296625259189336,
#   'bool_capes': 0.0,
#   'amostra_capes': 4598,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 1322,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO LIVRO-PUBLICADO-OU-ORGANIZADO ',
#   'Tamanho Amostra:': 6362,
#   'R2 ajustado': 0.6764275350317417,
#   'Confiança': 0.01,
#   'alfa': 0.9240199172264154,
#   'qty_2014': 1.2930673764103329,
#   'bool_capes': 0.0,
#   'amostra_capes': 2303,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 588,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO PARTICIPACAO-EM-SIMPOSIO ',
#   'Tamanho Amostra:': 15140,
#   'R2 ajustado': 0.7991873208170401,
#   'Confiança': 0.01,
#   'alfa': 0.7771630687400869,
#   'qty_2014': 1.117601634542679,
#   'bool_capes': 0.0,
#   'amostra_capes': 6374,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 2030,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-CONCLUSAO OUTROS ',
#   'Tamanho Amostra:': 11616,
#   'R2 ajustado': 0.8463136343406946,
#   'Confiança': 0.01,
#   'alfa': 0.59752180025706,
#   'qty_2014': 1.097470056677179,
#   'bool_capes': 0.0,
#   'amostra_capes': 4819,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 1422,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-INICIO OUTROS ',
#   'Tamanho Amostra:': 11824,
#   'R2 ajustado': 0.8470159989536162,
#   'Confiança': 0.01,
#   'alfa': 0.5880564400661087,
#   'qty_2014': 1.097316993698499,
#   'bool_capes': 0.0,
#   'amostra_capes': 4901,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 1445,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO OUTRAS-PARTICIPACOES-EM-EVENTOS-CONGRESSOS ',
#   'Tamanho Amostra:': 16696,
#   'R2 ajustado': 0.8849138606824668,
#   'Confiança': 0.01,
#   'alfa': 0.6786376582949272,
#   'qty_2014': 1.17400114642948,
#   'bool_capes': 0.0,
#   'amostra_capes': 6960,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 2097,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-FIM PARTICIPACAO-EM-PROJETO ',
#   'Tamanho Amostra:': 15117,
#   'R2 ajustado': 0.7166530687653614,
#   'Confiança': 0.01,
#   'alfa': 1.1343049139662091,
#   'qty_2014': 1.1616206891489056,
#   'bool_capes': -0.09964996039762387,
#   'amostra_capes': 6392,
#   'Impacto CAPES': -636.9625468616118,
#   'bool_cnpq': -0.16926112482354028,
#   'amostra_cnpq': 2027,
#   'Impacto CNPq': -343.0923000173161},
#  {'Indicador': '@ANO-FIM PROJETO-DE-PESQUISA ',
#   'Tamanho Amostra:': 15093,
#   'R2 ajustado': 0.6571672538622342,
#   'Confiança': 0.01,
#   'alfa': 1.3486369192694503,
#   'qty_2014': 1.214556948442296,
#   'bool_capes': -0.1488195169672214,
#   'amostra_capes': 6385,
#   'Impacto CAPES': -950.2126158357087,
#   'bool_cnpq': -0.2639342718946091,
#   'amostra_cnpq': 2028,
#   'Impacto CNPq': -535.2587034022673},
#  {'Indicador': '@ANO-INICIO PARTICIPACAO-EM-PROJETO ',
#   'Tamanho Amostra:': 16942,
#   'R2 ajustado': 0.7749738178933889,
#   'Confiança': 0.01,
#   'alfa': 1.1003210974901034,
#   'qty_2014': 1.1854601297213359,
#   'bool_capes': -0.16368712114166417,
#   'amostra_capes': 7135,
#   'Impacto CAPES': -1167.9076093457738,
#   'bool_cnpq': -0.1485700489464924,
#   'amostra_cnpq': 2250,
#   'Impacto CNPq': -334.28261012960786},
#  {'Indicador': '@ANO-INICIO PROJETO-DE-PESQUISA ',
#   'Tamanho Amostra:': 16841,
#   'R2 ajustado': 0.6975752629943415,
#   'Confiança': 0.01,
#   'alfa': 1.3742809554785524,
#   'qty_2014': 1.251844818340997,
#   'bool_capes': -0.23135336647235077,
#   'amostra_capes': 7096,
#   'Impacto CAPES': -1641.683488487801,
#   'bool_cnpq': -0.23240555300163382,
#   'amostra_cnpq': 2240,
#   'Impacto CNPq': -520.5884387236598},
#  {'Indicador': '@ANO CURSO-DE-CURTA-DURACAO-MINISTRADO ',
#   'Tamanho Amostra:': 11227,
#   'R2 ajustado': 0.8301043141330136,
#   'Confiança': 0.01,
#   'alfa': 0.7304356482844723,
#   'qty_2014': 1.2642415427810663,
#   'bool_capes': 0.378848334387597,
#   'amostra_capes': 4409,
#   'Impacto CAPES': 1670.3423063149153,
#   'bool_cnpq': 0.37098890322251543,
#   'amostra_cnpq': 1269,
#   'Impacto CNPq': 470.7849181893721},
#  {'Indicador': '@ANO-DE-CONCLUSAO FORMACAO-COMPLEMENTAR-DE-EXTENSAO-UNIVERSITARIA ',
#   'Tamanho Amostra:': 9554,
#   'R2 ajustado': 0.8724728787239879,
#   'Confiança': 0.01,
#   'alfa': 0.2848146935075053,
#   'qty_2014': 1.0900320103221812,
#   'bool_capes': 0.0,
#   'amostra_capes': 3869,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 1089,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-INICIO FORMACAO-COMPLEMENTAR-DE-EXTENSAO-UNIVERSITARIA ',
#   'Tamanho Amostra:': 9640,
#   'R2 ajustado': 0.8741787893306917,
#   'Confiança': 0.01,
#   'alfa': 0.27863065391646885,
#   'qty_2014': 1.0905116704177384,
#   'bool_capes': 0.0,
#   'amostra_capes': 3913,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 1097,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO DESENVOLVIMENTO-DE-MATERIAL-DIDATICO-OU-INSTRUCIONAL ',
#   'Tamanho Amostra:': 4350,
#   'R2 ajustado': 0.7449288961014588,
#   'Confiança': 0.01,
#   'alfa': 0.974652634438816,
#   'qty_2014': 1.101388732475212,
#   'bool_capes': 0.0,
#   'amostra_capes': 1583,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 425,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO OUTRA-PRODUCAO-TECNICA ',
#   'Tamanho Amostra:': 4553,
#   'R2 ajustado': 0.8924381935988586,
#   'Confiança': 0.01,
#   'alfa': 1.260525340797035,
#   'qty_2014': 1.0710362075544702,
#   'bool_capes': 0.0,
#   'amostra_capes': 1732,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 436,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO OUTRAS-BANCAS-JULGADORAS ',
#   'Tamanho Amostra:': 7149,
#   'R2 ajustado': 0.581926490790378,
#   'Confiança': 0.01,
#   'alfa': 1.979929819893537,
#   'qty_2014': 1.174762519099801,
#   'bool_capes': 0.0,
#   'amostra_capes': 2714,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 761,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO PARTICIPACAO-EM-EXPOSICAO ',
#   'Tamanho Amostra:': 1515,
#   'R2 ajustado': 0.3864504603068055,
#   'Confiança': 0.01,
#   'alfa': 1.0367439379314605,
#   'qty_2014': 0.9471913315328176,
#   'bool_capes': 0.0,
#   'amostra_capes': 576,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 187,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO PREFACIO-POSFACIO ',
#   'Tamanho Amostra:': 981,
#   'R2 ajustado': 0.567191184791224,
#   'Confiança': 0.01,
#   'alfa': 0.7629838789757,
#   'qty_2014': 1.1295911203892506,
#   'bool_capes': 0.0,
#   'amostra_capes': 361,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 87,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO PROGRAMA-DE-RADIO-OU-TV ',
#   'Tamanho Amostra:': 5794,
#   'R2 ajustado': 0.6168390940092414,
#   'Confiança': 0.01,
#   'alfa': 1.4690894674945976,
#   'qty_2014': 1.2225614316607825,
#   'bool_capes': 0.0,
#   'amostra_capes': 2281,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 615,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-CONCLUSAO MBA ',
#   'Tamanho Amostra:': 182,
#   'R2 ajustado': 0.6423570856992378,
#   'Confiança': 0.01,
#   'alfa': 0.3900986730180336,
#   'qty_2014': 0.7048315753657708,
#   'bool_capes': 0.0,
#   'amostra_capes': 67,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 14,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-INICIO MBA ',
#   'Tamanho Amostra:': 230,
#   'R2 ajustado': 0.5479996315998144,
#   'Confiança': 0.01,
#   'alfa': 0.49722442505947645,
#   'qty_2014': 0.6231165741475021,
#   'bool_capes': 0.0,
#   'amostra_capes': 81,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 25,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO ORIENTACAO-EM-ANDAMENTO-DE-MESTRADO ',
#   'Tamanho Amostra:': 2261,
#   'R2 ajustado': 0.07326496035407104,
#   'Confiança': 0.01,
#   'alfa': 0.5037519583027054,
#   'qty_2014': 1.5105473934201061,
#   'bool_capes': 0.0,
#   'amostra_capes': 941,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 366,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO ORIENTACOES-CONCLUIDAS-PARA-MESTRADO ',
#   'Tamanho Amostra:': 2050,
#   'R2 ajustado': 0.8881175642335742,
#   'Confiança': 0.01,
#   'alfa': 1.0438884024272492,
#   'qty_2014': 2.0867763932635834,
#   'bool_capes': 0.0,
#   'amostra_capes': 863,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 327,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO PARTICIPACAO-EM-BANCA-DE-EXAME-QUALIFICACAO ',
#   'Tamanho Amostra:': 5401,
#   'R2 ajustado': 0.09806917131048876,
#   'Confiança': 0.01,
#   'alfa': 1.730054631039388,
#   'qty_2014': 1.8237671672977416,
#   'bool_capes': 0.0,
#   'amostra_capes': 2296,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 728,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO TRABALHO-TECNICO ',
#   'Tamanho Amostra:': 7113,
#   'R2 ajustado': 0.6295217604134764,
#   'Confiança': 0.01,
#   'alfa': 2.769364080338465,
#   'qty_2014': 1.192251371779258,
#   'bool_capes': 0.7746229065328523,
#   'amostra_capes': 2756,
#   'Impacto CAPES': 2134.860730404541,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 750,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO PARTICIPACAO-EM-BANCA-DE-APERFEICOAMENTO-ESPECIALIZACAO ',
#   'Tamanho Amostra:': 4917,
#   'R2 ajustado': 0.5817169940296916,
#   'Confiança': 0.01,
#   'alfa': 3.8286512219126356,
#   'qty_2014': 1.1123650803642162,
#   'bool_capes': 0.0,
#   'amostra_capes': 1654,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 392,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO MIDIA-SOCIAL-WEBSITE-BLOG ',
#   'Tamanho Amostra:': 2473,
#   'R2 ajustado': 0.4488560508574172,
#   'Confiança': 0.01,
#   'alfa': 0.9417756259117032,
#   'qty_2014': 1.3123527372693964,
#   'bool_capes': 0.0,
#   'amostra_capes': 1036,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 302,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO PARTICIPACAO-EM-BANCA-DE-MESTRADO ',
#   'Tamanho Amostra:': 6431,
#   'R2 ajustado': 0.11564530421310493,
#   'Confiança': 0.01,
#   'alfa': 1.398859174506736,
#   'qty_2014': 1.363006729580428,
#   'bool_capes': 0.0,
#   'amostra_capes': 2624,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 857,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-CONCLUSAO ENSINO-MEDIO-SEGUNDO-GRAU ',
#   'Tamanho Amostra:': 2095,
#   'R2 ajustado': 0.99273151238669,
#   'Confiança': 0.01,
#   'alfa': 0.008573193072054633,
#   'qty_2014': 0.9923288830909267,
#   'bool_capes': 0.0,
#   'amostra_capes': 906,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 313,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-INICIO ENSINO-MEDIO-SEGUNDO-GRAU ',
#   'Tamanho Amostra:': 2095,
#   'R2 ajustado': 0.9926723306687908,
#   'Confiança': 0.01,
#   'alfa': 0.008646500825473663,
#   'qty_2014': 0.9922629207823837,
#   'bool_capes': 0.0,
#   'amostra_capes': 905,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 313,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DO-ARTIGO ARTIGO-ACEITO-PARA-PUBLICACAO ',
#   'Tamanho Amostra:': 3943,
#   'R2 ajustado': 0.44142344358134333,
#   'Confiança': 0.01,
#   'alfa': 0.5017780478691858,
#   'qty_2014': 1.018200172360583,
#   'bool_capes': -0.0854813054533206,
#   'amostra_capes': 1614,
#   'Impacto CAPES': -137.96682700165945,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 474,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO BANCA-JULGADORA-PARA-CONCURSO-PUBLICO ',
#   'Tamanho Amostra:': 3377,
#   'R2 ajustado': 0.7569722476754497,
#   'Confiança': 0.01,
#   'alfa': 1.0067365186048707,
#   'qty_2014': 0.9985468820248053,
#   'bool_capes': 0.0,
#   'amostra_capes': 909,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 267,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO ORIENTACAO-EM-ANDAMENTO-DE-GRADUACAO ',
#   'Tamanho Amostra:': 2616,
#   'R2 ajustado': 0.3466228906204655,
#   'Confiança': 0.01,
#   'alfa': 0.8767989009547817,
#   'qty_2014': 0.9492490160662638,
#   'bool_capes': 0.0,
#   'amostra_capes': 932,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 279,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO OUTRA-PRODUCAO-BIBLIOGRAFICA ',
#   'Tamanho Amostra:': 5723,
#   'R2 ajustado': 0.7440356660608809,
#   'Confiança': 0.01,
#   'alfa': 0.8029694156863085,
#   'qty_2014': 1.0870346929441221,
#   'bool_capes': 0.0,
#   'amostra_capes': 2197,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 654,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO RELATORIO-DE-PESQUISA ',
#   'Tamanho Amostra:': 2447,
#   'R2 ajustado': 0.7024249894427347,
#   'Confiança': 0.01,
#   'alfa': 0.683094444811194,
#   'qty_2014': 0.996247801892491,
#   'bool_capes': 0.0,
#   'amostra_capes': 1010,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 330,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-FIM OUTRA-ATIVIDADE-TECNICO-CIENTIFICA ',
#   'Tamanho Amostra:': 2308,
#   'R2 ajustado': 0.8406849364005865,
#   'Confiança': 0.01,
#   'alfa': 0.26751796951940365,
#   'qty_2014': 1.1099950849963878,
#   'bool_capes': 0.0,
#   'amostra_capes': 846,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 249,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-INICIO OUTRA-ATIVIDADE-TECNICO-CIENTIFICA ',
#   'Tamanho Amostra:': 2829,
#   'R2 ajustado': 0.8431152002045623,
#   'Confiança': 0.01,
#   'alfa': 0.3003387496687295,
#   'qty_2014': 1.1001419206251741,
#   'bool_capes': 0.0,
#   'amostra_capes': 1026,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 299,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO TRADUCAO ',
#   'Tamanho Amostra:': 840,
#   'R2 ajustado': 0.5909478711629959,
#   'Confiança': 0.01,
#   'alfa': 0.8364738898116992,
#   'qty_2014': 1.1277025009923702,
#   'bool_capes': 0.0,
#   'amostra_capes': 375,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.8288997036401291,
#   'amostra_cnpq': 105,
#   'Impacto CNPq': 87.03446888221356},
#  {'Indicador': '@ANO-DE-CONCLUSAO CURSO-TECNICO-PROFISSIONALIZANTE ',
#   'Tamanho Amostra:': 1791,
#   'R2 ajustado': 0.8171684665781116,
#   'Confiança': 0.01,
#   'alfa': 0.1683638965392198,
#   'qty_2014': 0.8601280028227253,
#   'bool_capes': 0.0,
#   'amostra_capes': 695,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 235,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-INICIO CURSO-TECNICO-PROFISSIONALIZANTE ',
#   'Tamanho Amostra:': 1812,
#   'R2 ajustado': 0.8268251964543798,
#   'Confiança': 0.01,
#   'alfa': 0.17441233950064994,
#   'qty_2014': 0.8552446530656974,
#   'bool_capes': 0.0,
#   'amostra_capes': 706,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 238,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DO-TEXTO TEXTO-EM-JORNAL-OU-REVISTA ',
#   'Tamanho Amostra:': 5398,
#   'R2 ajustado': 0.732188217306472,
#   'Confiança': 0.01,
#   'alfa': 0.6882880403954252,
#   'qty_2014': 1.2518620364483404,
#   'bool_capes': 0.0,
#   'amostra_capes': 2015,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 589,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO ORIENTACOES-CONCLUIDAS-PARA-DOUTORADO ',
#   'Tamanho Amostra:': 331,
#   'R2 ajustado': 0.03217767547170014,
#   'Confiança': 0.01,
#   'alfa': 0.801169590643275,
#   'qty_2014': 0.0,
#   'bool_capes': -0.2824195906432747,
#   'amostra_capes': 160,
#   'Impacto CAPES': -45.18713450292395,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 56,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO ARTES-VISUAIS ',
#   'Tamanho Amostra:': 968,
#   'R2 ajustado': 0.9202874857200456,
#   'Confiança': 0.01,
#   'alfa': 0.7598268062819045,
#   'qty_2014': 1.2330892674777467,
#   'bool_capes': 0.0,
#   'amostra_capes': 396,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 110,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO OUTRA-PRODUCAO-ARTISTICA-CULTURAL ',
#   'Tamanho Amostra:': 1417,
#   'R2 ajustado': 0.9229220504397032,
#   'Confiança': 0.01,
#   'alfa': 0.0,
#   'qty_2014': 1.1810459284028318,
#   'bool_capes': 0.0,
#   'amostra_capes': 565,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 109,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-CONCLUSAO APERFEICOAMENTO ',
#   'Tamanho Amostra:': 1357,
#   'R2 ajustado': 0.9484039158880003,
#   'Confiança': 0.01,
#   'alfa': 0.23434732928633747,
#   'qty_2014': 0.9786075504217215,
#   'bool_capes': 0.0,
#   'amostra_capes': 440,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 98,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-INICIO APERFEICOAMENTO ',
#   'Tamanho Amostra:': 1411,
#   'R2 ajustado': 0.9410116688609041,
#   'Confiança': 0.01,
#   'alfa': 0.24947466497083481,
#   'qty_2014': 0.9782454464978023,
#   'bool_capes': 0.0,
#   'amostra_capes': 465,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 104,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO ORIENTACAO-EM-ANDAMENTO-DE-INICIACAO-CIENTIFICA ',
#   'Tamanho Amostra:': 2576,
#   'R2 ajustado': 0.20307273972075368,
#   'Confiança': 0.01,
#   'alfa': 0.5697811158575821,
#   'qty_2014': 1.0797990647780096,
#   'bool_capes': 0.0,
#   'amostra_capes': 1008,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 385,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-CONCLUSAO POS-DOUTORADO ',
#   'Tamanho Amostra:': 2302,
#   'R2 ajustado': 0.005845487644613678,
#   'Confiança': 0.01,
#   'alfa': 0.5152087662951053,
#   'qty_2014': 0.6565274891365963,
#   'bool_capes': 0.0,
#   'amostra_capes': 1195,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.07731459819087445,
#   'amostra_cnpq': 535,
#   'Impacto CNPq': 41.36331003211783},
#  {'Indicador': '@ANO OUTRAS-ORIENTACOES-EM-ANDAMENTO ',
#   'Tamanho Amostra:': 896,
#   'R2 ajustado': 0.5363414575456534,
#   'Confiança': 0.01,
#   'alfa': 0.797764001198306,
#   'qty_2014': 1.1293941964615581,
#   'bool_capes': 0.0,
#   'amostra_capes': 301,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 107,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO PROCESSOS-OU-TECNICAS ',
#   'Tamanho Amostra:': 402,
#   'R2 ajustado': 0.533053548196035,
#   'Confiança': 0.01,
#   'alfa': 1.172723797039707,
#   'qty_2014': 1.0174340488284446,
#   'bool_capes': 0.0,
#   'amostra_capes': 135,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 43,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-FIM CONSELHO-COMISSAO-E-CONSULTORIA ',
#   'Tamanho Amostra:': 3542,
#   'R2 ajustado': 0.7691824363720844,
#   'Confiança': 0.01,
#   'alfa': 1.141779666899147,
#   'qty_2014': 1.0721088548686368,
#   'bool_capes': 0.0,
#   'amostra_capes': 1188,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 336,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-INICIO CONSELHO-COMISSAO-E-CONSULTORIA ',
#   'Tamanho Amostra:': 4601,
#   'R2 ajustado': 0.7336690730325721,
#   'Confiança': 0.01,
#   'alfa': 1.473012665887698,
#   'qty_2014': 1.0883897684208772,
#   'bool_capes': 0.0,
#   'amostra_capes': 1568,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 454,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DESENVOLVIMENTO MARCA ',
#   'Tamanho Amostra:': 108,
#   'R2 ajustado': 0.9882149202984317,
#   'Confiança': 0.01,
#   'alfa': 0.5940247500170384,
#   'qty_2014': 1.0174087452656588,
#   'bool_capes': 0.0,
#   'amostra_capes': 38,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 14,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO PARTICIPACAO-EM-FEIRA ',
#   'Tamanho Amostra:': 1367,
#   'R2 ajustado': 0.37989264644917187,
#   'Confiança': 0.01,
#   'alfa': 1.053881481626175,
#   'qty_2014': 0.8699726757276778,
#   'bool_capes': 0.0,
#   'amostra_capes': 529,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 166,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO SOFTWARE ',
#   'Tamanho Amostra:': 1012,
#   'R2 ajustado': 0.8133275150845354,
#   'Confiança': 0.01,
#   'alfa': 0.6972959029867818,
#   'qty_2014': 1.0664438776964493,
#   'bool_capes': 0.0,
#   'amostra_capes': 375,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 154,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-CONCLUSAO ENSINO-FUNDAMENTAL-PRIMEIRO-GRAU ',
#   'Tamanho Amostra:': 1045,
#   'R2 ajustado': 1.0,
#   'Confiança': 0.01,
#   'alfa': -2.7755575615628914e-16,
#   'qty_2014': 1.0000000000000002,
#   'bool_capes': -3.2612801348363973e-16,
#   'amostra_capes': 406,
#   'Impacto CAPES': -1.3240797347435773e-13,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 126,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-INICIO ENSINO-FUNDAMENTAL-PRIMEIRO-GRAU ',
#   'Tamanho Amostra:': 1045,
#   'R2 ajustado': 1.0,
#   'Confiança': 0.01,
#   'alfa': 3.885780586188048e-16,
#   'qty_2014': 0.9999999999999998,
#   'bool_capes': -1.942890293094024e-16,
#   'amostra_capes': 406,
#   'Impacto CAPES': -7.888134589961737e-14,
#   'bool_cnpq': 8.326672684688674e-17,
#   'amostra_cnpq': 126,
#   'Impacto CNPq': 1.049160758270773e-14},
#  {'Indicador': '@ANO EDITORACAO ',
#   'Tamanho Amostra:': 1272,
#   'R2 ajustado': 0.7775636113495641,
#   'Confiança': 0.01,
#   'alfa': 0.8729655329664365,
#   'qty_2014': 1.2323877570827233,
#   'bool_capes': 0.0,
#   'amostra_capes': 493,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 147,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-CONCLUSAO MESTRADO-PROFISSIONALIZANTE ',
#   'Tamanho Amostra:': 487,
#   'R2 ajustado': 0.1497729641424026,
#   'Confiança': 0.01,
#   'alfa': 0.7889691398555491,
#   'qty_2014': 0.2200262639527254,
#   'bool_capes': 0.0,
#   'amostra_capes': 110,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 20,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-INICIO MESTRADO-PROFISSIONALIZANTE ',
#   'Tamanho Amostra:': 500,
#   'R2 ajustado': 0.2666514084785414,
#   'Confiança': 0.01,
#   'alfa': 0.6572901009233411,
#   'qty_2014': 0.3529453868728078,
#   'bool_capes': 0.0,
#   'amostra_capes': 112,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 21,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-OBTENCAO-DO-TITULO MESTRADO-PROFISSIONALIZANTE ',
#   'Tamanho Amostra:': 424,
#   'R2 ajustado': 0.2458452692069375,
#   'Confiança': 0.01,
#   'alfa': 0.725473395595921,
#   'qty_2014': 0.2842087224745101,
#   'bool_capes': 0.0,
#   'amostra_capes': 93,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 18,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO CARTA-MAPA-OU-SIMILAR ',
#   'Tamanho Amostra:': 253,
#   'R2 ajustado': 0.7546617709113523,
#   'Confiança': 0.01,
#   'alfa': 0.0,
#   'qty_2014': 1.2201155720896,
#   'bool_capes': 1.5299854108106283,
#   'amostra_capes': 118,
#   'Impacto CAPES': 180.53827847565415,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 27,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO BANCA-JULGADORA-PARA-AVALIACAO-CURSOS ',
#   'Tamanho Amostra:': 476,
#   'R2 ajustado': 0.766638929176471,
#   'Confiança': 0.01,
#   'alfa': 0.7282465622137699,
#   'qty_2014': 1.3948404394057958,
#   'bool_capes': 0.0,
#   'amostra_capes': 143,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 41,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO PRODUTO-TECNOLOGICO ',
#   'Tamanho Amostra:': 555,
#   'R2 ajustado': 0.9291896006408767,
#   'Confiança': 0.01,
#   'alfa': 0.6984578057992166,
#   'qty_2014': 1.0140875956018143,
#   'bool_capes': 0.0,
#   'amostra_capes': 182,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 56,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO ORIENTACAO-EM-ANDAMENTO-DE-APERFEICOAMENTO-ESPECIALIZACAO ',
#   'Tamanho Amostra:': 740,
#   'R2 ajustado': 0.8201965947465599,
#   'Confiança': 0.01,
#   'alfa': 0.8347254304266559,
#   'qty_2014': 0.9797137687955524,
#   'bool_capes': 0.0,
#   'amostra_capes': 248,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 54,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DESENVOLVIMENTO PATENTE ',
#   'Tamanho Amostra:': 1034,
#   'R2 ajustado': 0.629922580786458,
#   'Confiança': 0.01,
#   'alfa': 1.200435014314573,
#   'qty_2014': 1.038822858700906,
#   'bool_capes': 0.0,
#   'amostra_capes': 435,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 186,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO BANCA-JULGADORA-PARA-PROFESSOR-TITULAR ',
#   'Tamanho Amostra:': 625,
#   'R2 ajustado': 0.5964113880982651,
#   'Confiança': 0.01,
#   'alfa': 1.2495958731110062,
#   'qty_2014': 0.9886242989854018,
#   'bool_capes': 0.0,
#   'amostra_capes': 147,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 25,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DESENVOLVIMENTO DESENHO-INDUSTRIAL ',
#   'Tamanho Amostra:': 28,
#   'R2 ajustado': 0.6807208598076058,
#   'Confiança': 0.01,
#   'alfa': 1.176209279368214,
#   'qty_2014': 0.8548864758144121,
#   'bool_capes': 0.0,
#   'amostra_capes': 11,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 0,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-CONCLUSAO RESIDENCIA-MEDICA ',
#   'Tamanho Amostra:': 660,
#   'R2 ajustado': 0.9460223802938846,
#   'Confiança': 0.01,
#   'alfa': 0.11760296525210173,
#   'qty_2014': 0.9526240273715577,
#   'bool_capes': 0.0,
#   'amostra_capes': 137,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 29,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-INICIO RESIDENCIA-MEDICA ',
#   'Tamanho Amostra:': 665,
#   'R2 ajustado': 0.963070436206759,
#   'Confiança': 0.01,
#   'alfa': 0.09650574354367114,
#   'qty_2014': 0.9591099111653024,
#   'bool_capes': 0.0,
#   'amostra_capes': 137,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 30,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DA-OBRA-DE-REFERENCIA DETALHAMENTO-DE-ARTES-CENICAS ',
#   'Tamanho Amostra:': 265,
#   'R2 ajustado': 0.9425352467188577,
#   'Confiança': 0.01,
#   'alfa': 0.0,
#   'qty_2014': 1.1491512915129147,
#   'bool_capes': 0.0,
#   'amostra_capes': 126,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 13,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO ARTES-CENICAS ',
#   'Tamanho Amostra:': 563,
#   'R2 ajustado': 0.9457434809088745,
#   'Confiança': 0.01,
#   'alfa': 0.5950496413353051,
#   'qty_2014': 1.1815912211710065,
#   'bool_capes': 0.0,
#   'amostra_capes': 238,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 49,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-SOLICITACAO CULTIVAR-REGISTRADA ',
#   'Tamanho Amostra:': 22,
#   'R2 ajustado': 0.658246897296001,
#   'Confiança': 0.01,
#   'alfa': 0.0,
#   'qty_2014': 0.9844115354637566,
#   'bool_capes': 2.7872174590802805,
#   'amostra_capes': 13,
#   'Impacto CAPES': 36.233826968043644,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 5,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO PARTICIPACAO-EM-OLIMPIADA ',
#   'Tamanho Amostra:': 344,
#   'R2 ajustado': 0.5314787782758785,
#   'Confiança': 0.01,
#   'alfa': 0.76579237341715,
#   'qty_2014': 0.8669683339655698,
#   'bool_capes': 0.0,
#   'amostra_capes': 118,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 49,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO MUSICA ',
#   'Tamanho Amostra:': 394,
#   'R2 ajustado': 0.9662131542228066,
#   'Confiança': 0.01,
#   'alfa': 0.0,
#   'qty_2014': 1.2338024987980893,
#   'bool_capes': 1.9468827841795344,
#   'amostra_capes': 176,
#   'Impacto CAPES': 342.65137001559805,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 32,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DA-OBRA-DE-REFERENCIA DETALHAMENTO-DA-MUSICA ',
#   'Tamanho Amostra:': 188,
#   'R2 ajustado': 0.9519725852277648,
#   'Confiança': 0.01,
#   'alfa': 0.8738652511150591,
#   'qty_2014': 1.043409466524696,
#   'bool_capes': 0.0,
#   'amostra_capes': 80,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 12,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-OBTENCAO-DO-TITULO MBA ',
#   'Tamanho Amostra:': 8,
#   'R2 ajustado': 1.0,
#   'Confiança': 0.01,
#   'alfa': 0.0,
#   'qty_2014': 1.0,
#   'bool_capes': 0.0,
#   'amostra_capes': 3,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 0,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO BANCA-JULGADORA-PARA-LIVRE-DOCENCIA ',
#   'Tamanho Amostra:': 89,
#   'R2 ajustado': 0.8790849662179265,
#   'Confiança': 0.01,
#   'alfa': 1.107748212586224,
#   'qty_2014': 0.9871164630837119,
#   'bool_capes': 0.0,
#   'amostra_capes': 23,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 4,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DA-OBRA DETALHAMENTO-DE-MANUTENCAO-DE-OBRA-ARTISTICA ',
#   'Tamanho Amostra:': 22,
#   'R2 ajustado': 0.9995626520438491,
#   'Confiança': 0.01,
#   'alfa': 0.0,
#   'qty_2014': 1.0050731125037302,
#   'bool_capes': 0.0,
#   'amostra_capes': 8,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 2,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO MANUTENCAO-DE-OBRA-ARTISTICA ',
#   'Tamanho Amostra:': 26,
#   'R2 ajustado': 0.998580166103648,
#   'Confiança': 0.01,
#   'alfa': 0.0,
#   'qty_2014': 1.063056954668733,
#   'bool_capes': 0.0,
#   'amostra_capes': 8,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 4,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-SOLICITACAO CULTIVAR-PROTEGIDA ',
#   'Tamanho Amostra:': 8,
#   'R2 ajustado': 0.9822898349214139,
#   'Confiança': 0.01,
#   'alfa': 1.2914979757085039,
#   'qty_2014': 1.4048582995951406,
#   'bool_capes': 0.0,
#   'amostra_capes': 4,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 1,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO MAQUETE ',
#   'Tamanho Amostra:': 90,
#   'R2 ajustado': 0.9970721308792916,
#   'Confiança': 0.01,
#   'alfa': 0.0,
#   'qty_2014': 1.1019763269241072,
#   'bool_capes': 0.0,
#   'amostra_capes': 47,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 4,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO PARTITURA-MUSICAL ',
#   'Tamanho Amostra:': 37,
#   'R2 ajustado': 0.8893499148628753,
#   'Confiança': 0.01,
#   'alfa': 0.0,
#   'qty_2014': 1.2033419628147801,
#   'bool_capes': 0.0,
#   'amostra_capes': 17,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 2,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO OUTRAS-PARTICIPACOES-EM-BANCA ',
#   'Tamanho Amostra:': 12,
#   'R2 ajustado': 1.0,
#   'Confiança': 0.01,
#   'alfa': 0.0,
#   'qty_2014': 0.9999999999999999,
#   'bool_capes': 0.0,
#   'amostra_capes': 2,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 0,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO CURSO-DE-CURTA-DURACAO ',
#   'Tamanho Amostra:': 35,
#   'R2 ajustado': 1.0,
#   'Confiança': 0.01,
#   'alfa': 0.0,
#   'qty_2014': 1.0000000000000004,
#   'bool_capes': 0.0,
#   'amostra_capes': 12,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 0.0,
#   'amostra_cnpq': 1,
#   'Impacto CNPq': 0.0},
#  {'Indicador': '@ANO-DE-OBTENCAO-DO-TITULO LIVRE-DOCENCIA ',
#   'Tamanho Amostra:': 24,
#   'R2 ajustado': 0.1989292414054762,
#   'Confiança': 0.05,
#   'alfa': 1.1052631578947376,
#   'qty_2014': 0.0,
#   'bool_capes': 0.0,
#   'amostra_capes': 4,
#   'Impacto CAPES': 0.0,
#   'bool_cnpq': 1.494736842105263,
#   'amostra_cnpq': 5,
#   'Impacto CNPq': 7.473684210526315}]
