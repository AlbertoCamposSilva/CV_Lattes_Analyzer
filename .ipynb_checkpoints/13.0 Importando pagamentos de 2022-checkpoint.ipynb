# %%
from Lattes import Lattes
import pandas
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from Carga import Carga

# %%
pagtos_2022 = pandas.read_excel(r'C:\Users\silva\CNPq\Lattes\Planilhas\Pagamentos\Relatorio_de_dados_abertos_CNPq 2022 (2022-31-12).xlsx', 
                                skiprows=3, 
                                header=1, 
                                #nrows=10
                               )
# Out:
# C:\Users\silva\AppData\Local\Temp/ipykernel_12200/4270829147.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype={value.dtype})
#   pagtos_2022 = pandas.read_excel(r'C:\Users\silva\CNPq\Lattes\Planilhas\Pagamentos\Relatorio_de_dados_abertos_CNPq 2022 (2022-31-12).xlsx',

# %%
pagtos_2022
# Out:
#         Ano Referência       Processo Data Início Processo  \
# 0                 2022  372325/2022-0           2022-09-01
# 1                 2022  372329/2022-5           2022-09-01
# 2                 2022  372580/2022-0           2022-10-01
# 3                 2022  166775/2021-5           2021-12-01
# 4                 2022  167064/2021-5           2021-12-01
# ...                ...            ...                  ...
# 167244            2022  381330/2021-4           2021-07-01
# 167245            2022  421530/2022-7           2022-10-14
# 167246            2022  404164/2022-6           2022-07-06
# 167247            2022  424890/2021-6           2021-11-22
# 167248            2022  400459/2022-1           2022-03-11
#
#        Data Término Processo          CPF                     Beneficiário  \
# 0                 2022-10-31  82571392549        Josemar Hipólito da Silva
# 1                 2022-10-31   7776135577         Mislene Pereira da Silva
# ...

# %%
pagtos_2022.drop(['CPF', 'Programa', 'Ação', 'UO'], axis=1, inplace=True)

# %%
pagtos_2022.rename(columns = {
                              'Data Início Processo':'Inicio Processo', 
                              'Data Término Processo':'Término Processo',
                              'Região Destino':'Região'
                             }, inplace = True)

# %%
list(pagtos_2022.columns)
# Out:
# ['Ano Referência',
#  'Processo',
#  'Inicio Processo',
#  'Término Processo',
#  'Beneficiário',
#  'Sexo',
#  'Linha de Fomento',
#  'Modalidade',
#  'Categoria/Nível',
#  'Nome Chamada',
#  'Programa CNPq',
#  'Grande Área',
#  'Área',
#  'Subárea',
#  'Instituição Origem',
#  'Sigla UF Origem',
#  'País Origem',
#  'Instituição Destino',
#  'Sigla Instituição Destino',
#  'Sigla Instituição Macro',
#  'Cidade Destino',
#  'Sigla UF Destino',
#  'Região',
#  'País Destino',
#  'Título do Projeto',
#  'Palavra Chave',
#  'Plano Interno',
#  'Fonte Recurso',
#  'Natureza de Despesa',
#  'Valor Pago']

# %%
engine = Carga.db_engine()
pagtos_2022.to_sql('pagamentos', engine, if_exists='append', index=False)

# %%
pagtos_2022
# Out:
#         Ano Referência       Processo Inicio Processo Término Processo  \
# 0                 2022  372325/2022-0      2022-09-01       2022-10-31
# 1                 2022  372329/2022-5      2022-09-01       2022-10-31
# 2                 2022  372580/2022-0      2022-10-01       2022-10-31
# 3                 2022  166775/2021-5      2021-12-01       2022-11-30
# 4                 2022  167064/2021-5      2021-12-01       2022-11-30
# ...                ...            ...             ...              ...
# 167244            2022  381330/2021-4      2021-07-01       2022-12-31
# 167245            2022  421530/2022-7      2022-10-14       2023-06-30
# 167246            2022  404164/2022-6      2022-07-06       2022-10-31
# 167247            2022  424890/2021-6      2021-11-22       2022-06-30
# 167248            2022  400459/2022-1      2022-03-11       2023-03-31
#
#                            Beneficiário Sexo  \
# 0             Josemar Hipólito da Silva    M
# ...
