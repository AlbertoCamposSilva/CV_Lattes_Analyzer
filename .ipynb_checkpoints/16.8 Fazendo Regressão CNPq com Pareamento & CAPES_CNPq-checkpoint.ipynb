# %%
print('Inicializando Variáveis do Programa')
#inicializando variáveis
#lista_confianças = [0.01]
lista_confianças = [0.01, 0.05]
variável_dependente = 'qty_2019'
variáveis_independentes = ('qty_2014', 'porcent_pagos', '-1')
ano_início = 2014
ano_fim = 2020
# Out:
# Inicializando Variáveis do Programa

# %%
from datetime import datetime
print('Início em: ', datetime.now())

print('Importações Iniciais')

from tkinter import NONE
from Lattes import Lattes
from Carga import Carga
from Database import Database
import psycopg2, pickle
import pandas, os
import statsmodels.api as sm
from urllib.parse import urlencode
from psycopg2.extensions import AsIs
from Carga import Carga
from pandas import pandas as pd
import numpy as np
import Database
import json
import locale
import statsmodels.formula.api as sm2
from itertools import combinations




print('Fim: ', datetime.now())
# Out:
# Início em:  2023-04-23 18:16:29.230236
# Importações Iniciais
# Fim:  2023-04-23 18:16:32.829735

# %%
sql = '''
select * from financiamentos_doutorandos_2014
    inner join indicadores_doutorado
        on indicadores_doutorado.id = financiamentos_doutorandos_2014.id
    inner join indicadores_nomes
        on indicadores_nomes.tipo = indicadores_doutorado.indicador_tipo                 
'''

# %%
#Carregar arquivo na memória
print('Carregando indicadores na memória. Início em: ', datetime.now())

db = Database.Database('CNPq')
engine = Carga.db_engine()

dt = pd.read_sql(sql, engine)
print(f'dt.size: {dt.size}')

print('Término em: ', datetime.now())
# Out:
# Carregando indicadores na memória. Início em:  2023-04-23 18:16:32.867053
# dt.size: 16139320
# Término em:  2023-04-23 18:16:42.146708

# %%
sql_ids_pareados = '''
select pareado_1 as id from public.par_doutorandos_2014_sem_reposicao
UNION select pareado_2 as id from public.par_doutorandos_2014_sem_reposicao
UNION select pareado_3 as id from public.par_doutorandos_2014_sem_reposicao
'''

# %%
print('Carregando indicadores dos pareados na memória. Início em: ', datetime.now())

db = Database.Database('CNPq')
engine = Carga.db_engine()

pareados = pd.read_sql(sql_ids_pareados, engine)
print(f'dt.size: {dt.size}')

print('Término em: ', datetime.now())
# Out:
# Carregando indicadores dos pareados na memória. Início em:  2023-04-23 18:16:42.194280
# dt.size: 16139320
# Término em:  2023-04-23 18:16:42.369201

# %%
## Normalizando as Tabelas

print('Realizando normalização da tabela. Início em: ', datetime.now())

dt['const'] = 1
dt = dt.loc[:,~dt.columns.duplicated()]

dt['bool_cnpq'] = dt['pagtos'].map(lambda pagtos: 1 if pagtos > 0 else 0)
dt['bool_capes'] = dt['capes'].map(lambda capes: 1 if capes == True else 0)


#Preenchendo Nan com zeros nos indicadores
dt.qty_2012 = dt.qty_2012.fillna(0)
dt.qty_2013 = dt.qty_2013.fillna(0)
dt.qty_2014 = dt.qty_2014.fillna(0)
dt.qty_2015 = dt.qty_2015.fillna(0)
dt.qty_2016 = dt.qty_2016.fillna(0)
dt.qty_2017 = dt.qty_2017.fillna(0)
dt.qty_2018 = dt.qty_2018.fillna(0)
dt.qty_2019 = dt.qty_2019.fillna(0)
dt.capes = dt.capes.fillna(0)
dt.pagtos = dt.pagtos.fillna(0)

valor_total_cnpq =  dt[['id', 'pagtos']].loc[dt['pagtos']>0].drop_duplicates().sum().pagtos
dt['porcent_pagos'] = dt['pagtos']/valor_total_cnpq


print('Fim em: ', datetime.now())
# Out:
# Realizando normalização da tabela. Início em:  2023-04-23 18:16:42.391198
# Fim em:  2023-04-23 18:16:43.414863

# %%
#Apagando os financiados pela CAPES
dt.drop(dt.loc[dt.bool_capes==True].index, inplace=True)

#Apagando os que não foram escolhidos pelo pareamento
dt.drop(dt.loc[~dt.id.isin(pareados.id)].loc[dt.pagtos==0].index, inplace=True)

# %%
def regressão(X,y):
    try:
        # OLS vem de Ordinary Least Squares e o método fit irá treinar o modelo
        reg = sm.OLS(y, X).fit()
        # mostrando as estatísticas do modelo
        #reg.summary()
        
        
        
        #guardando a regressão na memória

        result = {
                'Indicador': indicador,
                'Erro': False,
                'Prob (F-statistic)':reg.f_pvalue, 
                'Parâmetros': reg.params, 
                "P>|t|":reg.pvalues, 
                'Standard Error': reg.bse, 
                "Covariância entre os pasrâmetros": reg.normalized_cov_params, 
                'Number of observations n.': reg.nobs, 
                "R2 ajustado": reg.rsquared_adj, 
                "Modelo":reg.model,
            }
    except:
        result = {
                'Indicador': indicador,
                'Erro': True,
                'Prob (F-statistic)':None, 
                'Parâmetros': None, 
                "P>|t|":None, 
                'Standard Error': None, 
                "Covariância entre os pasrâmetros": None, 
                'Number of observations n.': None, 
                "R2 ajustado": None, 
                "Modelo": None,
            }
    return result

# %%
def regressão_r2(dados, variável_dependente, variáveis_independentes):
    
    lista_formulas = []
    
    for x in range(1,len(variáveis_independentes)+1):
        for a in combinations(variáveis_independentes,x):
            formula = f'{variável_dependente} ~ ' 
            if not a[0] == '-1':
                formula = (formula + ' + '.join(a)).replace('+ -1',' -1')
                lista_formulas.append(formula)
    
    list_results = []
    for formula in lista_formulas:
    
        try:
            # OLS vem de Ordinary Least Squares e o método fit irá treinar o modelo
            reg_ajustado = sm2.ols(formula, data = dados)
            reg = reg_ajustado.fit()
            # mostrando as estatísticas do modelo
            print('\nCom constante:\n',reg.summary2())  

            #guardando a regressão na memória

            result = {
                    'Indicador': indicador,
                    'Erro': False,
                    'Prob (F-statistic)':reg.f_pvalue, 
                    'Parâmetros': reg.params, 
                    "P>|t|":reg.pvalues, 
                    'Standard Error': reg.bse, 
                    "Covariância entre os pasrâmetros": reg.normalized_cov_params, 
                    'Number of observations n.': reg.nobs, 
                    "R2 ajustado": reg.rsquared_adj, 
                    "Modelo":reg.model,
                }

        except:
            result = {
                    'Indicador': indicador,
                    'Erro': True,
                    'Prob (F-statistic)':None, 
                    'Parâmetros': None, 
                    "P>|t|":None, 
                    'Standard Error': None, 
                    "Covariância entre os pasrâmetros": None, 
                    'Number of observations n.': None, 
                    "R2 ajustado": None, 
                    "Modelo": None,
                }
    
        list_results.append(result)
        
    maiorR = max(list_results, key=lambda x:x['R2 ajustado'])
        
    return maiorR

# %%
def regressão_com_confiança (X,y,confiança = 0.05): 
    result = regressão(X,y)
    #print(result)
    while result['Erro'] == False and result['P>|t|'].max() > confiança:
        X = X.drop(columns=result['P>|t|'].idxmax())
        result = regressão(X,y)
        #print(result)
        
        
    if result['Erro'] == False and result['Prob (F-statistic)'] < confiança and result['P>|t|'].max() < confiança:
        result['Confiança'] = confiança
        return result
    else:
        result['Confiança'] = 'Erro'
    return result

# %%
#inicializando variáveis
lista_regressões = []
tempo_início = datetime.now()
feitos = 0
print(f'Iniciado em {tempo_início}.')

#pegando lista de todos os indicadores
todos_indicadores = dt.nome.unique()

#iterando sobre cada indicador
número_total = len(todos_indicadores)
for indicador in todos_indicadores:
    
    #Realizando previsão de término
    if not feitos == 0:
        porcentagem_já_feita = (feitos/número_total)
        tempo_passado = datetime.now() - tempo_início
        tempo_por_id = tempo_passado / feitos
        tempo_restante = (número_total - feitos) * tempo_por_id
        tempo_em_que_vai_acabar = datetime.now() + tempo_restante
        print(f'{feitos}/{número_total}. {porcentagem_já_feita * 100}% feitos. Fazendo indicador: {indicador}. Acabará em {tempo_em_que_vai_acabar}. O Último demorou: {datetime.now() - tempo_último}.')
    else:
        print(f'{feitos}/{número_total}. Fazendo id: {indicador}.')
    feitos += 1
    tempo_último = datetime.now()

    #Realizando a regressão
    dados = dt.loc[dt.nome==indicador]
    #X = dados[['const','qty_2014', 'bool_cnpq']]
    #y = dados[['qty_2019']]
    #lista_confianças = (0.001, 0.01, 0.05, 0.1)
    result = regressão_r2(dados, variável_dependente, variáveis_independentes)


  

    lista_regressões.append(result)
# Out:
# Iniciado em 2023-04-23 18:16:44.461981.
# 0/128. Fazendo id: Conclusão de Doutorado.
#
# Com constante:
#                   Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.003
# Dependent Variable: qty_2019         AIC:                1212.4928
# Date:               2023-04-23 18:16 BIC:                1225.3200
# No. Observations:   4508             Log-Likelihood:     -604.25
# Df Model:           1                F-statistic:        16.62
# Df Residuals:       4506             Prob (F-statistic): 4.64e-05
# R-squared:          0.004            Scale:              0.076585
# --------------------------------------------------------------------
#              Coef.    Std.Err.      t       P>|t|    [0.025   0.975]
# --------------------------------------------------------------------
# Intercept    0.9748     0.0041   236.1209   0.0000   0.9668   0.9829
# qty_2014     0.2918     0.0716     4.0772   0.0000   0.1515   0.4321
# ------------------------------------------------------------------
# Omnibus:            1181.362      Durbin-Watson:         2.055
# Prob(Omnibus):      0.000         Jarque-Bera (JB):      21868.433
# Skew:               -0.772        Prob(JB):              0.000
# Kurtosis:           13.679        Condition No.:         17
# ==================================================================
#
#
# Com constante:
#                   Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     -0.000
# Dependent Variable: qty_2019         AIC:                1229.0376
# Date:               2023-04-23 18:16 BIC:                1241.8649
# No. Observations:   4508             Log-Likelihood:     -612.52
# Df Model:           1                F-statistic:        0.05539
# Df Residuals:       4506             Prob (F-statistic): 0.814
# R-squared:          0.000            Scale:              0.076866
# ------------------------------------------------------------------
#                   Coef.  Std.Err.    t     P>|t|   [0.025   0.975]
# ------------------------------------------------------------------
# Intercept         0.9751   0.0050 194.1393 0.0000   0.9653  0.9850
# porcent_pagos     3.4446  14.6358   0.2354 0.8139 -25.2487 32.1379
# ------------------------------------------------------------------
# Omnibus:            1164.605      Durbin-Watson:         2.055
# Prob(Omnibus):      0.000         Jarque-Bera (JB):      21958.892
# Skew:               -0.748        Prob(JB):              0.000
# Kurtosis:           13.708        Condition No.:         3544
# ==================================================================
# * The condition number is large (4e+03). This might indicate
# strong multicollinearity or other numerical problems.
#
# Com constante:
#                   Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.003
# Dependent Variable: qty_2019         AIC:                1214.4472
# Date:               2023-04-23 18:16 BIC:                1233.6880
# No. Observations:   4508             Log-Likelihood:     -604.22
# Df Model:           2                F-statistic:        8.333
# Df Residuals:       4505             Prob (F-statistic): 0.000244
# R-squared:          0.004            Scale:              0.076601
# ------------------------------------------------------------------
#                   Coef.  Std.Err.    t     P>|t|   [0.025   0.975]
# ------------------------------------------------------------------
# Intercept         0.9742   0.0050 194.1032 0.0000   0.9644  0.9841
# qty_2014          0.2917   0.0716   4.0755 0.0000   0.1514  0.4321
# porcent_pagos     3.1198  14.6107   0.2135 0.8309 -25.5243 31.7640
# ------------------------------------------------------------------
# Omnibus:            1181.515      Durbin-Watson:         2.055
# Prob(Omnibus):      0.000         Jarque-Bera (JB):      21867.484
# Skew:               -0.773        Prob(JB):              0.000
# Kurtosis:           13.679        Condition No.:         3544
# ==================================================================
# * The condition number is large (4e+03). This might indicate
# strong multicollinearity or other numerical problems.
#
# Com constante:
#                          Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.005
# Dependent Variable:     qty_2019         AIC:                         12900.8346
# Date:                   2023-04-23 18:16 BIC:                         12907.2482
# No. Observations:       4508             Log-Likelihood:              -6449.4
# Df Model:               1                F-statistic:                 23.50
# Df Residuals:           4507             Prob (F-statistic):          1.29e-06
# R-squared (uncentered): 0.005            Scale:                       1.0239
# -------------------------------------------------------------------------------------
#                  Coef.       Std.Err.        t         P>|t|       [0.025      0.975]
# -------------------------------------------------------------------------------------
# qty_2014         1.2667        0.2613      4.8481      0.0000      0.7544      1.7789
# --------------------------------------------------------------------------------
# Omnibus:                  1281.258          Durbin-Watson:             0.160
# Prob(Omnibus):            0.000             Jarque-Bera (JB):          21125.538
# Skew:                     -0.914            Prob(JB):                  0.000
# Kurtosis:                 13.446            Condition No.:             1
# ================================================================================
#
#
# Com constante:
#                          Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.301
# Dependent Variable:     qty_2019         AIC:                         11311.0613
# Date:                   2023-04-23 18:16 BIC:                         11317.4749
# No. Observations:       4508             Log-Likelihood:              -5654.5
# Df Model:               1                F-statistic:                 1939.
# Df Residuals:           4507             Prob (F-statistic):          0.00
# R-squared (uncentered): 0.301            Scale:                       0.71965
# ----------------------------------------------------------------------------------
#                      Coef.     Std.Err.      t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# porcent_pagos      1621.2038    36.8152   44.0362   0.0000   1549.0279   1693.3797
# --------------------------------------------------------------------------------
# Omnibus:                  2355.514          Durbin-Watson:             0.798
# Prob(Omnibus):            0.000             Jarque-Bera (JB):          26738.058
# Skew:                     -2.241            Prob(JB):                  0.000
# Kurtosis:                 14.057            Condition No.:             1
# ================================================================================
#
#
# Com constante:
#                          Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.303
# Dependent Variable:     qty_2019         AIC:                         11295.8651
# Date:                   2023-04-23 18:16 BIC:                         11308.6923
# No. Observations:       4508             Log-Likelihood:              -5645.9
# Df Model:               2                F-statistic:                 981.7
# Df Residuals:           4506             Prob (F-statistic):          0.00
# R-squared (uncentered): 0.303            Scale:                       0.71707
# ----------------------------------------------------------------------------------
#                      Coef.     Std.Err.      t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# qty_2014              0.9080     0.2188    4.1499   0.0000      0.4790      1.3369
# porcent_pagos      1615.5085    36.7748   43.9298   0.0000   1543.4119   1687.6051
# --------------------------------------------------------------------------------
# Omnibus:                  2350.583          Durbin-Watson:             0.799
# Prob(Omnibus):            0.000             Jarque-Bera (JB):          26319.638
# Skew:                     -2.240            Prob(JB):                  0.000
# Kurtosis:                 13.957            Condition No.:             168
# ================================================================================
#
# 1/128. 0.78125% feitos. Fazendo indicador: Conclusão de Curso de Curta Duração. Acabará em 2023-04-23 18:17:58.870429. O Último demorou: 0:00:00.526272.
#
# Com constante:
#                    Results: Ordinary least squares
# ===================================================================
# Model:              OLS              Adj. R-squared:     0.775
# Dependent Variable: qty_2019         AIC:                20827.1652
# Date:               2023-04-23 18:16 BIC:                20839.4896
# No. Observations:   3506             Log-Likelihood:     -10412.
# Df Model:           1                F-statistic:        1.209e+04
# Df Residuals:       3504             Prob (F-statistic): 0.00
# R-squared:          0.775            Scale:              22.242
# ---------------------------------------------------------------------
#               Coef.    Std.Err.      t       P>|t|    [0.025   0.975]
# ---------------------------------------------------------------------
# Intercept     1.1754     0.1048    11.2148   0.0000   0.9699   1.3809
# qty_2014      1.1777     0.0107   109.9485   0.0000   1.1567   1.1987
# -------------------------------------------------------------------
# Omnibus:             5432.929     Durbin-Watson:        2.017
# Prob(Omnibus):       0.000        Jarque-Bera (JB):     3957222.386
# Skew:                9.539        Prob(JB):             0.000
# Kurtosis:            166.477      Condition No.:        13
# ===================================================================
#
#
# Com constante:
#                    Results: Ordinary least squares
# ===================================================================
# Model:              OLS              Adj. R-squared:     0.000
# Dependent Variable: qty_2019         AIC:                26059.9819
# Date:               2023-04-23 18:16 BIC:                26072.3064
# No. Observations:   3506             Log-Likelihood:     -13028.
# Df Model:           1                F-statistic:        1.274
# Df Residuals:       3504             Prob (F-statistic): 0.259
# R-squared:          0.000            Scale:              98.941
# -------------------------------------------------------------------
#                 Coef.   Std.Err.    t    P>|t|    [0.025    0.975]
# -------------------------------------------------------------------
# Intercept        8.7983   0.2048 42.9582 0.0000     8.3967   9.1998
# porcent_pagos -664.8454 588.9782 -1.1288 0.2591 -1819.6203 489.9295
# -------------------------------------------------------------------
# Omnibus:            3476.184      Durbin-Watson:         2.068
# Prob(Omnibus):      0.000         Jarque-Bera (JB):      283043.283
# Skew:               4.658         Prob(JB):              0.000
# Kurtosis:           46.020        Condition No.:         3506
# ===================================================================
# * The condition number is large (4e+03). This might indicate
# strong multicollinearity or other numerical problems.
#
# Com constante:
#                    Results: Ordinary least squares
# ===================================================================
# Model:              OLS              Adj. R-squared:     0.775
# Dependent Variable: qty_2019         AIC:                20826.6044
# Date:               2023-04-23 18:16 BIC:                20845.0911
# No. Observations:   3506             Log-Likelihood:     -10410.
# Df Model:           2                F-statistic:        6048.
# Df Residuals:       3503             Prob (F-statistic): 0.00
# R-squared:          0.775            Scale:              22.232
# -------------------------------------------------------------------
#                 Coef.   Std.Err.    t     P>|t|    [0.025   0.975]
# -------------------------------------------------------------------
# Intercept        1.0826   0.1198   9.0374 0.0000    0.8477   1.3174
# qty_2014         1.1783   0.0107 109.9588 0.0000    1.1573   1.1993
# porcent_pagos  446.9600 279.3753   1.5999 0.1097 -100.7948 994.7148
# -------------------------------------------------------------------
# Omnibus:             5439.086     Durbin-Watson:        2.016
# Prob(Omnibus):       0.000        Jarque-Bera (JB):     3986218.881
# Skew:                9.559        Prob(JB):             0.000
# Kurtosis:            167.079      Condition No.:        34407
# ===================================================================
# * The condition number is large (3e+04). This might indicate
# strong multicollinearity or other numerical problems.
#
# Com constante:
#                          Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.868
# Dependent Variable:     qty_2019         AIC:                         20948.8023
# Date:                   2023-04-23 18:16 BIC:                         20954.9645
# No. Observations:       3506             Log-Likelihood:              -10473.
# Df Model:               1                F-statistic:                 2.298e+04
# Df Residuals:           3505             Prob (F-statistic):          0.00
# R-squared (uncentered): 0.868            Scale:                       23.034
# -------------------------------------------------------------------------------------
#                Coef.       Std.Err.         t          P>|t|       [0.025      0.975]
# -------------------------------------------------------------------------------------
# qty_2014       1.2557        0.0083      151.6002      0.0000      1.2395      1.2720
# --------------------------------------------------------------------------------
# Omnibus:                5188.523          Durbin-Watson:             1.976
# Prob(Omnibus):          0.000             Jarque-Bera (JB):          3178661.906
# Skew:                   8.729             Prob(JB):                  0.000
# Kurtosis:               149.473           Condition No.:             1
# ================================================================================
#
#
# Com constante:
#                          Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.132
# Dependent Variable:     qty_2019         AIC:                         27541.3040
# Date:                   2023-04-23 18:16 BIC:                         27547.4662
# No. Observations:       3506             Log-Likelihood:              -13770.
# Df Model:               1                F-statistic:                 535.3
# Df Residuals:           3505             Prob (F-statistic):          2.43e-110
# R-squared (uncentered): 0.132            Scale:                       151.01
# ----------------------------------------------------------------------------------
#                   Coef.      Std.Err.      t      P>|t|      [0.025       0.975]
# ----------------------------------------------------------------------------------
# porcent_pagos   13808.7501   596.8144   23.1374   0.0000   12638.6112   14978.8889
# --------------------------------------------------------------------------------
# Omnibus:                 2987.074          Durbin-Watson:             1.585
# Prob(Omnibus):           0.000             Jarque-Bera (JB):          173000.387
# Skew:                    3.717             Prob(JB):                  0.000
# Kurtosis:                36.600            Condition No.:             1
# ================================================================================
# Com constante:
#                          Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.869
# Dependent Variable:     qty_2019         AIC:                         20905.4113
# Date:                   2023-04-23 18:16 BIC:                         20917.7357
# No. Observations:       3506             Log-Likelihood:              -10451.
# Df Model:               2                F-statistic:                 1.166e+04
# Df Residuals:           3504             Prob (F-statistic):          0.00
# R-squared (uncentered): 0.869            Scale:                       22.744
# ----------------------------------------------------------------------------------
#                     Coef.     Std.Err.      t       P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# qty_2014             1.2350     0.0088   140.5945   0.0000      1.2178      1.2522
# porcent_pagos     1670.3083   247.1885     6.7572   0.0000   1185.6603   2154.9563
# --------------------------------------------------------------------------------
# Omnibus:                5266.540          Durbin-Watson:             1.991
# Prob(Omnibus):          0.000             Jarque-Bera (JB):          3423468.373
# Skew:                   8.980             Prob(JB):                  0.000
# Kurtosis:               155.028           Condition No.:             30031
# ================================================================================
# * The condition number is large (3e+04). This might indicate             strong
# multicollinearity or other numerical problems.
# 2/128. 1.5625% feitos. Fazendo indicador: Conclusão de Graduação. Acabará em 2023-04-23 18:17:36.980892. O Último demorou: 0:00:00.239291.
#
# Com constante:
#                    Results: Ordinary least squares
# ===================================================================
# Model:              OLS              Adj. R-squared:     0.836
# Dependent Variable: qty_2019         AIC:                -1916.3107
# Date:               2023-04-23 18:16 BIC:                -1903.4000
# No. Observations:   4700             Log-Likelihood:     960.16
# Df Model:           1                F-statistic:        2.391e+04
# Df Residuals:       4698             Prob (F-statistic): 0.00
# R-squared:          0.836            Scale:              0.038929
# ---------------------------------------------------------------------
#               Coef.    Std.Err.      t       P>|t|    [0.025   0.975]
# ---------------------------------------------------------------------
# Intercept     0.0189     0.0083     2.2841   0.0224   0.0027   0.0351
# qty_2014      1.0141     0.0066   154.6152   0.0000   1.0012   1.0270
# -------------------------------------------------------------------
# Omnibus:            5332.034      Durbin-Watson:         2.012
# Prob(Omnibus):      0.000         Jarque-Bera (JB):      375049.634
# Skew:               6.046         Prob(JB):              0.000
# Kurtosis:           45.059        Condition No.:         6
# ===================================================================
#
#
# Com constante:
#                   Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.001
# Dependent Variable: qty_2019         AIC:                6568.6207
# Date:               2023-04-23 18:16 BIC:                6581.5313
# No. Observations:   4700             Log-Likelihood:     -3282.3
# Df Model:           1                F-statistic:        5.170
# Df Residuals:       4698             Prob (F-statistic): 0.0230
# R-squared:          0.001            Scale:              0.23676
# ------------------------------------------------------------------
#                 Coef.   Std.Err.    t     P>|t|    [0.025   0.975]
# ------------------------------------------------------------------
# Intercept        1.2276   0.0086 142.9087 0.0000    1.2108  1.2444
# porcent_pagos  -56.6731  24.9241  -2.2738 0.0230 -105.5361 -7.8102
# ------------------------------------------------------------------
# Omnibus:            2607.806      Durbin-Watson:         2.001
# Prob(Omnibus):      0.000         Jarque-Bera (JB):      20616.467
# Skew:               2.586         Prob(JB):              0.000
# Kurtosis:           11.862        Condition No.:         3512
# ==================================================================
# * The condition number is large (4e+03). This might indicate
# strong multicollinearity or other numerical problems.
#
# Com constante:
#                    Results: Ordinary least squares
# ===================================================================
# Model:              OLS              Adj. R-squared:     0.836
# Dependent Variable: qty_2019         AIC:                -1914.3828
# Date:               2023-04-23 18:16 BIC:                -1895.0168
# No. Observations:   4700             Log-Likelihood:     960.19
# Df Model:           2                F-statistic:        1.195e+04
# Df Residuals:       4697             Prob (F-statistic): 0.00
# R-squared:          0.836            Scale:              0.038936
# --------------------------------------------------------------------
#                Coef.   Std.Err.     t      P>|t|    [0.025    0.975]
# --------------------------------------------------------------------
# Intercept      0.0183    0.0086    2.1323  0.0330    0.0015   0.0351
# qty_2014       1.0142    0.0066  154.4984  0.0000    1.0013   1.0270
# porcent_pagos  2.7156   10.1149    0.2685  0.7883  -17.1142  22.5455
# -------------------------------------------------------------------
# Omnibus:            5332.237      Durbin-Watson:         2.012
# Prob(Omnibus):      0.000         Jarque-Bera (JB):      375182.970
# Skew:               6.046         Prob(JB):              0.000
# Kurtosis:           45.067        Condition No.:         5568
# ===================================================================
# * The condition number is large (6e+03). This might indicate
# strong multicollinearity or other numerical problems.
#
# Com constante:
#                          Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.977
# Dependent Variable:     qty_2019         AIC:                         -1913.0945
# Date:                   2023-04-23 18:16 BIC:                         -1906.6391
# No. Observations:       4700             Log-Likelihood:              957.55
# Df Model:               1                F-statistic:                 2.024e+05
# Df Residuals:           4699             Prob (F-statistic):          0.00
# R-squared (uncentered): 0.977            Scale:                       0.038963
# -------------------------------------------------------------------------------------
#                Coef.       Std.Err.         t          P>|t|       [0.025      0.975]
# -------------------------------------------------------------------------------------
# qty_2014       1.0281        0.0023      449.9091      0.0000      1.0237      1.0326
# --------------------------------------------------------------------------------
# Omnibus:                 5306.800          Durbin-Watson:             2.015
# Prob(Omnibus):           0.000             Jarque-Bera (JB):          365019.242
# Skew:                    6.005             Prob(JB):                  0.000
# Kurtosis:                44.469            Condition No.:             1
# ================================================================================
#
#
# Com constante:
#                          Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.263
# Dependent Variable:     qty_2019         AIC:                         14446.4697
# Date:                   2023-04-23 18:16 BIC:                         14452.9251
# No. Observations:       4700             Log-Likelihood:              -7222.2
# Df Model:               1                F-statistic:                 1677.
# Df Residuals:           4699             Prob (F-statistic):          9.14e-314
# R-squared (uncentered): 0.263            Scale:                       1.2657
# ----------------------------------------------------------------------------------
#                      Coef.     Std.Err.      t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# porcent_pagos      1949.8146    47.6145   40.9501   0.0000   1856.4680   2043.1613
# --------------------------------------------------------------------------------
# Omnibus:                  849.478           Durbin-Watson:              0.894
# Prob(Omnibus):            0.000             Jarque-Bera (JB):           9525.400
# Skew:                     -0.524            Prob(JB):                   0.000
# Kurtosis:                 9.895             Condition No.:              1
# ================================================================================
#
#
# Com constante:
#                          Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.977
# Dependent Variable:     qty_2019         AIC:                         -1911.8355
# Date:                   2023-04-23 18:16 BIC:                         -1898.9248
# No. Observations:       4700             Log-Likelihood:              957.92
# Df Model:               2                F-statistic:                 1.012e+05
# Df Residuals:           4698             Prob (F-statistic):          0.00
# R-squared (uncentered): 0.977            Scale:                       0.038966
# -----------------------------------------------------------------------------------
#                     Coef.     Std.Err.       t        P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# qty_2014            1.0270      0.0027    384.6265    0.0000      1.0217     1.0322
# porcent_pagos       8.4009      9.7608      0.8607    0.3895    -10.7349    27.5366
# --------------------------------------------------------------------------------
# Omnibus:                 5309.841          Durbin-Watson:             2.014
# Prob(Omnibus):           0.000             Jarque-Bera (JB):          366372.111
# Skew:                    6.010             Prob(JB):                  0.000
# Kurtosis:                44.550            Condition No.:             4271
# ================================================================================
# * The condition number is large (4e+03). This might indicate             strong
# multicollinearity or other numerical problems.
# 3/128. 2.34375% feitos. Fazendo indicador: Conclusão de Mestrado. Acabará em 2023-04-23 18:17:28.936860. O Último demorou: 0:00:00.221772.
#
# Com constante:
#                    Results: Ordinary least squares
# ===================================================================
# Model:              OLS              Adj. R-squared:     0.530
# Dependent Variable: qty_2019         AIC:                -8791.7584
# Date:               2023-04-23 18:16 BIC:                -8778.9477
# No. Observations:   4471             Log-Likelihood:     4397.9
# Df Model:           1                F-statistic:        5046.
# Df Residuals:       4469             Prob (F-statistic): 0.00
# R-squared:          0.530            Scale:              0.0081910
# ---------------------------------------------------------------------
#                Coef.    Std.Err.      t      P>|t|    [0.025   0.975]
# ---------------------------------------------------------------------
# Intercept      0.3517     0.0094   37.2463   0.0000   0.3332   0.3702
# qty_2014       0.6601     0.0093   71.0334   0.0000   0.6419   0.6783
# -------------------------------------------------------------------
# Omnibus:             6677.202     Durbin-Watson:        1.985
# Prob(Omnibus):       0.000        Jarque-Bera (JB):     2119419.024
# Skew:                9.291        Prob(JB):             0.000
# Kurtosis:            108.031      Condition No.:        14
# ===================================================================
#
#
# Com constante:
#                    Results: Ordinary least squares
# ===================================================================
# Model:              OLS              Adj. R-squared:     -0.000
# Dependent Variable: qty_2019         AIC:                -5413.7010
# Date:               2023-04-23 18:16 BIC:                -5400.8903
# No. Observations:   4471             Log-Likelihood:     2708.9
# Df Model:           1                F-statistic:        0.5773
# Df Residuals:       4469             Prob (F-statistic): 0.447
# R-squared:          0.000            Scale:              0.017437
# --------------------------------------------------------------------
#                 Coef.   Std.Err.     t      P>|t|    [0.025   0.975]
# --------------------------------------------------------------------
# Intercept       1.0144    0.0024  420.1746  0.0000   1.0096   1.0191
# porcent_pagos   5.3921    7.0966    0.7598  0.4474  -8.5207  19.3049
# -------------------------------------------------------------------
# Omnibus:             6149.895     Durbin-Watson:        2.028
# Prob(Omnibus):       0.000        Jarque-Bera (JB):     1176205.267
# Skew:                8.103        Prob(JB):             0.000
# Kurtosis:            80.789       Condition No.:        3593
# ===================================================================
# * The condition number is large (4e+03). This might indicate
# strong multicollinearity or other numerical problems.
#
# Com constante:
#                    Results: Ordinary least squares
# ===================================================================
# Model:              OLS              Adj. R-squared:     0.530
# Dependent Variable: qty_2019         AIC:                -8789.7989
# Date:               2023-04-23 18:16 BIC:                -8770.5828
# No. Observations:   4471             Log-Likelihood:     4397.9
# Df Model:           2                F-statistic:        2522.
# Df Residuals:       4468             Prob (F-statistic): 0.00
# R-squared:          0.530            Scale:              0.0081927
# --------------------------------------------------------------------
#                  Coef.   Std.Err.     t     P>|t|    [0.025   0.975]
# --------------------------------------------------------------------
# Intercept        0.3515    0.0095  37.0808  0.0000   0.3329   0.3701
# qty_2014         0.6600    0.0093  71.0174  0.0000   0.6418   0.6783
# porcent_pagos    0.9790    4.8648   0.2012  0.8405  -8.5584  10.5165
# -------------------------------------------------------------------
# Omnibus:             6677.029     Durbin-Watson:        1.985
# Prob(Omnibus):       0.000        Jarque-Bera (JB):     2119223.289
# Skew:                9.290        Prob(JB):             0.000
# Kurtosis:            108.027      Condition No.:        5110
# ===================================================================
# * The condition number is large (5e+03). This might indicate
# strong multicollinearity or other numerical problems.
#
# Com constante:
#                          Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.990
# Dependent Variable:     qty_2019         AIC:                         -7585.0162
# Date:                   2023-04-23 18:16 BIC:                         -7578.6108
# No. Observations:       4471             Log-Likelihood:              3793.5
# Df Model:               1                F-statistic:                 4.324e+05
# Df Residuals:           4470             Prob (F-statistic):          0.00
# R-squared (uncentered): 0.990            Scale:                       0.010731
# -------------------------------------------------------------------------------------
#                Coef.       Std.Err.         t          P>|t|       [0.025      0.975]
# -------------------------------------------------------------------------------------
# qty_2014       1.0026        0.0015      657.5591      0.0000      0.9996      1.0056
# --------------------------------------------------------------------------------
# Omnibus:                7342.091          Durbin-Watson:             1.967
# Prob(Omnibus):          0.000             Jarque-Bera (JB):          3481706.588
# Skew:                   11.124            Prob(JB):                  0.000
# Kurtosis:               137.887           Condition No.:             1
# ================================================================================
#
#
# Com constante:
#                          Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.327
# Dependent Variable:     qty_2019         AIC:                         11133.3440
# Date:                   2023-04-23 18:16 BIC:                         11139.7494
# No. Observations:       4471             Log-Likelihood:              -5565.7
# Df Model:               1                F-statistic:                 2169.
# Df Residuals:           4470             Prob (F-statistic):          0.00
# R-squared (uncentered): 0.327            Scale:                       0.70612
# ----------------------------------------------------------------------------------
#                      Coef.     Std.Err.      t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# porcent_pagos      1720.5146    36.9415   46.5741   0.0000   1648.0911   1792.9382
# --------------------------------------------------------------------------------
# Omnibus:                  2662.544          Durbin-Watson:             0.701
# Prob(Omnibus):            0.000             Jarque-Bera (JB):          43678.606
# Skew:                     -2.529            Prob(JB):                  0.000
# Kurtosis:                 17.453            Condition No.:             1
# ================================================================================
#
#
# Com constante:
#                          Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.990
# Dependent Variable:     qty_2019         AIC:                         -7592.2273
# Date:                   2023-04-23 18:16 BIC:                         -7579.4165
# No. Observations:       4471             Log-Likelihood:              3798.1
# Df Model:               2                F-statistic:                 2.166e+05
# Df Residuals:           4469             Prob (F-statistic):          0.00
# R-squared (uncentered): 0.990            Scale:                       0.010712
# -----------------------------------------------------------------------------------
#                       Coef.     Std.Err.       t        P>|t|     [0.025     0.975]
# -----------------------------------------------------------------------------------
# qty_2014              0.9994      0.0019    538.6989    0.0000    0.9957     1.0030
# porcent_pagos        16.8220      5.5411      3.0359    0.0024    5.9587    27.6853
# --------------------------------------------------------------------------------
# Omnibus:                7334.602          Durbin-Watson:             1.966
# Prob(Omnibus):          0.000             Jarque-Bera (JB):          3473303.410
# Skew:                   11.101            Prob(JB):                  0.000
# Kurtosis:               137.728           Condition No.:             3637
# ================================================================================
# * The condition number is large (4e+03). This might indicate             strong
# multicollinearity or other numerical problems.
# 4/128. 3.125% feitos. Fazendo indicador: Início de Doutorado. Acabará em 2023-04-23 18:17:24.585630. O Último demorou: 0:00:00.211486.
#
# Com constante:
#                    Results: Ordinary least squares
# ===================================================================
# Model:              OLS              Adj. R-squared:     0.160
# Dependent Variable: qty_2019         AIC:                -3022.2106
# Date:               2023-04-23 18:16 BIC:                -3009.2429
# No. Observations:   4836             Log-Likelihood:     1513.1
# Df Model:           1                F-statistic:        923.5
# Df Residuals:       4834             Prob (F-statistic): 8.57e-186
# R-squared:          0.160            Scale:              0.031328
# ---------------------------------------------------------------------
#               Coef.    Std.Err.      t      P>|t|     [0.025   0.975]
# ---------------------------------------------------------------------
# Intercept     0.0616     0.0322    1.9133   0.0558   -0.0015   0.1247
# qty_2014      0.9692     0.0319   30.3898   0.0000    0.9067   1.0317
# -------------------------------------------------------------------
# Omnibus:            5334.963      Durbin-Watson:         2.020
# Prob(Omnibus):      0.000         Jarque-Bera (JB):      285235.679
# Skew:               5.891         Prob(JB):              0.000
# Kurtosis:           38.732        Condition No.:         25
# ===================================================================
#
#
# Com constante:
#                    Results: Ordinary least squares
# ===================================================================
# Model:              OLS              Adj. R-squared:     -0.000
# Dependent Variable: qty_2019         AIC:                -2176.7182
# Date:               2023-04-23 18:16 BIC:                -2163.7505
# No. Observations:   4836             Log-Likelihood:     1090.4
# Df Model:           1                F-statistic:        0.01594
# Df Residuals:       4834             Prob (F-statistic): 0.900
# R-squared:          0.000            Scale:              0.037314
# --------------------------------------------------------------------
#                Coef.   Std.Err.     t      P>|t|    [0.025    0.975]
# --------------------------------------------------------------------
# Intercept      1.0368    0.0033  309.7286  0.0000    1.0302   1.0433
# porcent_pagos  1.2412    9.8305    0.1263  0.8995  -18.0312  20.5135
# -------------------------------------------------------------------
# Omnibus:            4889.373      Durbin-Watson:         2.018
# Prob(Omnibus):      0.000         Jarque-Bera (JB):      176642.182
# Skew:               5.245         Prob(JB):              0.000
# Kurtosis:           30.687        Condition No.:         3539
# ===================================================================
# * The condition number is large (4e+03). This might indicate
# strong multicollinearity or other numerical problems.
#
# Com constante:
#                    Results: Ordinary least squares
# ===================================================================
# Model:              OLS              Adj. R-squared:     0.160
# Dependent Variable: qty_2019         AIC:                -3020.2938
# Date:               2023-04-23 18:16 BIC:                -3000.8422
# No. Observations:   4836             Log-Likelihood:     1513.1
# Df Model:           2                F-statistic:        461.7
# Df Residuals:       4833             Prob (F-statistic): 3.13e-184
# R-squared:          0.160            Scale:              0.031334
# --------------------------------------------------------------------
#                 Coef.   Std.Err.     t     P>|t|    [0.025    0.975]
# --------------------------------------------------------------------
# Intercept       0.0620    0.0322   1.9229  0.0545   -0.0012   0.1251
# qty_2014        0.9693    0.0319  30.3880  0.0000    0.9068   1.0319
# porcent_pagos  -2.5970    9.0094  -0.2882  0.7732  -20.2595  15.0656
# -------------------------------------------------------------------
# Omnibus:            5334.912      Durbin-Watson:         2.020
# Prob(Omnibus):      0.000         Jarque-Bera (JB):      285232.959
# Skew:               5.891         Prob(JB):              0.000
# Kurtosis:           38.732        Condition No.:         5026
# ===================================================================
# * The condition number is large (5e+03). This might indicate
# strong multicollinearity or other numerical problems.
#
# Com constante:
#                          Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.972
# Dependent Variable:     qty_2019         AIC:                         -3020.5499
# Date:                   2023-04-23 18:16 BIC:                         -3014.0660
# No. Observations:       4836             Log-Likelihood:              1511.3
# Df Model:               1                F-statistic:                 1.668e+05
# Df Residuals:           4835             Prob (F-statistic):          0.00
# R-squared (uncentered): 0.972            Scale:                       0.031346
# -------------------------------------------------------------------------------------
#                Coef.       Std.Err.         t          P>|t|       [0.025      0.975]
# -------------------------------------------------------------------------------------
# qty_2014       1.0300        0.0025      408.4504      0.0000      1.0251      1.0350
# --------------------------------------------------------------------------------
# Omnibus:                 5334.738          Durbin-Watson:             2.020
# Prob(Omnibus):           0.000             Jarque-Bera (JB):          285142.570
# Skew:                    5.890             Prob(JB):                  0.000
# Kurtosis:                38.726            Condition No.:             1
# ================================================================================
#
#
# Com constante:
#                          Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.301
# Dependent Variable:     qty_2019         AIC:                         12508.8169
# Date:                   2023-04-23 18:16 BIC:                         12515.3008
# No. Observations:       4836             Log-Likelihood:              -6253.4
# Df Model:               1                F-statistic:                 2085.
# Df Residuals:           4835             Prob (F-statistic):          0.00
# R-squared (uncentered): 0.301            Scale:                       0.77765
# ----------------------------------------------------------------------------------
#                      Coef.     Std.Err.      t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# porcent_pagos      1700.3181    37.2410   45.6571   0.0000   1627.3088   1773.3274
# --------------------------------------------------------------------------------
# Omnibus:                  2630.621          Durbin-Watson:             0.697
# Prob(Omnibus):            0.000             Jarque-Bera (JB):          38365.903
# Skew:                     -2.273            Prob(JB):                  0.000
# Kurtosis:                 16.028            Condition No.:             1
# ================================================================================
#
#
# Com constante:
#                          Results: Ordinary least squares
# ================================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.972
# Dependent Variable:     qty_2019         AIC:                         -3018.5953
# Date:                   2023-04-23 18:16 BIC:                         -3005.6276
# No. Observations:       4836             Log-Likelihood:              1511.3
# Df Model:               2                F-statistic:                 8.340e+04
# Df Residuals:           4834             Prob (F-statistic):          0.00
# R-squared (uncentered): 0.972            Scale:                       0.031352
# -----------------------------------------------------------------------------------
#                     Coef.     Std.Err.       t        P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# qty_2014            1.0304      0.0030    339.2538    0.0000      1.0244     1.0363
# porcent_pagos      -1.9186      9.0050     -0.2131    0.8313    -19.5725    15.7354
# --------------------------------------------------------------------------------
# Omnibus:                 5334.698          Durbin-Watson:             2.020
# Prob(Omnibus):           0.000             Jarque-Bera (JB):          285139.978
# Skew:                    5.890             Prob(JB):                  0.000
# Kurtosis:                38.725            Condition No.:             3571
# ================================================================================
# * The condition number is large (4e+03). This might indicate             strong
# multicollinearity or other numerical problems.
# 5/128. 3.90625% feitos. Fazendo indicador: Início de Curso de Curta Duração. Acabará em 2023-04-23 18:17:22.076061. O Último demorou: 0:00:00.215435.
#
# Com constante:
#                    Results: Ordinary least squares
# ===================================================================
# Model:              OLS              Adj. R-squared:     0.775
# Dependent Variable: qty_2019         AIC:                20871.2762
# Date:               2023-04-23 18:16 BIC:                20883.6041
# No. Observations:   3512             Log-Likelihood:     -10434.
# Df Model:           1                F-statistic:        1.209e+04
# Df Residuals:       3510             Prob (F-statistic): 0.00
# R-squared:          0.775            Scale:              22.296
# ---------------------------------------------------------------------
#               Coef.    Std.Err.      t       P>|t|    [0.025   0.975]
# ---------------------------------------------------------------------
# Intercept     1.1765     0.1049    11.2154   0.0000   0.9709   1.3822
# qty_2014      1.1777     0.0107   109.9729   0.0000   1.1567   1.1987
# -------------------------------------------------------------------
# Omnibus:             5446.439     Durbin-Watson:        2.022
# Prob(Omnibus):       0.000        Jarque-Bera (JB):     4009705.083
# ...
#                  Coef.    Std.Err.   t   P>|t|  [0.025  0.975]
# --------------------------------------------------------------
# qty_2014          0.0000       nan  nan    nan     nan     nan
# porcent_pagos  6574.5519       nan  nan    nan     nan     nan
# -------------------------------------------------------------
# Omnibus:              nan        Durbin-Watson:         nan
# Prob(Omnibus):        nan        Jarque-Bera (JB):      0.375
# Skew:                 0.000      Prob(JB):              0.829
# Kurtosis:             0.000      Condition No.:         1
# =============================================================
#
# 127/128. 99.21875% feitos. Fazendo indicador: Obtenção do Título de MBA. Acabará em 2023-04-23 18:17:12.083565. O Último demorou: 0:00:00.181428.
#
# Com constante:
#                   Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     nan
# Dependent Variable: qty_2019         AIC:                -66.4385
# Date:               2023-04-23 18:17 BIC:                -68.4385
# No. Observations:   1                Log-Likelihood:     34.219
# Df Model:           0                F-statistic:        nan
# Df Residuals:       0                Prob (F-statistic): nan
# R-squared:          -inf             Scale:              inf
# -------------------------------------------------------------------
#                Coef.    Std.Err.     t      P>|t|   [0.025   0.975]
# -------------------------------------------------------------------
# Intercept      0.5000        inf   0.0000     nan      nan      nan
# qty_2014       0.5000        inf   0.0000     nan      nan      nan
# -----------------------------------------------------------------
# Omnibus:              nan          Durbin-Watson:           0.000
# Prob(Omnibus):        nan          Jarque-Bera (JB):        0.375
# Skew:                 0.000        Prob(JB):                0.829
# Kurtosis:             0.000        Condition No.:           1
# =================================================================
#
#
# Com constante:
#                 Results: Ordinary least squares
# =============================================================
# Model:              OLS              Adj. R-squared:     nan
# Dependent Variable: qty_2019         AIC:                -inf
# Date:               2023-04-23 18:17 BIC:                -inf
# No. Observations:   1                Log-Likelihood:     inf
# Df Model:           0                F-statistic:        nan
# Df Residuals:       0                Prob (F-statistic): nan
# R-squared:          nan              Scale:              nan
# --------------------------------------------------------------
#                   Coef.   Std.Err.   t   P>|t|  [0.025  0.975]
# --------------------------------------------------------------
# Intercept         1.0000       nan  nan    nan     nan     nan
# porcent_pagos     0.0000       nan  nan    nan     nan     nan
# -------------------------------------------------------------
# Omnibus:              nan        Durbin-Watson:         nan
# Prob(Omnibus):        nan        Jarque-Bera (JB):      0.375
# Skew:                 0.000      Prob(JB):              0.829
# Kurtosis:             0.000      Condition No.:         1
# =============================================================
#
#
# Com constante:
#                   Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     nan
# Dependent Variable: qty_2019         AIC:                -66.4385
# Date:               2023-04-23 18:17 BIC:                -68.4385
# No. Observations:   1                Log-Likelihood:     34.219
# Df Model:           0                F-statistic:        nan
# Df Residuals:       0                Prob (F-statistic): nan
# R-squared:          -inf             Scale:              inf
# ------------------------------------------------------------------
#                    Coef.   Std.Err.    t     P>|t|  [0.025  0.975]
# ------------------------------------------------------------------
# Intercept          0.5000       inf  0.0000    nan     nan     nan
# qty_2014           0.5000       inf  0.0000    nan     nan     nan
# porcent_pagos      0.0000       nan     nan    nan     nan     nan
# -----------------------------------------------------------------
# Omnibus:              nan          Durbin-Watson:           0.000
# Prob(Omnibus):        nan          Jarque-Bera (JB):        0.375
# Skew:                 0.000        Prob(JB):                0.829
# Kurtosis:             0.000        Condition No.:           1
# =================================================================
#
#
# Com constante:
#                 Results: Ordinary least squares
# =============================================================
# Model:              OLS              Adj. R-squared:     nan
# Dependent Variable: qty_2019         AIC:                -inf
# Date:               2023-04-23 18:17 BIC:                -inf
# No. Observations:   1                Log-Likelihood:     inf
# Df Model:           0                F-statistic:        nan
# Df Residuals:       0                Prob (F-statistic): nan
# R-squared:          nan              Scale:              nan
# ---------------------------------------------------------------
#               Coef.    Std.Err.    t    P>|t|   [0.025   0.975]
# ---------------------------------------------------------------
# qty_2014      1.0000        nan   nan     nan      nan      nan
# -------------------------------------------------------------
# Omnibus:              nan        Durbin-Watson:         nan
# Prob(Omnibus):        nan        Jarque-Bera (JB):      0.375
# Skew:                 0.000      Prob(JB):              0.829
# Kurtosis:             0.000      Condition No.:         1
# =============================================================
#
#
# Com constante:
#                         Results: Ordinary least squares
# =============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.000
# Dependent Variable:     qty_2019         AIC:                         2.8379
# Date:                   2023-04-23 18:17 BIC:                         2.8379
# No. Observations:       1                Log-Likelihood:              -1.4189
# Df Model:               0                F-statistic:                 nan
# Df Residuals:           1                Prob (F-statistic):          nan
# R-squared (uncentered): 0.000            Scale:                       1.0000
# ---------------------------------------------------------------------------------
#                       Coef.      Std.Err.      t      P>|t|     [0.025     0.975]
# ---------------------------------------------------------------------------------
# porcent_pagos         0.0000       0.0000     nan       nan     0.0000     0.0000
# -----------------------------------------------------------------------------
# Omnibus:                  nan              Durbin-Watson:               0.000
# Prob(Omnibus):            nan              Jarque-Bera (JB):            0.375
# Skew:                     0.000            Prob(JB):                    0.829
# Kurtosis:                 0.000            Condition No.:               nan
# =============================================================================
# The smallest eigenvalue is      0. This might indicate that            there
# are strong multicollinearity problems or that the design            matrix is
# singular.
#
# Com constante:
# C:\Python\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 1 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\Python\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:50: RuntimeWarning: invalid value encountered in double_scalars
#   dw = np.sum(diff_resids**2, axis=axis) / np.sum(resids**2, axis=axis)
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1650: RuntimeWarning: invalid value encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1715: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1728: RuntimeWarning: invalid value encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:903: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# C:\Python\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 1 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1650: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1728: RuntimeWarning: invalid value encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# C:\Python\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 1 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\Python\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:50: RuntimeWarning: invalid value encountered in double_scalars
#   dw = np.sum(diff_resids**2, axis=axis) / np.sum(resids**2, axis=axis)
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1650: RuntimeWarning: invalid value encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1715: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1728: RuntimeWarning: invalid value encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:903: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# C:\Python\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 1 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1650: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# C:\Python\anaconda3\lib\site-packages\statsmodels\base\model.py:1452: RuntimeWarning: invalid value encountered in multiply
#   cov_p = self.normalized_cov_params * scale
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1728: RuntimeWarning: invalid value encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# C:\Python\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 1 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\Python\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:50: RuntimeWarning: invalid value encountered in double_scalars
#   dw = np.sum(diff_resids**2, axis=axis) / np.sum(resids**2, axis=axis)
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1650: RuntimeWarning: invalid value encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1715: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1728: RuntimeWarning: invalid value encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:903: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# C:\Python\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 1 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1860: RuntimeWarning: invalid value encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
# C:\Python\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 1 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\Python\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:50: RuntimeWarning: invalid value encountered in double_scalars
#   dw = np.sum(diff_resids**2, axis=axis) / np.sum(resids**2, axis=axis)
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1650: RuntimeWarning: invalid value encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1715: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1728: RuntimeWarning: invalid value encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# C:\Python\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:903: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
#                Results: Ordinary least squares
# =============================================================
# Model:              OLS              Adj. R-squared:     nan
# Dependent Variable: qty_2019         AIC:                -inf
# Date:               2023-04-23 18:17 BIC:                -inf
# No. Observations:   1                Log-Likelihood:     inf
# Df Model:           0                F-statistic:        nan
# Df Residuals:       0                Prob (F-statistic): nan
# R-squared:          nan              Scale:              nan
# --------------------------------------------------------------
#                   Coef.   Std.Err.   t   P>|t|  [0.025  0.975]
# --------------------------------------------------------------
# qty_2014          1.0000       nan  nan    nan     nan     nan
# porcent_pagos     0.0000       nan  nan    nan     nan     nan
# -------------------------------------------------------------
# Omnibus:              nan        Durbin-Watson:         nan
# Prob(Omnibus):        nan        Jarque-Bera (JB):      0.375
# Skew:                 0.000      Prob(JB):              0.829
# Kurtosis:             0.000      Condition No.:         1
# =============================================================

# %%
regressões = pd.DataFrame(lista_regressões)
regressões = pd.concat([regressões, 
                        regressões['Parâmetros'].apply(pd.Series), 
                        regressões['P>|t|'].apply(pd.Series), 
                        regressões['Standard Error'].apply(pd.Series)], 
                       axis=1)
regressões.to_excel(f'Regressões dos Doutorandos {ano_início} com Pareamento e sem Reposição.xlsx')

# %% [markdown]
# def real_br_money_mask(my_value):
#     a = '{:,.2f}'.format(float(my_value))
#     b = a.replace(',','v')
#     c = b.replace('.',',')
#     return c.replace('v','.')

# %% [markdown]
# Impacto = []
# for indicador in dt.indicador_tipo.unique():
#
#     try:
#         delta_cnpq = regressões.loc[regressões.Indicador == indicador].Parâmetros.iloc[0].loc['percentual_pago']
#         tamanho_amastra = len(dt[['id', 'pagtos']].loc[dt['pagtos']>0].loc[dt['indicador_tipo'] == indicador].drop_duplicates())
#         #efetividade = tamanho_amastra * delta_cnpq
#         efetividade = delta_cnpq
#
#         temp = {
#             'Indicador': indicador,
#             'Tamanho Amostra:': tamanho_amastra,
#             'Delta (CNPq): ': delta_cnpq,
#             'Efetividade: ': efetividade,
#             'Custo: ': real_br_money_mask(valor_total_cnpq),
#             'Custo-efetividade: ': real_br_money_mask(valor_total_cnpq/efetividade),
#         }
#         Impacto.append(temp)
#         print(temp)
#     except:
#         pass

# %% [markdown]
# impacto = pd.DataFrame(Impacto)
# impacto.to_excel(f'Impacto dos Doutorandos {ano_início} com Pareamento e Não Reposição - confiança 001.xlsx')

# %%
modelo_ajustado = sm2.ols(formula = 'qty_2019 ~ qty_2014 + C(bool_cnpq)', data = df)
modelo_treinado = modelo_ajustado.fit()
modelo_treinado.summary()

# %%
len(df.loc[df.bool_cnpq==True])*modelo_treinado.params[1]

# %%
df.loc[df.qty_2014 == 0].loc[df.pagtos==0].qty_2014.sum()

# %%
(df.loc[df.qty_2014 == 0].loc[df.pagtos==0].qty_2019.sum())/len(df.loc[df.qty_2014 == 0].loc[df.pagtos==0].qty_2014)

# %%
modelo_ajustado = sm2.ols(formula = 'qty_2019 ~ qty_2014 + pagtos -1', data = df)
modelo_treinado = modelo_ajustado.fit()
modelo_treinado.summary2()

# %%
valor_total_cnpq * modelo_treinado.params.pagtos

# %%
1/modelo_treinado.params.pagtos

# %%
modelo_treinado.rsquared_adj

# %%
df_cnpq = df.loc[df.pagtos > 0]
df_par = df.loc[df.pagtos == 0]

# %%
df_cnpq.qty_2014.sum()

# %%
df_cnpq.qty_2019.sum()

# %%
df_par.qty_2014.sum()

# %%
df_par.qty_2019.sum()

# %%
df_par.qty_2019.sum()/df_par.qty_2014.sum()

# %%
df_cnpq.qty_2019.sum()/df_cnpq.qty_2014.sum()

# %%
((df_cnpq.qty_2019.sum()/df_cnpq.qty_2014.sum())-(df_par.qty_2019.sum()/df_par.qty_2014.sum()))*df_cnpq.qty_2014.sum()
