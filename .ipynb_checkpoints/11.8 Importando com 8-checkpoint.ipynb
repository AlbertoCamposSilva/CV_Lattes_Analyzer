# %%
from Carga import Carga
cg = Carga()


#Origens
cg.de_hd = False
cg.de_all_lattes = True
cg.de_bd_demanda_bruta = False
cg.de_dados_pessoais = False

#Exceções
cg.pular_indicadores = False
cg.pular_palavras_chave = False
cg.pular_areas_conhecimento = False
cg.pular_publicações = True
cg.pular_dados_gerais=False
cg.pular_vinculos = False
cg.pular_erros = False
cg.pular_jsons = False

#Importações
cg.on_conflic_update = True
cg.importar_indicadores = True
cg.importar_palavras_chave = True
cg.importar_areas_conhecimento = True
cg.importar_publicações = True
cg.importar_dados_gerais=True
cg.importar_vinculos = True


#Outras Configurações
cg.on_conflic_update = True
cg.auto_save_json_to_bd = True
cg.pegar_lista_de_importação_de_arquivo = False
cg.data_mínima_atualização_lattes = None

cg.atualiza_todos_os_indicadores(começando_com = '8')
# Out:
# Iniciando Importação.
# Importação iniciada em 21/03/2022, 20:37:1218.
# 0.6% importados.
#
# Linhas por segundo lidas (total): 12.4
# 10,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 09:17:43
#
#
# Importação iniciada em 21/03/2022, 20:37:12489.
# 1.2% importados.
#
# Linhas por segundo lidas (total): 12.6
# 20,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 08:45:49
#
#
# Tentando recuperar Lattes compactado 8343900542098368 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8343900542098368
# Tentando recuperar Lattes compactado 8372638068076004 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8372638068076004
# Tentando recuperar Lattes compactado 8051483991560928 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8051483991560928
# Importação iniciada em 21/03/2022, 20:37:12774.
# 1.8% importados.
#
# Linhas por segundo lidas (total): 12.5
# 30,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 09:15:23
#
#
# Tentando recuperar Lattes compactado 8574142718008629 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8574142718008629
# Tentando recuperar Lattes compactado 8252703377309543 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8252703377309543
# Tentando recuperar Lattes compactado 8712804571134584 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8712804571134584
# Importação iniciada em 21/03/2022, 20:37:12579.
# 2.4% importados.
#
# Linhas por segundo lidas (total): 12.4
# 40,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 09:24:53
#
#
# Tentando recuperar Lattes compactado 8876285063964907 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8876285063964907
# Importação iniciada em 21/03/2022, 20:37:12559.
# 3.0% importados.
#
# Linhas por segundo lidas (total): 12.2
# 50,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 09:56:32
#
#
# Importação iniciada em 21/03/2022, 20:37:12670.
# 3.7% importados.
#
# Linhas por segundo lidas (total): 12.1
# 60,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 10:25:24
#
#
# Tentando recuperar Lattes compactado 8454348436709313 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8454348436709313
# Importação iniciada em 21/03/2022, 20:37:12539.
# 4.3% importados.
#
# Linhas por segundo lidas (total): 12.2
# 70,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 10:11:06
#
#
# Tentando recuperar Lattes compactado 8198245433222968 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8198245433222968
# Importação iniciada em 21/03/2022, 20:37:12516.
# 4.9% importados.
#
# Linhas por segundo lidas (total): 12.3
# 80,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 09:52:30
#
#
# Tentando recuperar Lattes compactado 8484722352381524 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8484722352381524
# Importação iniciada em 21/03/2022, 20:37:12010.
# 5.5% importados.
#
# Linhas por segundo lidas (total): 12.2
# 90,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 09:57:16
#
#
# Tentando recuperar Lattes compactado 8318656475361096 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8318656475361096
# Tentando recuperar Lattes compactado 8116282721209467 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8116282721209467
# Importação iniciada em 21/03/2022, 20:37:12829.
# 6.1% importados.
#
# Linhas por segundo lidas (total): 12.3
# 100,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 09:43:01
#
#
# Importação iniciada em 21/03/2022, 20:37:121578.
# 6.7% importados.
#
# Linhas por segundo lidas (total): 12.3
# 110,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 09:42:33
#
#
# Importação iniciada em 21/03/2022, 20:37:124872.
# 7.3% importados.
#
# Linhas por segundo lidas (total): 12.3
# 120,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 09:52:12
#
#
# Tentando recuperar Lattes compactado 8898219841445861 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8898219841445861
# Tentando recuperar Lattes compactado 8104768798721217 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8104768798721217
# Tentando recuperar Lattes compactado 8064380807483737 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8064380807483737
# Tentando recuperar Lattes compactado 8938519550109755 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8938519550109755
# Importação iniciada em 21/03/2022, 20:37:121526.
# 7.9% importados.
#
# Linhas por segundo lidas (total): 12.2
# 130,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 09:55:55
#
#
# Importação iniciada em 21/03/2022, 20:37:120579.
# 8.5% importados.
#
# Linhas por segundo lidas (total): 12.2
# 140,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 10:06:36
#
#
# Tentando recuperar Lattes compactado 8793316204761326 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8793316204761326
# Tentando recuperar Lattes compactado 8215842880170550 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8215842880170550
# Tentando recuperar Lattes compactado 8427107555237826 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8427107555237826
# Importação iniciada em 21/03/2022, 20:37:122171.
# 9.1% importados.
#
# Linhas por segundo lidas (total): 12.2
# 150,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 10:04:35
#
#
# Tentando recuperar Lattes compactado 8533117287436596 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8533117287436596
# Importação iniciada em 21/03/2022, 20:37:123829.
# 9.7% importados.
#
# Linhas por segundo lidas (total): 12.1
# 160,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 10:22:59
#
#
# Tentando recuperar Lattes compactado 8576727399643949 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8576727399643949
# Importação iniciada em 21/03/2022, 20:37:124919.
# 10.3% importados.
#
# Linhas por segundo lidas (total): 12.1
# 170,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 10:27:27
#
#
# Importação iniciada em 21/03/2022, 20:37:126656.
# 11.0% importados.
#
# Linhas por segundo lidas (total): 12.0
# 180,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 10:35:06
#
#
# Tentando recuperar Lattes compactado 8254060148074696 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8254060148074696
# Tentando recuperar Lattes compactado 8657238739694063 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8657238739694063
# Tentando recuperar Lattes compactado 8014360189240093 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8014360189240093
# Importação iniciada em 21/03/2022, 20:37:128397.
# 11.6% importados.
#
# Linhas por segundo lidas (total): 12.0
# 190,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 10:30:53
#
#
# Tentando recuperar Lattes compactado 8176324843514875 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8176324843514875
# Importação iniciada em 21/03/2022, 20:37:129409.
# 12.2% importados.
#
# Linhas por segundo lidas (total): 12.1
# 200,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 10:28:46
#
#
# Tentando recuperar Lattes compactado 8990256491607680 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8990256491607680
# Importação iniciada em 21/03/2022, 20:37:129456.
# 12.8% importados.
#
# Linhas por segundo lidas (total): 12.1
# 210,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 10:27:47
#
#
# Importação iniciada em 21/03/2022, 20:37:121649.
# 13.4% importados.
#
# Linhas por segundo lidas (total): 12.1
# 220,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 10:26:51
#
#
# Importação iniciada em 21/03/2022, 20:37:123986.
# 14.0% importados.
#
# Linhas por segundo lidas (total): 12.0
# 230,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 10:33:47
#
#
# Tentando recuperar Lattes compactado 8269540561553203 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8269540561553203
# Tentando recuperar Lattes compactado 8590444977829778 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8590444977829778
# Tentando recuperar Lattes compactado 8857105703399751 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8857105703399751
# Importação iniciada em 21/03/2022, 20:37:126562.
# 14.6% importados.
#
# Linhas por segundo lidas (total): 12.0
# 240,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 10:33:24
#
#
# Tentando recuperar Lattes compactado 8336459817348290 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8336459817348290
# Tentando recuperar Lattes compactado 8108470725125451 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8108470725125451
# Importação iniciada em 21/03/2022, 20:37:122732.
# 15.2% importados.
#
# Linhas por segundo lidas (total): 12.0
# 250,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 10:48:44
#
#
# Tentando recuperar Lattes compactado 8924441660536015 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8924441660536015
# Importação iniciada em 21/03/2022, 20:37:127999.
# 15.8% importados.
#
# Linhas por segundo lidas (total): 12.0
# 260,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 10:46:16
#
#
# Importação iniciada em 21/03/2022, 20:37:121337.
# 16.4% importados.
#
# Linhas por segundo lidas (total): 12.0
# 270,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 10:44:26
#
#
# Tentando recuperar Lattes compactado 8493676591107620 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8493676591107620
# Importação iniciada em 21/03/2022, 20:37:124412.
# 17.0% importados.
#
# Linhas por segundo lidas (total): 12.0
# 280,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 10:43:52
#
#
# Tentando recuperar Lattes compactado 8976165561490797 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8976165561490797
# Importação iniciada em 21/03/2022, 20:37:127867.
# 17.6% importados.
#
# Linhas por segundo lidas (total): 12.0
# 290,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 10:45:45
#
#
# Importação iniciada em 21/03/2022, 20:37:122246.
# 18.3% importados.
#
# Linhas por segundo lidas (total): 12.0
# 300,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 10:41:27
#
#
# Importação iniciada em 21/03/2022, 20:37:124423.
# 18.9% importados.
#
# Linhas por segundo lidas (total): 11.9
# 310,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 10:49:57
#
#
# Tentando recuperar Lattes compactado 8783496902788900 via SOAP
# Erro 1: "Erro nao previsto!".
# Esperando 16 segundos.
# Tentando novamente.
# Tentando recuperar Lattes compactado 8783496902788900 via SOAP
# Erro 2: "Erro nao previsto!".
# Esperando 64 segundos.
# Tentando novamente.
# Tentando recuperar Lattes compactado 8783496902788900 via SOAP
# Erro 3: "Erro nao previsto!".
# Esperando 144 segundos.
# Tentando novamente.
# Tentando recuperar Lattes compactado 8783496902788900 via SOAP
# ERRRO - Lattes não está carregado. ID: 8783496902788900
# Tentando recuperar Lattes compactado 8601705616489032 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8601705616489032
# Tentando recuperar Lattes compactado 8453126569274325 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8453126569274325
# Importação iniciada em 21/03/2022, 20:37:122617.
# 19.5% importados.
#
# Linhas por segundo lidas (total): 11.8
# 320,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 11:20:36
#
#
# Tentando recuperar Lattes compactado 8617758923861221 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8617758923861221
# Importação iniciada em 21/03/2022, 20:37:126632.
# 20.1% importados.
#
# Linhas por segundo lidas (total): 11.8
# 330,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 11:17:43
#
#
# Importação iniciada em 21/03/2022, 20:37:120534.
# 20.7% importados.
#
# Linhas por segundo lidas (total): 11.8
# 340,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 11:18:18
#
#
# Tentando recuperar Lattes compactado 8637008831730220 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8637008831730220
# Tentando recuperar Lattes compactado 8390157225505240 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8390157225505240
# Tentando recuperar Lattes compactado 8318697210225099 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8318697210225099
# Tentando recuperar Lattes compactado 8735352722825436 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8735352722825436
# Tentando recuperar Lattes compactado 8989725523845931 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8989725523845931
# Tentando recuperar Lattes compactado 8864841803927240 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8864841803927240
# Importação iniciada em 21/03/2022, 20:37:120603.
# 21.3% importados.
#
# Linhas por segundo lidas (total): 11.8
# 350,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 11:13:28
#
#
# Tentando recuperar Lattes compactado 8064380589455212 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8064380589455212
# Tentando recuperar Lattes compactado 8014394006880452 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8014394006880452
# Importação iniciada em 21/03/2022, 20:37:121164.
# 21.9% importados.
#
# Linhas por segundo lidas (total): 11.8
# 360,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 11:14:59
#
#
# Tentando recuperar Lattes compactado 8351152762256588 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8351152762256588
# Importação iniciada em 21/03/2022, 20:37:123066.
# 22.5% importados.
#
# Linhas por segundo lidas (total): 11.8
# 370,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 11:16:31
#
#
# Importação iniciada em 21/03/2022, 20:37:123337.
# 23.1% importados.
#
# Linhas por segundo lidas (total): 11.8
# 380,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 11:16:24
#
#
# Tentando recuperar Lattes compactado 8321469014534936 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8321469014534936
# Tentando recuperar Lattes compactado 8523506373374592 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8523506373374592
# Tentando recuperar Lattes compactado 8777569392539891 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8777569392539891
# Tentando recuperar Lattes compactado 8112293582735808 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8112293582735808
# Importação iniciada em 21/03/2022, 20:37:121831.
# 23.7% importados.
#
# Linhas por segundo lidas (total): 11.8
# 390,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 11:15:35
#
#
# Tentando recuperar Lattes compactado 8160511560971961 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8160511560971961
# Tentando recuperar Lattes compactado 8001505565319925 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8001505565319925
# Tentando recuperar Lattes compactado 8035084928991369 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8035084928991369
# Importação iniciada em 21/03/2022, 20:37:121695.
# 24.3% importados.
#
# Linhas por segundo lidas (total): 11.8
# 400,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 11:14:44
#
#
# Tentando recuperar Lattes compactado 8705930240648301 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8705930240648301
# Importação iniciada em 21/03/2022, 20:37:125469.
# 24.9% importados.
#
# Linhas por segundo lidas (total): 11.7
# 410,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 11:31:43
#
#
# Importação iniciada em 21/03/2022, 20:37:127715.
# 25.6% importados.
#
# Linhas por segundo lidas (total): 11.7
# 420,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 11:32:44
#
#
# Tentando recuperar Lattes compactado 8294136696623193 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8294136696623193
# Importação iniciada em 21/03/2022, 20:37:126674.
# 26.2% importados.
#
# Linhas por segundo lidas (total): 11.7
# 430,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 11:35:30
#
#
# Tentando recuperar Lattes compactado 8579394254950558 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8579394254950558
# Importação iniciada em 21/03/2022, 20:37:122205.
# 26.8% importados.
#
# Linhas por segundo lidas (total): 11.7
# 440,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 11:39:33
#
#
# Importação iniciada em 21/03/2022, 20:37:121053.
# 27.4% importados.
#
# Linhas por segundo lidas (total): 11.7
# 450,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 11:44:44
#
#
# Importação iniciada em 21/03/2022, 20:37:122736.
# 28.0% importados.
#
# Linhas por segundo lidas (total): 11.6
# 460,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 11:50:10
#
#
# Tentando recuperar Lattes compactado 8648773203873725 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8648773203873725
# Tentando recuperar Lattes compactado 8201377112288118 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8201377112288118
# Importação iniciada em 21/03/2022, 20:37:127818.
# 28.6% importados.
#
# Linhas por segundo lidas (total): 11.6
# 470,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 11:51:10
#
#
# Tentando recuperar Lattes compactado 8194135982722993 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8194135982722993
# Importação iniciada em 21/03/2022, 20:37:120293.
# 29.2% importados.
#
# Linhas por segundo lidas (total): 11.6
# 480,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 12:01:19
#
#
# Tentando recuperar Lattes compactado 8344862550531888 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8344862550531888
# Tentando recuperar Lattes compactado 8743232763727533 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8743232763727533
# Tentando recuperar Lattes compactado 8743438381645284 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8743438381645284
# Tentando recuperar Lattes compactado 8393322457348478 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8393322457348478
# Importação iniciada em 21/03/2022, 20:37:123169.
# 29.8% importados.
#
# Linhas por segundo lidas (total): 11.4
# 490,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 12:32:35
#
#
# Importação iniciada em 21/03/2022, 20:37:127294.
# 30.4% importados.
#
# Linhas por segundo lidas (total): 11.3
# 500,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 12:57:23
#
#
# Tentando recuperar Lattes compactado 8050013624070466 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8050013624070466
# Tentando recuperar Lattes compactado 8145837206688705 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8145837206688705
# Importação iniciada em 21/03/2022, 20:37:126647.
# 31.0% importados.
#
# Linhas por segundo lidas (total): 11.1
# 510,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 13:36:09
#
#
# Tentando recuperar Lattes compactado 8859639911200564 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8859639911200564
# Tentando recuperar Lattes compactado 8533462833419746 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8533462833419746
# Importação iniciada em 21/03/2022, 20:37:123668.
# 31.6% importados.
#
# Linhas por segundo lidas (total): 11.1
# 520,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 13:40:53
#
#
# Tentando recuperar Lattes compactado 8398072903301988 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8398072903301988
# Importação iniciada em 21/03/2022, 20:37:124421.
# 32.2% importados.
#
# Linhas por segundo lidas (total): 11.0
# 530,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:01:23
#
#
# Tentando recuperar Lattes compactado 8290906333301272 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8290906333301272
# Tentando recuperar Lattes compactado 8145978013177256 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8145978013177256
# Tentando recuperar Lattes compactado 8386635627896137 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8386635627896137
# Importação iniciada em 21/03/2022, 20:37:121179.
# 32.9% importados.
#
# Linhas por segundo lidas (total): 10.8
# 540,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:43:54
#
#
# Importação iniciada em 21/03/2022, 20:37:121634.
# 33.5% importados.
#
# Linhas por segundo lidas (total): 10.7
# 550,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:07:32
#
#
# Importação iniciada em 21/03/2022, 20:37:125400.
# 34.1% importados.
#
# Linhas por segundo lidas (total): 10.7
# 560,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:25:43
#
#
# Tentando recuperar Lattes compactado 8682557545426924 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8682557545426924
# Tentando recuperar Lattes compactado 8461850883210811 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8461850883210811
# Importação iniciada em 21/03/2022, 20:37:126722.
# 34.7% importados.
#
# Linhas por segundo lidas (total): 10.5
# 570,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 16:04:14
#
#
# Tentando recuperar Lattes compactado 8342917526069321 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8342917526069321
# Tentando recuperar Lattes compactado 8521084218206717 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8521084218206717
# Importação iniciada em 21/03/2022, 20:37:122706.
# 35.3% importados.
#
# Linhas por segundo lidas (total): 10.5
# 580,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 16:09:12
#
#
# Tentando recuperar Lattes compactado 8911519787813183 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8911519787813183
# Importação iniciada em 21/03/2022, 20:37:124688.
# 35.9% importados.
#
# Linhas por segundo lidas (total): 10.5
# 590,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 16:02:44
#
#
# Importação iniciada em 21/03/2022, 20:37:124140.
# 36.5% importados.
#
# Linhas por segundo lidas (total): 10.5
# 600,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:56:21
#
#
# Tentando recuperar Lattes compactado 8620132113055012 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8620132113055012
# Importação iniciada em 21/03/2022, 20:37:124103.
# 37.1% importados.
#
# Linhas por segundo lidas (total): 10.6
# 610,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:51:12
#
#
# Tentando recuperar Lattes compactado 8643596314426261 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8643596314426261
# Importação iniciada em 21/03/2022, 20:37:122597.
# 37.7% importados.
#
# Linhas por segundo lidas (total): 10.6
# 620,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:41:58
#
#
# Tentando recuperar Lattes compactado 8107617983897879 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8107617983897879
# Tentando recuperar Lattes compactado 8601495759405180 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8601495759405180
# Tentando recuperar Lattes compactado 8712383869250781 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8712383869250781
# Importação iniciada em 21/03/2022, 20:37:129602.
# 38.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 630,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:34:29
#
#
# Tentando recuperar Lattes compactado 8128617309402674 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8128617309402674
# Importação iniciada em 21/03/2022, 20:37:120461.
# 38.9% importados.
#
# Linhas por segundo lidas (total): 10.7
# 640,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:28:01
#
#
# Tentando recuperar Lattes compactado 8349257646012634 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8349257646012634
# Importação iniciada em 21/03/2022, 20:37:126064.
# 39.5% importados.
#
# Linhas por segundo lidas (total): 10.7
# 650,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:20:57
#
#
# Importação iniciada em 21/03/2022, 20:37:124577.
# 40.2% importados.
#
# Linhas por segundo lidas (total): 10.7
# 660,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:13:09
#
#
# Tentando recuperar Lattes compactado 8924329983807565 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8924329983807565
# Importação iniciada em 21/03/2022, 20:37:125164.
# 40.8% importados.
#
# Linhas por segundo lidas (total): 10.7
# 670,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:06:36
#
#
# Importação iniciada em 21/03/2022, 20:37:127380.
# 41.4% importados.
#
# Linhas por segundo lidas (total): 10.8
# 680,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:04:16
#
#
# Importação iniciada em 21/03/2022, 20:37:120407.
# 42.0% importados.
#
# Linhas por segundo lidas (total): 10.7
# 690,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:08:31
#
#
# Tentando recuperar Lattes compactado 8489135968933851 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8489135968933851
# Importação iniciada em 21/03/2022, 20:37:128714.
# 42.6% importados.
#
# Linhas por segundo lidas (total): 10.8
# 700,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:02:28
#
#
# Importação iniciada em 21/03/2022, 20:37:124451.
# 43.2% importados.
#
# Linhas por segundo lidas (total): 10.8
# 710,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:57:48
#
#
# Tentando recuperar Lattes compactado 8178182564305534 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8178182564305534
# Tentando recuperar Lattes compactado 8238259389371783 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8238259389371783
# Importação iniciada em 21/03/2022, 20:37:124078.
# 43.8% importados.
#
# Linhas por segundo lidas (total): 10.8
# 720,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:54:33
#
#
# Tentando recuperar Lattes compactado 8069452478862588 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8069452478862588
# Tentando recuperar Lattes compactado 8991150876118183 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8991150876118183
# Importação iniciada em 21/03/2022, 20:37:123367.
# 44.4% importados.
#
# Linhas por segundo lidas (total): 10.8
# 730,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:48:08
#
#
# Tentando recuperar Lattes compactado 8175393340539965 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8175393340539965
# Tentando recuperar Lattes compactado 8877215726455250 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8877215726455250
# Importação iniciada em 21/03/2022, 20:37:123775.
# 45.0% importados.
#
# Linhas por segundo lidas (total): 10.8
# 740,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:45:07
#
#
# Tentando recuperar Lattes compactado 8906137786419519 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8906137786419519
# Tentando recuperar Lattes compactado 8768863470672626 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8768863470672626
# Importação iniciada em 21/03/2022, 20:37:128822.
# 45.6% importados.
#
# Linhas por segundo lidas (total): 10.9
# 750,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:41:54
#
#
# Tentando recuperar Lattes compactado 8157626268654248 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8157626268654248
# Tentando recuperar Lattes compactado 8355077008685037 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8355077008685037
# Tentando recuperar Lattes compactado 8691774197452240 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8691774197452240
# Tentando recuperar Lattes compactado 8930226670032693 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8930226670032693
# Importação iniciada em 21/03/2022, 20:37:129805.
# 46.2% importados.
#
# Linhas por segundo lidas (total): 10.9
# 760,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:38:20
#
#
# Importação iniciada em 21/03/2022, 20:37:125456.
# 46.8% importados.
#
# Linhas por segundo lidas (total): 10.9
# 770,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:33:54
#
#
# Tentando recuperar Lattes compactado 8020425712772289 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8020425712772289
# Importação iniciada em 21/03/2022, 20:37:126270.
# 47.5% importados.
#
# Linhas por segundo lidas (total): 10.9
# 780,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:28:38
#
#
# Importação iniciada em 21/03/2022, 20:37:122842.
# 48.1% importados.
#
# Linhas por segundo lidas (total): 10.9
# 790,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:28:06
#
#
# Tentando recuperar Lattes compactado 8479264838180729 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8479264838180729
# Importação iniciada em 21/03/2022, 20:37:121319.
# 48.7% importados.
#
# Linhas por segundo lidas (total): 10.9
# 800,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:24:12
# Tentando recuperar Lattes compactado 8550018151279905 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8550018151279905
# Tentando recuperar Lattes compactado 8289195556481753 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8289195556481753
# Importação iniciada em 21/03/2022, 20:37:121569.
# 49.3% importados.
#
# Linhas por segundo lidas (total): 10.9
# 810,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:23:49
#
#
# Tentando recuperar Lattes compactado 8353392132418880 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8353392132418880
# Importação iniciada em 21/03/2022, 20:37:124646.
# 49.9% importados.
#
# Linhas por segundo lidas (total): 10.9
# 820,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:21:31
#
#
# Importação iniciada em 21/03/2022, 20:37:127391.
# 50.5% importados.
#
# Linhas por segundo lidas (total): 11.0
# 830,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:17:29
#
#
# Tentando recuperar Lattes compactado 8644289079123894 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8644289079123894
# Importação iniciada em 21/03/2022, 20:37:125335.
# 51.1% importados.
#
# Linhas por segundo lidas (total): 11.0
# 840,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:16:10
#
#
# Importação iniciada em 21/03/2022, 20:37:123309.
# 51.7% importados.
#
# Linhas por segundo lidas (total): 11.0
# 850,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:09:56
#
#
# Tentando recuperar Lattes compactado 8502539242778624 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8502539242778624
# Importação iniciada em 21/03/2022, 20:37:124143.
# 52.3% importados.
#
# Linhas por segundo lidas (total): 11.0
# 860,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:14:25
#
#
# Tentando recuperar Lattes compactado 8650956250585031 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8650956250585031
# Importação iniciada em 21/03/2022, 20:37:121168.
# 52.9% importados.
#
# Linhas por segundo lidas (total): 11.0
# 870,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:16:30
#
#
# Importação iniciada em 21/03/2022, 20:37:129318.
# 53.5% importados.
#
# Linhas por segundo lidas (total): 10.9
# 880,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:24:33
#
#
# Tentando recuperar Lattes compactado 8950526007201742 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8950526007201742
# Importação iniciada em 21/03/2022, 20:37:124642.
# 54.1% importados.
#
# Linhas por segundo lidas (total): 10.9
# 890,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:27:36
#
#
# Tentando recuperar Lattes compactado 8785787172080732 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8785787172080732
# Tentando recuperar Lattes compactado 8082303840978998 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8082303840978998
# Importação iniciada em 21/03/2022, 20:37:124862.
# 54.8% importados.
#
# Linhas por segundo lidas (total): 10.9
# 900,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:29:22
#
#
# Importação iniciada em 21/03/2022, 20:37:125509.
# 55.4% importados.
#
# Linhas por segundo lidas (total): 10.9
# 910,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:35:27
#
#
# Tentando recuperar Lattes compactado 8223125838606103 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8223125838606103
# Importação iniciada em 21/03/2022, 20:37:127234.
# 56.0% importados.
#
# Linhas por segundo lidas (total): 10.9
# 920,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:38:14
#
#
# Tentando recuperar Lattes compactado 8516392087057704 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8516392087057704
# Importação iniciada em 21/03/2022, 20:37:126049.
# 56.6% importados.
#
# Linhas por segundo lidas (total): 10.8
# 930,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:44:54
#
#
# Importação iniciada em 21/03/2022, 20:37:122825.
# 57.2% importados.
#
# Linhas por segundo lidas (total): 10.8
# 940,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:47:37
#
#
# Tentando recuperar Lattes compactado 8142761701081255 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8142761701081255
# Tentando recuperar Lattes compactado 8009907712220238 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8009907712220238
# Importação iniciada em 21/03/2022, 20:37:120135.
# 57.8% importados.
#
# Linhas por segundo lidas (total): 10.8
# 950,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:50:38
#
#
# Importação iniciada em 21/03/2022, 20:37:125718.
# 58.4% importados.
#
# Linhas por segundo lidas (total): 10.8
# 960,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:52:18
#
#
# Importação iniciada em 21/03/2022, 20:37:128038.
# 59.0% importados.
#
# Linhas por segundo lidas (total): 10.8
# 970,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:55:58
#
#
# Tentando recuperar Lattes compactado 8181939818705855 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8181939818705855
# Importação iniciada em 21/03/2022, 20:37:127238.
# 59.6% importados.
#
# Linhas por segundo lidas (total): 10.8
# 980,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 14:57:22
#
#
# Tentando recuperar Lattes compactado 8210066067226860 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8210066067226860
# Importação iniciada em 21/03/2022, 20:37:127435.
# 60.2% importados.
#
# Linhas por segundo lidas (total): 10.8
# 990,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:01:04
#
#
# Importação iniciada em 21/03/2022, 20:37:127235.
# 60.8% importados.
#
# Linhas por segundo lidas (total): 10.8
# 1,000,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:00:34
#
#
# Importação iniciada em 21/03/2022, 20:37:1283192.
# 61.4% importados.
#
# Linhas por segundo lidas (total): 10.8
# 1,010,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:01:46
#
#
# ERRRO - Lattes não está carregado. ID: 8450839038174929
# Tentando recuperar Lattes compactado 8376519887901486 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8376519887901486
# Importação iniciada em 21/03/2022, 20:37:1282773.
# 62.1% importados.
#
# Linhas por segundo lidas (total): 10.8
# 1,020,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:02:38
#
#
# Tentando recuperar Lattes compactado 8552401640987586 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8552401640987586
# Tentando recuperar Lattes compactado 8599235358639229 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8599235358639229
# Importação iniciada em 21/03/2022, 20:37:1298769.
# 62.7% importados.
#
# Linhas por segundo lidas (total): 10.8
# 1,030,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:01:10
#
#
# Tentando recuperar Lattes compactado 8127467751880329 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8127467751880329
# Tentando recuperar Lattes compactado 8318281269652816 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8318281269652816
# Tentando recuperar Lattes compactado 8741387678323980 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8741387678323980
# Importação iniciada em 21/03/2022, 20:37:1290968.
# 63.3% importados.
#
# Linhas por segundo lidas (total): 10.8
# 1,040,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:04:48
#
#
# Tentando recuperar Lattes compactado 8558397710588187 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8558397710588187
# Tentando recuperar Lattes compactado 8215204801600346 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8215204801600346
# Tentando recuperar Lattes compactado 8933522187672771 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8933522187672771
# Importação iniciada em 21/03/2022, 20:37:1224262.
# 63.9% importados.
#
# Linhas por segundo lidas (total): 10.7
# 1,050,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:09:16
#
#
# Tentando recuperar Lattes compactado 8109960768131544 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8109960768131544
# Tentando recuperar Lattes compactado 8014829692557079 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8014829692557079
# Importação iniciada em 21/03/2022, 20:37:1217570.
# 64.5% importados.
#
# Linhas por segundo lidas (total): 10.7
# 1,060,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:08:18
#
#
# Importação iniciada em 21/03/2022, 20:37:1217764.
# 65.1% importados.
#
# Linhas por segundo lidas (total): 10.7
# 1,070,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:12:22
#
#
# Tentando recuperar Lattes compactado 8842848440643814 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8842848440643814
# Tentando recuperar Lattes compactado 8847459143990041 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8847459143990041
# Importação iniciada em 21/03/2022, 20:37:1212235.
# 65.7% importados.
#
# Linhas por segundo lidas (total): 10.7
# 1,080,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:11:24
#
#
# Tentando recuperar Lattes compactado 8660432664353505 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8660432664353505
# Importação iniciada em 21/03/2022, 20:37:1284339.
# 66.3% importados.
#
# Linhas por segundo lidas (total): 10.7
# 1,090,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:19:13
#
#
# Importação iniciada em 21/03/2022, 20:37:1279219.
# 66.9% importados.
#
# Linhas por segundo lidas (total): 10.7
# 1,100,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:18:23
#
#
# Tentando recuperar Lattes compactado 8026730322234756 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8026730322234756
# Importação iniciada em 21/03/2022, 20:37:1223967.
# 67.5% importados.
#
# Linhas por segundo lidas (total): 10.7
# 1,110,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:21:39
#
#
# Tentando recuperar Lattes compactado 8291584506964609 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8291584506964609
# Tentando recuperar Lattes compactado 8928741242536263 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8928741242536263
# Importação iniciada em 21/03/2022, 20:37:1242766.
# 68.1% importados.
#
# Linhas por segundo lidas (total): 10.7
# 1,120,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:25:07
#
#
# Tentando recuperar Lattes compactado 8569079737803059 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8569079737803059
# Tentando recuperar Lattes compactado 8838734676246479 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8838734676246479
# Importação iniciada em 21/03/2022, 20:37:1282892.
# 68.7% importados.
#
# Linhas por segundo lidas (total): 10.7
# 1,130,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:27:07
#
#
# Importação iniciada em 21/03/2022, 20:37:1271543.
# 69.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,140,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:32:54
#
#
# Tentando recuperar Lattes compactado 8985313272063856 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8985313272063856
# Tentando recuperar Lattes compactado 8383595463210449 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8383595463210449
# Tentando recuperar Lattes compactado 8873525569519038 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8873525569519038
# Tentando recuperar Lattes compactado 8816809188329601 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8816809188329601
# Importação iniciada em 21/03/2022, 20:37:1296288.
# 70.0% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,150,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:33:42
#
#
# Tentando recuperar Lattes compactado 8580723124292270 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8580723124292270
# Tentando recuperar Lattes compactado 8811226708893384 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8811226708893384
# Importação iniciada em 21/03/2022, 20:37:1255762.
# 70.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,160,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:44:41
#
#
# Tentando recuperar Lattes compactado 8060649189494811 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8060649189494811
# Tentando recuperar Lattes compactado 8924251039685974 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8924251039685974
# Tentando recuperar Lattes compactado 8382544695398259 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8382544695398259
# Tentando recuperar Lattes compactado 8335255168092728 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8335255168092728
# Tentando recuperar Lattes compactado 8230372100218155 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8230372100218155
# Importação iniciada em 21/03/2022, 20:37:1215261.
# 71.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,170,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 15:47:08
#
#
# ...
# 77.3% importados.
#
# Linhas por segundo lidas (total): 10.5
# 1,270,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 16:01:17
#
#
# Tentando recuperar Lattes compactado 8576574157029671 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8576574157029671
# Importação iniciada em 21/03/2022, 20:37:1211773.
# 77.9% importados.
#
# Linhas por segundo lidas (total): 10.5
# 1,280,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 16:03:00
#
#
# Tentando recuperar Lattes compactado 8141246697885182 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8141246697885182
# Importação iniciada em 21/03/2022, 20:37:1264222.
# 78.5% importados.
#
# Linhas por segundo lidas (total): 10.5
# 1,290,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 16:03:21
#
#
# ERRO. ID da classe não é o mesmo do ID do Lattes. ID Lattes:  1469864494094121 . ID Classe:  8911518435791521 .
# Tentando recuperar Lattes compactado 8978951446914636 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8978951446914636
# Tentando recuperar Lattes compactado 8603668619069404 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8603668619069404
# Importação iniciada em 21/03/2022, 20:37:1287939.
# 79.1% importados.
#
# Linhas por segundo lidas (total): 10.5
# 1,300,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 16:04:59
#
#
# Tentando recuperar Lattes compactado 8434950028552656 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8434950028552656
# Importação iniciada em 21/03/2022, 20:37:1290262.
# 79.7% importados.
#
# Linhas por segundo lidas (total): 10.5
# 1,310,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 16:05:26
#
#
# Tentando recuperar Lattes compactado 8996122251626243 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8996122251626243
# Importação iniciada em 21/03/2022, 20:37:1210743.
# 80.3% importados.
#
# Linhas por segundo lidas (total): 10.5
# 1,320,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 16:07:07
#
#
# Tentando recuperar Lattes compactado 8326777911636932 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8326777911636932
# Importação iniciada em 21/03/2022, 20:37:1284171.
# 80.9% importados.
#
# Linhas por segundo lidas (total): 10.5
# 1,330,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 16:06:29
#
#
# Importação iniciada em 21/03/2022, 20:37:1253615.
# 81.5% importados.
#
# Linhas por segundo lidas (total): 10.5
# 1,340,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 16:10:19
#
#
# Tentando recuperar Lattes compactado 8151716040158067 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8151716040158067
# Importação iniciada em 21/03/2022, 20:37:1225587.
# 82.1% importados.
#
# Linhas por segundo lidas (total): 10.4
# 1,350,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 16:21:55
#
#
# Tentando recuperar Lattes compactado 8307271820351436 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8307271820351436
# Importação iniciada em 21/03/2022, 20:37:1269664.
# 82.7% importados.
#
# Linhas por segundo lidas (total): 10.4
# 1,360,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 16:37:03
#
#
# Tentando recuperar Lattes compactado 8028001192111088 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8028001192111088
# Importação iniciada em 21/03/2022, 20:37:1234769.
# 83.4% importados.
#
# Linhas por segundo lidas (total): 10.3
# 1,370,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 16:48:37
#
#
# Tentando recuperar Lattes compactado 8359045619553331 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8359045619553331
# Importação iniciada em 21/03/2022, 20:37:1284830.
# 84.0% importados.
#
# Linhas por segundo lidas (total): 10.3
# 1,380,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 17:08:09
#
#
# Tentando recuperar Lattes compactado 8609418614577701 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8609418614577701
# Tentando recuperar Lattes compactado 8531955572922285 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8531955572922285
# Importação iniciada em 21/03/2022, 20:37:1293488.
# 84.6% importados.
#
# Linhas por segundo lidas (total): 10.2
# 1,390,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 17:19:45
#
#
# Tentando recuperar Lattes compactado 8458713308790403 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8458713308790403
# Tentando recuperar Lattes compactado 8015924402440517 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8015924402440517
# Importação iniciada em 21/03/2022, 20:37:1244397.
# 85.2% importados.
#
# Linhas por segundo lidas (total): 10.2
# 1,400,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 17:30:20
#
#
# Tentando recuperar Lattes compactado 8652711432204272 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8652711432204272
# Tentando recuperar Lattes compactado 8711224507866869 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8711224507866869
# Tentando recuperar Lattes compactado 8084057994642615 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8084057994642615
# Importação iniciada em 21/03/2022, 20:37:1216904.
# 85.8% importados.
#
# Linhas por segundo lidas (total): 10.1
# 1,410,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 17:40:25
#
#
# Importação iniciada em 21/03/2022, 20:37:1228544.
# 86.4% importados.
#
# Linhas por segundo lidas (total): 10.1
# 1,420,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 17:48:49
#
#
# Importação iniciada em 21/03/2022, 20:37:1228575.
# 87.0% importados.
#
# Linhas por segundo lidas (total): 10.1
# 1,430,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 17:46:22
#
#
# Tentando recuperar Lattes compactado 8210005441453065 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8210005441453065
# Importação iniciada em 21/03/2022, 20:37:1290813.
# 87.6% importados.
#
# Linhas por segundo lidas (total): 10.1
# 1,440,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 17:46:51
#
#
# Tentando recuperar Lattes compactado 8387747175822625 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8387747175822625
# Tentando recuperar Lattes compactado 8607821209802850 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8607821209802850
# Importação iniciada em 21/03/2022, 20:37:1278679.
# 88.2% importados.
#
# Linhas por segundo lidas (total): 10.1
# 1,450,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 17:44:49
#
#
# Tentando recuperar Lattes compactado 8354824265338647 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8354824265338647
# ERRRO - Lattes não está carregado. ID: 8677279602700447
# Importação iniciada em 21/03/2022, 20:37:1230215.
# 88.8% importados.
#
# Linhas por segundo lidas (total): 10.1
# 1,460,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 17:45:06
#
#
# Tentando recuperar Lattes compactado 8919103428911622 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8919103428911622
# Tentando recuperar Lattes compactado 8645501700434070 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8645501700434070
# Importação iniciada em 21/03/2022, 20:37:1286632.
# 89.4% importados.
#
# Linhas por segundo lidas (total): 10.1
# 1,470,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 17:50:46
#
#
# Tentando recuperar Lattes compactado 8751838101603829 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8751838101603829
# Tentando recuperar Lattes compactado 8167241089950590 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8167241089950590
# Tentando recuperar Lattes compactado 8524809500404193 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8524809500404193
# Importação iniciada em 21/03/2022, 20:37:1262435.
# 90.0% importados.
#
# Linhas por segundo lidas (total): 10.1
# 1,480,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 17:54:23
#
#
# Importação iniciada em 21/03/2022, 20:37:1254019.
# 90.7% importados.
#
# Linhas por segundo lidas (total): 10.0
# 1,490,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 18:03:15
#
#
# Tentando recuperar Lattes compactado 8524714395246936 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8524714395246936
# Importação iniciada em 21/03/2022, 20:37:1228921.
# 91.3% importados.
#
# Linhas por segundo lidas (total): 10.0
# 1,500,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 18:06:21
#
#
# Tentando recuperar Lattes compactado 8473070142767664 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8473070142767664
# Importação iniciada em 21/03/2022, 20:37:1246387.
# 91.9% importados.
#
# Linhas por segundo lidas (total): 10.0
# 1,510,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 18:11:11
#
#
# Tentando recuperar Lattes compactado 8380897106547510 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8380897106547510
# Importação iniciada em 21/03/2022, 20:37:1225830.
# 92.5% importados.
#
# Linhas por segundo lidas (total): 10.0
# 1,520,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 18:12:58
#
#
# Tentando recuperar Lattes compactado 8460569168023572 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8460569168023572
# Tentando recuperar Lattes compactado 8914558198551472 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8914558198551472
# Tentando recuperar Lattes compactado 8927498169242814 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8927498169242814
# Importação iniciada em 21/03/2022, 20:37:1265897.
# 93.1% importados.
#
# Linhas por segundo lidas (total): 10.0
# 1,530,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 18:14:19
#
#
# Tentando recuperar Lattes compactado 8400558091810234 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8400558091810234
# Tentando recuperar Lattes compactado 8955628641518677 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8955628641518677
# Importação iniciada em 21/03/2022, 20:37:1297227.
# 93.7% importados.
#
# Linhas por segundo lidas (total): 10.0
# 1,540,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 18:11:38
#
#
# Tentando recuperar Lattes compactado 8438804262365496 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8438804262365496
# Tentando recuperar Lattes compactado 8004180932690370 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8004180932690370
# Tentando recuperar Lattes compactado 8486137971664428 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8486137971664428
# Importação iniciada em 21/03/2022, 20:37:1281121.
# 94.3% importados.
#
# Linhas por segundo lidas (total): 10.0
# 1,550,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 18:11:14
#
#
# Tentando recuperar Lattes compactado 8387671309466440 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8387671309466440
# Tentando recuperar Lattes compactado 8775800763264120 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8775800763264120
# Importação iniciada em 21/03/2022, 20:37:1223004.
# 94.9% importados.
#
# Linhas por segundo lidas (total): 10.0
# 1,560,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 18:09:44
#
#
# Tentando recuperar Lattes compactado 8285224345265381 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8285224345265381
# Importação iniciada em 21/03/2022, 20:37:1234068.
# 95.5% importados.
#
# Linhas por segundo lidas (total): 10.0
# 1,570,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 18:07:36
#
#
# Tentando recuperar Lattes compactado 8973310776857597 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8973310776857597
# Importação iniciada em 21/03/2022, 20:37:1259096.
# 96.1% importados.
#
# Linhas por segundo lidas (total): 10.0
# 1,580,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 18:05:02
#
#
# Importação iniciada em 21/03/2022, 20:37:1214135.
# 96.7% importados.
#
# Linhas por segundo lidas (total): 10.0
# 1,590,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 18:10:40
#
#
# Tentando recuperar Lattes compactado 8573117712611770 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8573117712611770
# Importação iniciada em 21/03/2022, 20:37:1205080.
# 97.3% importados.
#
# Linhas por segundo lidas (total): 10.0
# 1,600,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 18:07:34
#
#
# Importação iniciada em 21/03/2022, 20:37:1273689.
# 98.0% importados.
#
# Linhas por segundo lidas (total): 10.0
# 1,610,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 18:03:06
# Tentando recuperar Lattes compactado 8787312166835715 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8787312166835715
# Importação iniciada em 21/03/2022, 20:37:1247389.
# 98.6% importados.
#
# Linhas por segundo lidas (total): 10.1
# 1,620,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 17:57:48
#
#
# Tentando recuperar Lattes compactado 8820870574626898 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8820870574626898
# Tentando recuperar Lattes compactado 8333074010585964 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8333074010585964
# Tentando recuperar Lattes compactado 8976238349394997 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8976238349394997
# Importação iniciada em 21/03/2022, 20:37:1257957.
# 99.2% importados.
#
# Linhas por segundo lidas (total): 10.1
# 1,630,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 17:53:53
#
#
# Tentando recuperar Lattes compactado 8919910280927841 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8919910280927841
# Importação iniciada em 21/03/2022, 20:37:1265923.
# 99.8% importados.
#
# Linhas por segundo lidas (total): 10.1
# 1,640,000 de 1,643,644
# Acabará em:
#     Cálculo considerando desde o início: 23/03/2022, 17:48:49
#
#
# Tentando recuperar Lattes compactado 8100346556580005 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8100346556580005
# 1643642 / 1643644. Importing id 8121180598713396.
