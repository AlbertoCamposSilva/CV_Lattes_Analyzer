# %%
from Lattes import Lattes

# %%
lattes = Lattes(id='1600461423386842')

# %%
lattes.path = r'C:\Users\silva\CNPq\Lattes\Downloads'

# %%
lattes.get_xml()
# Out:
# Data de atualização pega do Banco de dados: 2021-09-07 14:39:50+00:00
# Impossível recuperar SOAP - IP errado. Tentando recuperar pelo arquivo.
# Arquivo compactado lido no disco.
# XML atualizado a partir do Lattes compactado.
# Arquivo zip recuperado do disco.
# Classe Indicadores criada
# Data de atualização do Lattes pega pelo XML:  2021-09-07 14:39:50

# %%
print (lattes.xml)
# Out:
# <?xml version="1.0" standalone="no"?><CURRICULO-VITAE SISTEMA-ORIGEM-XML="LATTES_OFFLINE" NUMERO-IDENTIFICADOR="1600461423386842" DATA-ATUALIZACAO="07092021" HORA-ATUALIZACAO="143950"><DADOS-GERAIS NOME-COMPLETO="Livio Amaral" NOME-EM-CITACOES-BIBLIOGRAFICAS="AMARAL, L.;Amaral, L.;Amaral, Livio;L Amaral;L. Amaral;Livio Amaral;AMARAL L;L AMARAL;Lívio Amaral" NACIONALIDADE="B" PAIS-DE-NASCIMENTO="Brasil" UF-NASCIMENTO="PR" CIDADE-NASCIMENTO="Curitiba" PERMISSAO-DE-DIVULGACAO="NAO" DATA-FALECIMENTO="" SIGLA-PAIS-NACIONALIDADE="BRA" PAIS-DE-NACIONALIDADE="Brasil" ORCID-ID="https://orcid.org/0000-0002-4732-5502"><RESUMO-CV TEXTO-RESUMO-CV-RH="Bacharel em Física (1974), Mestre (1977) e Doutor em Física (1982) pela Universidade Federal do Rio Grande do Sul, com pós-doutorados em Paris  (1983-1985) e Amsterdam (1992). Desde 1998 é Professor Titular do Departamento de Física da Universidade Federal do Rio Grande do Sul. Tem área de atuação na física experimental: implantação iônica, modificaç
# ...

# %%
print(len(lattes.indicadores.indicador['Ano']))
# Out:
# 533

# %%
print (lattes.indicadores)

# %%
print(lattes.indicadores.lattes)
# Out:
# {'AREA-DE-ATUACAO': [('Grande Área', 'Área', 'Sub-Área', 'Especialidade'), ('CIENCIAS_EXATAS_E_DA_TERRA', 'Física', 'Física da Matéria Condensada', ''), ('CIENCIAS_EXATAS_E_DA_TERRA', 'Física', 'Física da Matéria Condensada', 'Estruturas Eletrônicas e Propriedades Elétricas de Superfícies; Interf. e Partículas'), ('CIENCIAS_EXATAS_E_DA_TERRA', 'Física', 'Física da Matéria Condensada', 'Prop. Óticas e Espectrosc. da Mat. Condens; Outras Inter. da Mat. com Rad. e Part.'), ('CIENCIAS_SOCIAIS_APLICADAS', 'Ciência da Informação', 'Avaliação - Cientometria', '')], 'CURSO-TECNICO-PROFISSIONALIZANTE': [], 'ENSINO-FUNDAMENTAL-PRIMEIRO-GRAU': [], 'ENSINO-MEDIO-SEGUNDO-GRAU': [], 'GRADUACAO': [{'SEQUENCIA-FORMACAO': '6', 'NIVEL': '1', 'TITULO-DO-TRABALHO-DE-CONCLUSAO-DE-CURSO': '', 'NOME-DO-ORIENTADOR': '', 'CODIGO-INSTITUICAO': '019200000005', 'NOME-INSTITUICAO': 'Universidade Federal do Rio Grande do Sul', 'CODIGO-ORGAO': '', 'NOME-ORGAO': '', 'CODIGO-CURSO': '90000000', 'NOME-CURSO': 'Bachar
# ...

# %%
for item in lattes.indicadores.lattes.items():
    print(item[0])
# Out:
# AREA-DE-ATUACAO
# CURSO-TECNICO-PROFISSIONALIZANTE
# ENSINO-FUNDAMENTAL-PRIMEIRO-GRAU
# ENSINO-MEDIO-SEGUNDO-GRAU
# GRADUACAO
# APERFEICOAMENTO
# ESPECIALIZACAO
# MESTRADO
# MESTRADO-PROFISSIONALIZANTE
# DOUTORADO
# RESIDENCIA-MEDICA
# LIVRE-DOCENCIA
# POS-DOUTORADO
# VINCULOS
# DIRECAO-E-ADMINISTRACAO
# PESQUISA-E-DESENVOLVIMENTO
# ENSINO
# ESTAGIO
# SERVICO-TECNICO-ESPECIALIZADO
# EXTENSAO-UNIVERSITARIA
# TREINAMENTO-MINISTRADO
# OUTRA-ATIVIDADE-TECNICO-CIENTIFICA
# CONSELHO-COMISSAO-E-CONSULTORIA
# AREAS-DE-ATUACAO
# IDIOMA
# PREMIOS-TITULOS
# PARTICIPACAO-EM-PROJETO
# TRABALHOS-EM-EVENTOS
# ARTIGO-PUBLICADO
# ARTIGO-ACEITO-PARA-PUBLICACAO
# LIVRO-PUBLICADO-OU-ORGANIZADO
# TEXTO-EM-JORNAL-OU-REVISTA
# SOFTWARE
# PRODUTO-TECNOLOGICO
# PATENTE
# CULTIVAR-PROTEGIDA
# CULTIVAR-REGISTRADA
# DESENHO-INDUSTRIAL
# MARCA
# TOPOGRAFIA-DE-CIRCUITO-INTEGRADO
# PROCESSOS-OU-TECNICAS
# TRABALHO-TECNICO
# APRESENTACAO-DE-TRABALHO
# CARTA-MAPA-OU-SIMILAR
# CURSO-DE-CURTA-DURACAO-MINISTRADO
# ...
