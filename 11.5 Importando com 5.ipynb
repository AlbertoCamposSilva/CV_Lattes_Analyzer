# %%
from Carga import Carga
cg = Carga()


#Origens
cg.de_hd = False
cg.de_all_lattes = True
cg.de_bd_demanda_bruta = False
cg.de_dados_pessoais = False

#Exceções
cg.pular_indicadores = False
cg.pular_palavras_chave = False
cg.pular_areas_conhecimento = False
cg.pular_publicações = True
cg.pular_dados_gerais=False
cg.pular_vinculos = False
cg.pular_erros = False
cg.pular_jsons = False

#Importações
cg.on_conflic_update = True
cg.importar_indicadores = True
cg.importar_palavras_chave = True
cg.importar_areas_conhecimento = True
cg.importar_publicações = True
cg.importar_dados_gerais=True
cg.importar_vinculos = True


#Outras Configurações
cg.on_conflic_update = True
cg.auto_save_json_to_bd = True
cg.pegar_lista_de_importação_de_arquivo = False
cg.data_mínima_atualização_lattes = None

cg.atualiza_todos_os_indicadores(começando_com = '5')
# Out:
# Carregando lista de indicadores para importar da tabela all_lattes do BD
#
# Carregando lista de Ids da tabela publicacoes para pular
#
# Retirando ids a exluir...
# Salvando o arquivo com a lista no disco.
# Iniciando Importação.
# Tentando recuperar Lattes compactado 5413458530618069 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 5413458530618069
# Tentando recuperar Lattes compactado 5770806634950851 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 5770806634950851
# Tentando recuperar Lattes compactado 5261188406560466 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 5261188406560466
# Tentando recuperar Lattes compactado 5305655989209585 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 5305655989209585
# Tentando recuperar Lattes compactado 5855471167349160 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 5855471167349160
# Tentando recuperar Lattes compactado 5261828877657622 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5222185390154641 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5228272186044324 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5637461701024093 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5019538246809307 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5283813718292805 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5213971288091080 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 5213971288091080
# Tentando recuperar Lattes compactado 5502404668773821 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5330916450890029 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5055049962714209 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5345192403439305 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5556211498027281 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5056310401129120 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5452418973538590 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5090791506676186 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5482295438750459 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5563600651436198 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 5563600651436198
# Tentando recuperar Lattes compactado 5002587543200935 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5320519207558864 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5831983268491612 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5140711685740991 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5777030516204012 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5302105440964711 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5855620221140674 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5100595912465312 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5325067547545006 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5220698423672507 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5376433390252448 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5165095117356189 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5486832030816877 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5428152117423481 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5258427604611737 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5235045802748223 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5846382280290258 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5199467489076861 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5480441283136692 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5452754385709457 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5549577908130331 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5909701777644752 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5071109735247353 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5217110902976884 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5259457191233547 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5445335067521538 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5071943748396703 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5770181274239291 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5161365604351824 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5218651111388116 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5468225191609510 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 5468225191609510
# Tentando recuperar Lattes compactado 5754591400589886 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5856652559181844 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 5856652559181844
# Tentando recuperar Lattes compactado 5296016444255500 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5420323009211273 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5277334115518347 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5189732977095949 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5717693309897648 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5364535577251468 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5024590057854701 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5378682553079455 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5107035501001079 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5394794645130260 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5023902243718666 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5038973179967031 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5171181411985055 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 
via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Importação iniciada em 29/08/2022, 22:57:0471.
# 0.2% importados.
#
# Linhas por segundo lidas (total): 4.2
# 10,000 de 5,654,187
# Acabará em:
#     Cálculo considerando desde o início: 14/09/2022, 13:22:33
#
#
# Tentando recuperar Lattes compactado 5536238780959231 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 5536238780959231
# Tentando recuperar Lattes compactado 5152295429950938 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5286624634112460 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5733525329464907 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5121809224488208 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5908095420089962 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5269990951740703 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5585527671886302 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5243966551973058 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5302366480159769 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5234024526841459 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5698151451666490 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5211493555756239 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5143795678744217 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5966794597259300 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5123808998143151 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5923442869081580 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5528129247934292 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5714102153380242 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5037306118682107 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5992775661568899 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5851164248581859 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5676965464647425 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5108505838610293 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5095142374639806 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5801838589491539 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5100390377692484 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5577649950970937 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5437366612694989 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5349161561007455 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5315160967508644 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5400676087430798 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5209998793349380 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5069118247302950 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5569577050083497 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5474671733197655 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5788418659681840 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5367592695500233 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5591569874122680 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5970237988447595 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5775054074448529 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5091441812607846 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5880183281322276 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5948239326754113 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5261123203377022 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5766622587622617 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5317816068637421 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5070519396395439 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 5070519396395439
# Tentando recuperar Lattes compactado 5974429427650680 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5736768499296351 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5141309699191725 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5122675358773850 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5056111708126559 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5560145625878640 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5056163470561298 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5474264907365716 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5390233846505308 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5380481717311081 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5961928320659685 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5860341073454963 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5227169844396561 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5981556354154490 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 5517710759622018 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# 11710 / 5654187. Importing id 5856488093355096.
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11400/2602140565.py in <module>
#      35 cg.data_mínima_atualização_lattes = None
#      36
# ---> 37 cg.atualiza_todos_os_indicadores(começando_com = '5')
#
# ~\CNPq\Lattes\Python\Carga.py in atualiza_todos_os_indicadores(self, num_imports_skip_before_log, começando_com)
#    1063                 print(f'{num} / {linhas_totais}. Importing id {id}.\r', end="", flush=True)
#    1064
# -> 1065                 ind = Indicadores (id = id, auto_save_json_to_bd = self.auto_save_json_to_bd)
#    1066                 ind.on_conflic_update = self.on_conflic_update
#    1067                 ind.atualiza(
#
# ~\CNPq\Lattes\Python\Indicadores.py in __init__(self, id, json, filename, show_execution_time, show_sql, auto_save_json_to_bd, on_conflic_update)
#      26         self.show_sql = show_sql
#      27         self.auto_save_json_to_bd = auto_save_json_to_bd
# ---> 28         self.db = Database('CNPq', show_sql = show_sql)
#      29         self.indicadores = []
#      30         self.list_indicadores = []
#
# ~\CNPq\Lattes\Python\Database.py in __init__(self, name, show_sql)
#      34     def __init__(self, name = 'CNPq', show_sql = False):
#      35         self.params = Database.config_db_connection()
# ---> 36         self.conn = psycopg2.connect(**self.params)
#      37         self.cur = self.conn.cursor()
#      38         self.show_sql = show_sql
#
# ~\Anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     120
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#     124         conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "albertocampos.ddns.net" (200.169.188.152), port 8080 failed: Connection timed out (0x0000274C/10060)
# 	Is the server running on that host and accepting TCP/IP connections?
