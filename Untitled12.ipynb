# %%
from Carga import Carga
cg = Carga()
cg.atualiza_todos_os_indicadores (on_conflic_update = True, 
                                  pula_bd_indicadores = True, 
                                  pula_erros = False, 
                                  data_mínima_atualização_lattes = '2020-01-01', 
                                  de_all_lattes = True, 
                                  começando_com=[2],
                                 )
# Out:
# Carregando lista de Ids da tabela indicadores para pular
#
# Carregando lista de indicadores para importar da tabela Lattes do BD
#
# Carregando lista de indicadores para importar da tabela demanda_bruta do BD
#
# Carregando lista de indicadores para importar da tabela carga_dados_pessoais do BD
#
# Retirando ids a exluir...
# Iniciando Importação.
# Importação iniciada em 13/03/2022, 17:32:5561.
# 0.1% importados.
#
# Linhas por segundo lidas (total): 9.9
# 1,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:05:56
#
#
# Importação iniciada em 13/03/2022, 17:32:5519.
# 0.1% importados.
#
# Linhas por segundo lidas (total): 9.5
# 2,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:58:14
#
#
# Importação iniciada em 13/03/2022, 17:32:5515.
# 0.2% importados.
#
# Linhas por segundo lidas (total): 9.5
# 2,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:45:13
#
#
# Importação iniciada em 13/03/2022, 17:32:5562.
# 0.3% importados.
#
# Linhas por segundo lidas (total): 9.4
# 4,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 11:00:49
#
#
# Importação iniciada em 13/03/2022, 17:32:5504.
# 0.4% importados.
#
# Linhas por segundo lidas (total): 9.2
# 5,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 11:56:13
#
#
# Importação iniciada em 13/03/2022, 17:32:5576.
# 0.4% importados.
#
# Linhas por segundo lidas (total): 9.3
# 6,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 11:29:46
#
#
# Importação iniciada em 13/03/2022, 17:32:5541.
# 0.5% importados.
#
# Linhas por segundo lidas (total): 9.3
# 6,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 11:24:47
#
#
# Tentando recuperar Lattes compactado 2818665148998081 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 2818665148998081
# Importação iniciada em 13/03/2022, 17:32:5581.
# 0.7% importados.
#
# Linhas por segundo lidas (total): 9.3
# 9,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 11:20:09
#
#
# Importação iniciada em 13/03/2022, 17:32:55277.
# 0.8% importados.
#
# Linhas por segundo lidas (total): 9.5
# 11,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:45:04
#
#
# Importação iniciada em 13/03/2022, 17:32:55652.
# 0.9% importados.
#
# Linhas por segundo lidas (total): 9.5
# 12,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:41:06
#
#
# Importação iniciada em 13/03/2022, 17:32:55608.
# 0.9% importados.
#
# Linhas por segundo lidas (total): 9.5
# 12,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:36:50
#
#
# Importação iniciada em 13/03/2022, 17:32:55398.
# 1.0% importados.
#
# Linhas por segundo lidas (total): 9.4
# 14,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:51:28
#
#
# Importação iniciada em 13/03/2022, 17:32:55833.
# 1.0% importados.
#
# Linhas por segundo lidas (total): 9.4
# 14,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 11:03:12
#
#
# Tentando recuperar Lattes compactado 2817986070093684 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2817986070093684
# Importação iniciada em 13/03/2022, 17:32:55898.
# 1.1% importados.
#
# Linhas por segundo lidas (total): 9.5
# 15,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:30:57
#
#
# Importação iniciada em 13/03/2022, 17:32:55040.
# 1.1% importados.
#
# Linhas por segundo lidas (total): 9.5
# 15,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:30:58
#
#
# Importação iniciada em 13/03/2022, 17:32:55235.
# 1.2% importados.
#
# Linhas por segundo lidas (total): 9.4
# 17,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:37:55
#
#
# Importação iniciada em 13/03/2022, 17:32:55345.
# 1.3% importados.
#
# Linhas por segundo lidas (total): 9.5
# 18,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:15:59
#
#
# Importação iniciada em 13/03/2022, 17:32:55576.
# 1.3% importados.
#
# Linhas por segundo lidas (total): 9.5
# 19,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:17:07
#
#
# Importação iniciada em 13/03/2022, 17:32:55984.
# 1.4% importados.
#
# Linhas por segundo lidas (total): 9.5
# 19,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:23:08
#
#
# Importação iniciada em 13/03/2022, 17:32:55240.
# 1.4% importados.
#
# Linhas por segundo lidas (total): 9.5
# 19,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:17:53
#
#
# Tentando recuperar Lattes compactado 2676392955019499 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2676392955019499
# Importação iniciada em 13/03/2022, 17:32:55054.
# 1.4% importados.
#
# Linhas por segundo lidas (total): 9.5
# 19,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:12:09
#
#
# Tentando recuperar Lattes compactado 2905506131144519 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2905506131144519
# Importação iniciada em 13/03/2022, 17:32:55015.
# 1.6% importados.
#
# Linhas por segundo lidas (total): 9.7
# 22,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:29:25
#
#
# Importação iniciada em 13/03/2022, 17:32:55952.
# 1.7% importados.
#
# Linhas por segundo lidas (total): 9.7
# 24,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:18:13
#
#
# Importação iniciada em 13/03/2022, 17:32:55699.
# 1.9% importados.
#
# Linhas por segundo lidas (total): 10.0
# 27,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:10:43
#
#
# Importação iniciada em 13/03/2022, 17:32:55504.
# 2.0% importados.
#
# Linhas por segundo lidas (total): 10.0
# 28,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:56:37
#
#
# Tentando recuperar Lattes compactado 2548515604169095 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2548515604169095
# Tentando recuperar Lattes compactado 2186122970923578 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2186122970923578
# Importação iniciada em 13/03/2022, 17:32:55395.
# 2.2% importados.
#
# Linhas por segundo lidas (total): 10.0
# 30,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:56:00
#
#
# Importação iniciada em 13/03/2022, 17:32:55165.
# 2.2% importados.
#
# Linhas por segundo lidas (total): 10.0
# 31,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:53:18
#
#
# Importação iniciada em 13/03/2022, 17:32:55034.
# 2.3% importados.
#
# Linhas por segundo lidas (total): 9.9
# 33,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:06:27
#
#
# Importação iniciada em 13/03/2022, 17:32:55871.
# 2.5% importados.
#
# Linhas por segundo lidas (total): 9.9
# 34,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:12:56
#
#
# Importação iniciada em 13/03/2022, 17:32:55250.
# 2.5% importados.
#
# Linhas por segundo lidas (total): 9.9
# 35,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:13:13
#
#
# Importação iniciada em 13/03/2022, 17:32:55381.
# 2.6% importados.
#
# Linhas por segundo lidas (total): 9.9
# 37,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:05:11
#
#
# Importação iniciada em 13/03/2022, 17:32:55090.
# 2.9% importados.
#
# Linhas por segundo lidas (total): 9.9
# 40,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:55:27
#
#
# Importação iniciada em 13/03/2022, 17:32:55025.
# 3.0% importados.
#
# Linhas por segundo lidas (total): 9.9
# 42,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:53:37
#
#
# Importação iniciada em 13/03/2022, 17:32:55774.
# 3.1% importados.
#
# Linhas por segundo lidas (total): 10.0
# 43,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:42:39
#
#
# Importação iniciada em 13/03/2022, 17:32:55701.
# 3.2% importados.
#
# Linhas por segundo lidas (total): 9.8
# 44,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:17:58
# Importação iniciada em 13/03/2022, 17:32:55625.
# 3.2% importados.
#
# Linhas por segundo lidas (total): 9.8
# 44,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:20:44
#
#
# Importação iniciada em 13/03/2022, 17:32:55312.
# 3.3% importados.
#
# Linhas por segundo lidas (total): 9.8
# 46,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:15:47
#
#
# Tentando recuperar Lattes compactado 2431245492217394 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2431245492217394
# Importação iniciada em 13/03/2022, 17:32:55128.
# 3.4% importados.
#
# Linhas por segundo lidas (total): 9.8
# 47,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:08:31
#
#
# Importação iniciada em 13/03/2022, 17:32:55151.
# 3.5% importados.
#
# Linhas por segundo lidas (total): 9.9
# 49,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:01:19
#
#
# Importação iniciada em 13/03/2022, 17:32:55542.
# 3.5% importados.
#
# Linhas por segundo lidas (total): 9.9
# 50,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:59:02
#
#
# Importação iniciada em 13/03/2022, 17:32:55766.
# 3.6% importados.
#
# Linhas por segundo lidas (total): 9.8
# 50,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:01:43
#
#
# Importação iniciada em 13/03/2022, 17:32:55707.
# 3.6% importados.
#
# Linhas por segundo lidas (total): 9.8
# 51,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:59:04
#
#
# Importação iniciada em 13/03/2022, 17:32:55950.
# 3.9% importados.
#
# Linhas por segundo lidas (total): 9.9
# 55,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:44:47
#
#
# Importação iniciada em 13/03/2022, 17:32:55470.
# 4.0% importados.
#
# Linhas por segundo lidas (total): 9.9
# 56,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:40:48
#
#
# Importação iniciada em 13/03/2022, 17:32:55727.
# 4.0% importados.
#
# Linhas por segundo lidas (total): 9.9
# 56,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:39:19
#
#
# Importação iniciada em 13/03/2022, 17:32:55747.
# 4.1% importados.
#
# Linhas por segundo lidas (total): 9.9
# 58,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:33:05
#
#
# Importação iniciada em 13/03/2022, 17:32:55666.
# 4.3% importados.
#
# Linhas por segundo lidas (total): 9.9
# 60,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:19:33
#
#
# Importação iniciada em 13/03/2022, 17:32:55427.
# 4.4% importados.
#
# Linhas por segundo lidas (total): 10.0
# 61,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:16:32
#
#
# Importação iniciada em 13/03/2022, 17:32:55171.
# 4.4% importados.
#
# Linhas por segundo lidas (total): 9.9
# 62,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:17:38
#
#
# Importação iniciada em 13/03/2022, 17:32:55350.
# 4.4% importados.
#
# Linhas por segundo lidas (total): 9.9
# 62,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:17:21
#
#
# Importação iniciada em 13/03/2022, 17:32:55195.
# 4.4% importados.
#
# Linhas por segundo lidas (total): 9.9
# 62,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:17:14
#
#
# Importação iniciada em 13/03/2022, 17:32:55702.
# 4.5% importados.
#
# Linhas por segundo lidas (total): 9.9
# 64,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:15:01
#
#
# Tentando recuperar Lattes compactado 2315609072352425 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2315609072352425
# Importação iniciada em 13/03/2022, 17:32:55384.
# 4.7% importados.
#
# Linhas por segundo lidas (total): 10.0
# 67,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:08:09
#
#
# Importação iniciada em 13/03/2022, 17:32:55272.
# 4.8% importados.
#
# Linhas por segundo lidas (total): 10.0
# 68,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:57:37
#
#
# Tentando recuperar Lattes compactado 2262179124682064 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2262179124682064
# Importação iniciada em 13/03/2022, 17:32:55487.
# 5.1% importados.
#
# Linhas por segundo lidas (total): 10.0
# 71,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:47:34
#
#
# Importação iniciada em 13/03/2022, 17:32:55568.
# 5.1% importados.
#
# Linhas por segundo lidas (total): 10.0
# 72,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:43:58
#
#
# Importação iniciada em 13/03/2022, 17:32:55593.
# 5.2% importados.
#
# Linhas por segundo lidas (total): 10.0
# 73,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:38:41
#
#
# Tentando recuperar Lattes compactado 2743597264184901 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2743597264184901
# Importação iniciada em 13/03/2022, 17:32:55436.
# 5.3% importados.
#
# Linhas por segundo lidas (total): 10.0
# 74,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:40:32
#
#
# Importação iniciada em 13/03/2022, 17:32:55137.
# 5.4% importados.
#
# Linhas por segundo lidas (total): 10.0
# 76,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:33:17
#
#
# Importação iniciada em 13/03/2022, 17:32:55273.
# 5.4% importados.
#
# Linhas por segundo lidas (total): 10.0
# 76,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:33:47
#
#
# Importação iniciada em 13/03/2022, 17:32:55511.
# 5.4% importados.
#
# Linhas por segundo lidas (total): 10.0
# 77,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:35:16
#
#
# Importação iniciada em 13/03/2022, 17:32:55615.
# 5.5% importados.
#
# Linhas por segundo lidas (total): 10.0
# 77,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:34:36
#
#
# Tentando recuperar Lattes compactado 2168548341455167 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2168548341455167
# Importação iniciada em 13/03/2022, 17:32:55892.
# 5.5% importados.
#
# Linhas por segundo lidas (total): 10.0
# 77,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:36:56
#
#
# Importação iniciada em 13/03/2022, 17:32:55964.
# 5.6% importados.
#
# Linhas por segundo lidas (total): 10.0
# 79,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:34:04
#
#
# Importação iniciada em 13/03/2022, 17:32:55219.
# 5.6% importados.
#
# Linhas por segundo lidas (total): 10.0
# 79,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:34:11
#
#
# Tentando recuperar Lattes compactado 2079709415265229 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2079709415265229
# Importação iniciada em 13/03/2022, 17:32:55603.
# 5.6% importados.
#
# Linhas por segundo lidas (total): 10.0
# 79,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:33:33
#
#
# Importação iniciada em 13/03/2022, 17:32:55303.
# 5.7% importados.
#
# Linhas por segundo lidas (total): 10.0
# 80,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:28:00
#
#
# Tentando recuperar Lattes compactado 2022892101934799 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2022892101934799
# Importação iniciada em 13/03/2022, 17:32:55314.
# 5.8% importados.
#
# Linhas por segundo lidas (total): 10.1
# 82,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:16:18
#
#
# Importação iniciada em 13/03/2022, 17:32:55426.
# 5.8% importados.
#
# Linhas por segundo lidas (total): 10.1
# 82,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:16:36
#
#
# Importação iniciada em 13/03/2022, 17:32:55684.
# 5.9% importados.
#
# Linhas por segundo lidas (total): 10.1
# 83,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:12:32
#
#
# Importação iniciada em 13/03/2022, 17:32:55093.
# 5.9% importados.
#
# Linhas por segundo lidas (total): 10.1
# 83,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:12:56
# Importação iniciada em 13/03/2022, 17:32:55986.
# 6.0% importados.
#
# Linhas por segundo lidas (total): 10.1
# 84,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:16:02
#
#
# Importação iniciada em 13/03/2022, 17:32:55129.
# 6.0% importados.
#
# Linhas por segundo lidas (total): 10.1
# 84,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:15:19
#
#
# Importação iniciada em 13/03/2022, 17:32:55740.
# 6.0% importados.
#
# Linhas por segundo lidas (total): 10.1
# 85,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:10:38
#
#
# Tentando recuperar Lattes compactado 2062169696536522 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2062169696536522
# Importação iniciada em 13/03/2022, 17:32:55831.
# 6.1% importados.
#
# Linhas por segundo lidas (total): 10.1
# 86,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:07:29
#
#
# Tentando recuperar Lattes compactado 2262944204867132 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2262944204867132
# Importação iniciada em 13/03/2022, 17:32:55556.
# 6.1% importados.
#
# Linhas por segundo lidas (total): 10.1
# 86,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:06:08
#
#
# Importação iniciada em 13/03/2022, 17:32:55267.
# 6.2% importados.
#
# Linhas por segundo lidas (total): 10.1
# 87,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:07:33
#
#
# Importação iniciada em 13/03/2022, 17:32:55876.
# 6.2% importados.
#
# Linhas por segundo lidas (total): 10.1
# 87,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:06:03
#
#
# Importação iniciada em 13/03/2022, 17:32:55337.
# 6.2% importados.
#
# Linhas por segundo lidas (total): 10.1
# 87,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:04:31
#
#
# Importação iniciada em 13/03/2022, 17:32:55608.
# 6.2% importados.
#
# Linhas por segundo lidas (total): 10.1
# 88,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:05:59
#
#
# Importação iniciada em 13/03/2022, 17:32:55855.
# 6.4% importados.
#
# Linhas por segundo lidas (total): 10.1
# 89,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:59:36
#
#
# Importação iniciada em 13/03/2022, 17:32:55437.
# 6.4% importados.
#
# Linhas por segundo lidas (total): 10.1
# 90,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:59:22
#
#
# Importação iniciada em 13/03/2022, 17:32:55301.
# 6.4% importados.
#
# Linhas por segundo lidas (total): 10.1
# 90,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:56:47
#
#
# Importação iniciada em 13/03/2022, 17:32:55715.
# 6.4% importados.
#
# Linhas por segundo lidas (total): 10.1
# 91,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:57:56
#
#
# Tentando recuperar Lattes compactado 2437511853917147 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2437511853917147
# Importação iniciada em 13/03/2022, 17:32:55567.
# 6.5% importados.
#
# Linhas por segundo lidas (total): 10.1
# 92,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:01:11
#
#
# Tentando recuperar Lattes compactado 2887213733596718 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 2887213733596718
# Importação iniciada em 13/03/2022, 17:32:55675.
# 6.5% importados.
#
# Linhas por segundo lidas (total): 10.1
# 92,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:02:17
#
#
# Tentando recuperar Lattes compactado 2025478247924053 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2025478247924053
# Importação iniciada em 13/03/2022, 17:32:55274.
# 6.6% importados.
#
# Linhas por segundo lidas (total): 10.1
# 93,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:56:36
#
#
# Importação iniciada em 13/03/2022, 17:32:55084.
# 6.7% importados.
#
# Linhas por segundo lidas (total): 10.1
# 94,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:58:09
#
#
# Importação iniciada em 13/03/2022, 17:32:55000.
# 6.7% importados.
#
# Linhas por segundo lidas (total): 10.1
# 94,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:59:39
#
#
# Importação iniciada em 13/03/2022, 17:32:55363.
# 6.7% importados.
#
# Linhas por segundo lidas (total): 10.1
# 94,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:58:21
#
#
# Importação iniciada em 13/03/2022, 17:32:55118.
# 6.7% importados.
#
# Linhas por segundo lidas (total): 10.0
# 95,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:00:53
#
#
# Tentando recuperar Lattes compactado 2381358452930182 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2381358452930182
# Importação iniciada em 13/03/2022, 17:32:55273.
# 6.9% importados.
#
# Linhas por segundo lidas (total): 10.1
# 98,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:47:26
#
#
# Tentando recuperar Lattes compactado 2808840264155966 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2808840264155966
# Importação iniciada em 13/03/2022, 17:32:551455.
# 7.1% importados.
#
# Linhas por segundo lidas (total): 10.1
# 101,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:38:04
#
#
# Importação iniciada em 13/03/2022, 17:32:558616.
# 7.2% importados.
#
# Linhas por segundo lidas (total): 10.1
# 101,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:36:45
#
#
# Importação iniciada em 13/03/2022, 17:32:553035.
# 7.2% importados.
#
# Linhas por segundo lidas (total): 10.1
# 101,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:35:09
#
#
# Importação iniciada em 13/03/2022, 17:32:557311.
# 7.2% importados.
#
# Linhas por segundo lidas (total): 10.1
# 101,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:35:28
#
#
# Importação iniciada em 13/03/2022, 17:32:559138.
# 7.2% importados.
#
# Linhas por segundo lidas (total): 10.1
# 102,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:38:13
#
#
# Tentando recuperar Lattes compactado 2788231587842188 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2788231587842188
# Importação iniciada em 13/03/2022, 17:32:550438.
# 7.4% importados.
#
# Linhas por segundo lidas (total): 10.1
# 104,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:34:01
#
#
# Importação iniciada em 13/03/2022, 17:32:557389.
# 7.4% importados.
#
# Linhas por segundo lidas (total): 10.1
# 105,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:32:38
#
#
# Importação iniciada em 13/03/2022, 17:32:554185.
# 7.6% importados.
#
# Linhas por segundo lidas (total): 10.1
# 107,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:34:15
#
#
# Importação iniciada em 13/03/2022, 17:32:555535.
# 7.6% importados.
#
# Linhas por segundo lidas (total): 10.1
# 107,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:33:59
#
#
# Importação iniciada em 13/03/2022, 17:32:558160.
# 7.8% importados.
#
# Linhas por segundo lidas (total): 10.1
# 109,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:26:51
#
#
# Importação iniciada em 13/03/2022, 17:32:550596.
# 7.8% importados.
#
# Linhas por segundo lidas (total): 10.1
# 110,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:23:55
#
#
# Tentando recuperar Lattes compactado 2855539552901948 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2855539552901948
# Importação iniciada em 13/03/2022, 17:32:551403.
# 8.1% importados.
#
# Linhas por segundo lidas (total): 10.1
# 114,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:12:44
#
#
# Importação iniciada em 13/03/2022, 17:32:556487.
# 8.1% importados.
#
# Linhas por segundo lidas (total): 10.1
# 114,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:09:03
# Importação iniciada em 13/03/2022, 17:32:552280.
# 8.1% importados.
#
# Linhas por segundo lidas (total): 10.1
# 115,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:07:47
#
#
# Importação iniciada em 13/03/2022, 17:32:555337.
# 8.3% importados.
#
# Linhas por segundo lidas (total): 10.2
# 117,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:58:31
#
#
# Importação iniciada em 13/03/2022, 17:32:557094.
# 8.3% importados.
#
# Linhas por segundo lidas (total): 10.2
# 117,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:55:51
#
#
# Tentando recuperar Lattes compactado 2702939008233316 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 2702939008233316
# Importação iniciada em 13/03/2022, 17:32:557780.
# 8.4% importados.
#
# Linhas por segundo lidas (total): 10.2
# 118,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:51:12
#
#
# Importação iniciada em 13/03/2022, 17:32:550022.
# 8.6% importados.
#
# Linhas por segundo lidas (total): 10.2
# 121,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:40:46
#
#
# Importação iniciada em 13/03/2022, 17:32:554294.
# 8.6% importados.
#
# Linhas por segundo lidas (total): 10.2
# 121,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:40:38
#
#
# Tentando recuperar Lattes compactado 2108958260198911 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2108958260198911
# Importação iniciada em 13/03/2022, 17:32:555429.
# 8.6% importados.
#
# Linhas por segundo lidas (total): 10.2
# 121,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:43:04
#
#
# Importação iniciada em 13/03/2022, 17:32:553731.
# 8.7% importados.
#
# Linhas por segundo lidas (total): 10.2
# 122,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:44:46
#
#
# Importação iniciada em 13/03/2022, 17:32:559289.
# 8.7% importados.
#
# Linhas por segundo lidas (total): 10.2
# 123,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:48:33
#
#
# Importação iniciada em 13/03/2022, 17:32:559028.
# 8.8% importados.
#
# Linhas por segundo lidas (total): 10.2
# 123,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:48:16
#
#
# Importação iniciada em 13/03/2022, 17:32:553509.
# 8.8% importados.
#
# Linhas por segundo lidas (total): 10.1
# 124,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:49:57
#
#
# Importação iniciada em 13/03/2022, 17:32:559392.
# 8.9% importados.
#
# Linhas por segundo lidas (total): 10.1
# 125,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:51:38
#
#
# Importação iniciada em 13/03/2022, 17:32:551846.
# 8.9% importados.
#
# Linhas por segundo lidas (total): 10.1
# 125,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:52:08
#
#
# Importação iniciada em 13/03/2022, 17:32:558654.
# 9.0% importados.
#
# Linhas por segundo lidas (total): 10.1
# 127,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:49:25
#
#
# Importação iniciada em 13/03/2022, 17:32:559676.
# 9.0% importados.
#
# Linhas por segundo lidas (total): 10.1
# 127,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:48:17
#
#
# Importação iniciada em 13/03/2022, 17:32:557777.
# 9.1% importados.
#
# Linhas por segundo lidas (total): 10.1
# 128,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:48:51
#
#
# Importação iniciada em 13/03/2022, 17:32:552879.
# 9.2% importados.
#
# Linhas por segundo lidas (total): 10.1
# 129,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:44:11
#
#
# Tentando recuperar Lattes compactado 2017421123227503 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2017421123227503
# Tentando recuperar Lattes compactado 2793987186091138 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2793987186091138
# Importação iniciada em 13/03/2022, 17:32:559721.
# 9.3% importados.
#
# Linhas por segundo lidas (total): 10.2
# 130,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:36:36
#
#
# Importação iniciada em 13/03/2022, 17:32:554271.
# 9.3% importados.
#
# Linhas por segundo lidas (total): 10.2
# 131,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:34:19
#
#
# Importação iniciada em 13/03/2022, 17:32:550220.
# 9.3% importados.
#
# Linhas por segundo lidas (total): 10.2
# 132,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:33:44
#
#
# Importação iniciada em 13/03/2022, 17:32:551110.
# 9.4% importados.
#
# Linhas por segundo lidas (total): 10.2
# 132,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:34:11
#
#
# Importação iniciada em 13/03/2022, 17:32:552356.
# 9.5% importados.
#
# Linhas por segundo lidas (total): 10.2
# 134,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:24:24
#
#
# Importação iniciada em 13/03/2022, 17:32:559082.
# 9.6% importados.
#
# Linhas por segundo lidas (total): 10.2
# 135,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:22:13
#
#
# Importação iniciada em 13/03/2022, 17:32:552075.
# 9.7% importados.
#
# Linhas por segundo lidas (total): 10.2
# 136,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:17:52
#
#
# Importação iniciada em 13/03/2022, 17:32:557185.
# 9.7% importados.
#
# Linhas por segundo lidas (total): 10.2
# 137,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:16:50
#
#
# Importação iniciada em 13/03/2022, 17:32:557214.
# 9.8% importados.
#
# Linhas por segundo lidas (total): 10.2
# 138,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:13:12
#
#
# Importação iniciada em 13/03/2022, 17:32:558179.
# 9.8% importados.
#
# Linhas por segundo lidas (total): 10.2
# 139,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:11:36
#
#
# Importação iniciada em 13/03/2022, 17:32:552084.
# 9.9% importados.
#
# Linhas por segundo lidas (total): 10.2
# 140,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:10:28
#
#
# Importação iniciada em 13/03/2022, 17:32:559146.
# 10.0% importados.
#
# Linhas por segundo lidas (total): 10.2
# 141,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:07:37
#
#
# Importação iniciada em 13/03/2022, 17:32:558515.
# 10.1% importados.
#
# Linhas por segundo lidas (total): 10.2
# 142,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:02:38
#
#
# Importação iniciada em 13/03/2022, 17:32:558265.
# 10.3% importados.
#
# Linhas por segundo lidas (total): 10.3
# 145,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:49:19
#
#
# Importação iniciada em 13/03/2022, 17:32:553051.
# 10.4% importados.
#
# Linhas por segundo lidas (total): 10.3
# 146,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:48:17
#
#
# Importação iniciada em 13/03/2022, 17:32:554787.
# 10.4% importados.
#
# Linhas por segundo lidas (total): 10.3
# 146,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:48:13
#
#
# Importação iniciada em 13/03/2022, 17:32:554049.
# 10.4% importados.
#
# Linhas por segundo lidas (total): 10.3
# 147,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:45:25
#
#
# Importação iniciada em 13/03/2022, 17:32:557250.
# 10.5% importados.
#
# Linhas por segundo lidas (total): 10.3
# 147,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:44:10
#
#
# Importação iniciada em 13/03/2022, 17:32:555848.
# 10.5% importados.
#
# Linhas por segundo lidas (total): 10.3
# 149,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:38:39
#
#
# Importação iniciada em 13/03/2022, 17:32:550336.
# 10.6% importados.
#
# Linhas por segundo lidas (total): 10.3
# 150,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:38:34
# Importação iniciada em 13/03/2022, 17:32:550983.
# 10.7% importados.
#
# Linhas por segundo lidas (total): 10.3
# 150,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:38:35
#
#
# Importação iniciada em 13/03/2022, 17:32:552709.
# 10.7% importados.
#
# Linhas por segundo lidas (total): 10.3
# 151,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:37:08
#
#
# Importação iniciada em 13/03/2022, 17:32:551682.
# 10.7% importados.
#
# Linhas por segundo lidas (total): 10.3
# 151,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:36:55
#
#
# Importação iniciada em 13/03/2022, 17:32:558268.
# 10.9% importados.
#
# Linhas por segundo lidas (total): 10.3
# 153,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:31:14
#
#
# Tentando recuperar Lattes compactado 2531986810893058 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2531986810893058
# Importação iniciada em 13/03/2022, 17:32:554290.
# 11.1% importados.
#
# Linhas por segundo lidas (total): 10.3
# 156,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:22:04
#
#
# Tentando recuperar Lattes compactado 2239478707115084 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2239478707115084
# Importação iniciada em 13/03/2022, 17:32:557641.
# 11.3% importados.
#
# Linhas por segundo lidas (total): 10.3
# 159,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:14:27
#
#
# Importação iniciada em 13/03/2022, 17:32:559201.
# 11.4% importados.
#
# Linhas por segundo lidas (total): 10.3
# 160,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:10:52
#
#
# Tentando recuperar Lattes compactado 2308002858607045 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2308002858607045
# Importação iniciada em 13/03/2022, 17:32:559458.
# 11.5% importados.
#
# Linhas por segundo lidas (total): 10.4
# 162,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:03:24
#
#
# Importação iniciada em 13/03/2022, 17:32:558162.
# 11.6% importados.
#
# Linhas por segundo lidas (total): 10.4
# 164,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:01:00
#
#
# Importação iniciada em 13/03/2022, 17:32:551349.
# 11.6% importados.
#
# Linhas por segundo lidas (total): 10.4
# 164,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:00:01
#
#
# Tentando recuperar Lattes compactado 2402346842405718 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2402346842405718
# Importação iniciada em 13/03/2022, 17:32:559258.
# 11.7% importados.
#
# Linhas por segundo lidas (total): 10.4
# 165,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:59:49
#
#
# Importação iniciada em 13/03/2022, 17:32:558031.
# 11.7% importados.
#
# Linhas por segundo lidas (total): 10.4
# 166,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:59:19
#
#
# Importação iniciada em 13/03/2022, 17:32:551794.
# 11.8% importados.
#
# Linhas por segundo lidas (total): 10.4
# 166,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:58:49
#
#
# Importação iniciada em 13/03/2022, 17:32:559487.
# 11.9% importados.
#
# Linhas por segundo lidas (total): 10.4
# 167,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:56:42
#
#
# Importação iniciada em 13/03/2022, 17:32:555583.
# 11.9% importados.
#
# Linhas por segundo lidas (total): 10.4
# 168,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:53:44
#
#
# Importação iniciada em 13/03/2022, 17:32:551866.
# 12.0% importados.
#
# Linhas por segundo lidas (total): 10.4
# 169,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:51:48
#
#
# Importação iniciada em 13/03/2022, 17:32:559259.
# 12.1% importados.
#
# Linhas por segundo lidas (total): 10.4
# 170,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:46:08
#
#
# Tentando recuperar Lattes compactado 2230560984989256 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2230560984989256
# Importação iniciada em 13/03/2022, 17:32:551573.
# 12.1% importados.
#
# Linhas por segundo lidas (total): 10.4
# 171,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:45:42
#
#
# Importação iniciada em 13/03/2022, 17:32:558642.
# 12.3% importados.
#
# Linhas por segundo lidas (total): 10.4
# 173,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:41:14
#
#
# Importação iniciada em 13/03/2022, 17:32:554990.
# 12.3% importados.
#
# Linhas por segundo lidas (total): 10.4
# 173,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:39:23
#
#
# Importação iniciada em 13/03/2022, 17:32:554793.
# 12.4% importados.
#
# Linhas por segundo lidas (total): 10.4
# 174,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:38:46
#
#
# Tentando recuperar Lattes compactado 2363033895654485 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2363033895654485
# Importação iniciada em 13/03/2022, 17:32:556888.
# 12.5% importados.
#
# Linhas por segundo lidas (total): 10.4
# 176,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:34:00
#
#
# Importação iniciada em 13/03/2022, 17:32:553273.
# 12.5% importados.
#
# Linhas por segundo lidas (total): 10.4
# 176,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:32:25
#
#
# Tentando recuperar Lattes compactado 2502938661299754 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 2502938661299754
# Importação iniciada em 13/03/2022, 17:32:557281.
# 12.6% importados.
#
# Linhas por segundo lidas (total): 10.4
# 178,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:28:48
#
#
# Importação iniciada em 13/03/2022, 17:32:557860.
# 12.6% importados.
#
# Linhas por segundo lidas (total): 10.4
# 178,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:27:16
#
#
# Importação iniciada em 13/03/2022, 17:32:555867.
# 12.7% importados.
#
# Linhas por segundo lidas (total): 10.4
# 179,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:26:10
#
#
# Importação iniciada em 13/03/2022, 17:32:555746.
# 12.7% importados.
#
# Linhas por segundo lidas (total): 10.4
# 179,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:24:57
#
#
# Importação iniciada em 13/03/2022, 17:32:555234.
# 12.7% importados.
#
# Linhas por segundo lidas (total): 10.4
# 180,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:25:27
#
#
# Importação iniciada em 13/03/2022, 17:32:551382.
# 12.8% importados.
#
# Linhas por segundo lidas (total): 10.4
# 180,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:24:48
#
#
# Importação iniciada em 13/03/2022, 17:32:550051.
# 12.9% importados.
#
# Linhas por segundo lidas (total): 10.4
# 182,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:19:56
#
#
# Importação iniciada em 13/03/2022, 17:32:550915.
# 13.0% importados.
#
# Linhas por segundo lidas (total): 10.4
# 183,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:17:32
#
#
# Tentando recuperar Lattes compactado 2650241849765153 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 2650241849765153
# Importação iniciada em 13/03/2022, 17:32:553693.
# 13.2% importados.
#
# Linhas por segundo lidas (total): 10.4
# 186,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:10:18
#
#
# Importação iniciada em 13/03/2022, 17:32:553616.
# 13.3% importados.
#
# Linhas por segundo lidas (total): 10.4
# 188,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:09:00
#
#
# Importação iniciada em 13/03/2022, 17:32:550339.
# 13.3% importados.
#
# Linhas por segundo lidas (total): 10.4
# 188,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:08:35
# Importação iniciada em 13/03/2022, 17:32:558058.
# 13.4% importados.
#
# Linhas por segundo lidas (total): 10.4
# 188,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:08:27
#
#
# Importação iniciada em 13/03/2022, 17:32:551420.
# 13.4% importados.
#
# Linhas por segundo lidas (total): 10.4
# 189,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:07:28
#
#
# Importação iniciada em 13/03/2022, 17:32:554256.
# 13.6% importados.
#
# Linhas por segundo lidas (total): 10.5
# 192,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:59:35
#
#
# Importação iniciada em 13/03/2022, 17:32:552622.
# 13.6% importados.
#
# Linhas por segundo lidas (total): 10.5
# 192,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:59:07
#
#
# Importação iniciada em 13/03/2022, 17:32:556442.
# 13.7% importados.
#
# Linhas por segundo lidas (total): 10.5
# 193,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:56:18
#
#
# Importação iniciada em 13/03/2022, 17:32:550876.
# 13.8% importados.
#
# Linhas por segundo lidas (total): 10.5
# 194,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:53:36
#
#
# Tentando recuperar Lattes compactado 2853312424687216 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2853312424687216
# Importação iniciada em 13/03/2022, 17:32:551773.
# 13.8% importados.
#
# Linhas por segundo lidas (total): 10.5
# 195,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:53:02
#
#
# Importação iniciada em 13/03/2022, 17:32:554349.
# 13.8% importados.
#
# Linhas por segundo lidas (total): 10.5
# 195,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:52:39
#
#
# Importação iniciada em 13/03/2022, 17:32:556389.
# 13.9% importados.
#
# Linhas por segundo lidas (total): 10.5
# 196,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:49:52
#
#
# Importação iniciada em 13/03/2022, 17:32:553436.
# 13.9% importados.
#
# Linhas por segundo lidas (total): 10.5
# 196,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:49:39
#
#
# Importação iniciada em 13/03/2022, 17:32:555249.
# 13.9% importados.
#
# Linhas por segundo lidas (total): 10.5
# 197,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:50:01
#
#
# Importação iniciada em 13/03/2022, 17:32:559248.
# 14.0% importados.
#
# Linhas por segundo lidas (total): 10.5
# 198,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:46:32
#
#
# Importação iniciada em 13/03/2022, 17:32:559301.
# 14.1% importados.
#
# Linhas por segundo lidas (total): 10.5
# 198,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:46:04
#
#
# Importação iniciada em 13/03/2022, 17:32:555838.
# 14.1% importados.
#
# Linhas por segundo lidas (total): 10.5
# 199,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:45:13
#
#
# Tentando recuperar Lattes compactado 2246399621540427 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2246399621540427
# Importação iniciada em 13/03/2022, 17:32:552789.
# 14.3% importados.
#
# Linhas por segundo lidas (total): 10.5
# 201,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:39:59
#
#
# Importação iniciada em 13/03/2022, 17:32:557839.
# 14.3% importados.
#
# Linhas por segundo lidas (total): 10.5
# 202,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:37:50
#
#
# Importação iniciada em 13/03/2022, 17:32:555000.
# 14.3% importados.
#
# Linhas por segundo lidas (total): 10.5
# 202,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:37:34
#
#
# Importação iniciada em 13/03/2022, 17:32:559853.
# 14.3% importados.
#
# Linhas por segundo lidas (total): 10.5
# 202,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:37:22
#
#
# Importação iniciada em 13/03/2022, 17:32:554383.
# 14.4% importados.
#
# Linhas por segundo lidas (total): 10.5
# 203,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:35:53
#
#
# Importação iniciada em 13/03/2022, 17:32:553335.
# 14.4% importados.
#
# Linhas por segundo lidas (total): 10.5
# 203,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:34:34
#
#
# Tentando recuperar Lattes compactado 2922655026935873 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2922655026935873
# Tentando recuperar Lattes compactado 2787672253275847 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 2787672253275847
# Importação iniciada em 13/03/2022, 17:32:556326.
# 14.6% importados.
#
# Linhas por segundo lidas (total): 10.5
# 206,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:30:55
#
#
# Importação iniciada em 13/03/2022, 17:32:554886.
# 14.8% importados.
#
# Linhas por segundo lidas (total): 10.5
# 209,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:23:42
#
#
# Importação iniciada em 13/03/2022, 17:32:555176.
# 14.8% importados.
#
# Linhas por segundo lidas (total): 10.5
# 209,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:21:43
#
#
# Importação iniciada em 13/03/2022, 17:32:557320.
# 14.9% importados.
#
# Linhas por segundo lidas (total): 10.5
# 210,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:20:57
#
#
# Importação iniciada em 13/03/2022, 17:32:550641.
# 15.0% importados.
#
# Linhas por segundo lidas (total): 10.5
# 212,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:16:57
#
#
# Importação iniciada em 13/03/2022, 17:32:551774.
# 15.1% importados.
#
# Linhas por segundo lidas (total): 10.5
# 213,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:16:25
#
#
# Importação iniciada em 13/03/2022, 17:32:556532.
# 15.1% importados.
#
# Linhas por segundo lidas (total): 10.5
# 213,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:16:32
#
#
# Importação iniciada em 13/03/2022, 17:32:550303.
# 15.1% importados.
#
# Linhas por segundo lidas (total): 10.5
# 213,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:16:28
#
#
# Importação iniciada em 13/03/2022, 17:32:551140.
# 15.1% importados.
#
# Linhas por segundo lidas (total): 10.5
# 213,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:16:04
#
#
# Importação iniciada em 13/03/2022, 17:32:551155.
# ...
# 94.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,333,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 19:38:55
#
#
# Importação iniciada em 13/03/2022, 17:32:5566174.
# 94.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,334,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 19:38:35
#
#
# Importação iniciada em 13/03/2022, 17:32:5509488.
# 94.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,334,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 19:37:48
#
#
# Importação iniciada em 13/03/2022, 17:32:5508110.
# 94.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,334,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 19:37:39
#
#
# Importação iniciada em 13/03/2022, 17:32:5556257.
# 94.5% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,335,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 19:36:13
#
#
# Importação iniciada em 13/03/2022, 17:32:5597027.
# 94.5% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,336,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 19:35:25
#
#
# Importação iniciada em 13/03/2022, 17:32:5584150.
# 94.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,336,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 19:34:09
#
#
# Importação iniciada em 13/03/2022, 17:32:5532121.
# 94.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,337,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 19:33:13
#
#
# Importação iniciada em 13/03/2022, 17:32:5532962.
# 94.7% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,339,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 19:30:40
#
#
# Importação iniciada em 13/03/2022, 17:32:5572734.
# 94.8% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,340,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 19:28:45
#
#
# Importação iniciada em 13/03/2022, 17:32:5542780.
# 94.8% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,340,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 19:27:48
#
#
# Importação iniciada em 13/03/2022, 17:32:5560977.
# 94.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,341,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 19:26:32
#
#
# Importação iniciada em 13/03/2022, 17:32:5537917.
# 95.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,345,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 19:20:20
#
#
# Importação iniciada em 13/03/2022, 17:32:5537074.
# 95.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,346,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 19:19:04
#
#
# Importação iniciada em 13/03/2022, 17:32:5507482.
# 95.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,346,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 19:18:35
#
#
# Importação iniciada em 13/03/2022, 17:32:5536274.
# 95.7% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,352,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 19:09:07
#
#
# Importação iniciada em 13/03/2022, 17:32:5551865.
# 95.7% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,353,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 19:08:20
#
#
# Importação iniciada em 13/03/2022, 17:32:5502170.
# 95.7% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,353,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 19:07:52
#
#
# Importação iniciada em 13/03/2022, 17:32:5595826.
# 95.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,355,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 19:05:20
#
#
# Importação iniciada em 13/03/2022, 17:32:5585162.
# 95.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,355,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 19:05:11
#
#
# Importação iniciada em 13/03/2022, 17:32:5583884.
# 95.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,356,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 19:03:07
#
#
# Importação iniciada em 13/03/2022, 17:32:5528229.
# 96.1% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,358,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:59:47
#
#
# Importação iniciada em 13/03/2022, 17:32:5501993.
# 96.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,359,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:58:03
#
#
# Importação iniciada em 13/03/2022, 17:32:5531320.
# 96.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,360,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:56:19
#
#
# Importação iniciada em 13/03/2022, 17:32:5556438.
# 96.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,361,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:55:50
#
#
# Importação iniciada em 13/03/2022, 17:32:5544675.
# 96.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,361,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:54:53
#
#
# Importação iniciada em 13/03/2022, 17:32:5510592.
# 96.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,362,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:54:06
#
#
# Importação iniciada em 13/03/2022, 17:32:5544034.
# 96.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,362,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:53:46
#
#
# Importação iniciada em 13/03/2022, 17:32:5531087.
# 96.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,363,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:52:40
#
#
# Importação iniciada em 13/03/2022, 17:32:5561410.
# 96.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,365,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:48:24
#
#
# Tentando recuperar Lattes compactado 2945883868860294 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 2945883868860294
# Importação iniciada em 13/03/2022, 17:32:5551901.
# 96.8% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,368,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:43:48
#
#
# Tentando recuperar Lattes compactado 2730032915461438 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 2730032915461438
# Importação iniciada em 13/03/2022, 17:32:5515114.
# 96.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,370,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:41:35
#
#
# Importação iniciada em 13/03/2022, 17:32:5554073.
# 97.0% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,370,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:40:19
#
#
# Importação iniciada em 13/03/2022, 17:32:5544129.
# 97.0% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,371,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:38:34
#
#
# Tentando recuperar Lattes compactado 2047246618237062 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2047246618237062
# Importação iniciada em 13/03/2022, 17:32:5532883.
# 97.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,374,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:34:28
#
#
# Importação iniciada em 13/03/2022, 17:32:5556798.
# 97.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,375,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:33:12
#
#
# Importação iniciada em 13/03/2022, 17:32:5527139.
# 97.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,379,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:27:13
#
#
# Importação iniciada em 13/03/2022, 17:32:5578799.
# 97.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,379,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:27:04
#
#
# Importação iniciada em 13/03/2022, 17:32:5570891.
# 97.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,380,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:25:39
#
#
# Importação iniciada em 13/03/2022, 17:32:5541078.
# 97.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,380,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:25:11
#
#
# Importação iniciada em 13/03/2022, 17:32:5575722.
# 97.7% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,381,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:23:08
#
#
# Importação iniciada em 13/03/2022, 17:32:5505931.
# 97.8% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,382,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:22:11
#
#
# Importação iniciada em 13/03/2022, 17:32:5554167.
# 97.8% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,383,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:20:55
#
#
# Importação iniciada em 13/03/2022, 17:32:5565082.
# 98.0% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,385,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:17:37
#
#
# Importação iniciada em 13/03/2022, 17:32:5534508.
# 98.0% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,385,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:16:50
#
#
# Importação iniciada em 13/03/2022, 17:32:5561973.
# 98.1% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,386,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:15:15
#
#
# Importação iniciada em 13/03/2022, 17:32:5597550.
# 98.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,388,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:13:13
#
#
# Importação iniciada em 13/03/2022, 17:32:5516451.
# 98.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,389,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:11:00
#
#
# Importação iniciada em 13/03/2022, 17:32:5555521.
# 98.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,390,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:08:57
#
#
# Importação iniciada em 13/03/2022, 17:32:5541661.
# 98.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,391,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:07:42
#
#
# Importação iniciada em 13/03/2022, 17:32:5508796.
# 98.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,391,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:07:33
#
#
# Importação iniciada em 13/03/2022, 17:32:5579466.
# 98.5% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,392,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:06:36
#
#
# Importação iniciada em 13/03/2022, 17:32:5535716.
# 98.7% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,395,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 18:00:47
#
#
# Importação iniciada em 13/03/2022, 17:32:5503349.
# 98.8% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,396,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 17:59:51
#
#
# Importação iniciada em 13/03/2022, 17:32:5576243.
# 98.8% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,396,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 17:59:22
#
#
# Importação iniciada em 13/03/2022, 17:32:5584110.
# 98.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,397,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 17:57:57
#
#
# Importação iniciada em 13/03/2022, 17:32:5521538.
# 98.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,398,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 17:57:20
#
#
# Importação iniciada em 13/03/2022, 17:32:5508319.
# 99.0% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,398,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 17:56:04
#
#
# Importação iniciada em 13/03/2022, 17:32:5533795.
# 99.0% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,399,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 17:55:46
#
#
# Importação iniciada em 13/03/2022, 17:32:5521092.
# 99.1% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,400,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 17:53:43
#
#
# Importação iniciada em 13/03/2022, 17:32:5520045.
# 99.1% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,401,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 17:52:37
#
#
# Importação iniciada em 13/03/2022, 17:32:5533393.
# 99.1% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,401,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 17:51:50
#
#
# Importação iniciada em 13/03/2022, 17:32:5526116.
# 99.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,402,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 17:51:12
#
#
# Importação iniciada em 13/03/2022, 17:32:5567903.
# 99.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,402,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 17:51:03
#
#
# Importação iniciada em 13/03/2022, 17:32:5519402.
# 99.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,402,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 17:50:44
#
#
# Importação iniciada em 13/03/2022, 17:32:5549125.
# 99.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,402,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 17:49:48
#
#
# Importação iniciada em 13/03/2022, 17:32:5573551.
# 99.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,403,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 17:48:51
#
#
# Importação iniciada em 13/03/2022, 17:32:5514379.
# 99.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,404,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 17:47:27
#
#
# Importação iniciada em 13/03/2022, 17:32:5511696.
# 99.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,404,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 17:46:39
#
#
# Tentando recuperar Lattes compactado 2635871855151469 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 2635871855151469
# Importação iniciada em 13/03/2022, 17:32:5570965.
# 99.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,408,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 17:41:10
#
#
# Importação iniciada em 13/03/2022, 17:32:5584041.
# 99.7% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,408,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 17:40:23
#
#
# Importação iniciada em 13/03/2022, 17:32:5593293.
# 99.8% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,410,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 17:38:21
#
#
# Importação iniciada em 13/03/2022, 17:32:5545186.
# 99.8% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,411,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 17:36:38
#
#
# Importação iniciada em 13/03/2022, 17:32:5505671.
# 99.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,412,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 13/03/2022, 17:34:07
#
#
# 1413654 / 1413665. Importing id 2672616551229880.
