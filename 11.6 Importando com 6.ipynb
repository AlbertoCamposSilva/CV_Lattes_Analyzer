# %%
from Carga import Carga
cg = Carga()


#Origens
cg.de_hd = False
cg.de_all_lattes = True
cg.de_bd_demanda_bruta = False
cg.de_dados_pessoais = False

#Exceções
cg.pular_indicadores = False
cg.pular_palavras_chave = False
cg.pular_areas_conhecimento = False
cg.pular_publicações = True
cg.pular_dados_gerais=False
cg.pular_vinculos = False
cg.pular_erros = False
cg.pular_jsons = False

#Importações
cg.on_conflic_update = True
cg.importar_indicadores = True
cg.importar_palavras_chave = True
cg.importar_areas_conhecimento = True
cg.importar_publicações = True
cg.importar_dados_gerais=True
cg.importar_vinculos = True


#Outras Configurações
cg.on_conflic_update = True
cg.auto_save_json_to_bd = True
cg.pegar_lista_de_importação_de_arquivo = False
cg.data_mínima_atualização_lattes = None

cg.atualiza_todos_os_indicadores(começando_com = '6')
# Out:
# Carregando lista de indicadores para importar da tabela all_lattes do BD
#
# Carregando lista de Ids da tabela publicacoes para pular
#
# Retirando ids a exluir...
# Salvando o arquivo com a lista no disco.
# Iniciando Importação.
# Tentando recuperar Lattes compactado 6436350834893051 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6436350834893051
# Tentando recuperar Lattes compactado 6390923742900990 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6390923742900990
# Tentando recuperar Lattes compactado 6257814685503996 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6143906870528810 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6772023521157659 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6869927680547977 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6804395931202037 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6340109424654992 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6970232264146862 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6945635241497775 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6517712829512783 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6559624824348082 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6559624824348082
# Tentando recuperar Lattes compactado 6791926507512969 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6687749732327331 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6964920809029679 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6120374590042777 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6475501887405794 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6035665753792046 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6799634915423174 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6327871956681263 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6213946952449693 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6161338533605297 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6607793517683475 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6346595573946851 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6227916259387991 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6987732570785712 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6450504854729399 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6078296565411549 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6060831691817998 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6678346576078805 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6271218287995744 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6271218287995744
# Tentando recuperar Lattes compactado 6773611550274158 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6968439403096308 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6107642621924699 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6759556790085204 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6437297790377296 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6674557399829091 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6582147999407029 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6449325893575709 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6722453093201293 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6307026497325244 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6059692899052482 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6331551972854096 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6331551972854096
# Tentando recuperar Lattes compactado 6248170534020352 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6293737665522478 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6207495710555750 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 6138881441209351 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# 2346 / 5654187. Importing id 6550333891490219.
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3904/433994444.py in <module>
#      35 cg.data_mínima_atualização_lattes = None
#      36
# ---> 37 cg.atualiza_todos_os_indicadores(começando_com = '6')
#
# ~\CNPq\Lattes\Python\Carga.py in atualiza_todos_os_indicadores(self, num_imports_skip_before_log, começando_com)
#    1063                 print(f'{num} / {linhas_totais}. Importing id {id}.\r', end="", flush=True)
#    1064
# -> 1065                 ind = Indicadores (id = id, auto_save_json_to_bd = self.auto_save_json_to_bd)
#    1066                 ind.on_conflic_update = self.on_conflic_update
#    1067                 ind.atualiza(
#
# ~\CNPq\Lattes\Python\Indicadores.py in __init__(self, id, json, filename, show_execution_time, show_sql, auto_save_json_to_bd, on_conflic_update)
#      26         self.show_sql = show_sql
#      27         self.auto_save_json_to_bd = auto_save_json_to_bd
# ---> 28         self.db = Database('CNPq', show_sql = show_sql)
#      29         self.indicadores = []
#      30         self.list_indicadores = []
#
# ~\CNPq\Lattes\Python\Database.py in __init__(self, name, show_sql)
#      34     def __init__(self, name = 'CNPq', show_sql = False):
#      35         self.params = Database.config_db_connection()
# ---> 36         self.conn = psycopg2.connect(**self.params)
#      37         self.cur = self.conn.cursor()
#      38         self.show_sql = show_sql
#
# ~\Anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     120
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#     124         conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "albertocampos.ddns.net" (200.169.188.152), port 8080 failed: Connection timed out (0x0000274C/10060)
# 	Is the server running on that host and accepting TCP/IP connections?
