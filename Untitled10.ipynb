# %%
from Carga import Carga
cg = Carga()
cg.atualiza_todos_os_indicadores (on_conflic_update = True, 
                                  pula_bd_indicadores = True, 
                                  pula_erros = False, 
                                  data_mínima_atualização_lattes = '2020-01-01', 
                                  de_all_lattes = True, 
                                  começando_com=[8],
                                 )
# Out:
# Carregando lista de Ids da tabela indicadores para pular
#
# Carregando lista de indicadores para importar da tabela Lattes do BD
#
# Carregando lista de indicadores para importar da tabela demanda_bruta do BD
#
# Carregando lista de indicadores para importar da tabela carga_dados_pessoais do BD
#
# Retirando ids a exluir...
# Iniciando Importação.
# Importação iniciada em 13/03/2022, 17:33:2593.
# 0.2% importados.
#
# Linhas por segundo lidas (total): 9.9
# 3,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:12:36
#
#
# Importação iniciada em 13/03/2022, 17:33:2553.
# 0.3% importados.
#
# Linhas por segundo lidas (total): 9.9
# 4,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:07:14
#
#
# Importação iniciada em 13/03/2022, 17:33:2576.
# 0.4% importados.
#
# Linhas por segundo lidas (total): 9.7
# 5,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:51:26
#
#
# Importação iniciada em 13/03/2022, 17:33:2511.
# 0.4% importados.
#
# Linhas por segundo lidas (total): 9.6
# 5,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:25:52
#
#
# Importação iniciada em 13/03/2022, 17:33:2560.
# 0.4% importados.
#
# Linhas por segundo lidas (total): 9.7
# 5,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:00:56
#
#
# Importação iniciada em 13/03/2022, 17:33:2524.
# 0.5% importados.
#
# Linhas por segundo lidas (total): 9.8
# 6,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:28:14
#
#
# Tentando recuperar Lattes compactado 8372638068076004 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8372638068076004
# Importação iniciada em 13/03/2022, 17:33:2534.
# 0.5% importados.
#
# Linhas por segundo lidas (total): 9.8
# 6,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:16:57
#
#
# Importação iniciada em 13/03/2022, 17:33:2513.
# 0.6% importados.
#
# Linhas por segundo lidas (total): 9.9
# 8,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:49:35
#
#
# Importação iniciada em 13/03/2022, 17:33:2574.
# 0.7% importados.
#
# Linhas por segundo lidas (total): 9.9
# 9,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:05:50
#
#
# Importação iniciada em 13/03/2022, 17:33:25134.
# 0.7% importados.
#
# Linhas por segundo lidas (total): 10.0
# 10,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:42:35
#
#
# Importação iniciada em 13/03/2022, 17:33:25000.
# 0.7% importados.
#
# Linhas por segundo lidas (total): 9.9
# 10,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:50:59
#
#
# Importação iniciada em 13/03/2022, 17:33:25321.
# 1.0% importados.
#
# Linhas por segundo lidas (total): 10.1
# 14,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:56:14
#
#
# Importação iniciada em 13/03/2022, 17:33:25269.
# 1.1% importados.
#
# Linhas por segundo lidas (total): 10.1
# 14,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:11:37
#
#
# Importação iniciada em 13/03/2022, 17:33:25026.
# 1.1% importados.
#
# Linhas por segundo lidas (total): 10.0
# 16,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:15:28
#
#
# Importação iniciada em 13/03/2022, 17:33:25461.
# 1.2% importados.
#
# Linhas por segundo lidas (total): 10.1
# 17,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:59:03
#
#
# Importação iniciada em 13/03/2022, 17:33:25669.
# 1.2% importados.
#
# Linhas por segundo lidas (total): 10.1
# 17,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:59:29
#
#
# Importação iniciada em 13/03/2022, 17:33:25855.
# 1.4% importados.
#
# Linhas por segundo lidas (total): 10.1
# 20,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:00:11
#
#
# Importação iniciada em 13/03/2022, 17:33:25319.
# 1.4% importados.
#
# Linhas por segundo lidas (total): 10.1
# 20,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:55:53
#
#
# Importação iniciada em 13/03/2022, 17:33:25353.
# 1.5% importados.
#
# Linhas por segundo lidas (total): 10.1
# 21,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:00:57
#
#
# Importação iniciada em 13/03/2022, 17:33:25683.
# 1.6% importados.
#
# Linhas por segundo lidas (total): 10.1
# 22,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:55:36
#
#
# Importação iniciada em 13/03/2022, 17:33:25855.
# 1.6% importados.
#
# Linhas por segundo lidas (total): 10.1
# 22,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:56:06
#
#
# Importação iniciada em 13/03/2022, 17:33:25326.
# 1.7% importados.
#
# Linhas por segundo lidas (total): 10.2
# 23,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:32:06
#
#
# Importação iniciada em 13/03/2022, 17:33:25586.
# 1.8% importados.
#
# Linhas por segundo lidas (total): 10.3
# 25,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:10:32
#
#
# Importação iniciada em 13/03/2022, 17:33:25954.
# 1.8% importados.
#
# Linhas por segundo lidas (total): 10.3
# 26,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:50:48
#
#
# Importação iniciada em 13/03/2022, 17:33:25963.
# 1.9% importados.
#
# Linhas por segundo lidas (total): 10.4
# 26,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:42:28
#
#
# Importação iniciada em 13/03/2022, 17:33:25528.
# 1.9% importados.
#
# Linhas por segundo lidas (total): 10.4
# 26,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:34:18
#
#
# Importação iniciada em 13/03/2022, 17:33:25193.
# 2.0% importados.
#
# Linhas por segundo lidas (total): 10.4
# 28,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:26:13
#
#
# Tentando recuperar Lattes compactado 8064380807483737 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8064380807483737
# Importação iniciada em 13/03/2022, 17:33:25539.
# 2.1% importados.
#
# Linhas por segundo lidas (total): 10.5
# 30,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:06:08
#
#
# Importação iniciada em 13/03/2022, 17:33:25797.
# 2.1% importados.
#
# Linhas por segundo lidas (total): 10.5
# 30,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:02:34
#
#
# Importação iniciada em 13/03/2022, 17:33:25560.
# 2.2% importados.
#
# Linhas por segundo lidas (total): 10.5
# 31,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:02:35
#
#
# Tentando recuperar Lattes compactado 8985313272063856 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8985313272063856
# Importação iniciada em 13/03/2022, 17:33:25487.
# 2.3% importados.
#
# Linhas por segundo lidas (total): 10.5
# 31,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:04:19
#
#
# Importação iniciada em 13/03/2022, 17:33:25000.
# 2.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 33,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:53:06
#
#
# Importação iniciada em 13/03/2022, 17:33:25401.
# 2.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 34,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:47:02
#
#
# Importação iniciada em 13/03/2022, 17:33:25496.
# 2.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 34,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:47:14
#
#
# Importação iniciada em 13/03/2022, 17:33:25421.
# 2.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 34,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:49:06
#
#
# Importação iniciada em 13/03/2022, 17:33:25443.
# 2.5% importados.
#
# Linhas por segundo lidas (total): 10.4
# 36,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:10:54
#
#
# Importação iniciada em 13/03/2022, 17:33:25046.
# 2.6% importados.
#
# Linhas por segundo lidas (total): 10.5
# 36,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:05:56
# Importação iniciada em 13/03/2022, 17:33:25481.
# 2.6% importados.
#
# Linhas por segundo lidas (total): 10.4
# 37,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:09:22
#
#
# Importação iniciada em 13/03/2022, 17:33:25815.
# 2.7% importados.
#
# Linhas por segundo lidas (total): 10.4
# 37,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:19:19
#
#
# Importação iniciada em 13/03/2022, 17:33:25323.
# 2.9% importados.
#
# Linhas por segundo lidas (total): 10.5
# 40,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:55:06
#
#
# Importação iniciada em 13/03/2022, 17:33:25717.
# 2.9% importados.
#
# Linhas por segundo lidas (total): 10.5
# 41,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:00:32
#
#
# Tentando recuperar Lattes compactado 8198245433222968 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8198245433222968
# Tentando recuperar Lattes compactado 8990256491607680 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8990256491607680
# Importação iniciada em 13/03/2022, 17:33:25573.
# 3.1% importados.
#
# Linhas por segundo lidas (total): 10.5
# 43,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:49:28
#
#
# Importação iniciada em 13/03/2022, 17:33:25115.
# 3.1% importados.
#
# Linhas por segundo lidas (total): 10.5
# 44,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:53:03
#
#
# Importação iniciada em 13/03/2022, 17:33:25262.
# 3.2% importados.
#
# Linhas por segundo lidas (total): 10.5
# 44,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:54:59
#
#
# Tentando recuperar Lattes compactado 8914558198551472 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8914558198551472
# Importação iniciada em 13/03/2022, 17:33:25565.
# 3.4% importados.
#
# Linhas por segundo lidas (total): 10.4
# 47,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:08:41
#
#
# Importação iniciada em 13/03/2022, 17:33:25457.
# 3.5% importados.
#
# Linhas por segundo lidas (total): 10.4
# 48,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:00:45
#
#
# Importação iniciada em 13/03/2022, 17:33:25438.
# 3.5% importados.
#
# Linhas por segundo lidas (total): 10.4
# 49,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:01:56
#
#
# Importação iniciada em 13/03/2022, 17:33:25616.
# 3.5% importados.
#
# Linhas por segundo lidas (total): 10.4
# 49,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:02:16
#
#
# Importação iniciada em 13/03/2022, 17:33:25959.
# 3.7% importados.
#
# Linhas por segundo lidas (total): 10.5
# 52,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:42:08
#
#
# Importação iniciada em 13/03/2022, 17:33:25985.
# 3.9% importados.
#
# Linhas por segundo lidas (total): 10.5
# 54,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:33:40
#
#
# Importação iniciada em 13/03/2022, 17:33:25106.
# 4.0% importados.
#
# Linhas por segundo lidas (total): 10.5
# 57,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:33:35
#
#
# Importação iniciada em 13/03/2022, 17:33:25533.
# 4.0% importados.
#
# Linhas por segundo lidas (total): 10.5
# 57,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:32:36
#
#
# Importação iniciada em 13/03/2022, 17:33:25860.
# 4.1% importados.
#
# Linhas por segundo lidas (total): 10.5
# 58,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:33:48
#
#
# Importação iniciada em 13/03/2022, 17:33:25098.
# 4.2% importados.
#
# Linhas por segundo lidas (total): 10.5
# 59,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:29:38
#
#
# Importação iniciada em 13/03/2022, 17:33:25452.
# 4.2% importados.
#
# Linhas por segundo lidas (total): 10.5
# 60,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:29:25
#
#
# Importação iniciada em 13/03/2022, 17:33:25352.
# 4.3% importados.
#
# Linhas por segundo lidas (total): 10.5
# 60,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:29:09
#
#
# Importação iniciada em 13/03/2022, 17:33:25716.
# 4.4% importados.
#
# Linhas por segundo lidas (total): 10.5
# 62,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:07:33
#
#
# Importação iniciada em 13/03/2022, 17:33:25733.
# 4.5% importados.
#
# Linhas por segundo lidas (total): 10.6
# 63,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:07:09
#
#
# Importação iniciada em 13/03/2022, 17:33:25226.
# 4.5% importados.
#
# Linhas por segundo lidas (total): 10.6
# 64,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:00:12
#
#
# Tentando recuperar Lattes compactado 8743438381645284 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8743438381645284
# Importação iniciada em 13/03/2022, 17:33:25476.
# 4.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 65,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:58:12
#
#
# Importação iniciada em 13/03/2022, 17:33:25089.
# 4.7% importados.
#
# Linhas por segundo lidas (total): 10.6
# 66,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:55:19
#
#
# Importação iniciada em 13/03/2022, 17:33:25693.
# 4.8% importados.
#
# Linhas por segundo lidas (total): 10.6
# 67,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:49:15
#
#
# Tentando recuperar Lattes compactado 8128617309402674 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8128617309402674
# Importação iniciada em 13/03/2022, 17:33:25908.
# 4.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 69,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:55:11
#
#
# Importação iniciada em 13/03/2022, 17:33:25562.
# 5.0% importados.
#
# Linhas por segundo lidas (total): 10.6
# 70,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:54:02
#
#
# Importação iniciada em 13/03/2022, 17:33:25733.
# 5.0% importados.
#
# Linhas por segundo lidas (total): 10.6
# 71,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:52:34
#
#
# Importação iniciada em 13/03/2022, 17:33:25385.
# 5.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 74,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:44:41
#
#
# Tentando recuperar Lattes compactado 8359045619553331 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8359045619553331
# Tentando recuperar Lattes compactado 8609418614577701 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8609418614577701
# Importação iniciada em 13/03/2022, 17:33:25514.
# 5.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 76,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:38:48
#
#
# Importação iniciada em 13/03/2022, 17:33:25839.
# 5.5% importados.
#
# Linhas por segundo lidas (total): 10.6
# 77,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:39:49
#
#
# Tentando recuperar Lattes compactado 8390157225505240 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8390157225505240
# Importação iniciada em 13/03/2022, 17:33:25193.
# 5.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 78,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:39:07
#
#
# Importação iniciada em 13/03/2022, 17:33:25041.
# 5.7% importados.
#
# Linhas por segundo lidas (total): 10.5
# 80,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:40:51
#
#
# Importação iniciada em 13/03/2022, 17:33:25601.
# 5.8% importados.
#
# Linhas por segundo lidas (total): 10.5
# 81,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:37:57
#
#
# Importação iniciada em 13/03/2022, 17:33:25039.
# 5.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 82,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:31:16
# Importação iniciada em 13/03/2022, 17:33:25043.
# 5.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 83,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:35:13
#
#
# Importação iniciada em 13/03/2022, 17:33:25195.
# 5.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 83,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:31:09
#
#
# Tentando recuperar Lattes compactado 8291584506964609 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8291584506964609
# Importação iniciada em 13/03/2022, 17:33:25342.
# 6.0% importados.
#
# Linhas por segundo lidas (total): 10.6
# 84,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:29:02
#
#
# Importação iniciada em 13/03/2022, 17:33:25404.
# 6.1% importados.
#
# Linhas por segundo lidas (total): 10.6
# 86,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:26:41
#
#
# Importação iniciada em 13/03/2022, 17:33:25269.
# 6.1% importados.
#
# Linhas por segundo lidas (total): 10.6
# 86,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:26:26
#
#
# Importação iniciada em 13/03/2022, 17:33:25265.
# 6.2% importados.
#
# Linhas por segundo lidas (total): 10.5
# 87,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:28:53
#
#
# Importação iniciada em 13/03/2022, 17:33:25794.
# 6.2% importados.
#
# Linhas por segundo lidas (total): 10.5
# 88,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:29:45
#
#
# Importação iniciada em 13/03/2022, 17:33:25228.
# 6.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 89,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:23:56
#
#
# Importação iniciada em 13/03/2022, 17:33:25130.
# 6.3% importados.
#
# Linhas por segundo lidas (total): 10.5
# 89,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:26:11
#
#
# Importação iniciada em 13/03/2022, 17:33:25052.
# 6.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 90,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:22:33
#
#
# Importação iniciada em 13/03/2022, 17:33:25391.
# 6.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 91,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:21:41
#
#
# Importação iniciada em 13/03/2022, 17:33:25931.
# 6.5% importados.
#
# Linhas por segundo lidas (total): 10.6
# 92,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:18:03
#
#
# Tentando recuperar Lattes compactado 8741387678323980 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8741387678323980
# Importação iniciada em 13/03/2022, 17:33:25248.
# 6.7% importados.
#
# Linhas por segundo lidas (total): 10.6
# 94,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:15:27
#
#
# Importação iniciada em 13/03/2022, 17:33:25768.
# 6.8% importados.
#
# Linhas por segundo lidas (total): 10.6
# 96,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:13:11
#
#
# Importação iniciada em 13/03/2022, 17:33:25480.
# 6.8% importados.
#
# Linhas por segundo lidas (total): 10.6
# 96,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:10:42
#
#
# Importação iniciada em 13/03/2022, 17:33:25024.
# 6.8% importados.
#
# Linhas por segundo lidas (total): 10.6
# 96,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:10:23
#
#
# Tentando recuperar Lattes compactado 8215204801600346 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8215204801600346
# Importação iniciada em 13/03/2022, 17:33:256853.
# 7.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 101,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:02:18
#
#
# Importação iniciada em 13/03/2022, 17:33:257569.
# 7.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 102,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:02:35
#
#
# Importação iniciada em 13/03/2022, 17:33:252111.
# 7.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 102,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:01:57
#
#
# Importação iniciada em 13/03/2022, 17:33:254987.
# 7.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 102,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 04:01:46
#
#
# Importação iniciada em 13/03/2022, 17:33:257246.
# 7.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 104,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:53:01
#
#
# Importação iniciada em 13/03/2022, 17:33:256508.
# 7.5% importados.
#
# Linhas por segundo lidas (total): 10.6
# 106,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:44:03
#
#
# Importação iniciada em 13/03/2022, 17:33:252740.
# 7.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 107,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:44:44
#
#
# Importação iniciada em 13/03/2022, 17:33:251511.
# 7.7% importados.
#
# Linhas por segundo lidas (total): 10.6
# 108,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:44:33
#
#
# Importação iniciada em 13/03/2022, 17:33:250632.
# 7.8% importados.
#
# Linhas por segundo lidas (total): 10.6
# 110,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:44:43
#
#
# Importação iniciada em 13/03/2022, 17:33:252513.
# 7.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 111,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:47:40
#
#
# Importação iniciada em 13/03/2022, 17:33:250234.
# 7.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 111,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:47:40
#
#
# Tentando recuperar Lattes compactado 8820870574626898 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8820870574626898
# Importação iniciada em 13/03/2022, 17:33:251395.
# 8.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 116,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:33:30
#
#
# Importação iniciada em 13/03/2022, 17:33:254396.
# 8.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 116,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:32:58
#
#
# Importação iniciada em 13/03/2022, 17:33:258020.
# 8.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 117,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:29:22
#
#
# Importação iniciada em 13/03/2022, 17:33:259757.
# 8.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 117,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:27:08
#
#
# Tentando recuperar Lattes compactado 8645017704720076 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Importação iniciada em 13/03/2022, 17:33:256122.
# 8.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 118,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:27:33
#
#
# Importação iniciada em 13/03/2022, 17:33:256120.
# 8.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 118,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:29:04
#
#
# Importação iniciada em 13/03/2022, 17:33:250879.
# 8.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 118,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:28:14
#
#
# Tentando recuperar Lattes compactado 8838734676246479 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8838734676246479
# Importação iniciada em 13/03/2022, 17:33:250547.
# 8.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 121,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:16:41
#
#
# Tentando recuperar Lattes compactado 8460569168023572 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8460569168023572
# Importação iniciada em 13/03/2022, 17:33:258529.
# 8.6% importados.
#
# Linhas por segundo lidas (total): 10.7
# 121,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:14:17
#
#
# Importação iniciada em 13/03/2022, 17:33:251952.
# 8.6% importados.
#
# Linhas por segundo lidas (total): 10.7
# 121,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:14:09
#
#
# Tentando recuperar Lattes compactado 8712804571134584 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8712804571134584
# Importação iniciada em 13/03/2022, 17:33:259207.
# 8.7% importados.
#
# Linhas por segundo lidas (total): 10.7
# 122,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:11:49
#
#
# Importação iniciada em 13/03/2022, 17:33:256368.
# 8.7% importados.
#
# Linhas por segundo lidas (total): 10.7
# 123,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:08:44
#
#
# Importação iniciada em 13/03/2022, 17:33:250996.
# 8.8% importados.
#
# Linhas por segundo lidas (total): 10.7
# 123,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:08:27
#
#
# Importação iniciada em 13/03/2022, 17:33:253915.
# 8.8% importados.
#
# Linhas por segundo lidas (total): 10.7
# 124,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:07:01
#
#
# Importação iniciada em 13/03/2022, 17:33:258762.
# 8.9% importados.
#
# Linhas por segundo lidas (total): 10.7
# 125,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:00:44
#
#
# Importação iniciada em 13/03/2022, 17:33:259598.
# 8.9% importados.
#
# Linhas por segundo lidas (total): 10.7
# 126,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:01:56
#
#
# Importação iniciada em 13/03/2022, 17:33:254106.
# 9.0% importados.
#
# Linhas por segundo lidas (total): 10.7
# 126,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:02:30
#
#
# Tentando recuperar Lattes compactado 8014829692557079 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8014829692557079
# Importação iniciada em 13/03/2022, 17:33:253205.
# 9.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 130,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:06:55
#
#
# Importação iniciada em 13/03/2022, 17:33:258299.
# 9.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 130,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:08:11
#
#
# Importação iniciada em 13/03/2022, 17:33:259357.
# 9.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 130,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:09:02
#
#
# Importação iniciada em 13/03/2022, 17:33:256094.
# 9.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 130,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:09:00
#
#
# Importação iniciada em 13/03/2022, 17:33:252327.
# 9.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 131,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:08:31
#
#
# Importação iniciada em 13/03/2022, 17:33:258211.
# 9.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 132,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:07:20
#
#
# Importação iniciada em 13/03/2022, 17:33:254047.
# 9.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 132,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 03:04:41
#
#
# Importação iniciada em 13/03/2022, 17:33:258432.
# 9.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 135,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:55:42
#
#
# Importação iniciada em 13/03/2022, 17:33:257588.
# 9.7% importados.
#
# Linhas por segundo lidas (total): 10.7
# 137,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:49:32
#
#
# Importação iniciada em 13/03/2022, 17:33:253036.
# 9.8% importados.
#
# Linhas por segundo lidas (total): 10.7
# 137,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:48:40
#
#
# Importação iniciada em 13/03/2022, 17:33:254520.
# 9.8% importados.
#
# Linhas por segundo lidas (total): 10.7
# 138,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:47:22
#
#
# Importação iniciada em 13/03/2022, 17:33:259025.
# 9.9% importados.
#
# Linhas por segundo lidas (total): 10.7
# 140,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:37:55
#
#
# Importação iniciada em 13/03/2022, 17:33:258173.
# 10.3% importados.
#
# Linhas por segundo lidas (total): 10.7
# 145,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:25:27
#
#
# Tentando recuperar Lattes compactado 8643596314426261 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8643596314426261
# Importação iniciada em 13/03/2022, 17:33:255022.
# 10.5% importados.
#
# Linhas por segundo lidas (total): 10.8
# 148,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:13:06
#
#
# Importação iniciada em 13/03/2022, 17:33:250144.
# 10.7% importados.
#
# Linhas por segundo lidas (total): 10.8
# 151,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:09:09
#
#
# Importação iniciada em 13/03/2022, 17:33:253672.
# 10.8% importados.
#
# Linhas por segundo lidas (total): 10.8
# 152,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 02:07:33
#
#
# Importação iniciada em 13/03/2022, 17:33:259712.
# 11.0% importados.
#
# Linhas por segundo lidas (total): 10.8
# 155,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:56:44
#
#
# Importação iniciada em 13/03/2022, 17:33:257064.
# 11.0% importados.
#
# Linhas por segundo lidas (total): 10.8
# 155,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:55:39
#
#
# Importação iniciada em 13/03/2022, 17:33:256402.
# 11.0% importados.
#
# Linhas por segundo lidas (total): 10.8
# 156,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:55:00
#
#
# Importação iniciada em 13/03/2022, 17:33:250224.
# 11.3% importados.
#
# Linhas por segundo lidas (total): 10.8
# 160,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:46:15
#
#
# Importação iniciada em 13/03/2022, 17:33:250879.
# 11.5% importados.
#
# Linhas por segundo lidas (total): 10.8
# 162,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:42:57
#
#
# Importação iniciada em 13/03/2022, 17:33:252899.
# 11.5% importados.
#
# Linhas por segundo lidas (total): 10.8
# 162,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:43:24
#
#
# Tentando recuperar Lattes compactado 8461850883210811 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8461850883210811
# Importação iniciada em 13/03/2022, 17:33:252473.
# 11.6% importados.
#
# Linhas por segundo lidas (total): 10.8
# 164,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:39:40
#
#
# Importação iniciada em 13/03/2022, 17:33:254902.
# 11.7% importados.
#
# Linhas por segundo lidas (total): 10.8
# 164,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:39:29
#
#
# Importação iniciada em 13/03/2022, 17:33:251557.
# 11.7% importados.
#
# Linhas por segundo lidas (total): 10.8
# 165,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:38:33
#
#
# Tentando recuperar Lattes compactado 8590444977829778 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8590444977829778
# Importação iniciada em 13/03/2022, 17:33:254618.
# 11.7% importados.
#
# Linhas por segundo lidas (total): 10.8
# 165,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:39:09
#
#
# Importação iniciada em 13/03/2022, 17:33:257929.
# 11.8% importados.
#
# Linhas por segundo lidas (total): 10.8
# 166,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:37:46
#
#
# Importação iniciada em 13/03/2022, 17:33:256588.
# 11.8% importados.
#
# Linhas por segundo lidas (total): 10.8
# 167,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:35:07
# Importação iniciada em 13/03/2022, 17:33:258511.
# 11.9% importados.
#
# Linhas por segundo lidas (total): 10.8
# 168,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:32:53
#
#
# Importação iniciada em 13/03/2022, 17:33:259923.
# 12.0% importados.
#
# Linhas por segundo lidas (total): 10.8
# 169,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:31:04
#
#
# Importação iniciada em 13/03/2022, 17:33:255309.
# 12.0% importados.
#
# Linhas por segundo lidas (total): 10.8
# 169,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:30:05
#
#
# Importação iniciada em 13/03/2022, 17:33:259040.
# 12.1% importados.
#
# Linhas por segundo lidas (total): 10.8
# 170,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:28:35
#
#
# Tentando recuperar Lattes compactado 8897512753401200 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Importação iniciada em 13/03/2022, 17:33:258486.
# 12.2% importados.
#
# Linhas por segundo lidas (total): 10.8
# 172,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:23:41
#
#
# Importação iniciada em 13/03/2022, 17:33:256703.
# 12.2% importados.
#
# Linhas por segundo lidas (total): 10.8
# 173,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:22:07
#
#
# Importação iniciada em 13/03/2022, 17:33:257298.
# 12.3% importados.
#
# Linhas por segundo lidas (total): 10.8
# 174,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:18:36
#
#
# Tentando recuperar Lattes compactado 8924441660536015 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8924441660536015
# Importação iniciada em 13/03/2022, 17:33:257371.
# 12.4% importados.
#
# Linhas por segundo lidas (total): 10.8
# 175,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:15:45
#
#
# Importação iniciada em 13/03/2022, 17:33:254244.
# 12.5% importados.
#
# Linhas por segundo lidas (total): 10.9
# 176,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:11:49
#
#
# Tentando recuperar Lattes compactado 8955628641518677 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8955628641518677
# Importação iniciada em 13/03/2022, 17:33:251530.
# 12.5% importados.
#
# Linhas por segundo lidas (total): 10.9
# 177,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:08:52
#
#
# Tentando recuperar Lattes compactado 8336459817348290 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8336459817348290
# Importação iniciada em 13/03/2022, 17:33:253771.
# 12.6% importados.
#
# Linhas por segundo lidas (total): 10.9
# 177,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:07:49
#
#
# Importação iniciada em 13/03/2022, 17:33:256168.
# 12.6% importados.
#
# Linhas por segundo lidas (total): 10.9
# 178,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:07:07
#
#
# Importação iniciada em 13/03/2022, 17:33:251034.
# 12.7% importados.
#
# Linhas por segundo lidas (total): 10.9
# 179,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:03:45
#
#
# Importação iniciada em 13/03/2022, 17:33:256907.
# 12.7% importados.
#
# Linhas por segundo lidas (total): 10.9
# 179,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:03:42
#
#
# Importação iniciada em 13/03/2022, 17:33:253036.
# 12.7% importados.
#
# Linhas por segundo lidas (total): 10.9
# 180,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 01:02:52
#
#
# Importação iniciada em 13/03/2022, 17:33:250413.
# 13.1% importados.
#
# Linhas por segundo lidas (total): 10.9
# 184,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:54:32
#
#
# Importação iniciada em 13/03/2022, 17:33:250290.
# 13.1% importados.
#
# Linhas por segundo lidas (total): 10.9
# 184,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:54:37
#
#
# Importação iniciada em 13/03/2022, 17:33:258496.
# 13.1% importados.
#
# Linhas por segundo lidas (total): 10.9
# 185,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:54:41
#
#
# Importação iniciada em 13/03/2022, 17:33:250983.
# 13.4% importados.
#
# Linhas por segundo lidas (total): 10.9
# 189,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:47:25
#
#
# Importação iniciada em 13/03/2022, 17:33:252278.
# 13.5% importados.
#
# Linhas por segundo lidas (total): 10.9
# 190,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:43:01
#
#
# Importação iniciada em 13/03/2022, 17:33:257928.
# 13.5% importados.
#
# Linhas por segundo lidas (total): 10.9
# 191,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:41:57
#
#
# Tentando recuperar Lattes compactado 8580723124292270 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8580723124292270
# Importação iniciada em 13/03/2022, 17:33:258935.
# 13.6% importados.
#
# Linhas por segundo lidas (total): 10.9
# 192,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:39:36
#
#
# Importação iniciada em 13/03/2022, 17:33:257534.
# 13.7% importados.
#
# Linhas por segundo lidas (total): 10.9
# 193,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:37:11
#
#
# Importação iniciada em 13/03/2022, 17:33:254407.
# 13.7% importados.
#
# Linhas por segundo lidas (total): 10.9
# 193,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:36:54
#
#
# Importação iniciada em 13/03/2022, 17:33:255252.
# 13.9% importados.
#
# Linhas por segundo lidas (total): 10.9
# 196,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:28:59
#
#
# Importação iniciada em 13/03/2022, 17:33:252906.
# 13.9% importados.
#
# Linhas por segundo lidas (total): 10.9
# 197,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:27:56
#
#
# Tentando recuperar Lattes compactado 8644289079123894 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8644289079123894
# Importação iniciada em 13/03/2022, 17:33:252846.
# 14.0% importados.
#
# Linhas por segundo lidas (total): 10.9
# 197,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:27:11
#
#
# Importação iniciada em 13/03/2022, 17:33:251680.
# 14.0% importados.
#
# Linhas por segundo lidas (total): 10.9
# 197,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:27:03
#
#
# Importação iniciada em 13/03/2022, 17:33:250467.
# 14.0% importados.
#
# Linhas por segundo lidas (total): 10.9
# 198,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:26:24
#
#
# Importação iniciada em 13/03/2022, 17:33:254159.
# 14.1% importados.
#
# Linhas por segundo lidas (total): 10.9
# 199,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:24:20
#
#
# Importação iniciada em 13/03/2022, 17:33:256923.
# 14.2% importados.
#
# Linhas por segundo lidas (total): 10.9
# 201,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:20:44
#
#
# Importação iniciada em 13/03/2022, 17:33:250484.
# 14.3% importados.
#
# Linhas por segundo lidas (total): 10.9
# 201,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:19:56
#
#
# Importação iniciada em 13/03/2022, 17:33:256564.
# 14.4% importados.
#
# Linhas por segundo lidas (total): 11.0
# 203,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:15:46
#
#
# Tentando recuperar Lattes compactado 8775138839310700 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 8775138839310700
# Importação iniciada em 13/03/2022, 17:33:254879.
# 14.6% importados.
#
# Linhas por segundo lidas (total): 10.9
# 206,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:12:18
#
#
# Importação iniciada em 13/03/2022, 17:33:251095.
# 14.6% importados.
#
# Linhas por segundo lidas (total): 11.0
# 207,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:09:59
# Importação iniciada em 13/03/2022, 17:33:250979.
# 14.7% importados.
#
# Linhas por segundo lidas (total): 11.0
# 208,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:07:29
#
#
# Importação iniciada em 13/03/2022, 17:33:259027.
# 14.9% importados.
#
# Linhas por segundo lidas (total): 11.0
# 210,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:02:31
#
#
# Importação iniciada em 13/03/2022, 17:33:251543.
# 14.9% importados.
#
# Linhas por segundo lidas (total): 11.0
# 210,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:02:30
#
#
# Importação iniciada em 13/03/2022, 17:33:258926.
# 14.9% importados.
#
# Linhas por segundo lidas (total): 11.0
# 210,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:01:51
#
#
# Importação iniciada em 13/03/2022, 17:33:255238.
# 14.9% importados.
#
# Linhas por segundo lidas (total): 11.0
# 210,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 00:01:12
#
#
# Importação iniciada em 13/03/2022, 17:33:258597.
# 15.1% importados.
#
# Linhas por segundo lidas (total): 11.0
# 213,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 23:54:43
#
#
# Importação iniciada em 13/03/2022, 17:33:250751.
# 15.2% importados.
#
# Linhas por segundo lidas (total): 11.0
# 215,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 23:51:41
#
#
# Importação iniciada em 13/03/2022, 17:33:253288.
# 15.2% importados.
#
# Linhas por segundo lidas (total): 11.0
# 215,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 23:51:58
#
#
# Importação iniciada em 13/03/2022, 17:33:251382.
# 15.4% importados.
#
# Linhas por segundo lidas (total): 11.0
# 217,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 23:46:40
#
#
# Importação iniciada em 13/03/2022, 17:33:259915.
# 15.6% importados.
#
# Linhas por segundo lidas (total): 11.0
# 220,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 23:42:08
#
#
# Importação iniciada em 13/03/2022, 17:33:252569.
# 15.6% importados.
#
# Linhas por segundo lidas (total): 11.0
# 220,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 23:42:25
#
#
# Importação iniciada em 13/03/2022, 17:33:255699.
# 15.7% importados.
#
# Linhas por segundo lidas (total): 11.0
# 221,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 23:41:30
#
#
# Tentando recuperar Lattes compactado 8711224507866869 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8711224507866869
# Importação iniciada em 13/03/2022, 17:33:252184.
# 15.8% importados.
#
# Linhas por segundo lidas (total): 11.0
# 223,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 23:38:17
#
#
# Tentando recuperar Lattes compactado 8489135968933851 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8489135968933851
# Tentando recuperar Lattes compactado 8793316204761326 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8793316204761326
# Tentando recuperar Lattes compactado 8285224345265381 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8285224345265381
# Importação iniciada em 13/03/2022, 17:33:255010.
# 16.3% importados.
#
# Linhas por segundo lidas (total): 11.0
# 230,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 23:30:08
#
#
# Importação iniciada em 13/03/2022, 17:33:259076.
# 16.4% importados.
#
# Linhas por segundo lidas (total): 11.0
# 231,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 23:27:55
#
#
# Tentando recuperar Lattes compactado 8531955572922285 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8531955572922285
# Importação iniciada em 13/03/2022, 17:33:257193.
# 16.4% importados.
#
# Linhas por segundo lidas (total): 11.0
# 231,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 23:27:25
#
#
# Importação iniciada em 13/03/2022, 17:33:254142.
# 16.5% importados.
#
# Linhas por segundo lidas (total): 11.0
# 232,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 23:25:46
#
#
# Importação iniciada em 13/03/2022, 17:33:259193.
# 16.7% importados.
#
# Linhas por segundo lidas (total): 11.0
# 235,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 23:17:50
#
#
# Importação iniciada em 13/03/2022, 17:33:257498.
# 16.7% importados.
#
# Linhas por segundo lidas (total): 11.0
# 236,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 23:17:42
#
#
# Importação iniciada em 13/03/2022, 17:33:257539.
# 16.7% importados.
#
# Linhas por segundo lidas (total): 11.0
# 236,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 23:16:47
#
#
# Importação iniciada em 13/03/2022, 17:33:257015.
# 16.8% importados.
#
# Linhas por segundo lidas (total): 11.0
# 237,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 23:15:57
#
#
# Importação iniciada em 13/03/2022, 17:33:257601.
# 16.8% importados.
#
# Linhas por segundo lidas (total): 11.0
# 237,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 23:14:37
#
#
# Importação iniciada em 13/03/2022, 17:33:251414.
# 16.9% importados.
#
# Linhas por segundo lidas (total): 11.0
# 238,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 23:11:02
#
#
# Importação iniciada em 13/03/2022, 17:33:256500.
# 16.9% importados.
#
# Linhas por segundo lidas (total): 11.0
# 239,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 23:10:27
#
#
# Tentando recuperar Lattes compactado 8424778361299914 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8424778361299914
# Importação iniciada em 13/03/2022, 17:33:257289.
# 17.2% importados.
#
# Linhas por segundo lidas (total): 11.0
# 243,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 23:00:24
#
#
# Importação iniciada em 13/03/2022, 17:33:259781.
# 17.3% importados.
#
# Linhas por segundo lidas (total): 11.0
# 245,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 22:57:41
#
#
# Importação iniciada em 13/03/2022, 17:33:253521.
# 17.4% importados.
#
# Linhas por segundo lidas (total): 11.0
# 246,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 22:56:04
#
#
# Importação iniciada em 13/03/2022, 17:33:256806.
# 17.5% importados.
#
# Linhas por segundo lidas (total): 11.0
# 247,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 22:54:49
#
#
# Importação iniciada em 13/03/2022, 17:33:251141.
# ...
# 66.9% importados.
#
# Linhas por segundo lidas (total): 10.5
# 946,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:55:35
#
#
# Importação iniciada em 13/03/2022, 17:33:254317.
# 67.0% importados.
#
# Linhas por segundo lidas (total): 10.5
# 947,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:53:24
#
#
# Importação iniciada em 13/03/2022, 17:33:250400.
# 67.0% importados.
#
# Linhas por segundo lidas (total): 10.5
# 947,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:53:07
#
#
# Importação iniciada em 13/03/2022, 17:33:258787.
# 67.1% importados.
#
# Linhas por segundo lidas (total): 10.5
# 948,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:51:39
#
#
# Importação iniciada em 13/03/2022, 17:33:259475.
# 67.1% importados.
#
# Linhas por segundo lidas (total): 10.5
# 948,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:51:23
#
#
# Importação iniciada em 13/03/2022, 17:33:256478.
# 67.1% importados.
#
# Linhas por segundo lidas (total): 10.5
# 949,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:51:03
#
#
# Importação iniciada em 13/03/2022, 17:33:255689.
# 67.2% importados.
#
# Linhas por segundo lidas (total): 10.5
# 950,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:48:53
#
#
# Importação iniciada em 13/03/2022, 17:33:252679.
# 67.4% importados.
#
# Linhas por segundo lidas (total): 10.5
# 952,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:44:45
#
#
# Importação iniciada em 13/03/2022, 17:33:251770.
# 67.6% importados.
#
# Linhas por segundo lidas (total): 10.5
# 955,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:39:34
#
#
# Importação iniciada em 13/03/2022, 17:33:253533.
# 67.6% importados.
#
# Linhas por segundo lidas (total): 10.5
# 956,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:39:14
#
#
# Importação iniciada em 13/03/2022, 17:33:254928.
# 67.7% importados.
#
# Linhas por segundo lidas (total): 10.5
# 957,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:37:36
#
#
# Importação iniciada em 13/03/2022, 17:33:250427.
# 67.8% importados.
#
# Linhas por segundo lidas (total): 10.5
# 958,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:35:13
#
#
# Importação iniciada em 13/03/2022, 17:33:256507.
# 67.9% importados.
#
# Linhas por segundo lidas (total): 10.5
# 959,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:33:36
#
#
# Importação iniciada em 13/03/2022, 17:33:257834.
# 68.0% importados.
#
# Linhas por segundo lidas (total): 10.5
# 961,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:31:18
#
#
# Importação iniciada em 13/03/2022, 17:33:255733.
# 68.0% importados.
#
# Linhas por segundo lidas (total): 10.5
# 961,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:30:29
#
#
# Importação iniciada em 13/03/2022, 17:33:254906.
# 68.1% importados.
#
# Linhas por segundo lidas (total): 10.5
# 962,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:29:12
#
#
# Importação iniciada em 13/03/2022, 17:33:259486.
# 68.1% importados.
#
# Linhas por segundo lidas (total): 10.5
# 963,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:28:14
#
#
# Tentando recuperar Lattes compactado 8682557545426924 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8682557545426924
# Importação iniciada em 13/03/2022, 17:33:253035.
# 68.2% importados.
#
# Linhas por segundo lidas (total): 10.5
# 963,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:27:08
#
#
# Importação iniciada em 13/03/2022, 17:33:254674.
# 68.2% importados.
#
# Linhas por segundo lidas (total): 10.5
# 964,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:25:22
#
#
# Importação iniciada em 13/03/2022, 17:33:250992.
# 68.3% importados.
#
# Linhas por segundo lidas (total): 10.5
# 965,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:24:31
#
#
# Tentando recuperar Lattes compactado 8014360189240093 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8014360189240093
# Importação iniciada em 13/03/2022, 17:33:255940.
# 68.4% importados.
#
# Linhas por segundo lidas (total): 10.5
# 967,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:21:31
#
#
# Importação iniciada em 13/03/2022, 17:33:251027.
# 68.5% importados.
#
# Linhas por segundo lidas (total): 10.5
# 969,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:18:25
#
#
# Importação iniciada em 13/03/2022, 17:33:257339.
# 68.6% importados.
#
# Linhas por segundo lidas (total): 10.5
# 969,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:17:57
#
#
# Importação iniciada em 13/03/2022, 17:33:259460.
# 68.6% importados.
#
# Linhas por segundo lidas (total): 10.5
# 970,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:16:22
#
#
# Tentando recuperar Lattes compactado 8353392132418880 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8353392132418880
# Importação iniciada em 13/03/2022, 17:33:252557.
# 68.7% importados.
#
# Linhas por segundo lidas (total): 10.5
# 971,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:13:56
#
#
# Importação iniciada em 13/03/2022, 17:33:256126.
# 68.8% importados.
#
# Linhas por segundo lidas (total): 10.5
# 972,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:13:05
#
#
# Importação iniciada em 13/03/2022, 17:33:257793.
# 68.9% importados.
#
# Linhas por segundo lidas (total): 10.5
# 974,600 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:09:15
#
#
# Importação iniciada em 13/03/2022, 17:33:252287.
# 68.9% importados.
#
# Linhas por segundo lidas (total): 10.5
# 974,700 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:09:05
#
#
# Importação iniciada em 13/03/2022, 17:33:258227.
# 69.0% importados.
#
# Linhas por segundo lidas (total): 10.5
# 974,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:08:48
#
#
# Importação iniciada em 13/03/2022, 17:33:259935.
# 69.0% importados.
#
# Linhas por segundo lidas (total): 10.5
# 975,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:08:39
#
#
# Importação iniciada em 13/03/2022, 17:33:253007.
# 69.0% importados.
#
# Linhas por segundo lidas (total): 10.5
# 975,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:08:29
#
#
# Importação iniciada em 13/03/2022, 17:33:255841.
# 69.0% importados.
#
# Linhas por segundo lidas (total): 10.5
# 975,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 05:08:07
#
#
# Importação iniciada em 13/03/2022, 17:33:250333.
# 69.4% importados.
#
# Linhas por segundo lidas (total): 10.5
# 980,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:59:22
#
#
# Importação iniciada em 13/03/2022, 17:33:250362.
# 69.4% importados.
#
# Linhas por segundo lidas (total): 10.5
# 981,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:57:51
# Tentando recuperar Lattes compactado 8201377112288118 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8201377112288118
# Importação iniciada em 13/03/2022, 17:33:253493.
# 69.6% importados.
#
# Linhas por segundo lidas (total): 10.5
# 984,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:53:13
#
#
# Tentando recuperar Lattes compactado 8989725523845931 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8989725523845931
# Importação iniciada em 13/03/2022, 17:33:252023.
# 69.8% importados.
#
# Linhas por segundo lidas (total): 10.5
# 986,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:49:22
#
#
# Tentando recuperar Lattes compactado 8009907712220238 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8009907712220238
# Importação iniciada em 13/03/2022, 17:33:251894.
# 69.9% importados.
#
# Linhas por segundo lidas (total): 10.5
# 988,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:47:22
#
#
# Importação iniciada em 13/03/2022, 17:33:252969.
# 70.0% importados.
#
# Linhas por segundo lidas (total): 10.5
# 989,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:45:25
#
#
# Importação iniciada em 13/03/2022, 17:33:252117.
# 70.1% importados.
#
# Linhas por segundo lidas (total): 10.5
# 990,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:43:31
#
#
# Importação iniciada em 13/03/2022, 17:33:258021.
# 70.1% importados.
#
# Linhas por segundo lidas (total): 10.5
# 991,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:42:20
#
#
# Importação iniciada em 13/03/2022, 17:33:250192.
# 70.2% importados.
#
# Linhas por segundo lidas (total): 10.5
# 991,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:40:53
#
#
# Importação iniciada em 13/03/2022, 17:33:257535.
# 70.3% importados.
#
# Linhas por segundo lidas (total): 10.5
# 993,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:38:35
#
#
# Importação iniciada em 13/03/2022, 17:33:258457.
# 70.5% importados.
#
# Linhas por segundo lidas (total): 10.5
# 996,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:33:44
#
#
# Importação iniciada em 13/03/2022, 17:33:250643.
# 70.5% importados.
#
# Linhas por segundo lidas (total): 10.5
# 996,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:33:24
#
#
# Importação iniciada em 13/03/2022, 17:33:253101.
# 70.7% importados.
#
# Linhas por segundo lidas (total): 10.5
# 998,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:29:26
#
#
# Importação iniciada em 13/03/2022, 17:33:2513164.
# 70.8% importados.
#
# Linhas por segundo lidas (total): 10.5
# 1,000,500 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:26:46
#
#
# Importação iniciada em 13/03/2022, 17:33:2526666.
# 71.2% importados.
#
# Linhas por segundo lidas (total): 10.5
# 1,006,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:17:14
#
#
# Importação iniciada em 13/03/2022, 17:33:2554814.
# 71.3% importados.
#
# Linhas por segundo lidas (total): 10.5
# 1,008,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:14:07
#
#
# Importação iniciada em 13/03/2022, 17:33:2554551.
# 71.3% importados.
#
# Linhas por segundo lidas (total): 10.5
# 1,008,400 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:13:57
#
#
# Importação iniciada em 13/03/2022, 17:33:2552108.
# 71.5% importados.
#
# Linhas por segundo lidas (total): 10.5
# 1,010,900 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:09:48
#
#
# Importação iniciada em 13/03/2022, 17:33:2582123.
# 71.6% importados.
#
# Linhas por segundo lidas (total): 10.5
# 1,011,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:08:27
#
#
# Tentando recuperar Lattes compactado 8051483991560928 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 8051483991560928
# Importação iniciada em 13/03/2022, 17:33:2585471.
# 71.7% importados.
#
# Linhas por segundo lidas (total): 10.5
# 1,013,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:06:07
#
#
# Importação iniciada em 13/03/2022, 17:33:2583323.
# 71.7% importados.
#
# Linhas por segundo lidas (total): 10.5
# 1,014,000 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:04:50
#
#
# Importação iniciada em 13/03/2022, 17:33:2569232.
# 71.7% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,014,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:04:18
#
#
# Importação iniciada em 13/03/2022, 17:33:2539697.
# 71.8% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,015,300 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:02:37
#
#
# Importação iniciada em 13/03/2022, 17:33:2553305.
# 71.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,016,200 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:01:16
#
#
# Importação iniciada em 13/03/2022, 17:33:2541952.
# 71.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,016,800 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 04:00:15
#
#
# Importação iniciada em 13/03/2022, 17:33:2516140.
# 71.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 1,017,100 de 1,413,665
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 03:59:48
#
#
# 1017644 / 1413665. Importing id 8094645998259457.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13672/384463816.py in <module>
#       1 from Carga import Carga
#       2 cg = Carga()
# ----> 3 cg.atualiza_todos_os_indicadores (on_conflic_update = True,
#       4                                   pula_bd_indicadores = True,
#       5                                   pula_erros = False,
#
# ~\CNPq\Lattes\Python\Carga.py in atualiza_todos_os_indicadores(self, path, log_file, max, de_hd, de_bd_lattes, de_all_lattes, de_bd_demanda_bruta, de_carga_dados_pessoais, pula_bd_indicadores, pula_erros, data_mínima_atualização_lattes, show_import_messages, num_imports_skip_before_log, começando_com, on_conflic_update, nível_mínimo)
#    1015             #         t.join()
#    1016             #     list_threads = []
# -> 1017             atualiza_indicador (id, on_conflic_update = on_conflic_update)
#    1018             if num%num_imports_skip_before_log == 0:
#    1019                 segundos_por_linha = (datetime.now() - tempo_inicio)/num_imports_skip_before_log
#
# ~\CNPq\Lattes\Python\Carga.py in atualiza_indicador(id, on_conflic_update)
#     995         def atualiza_indicador (id, on_conflic_update = False):
#     996             ind = Indicadores (id = id)
# --> 997             ind.atualiza(on_conflic_update=on_conflic_update)
#     998             del ind
#     999
#
# ~\CNPq\Lattes\Python\Indicadores.py in wrap(*args, **kw)
#      58         def wrap(*args, **kw):
#      59             if args[0].show_execution_time: ts = datetime.now()
# ---> 60             result = f(*args, **kw)
#      61             if args[0].show_execution_time:
#      62                 te = datetime.now()
#
# ~\CNPq\Lattes\Python\Indicadores.py in atualiza(self, indicadores, palavras_chave, areas_conhecimento, publicações, dados_pessoais, on_conflic_update)
#     444                 print ('ERRRO - Não foi possível carregar Áreas do Conhecimento. ID:', self.id)
#     445             else:
# --> 446                 self.salva_areas_do_conhecimento_no_bd(on_conflic_update = on_conflic_update)
#     447         if publicações:
#     448             if not self.get_publicações():
#
# ~\CNPq\Lattes\Python\Indicadores.py in wrap(*args, **kw)
#      58         def wrap(*args, **kw):
#      59             if args[0].show_execution_time: ts = datetime.now()
# ---> 60             result = f(*args, **kw)
#      61             if args[0].show_execution_time:
#      62                 te = datetime.now()
#
# ~\CNPq\Lattes\Python\Indicadores.py in salva_areas_do_conhecimento_no_bd(self, on_conflic_update)
#     300         insert into public."areas_conhecimento" (id, tipo, area) VALUES \n''' + args_str + '''
#     301         ON CONFLICT (id, tipo, area) DO NOTHING'''
# --> 302         sql = self.db.cursor.mogrify(sql)
#     303         if self.show_sql: print (sql)
#     304         self.db.execute(sql)
#
# ValueError: unsupported format character '2' (0x32) at index 194
