# %%
from Carga import Carga
cg = Carga()


#Origens
cg.de_hd = False
cg.de_all_lattes = True
cg.de_bd_demanda_bruta = False
cg.de_dados_pessoais = False

#Exceções
cg.pular_indicadores = False
cg.pular_palavras_chave = False
cg.pular_areas_conhecimento = False
cg.pular_publicações = True
cg.pular_dados_gerais=False
cg.pular_vinculos = False
cg.pular_erros = False
cg.pular_jsons = False

#Importações
cg.on_conflic_update = True
cg.importar_indicadores = True
cg.importar_palavras_chave = True
cg.importar_areas_conhecimento = True
cg.importar_publicações = True
cg.importar_dados_gerais=True
cg.importar_vinculos = True


#Outras Configurações
cg.on_conflic_update = True
cg.auto_save_json_to_bd = True
cg.pegar_lista_de_importação_de_arquivo = False
cg.data_mínima_atualização_lattes = None

cg.atualiza_todos_os_indicadores(começando_com = '3')
# Out:
# Carregando lista de indicadores para importar da tabela all_lattes do BD
#
# Carregando lista de Ids da tabela publicacoes para pular
#
# Retirando ids a exluir...
# Salvando o arquivo com a lista no disco.
# Iniciando Importação.
# Tentando recuperar Lattes compactado 3433151642473051 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3285684825586583 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3366761905562980 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3122142042722655 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3798641332300360 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3296667412166609 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3216423610477152 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3171955013575626 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3939371254528164 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3847331886480674 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3162249216076298 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3134937229757835 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3130314697790771 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3747447139065121 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3102097953459755 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3032177384706214 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3690340412241607 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3603227776906356 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3405363139871920 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3435012360754120 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3063186285987837 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3654526178084803 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3785242335223975 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3856454620411890 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3280410020360001 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3952418344336108 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3455966968286580 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3547385846434217 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3591748052976895 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3334994775997038 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3318528800458847 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3605160500737261 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3126381458330726 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3490516650668397 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3320446339770542 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3283718323377052 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3636110481491393 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3630387600876218 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3518021807570331 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3663030109085411 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3973109938450913 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3265009465160966 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3938473792782945 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3785015586324032 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3553895589471918 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3932485449439016 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3497926247026531 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3411312349043697 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3132028537381552 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3564084992918509 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3571613237218496 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3677062860756487 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3014974466760423 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3616400467101122 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3864734630678629 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3124584078227076 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3106235144958908 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3001571399256137 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3157340490407940 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3005430321865112 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3352614430528570 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3905344655949619 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3981656315584192 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3373498142629250 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3228684561197260 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3438287772601776 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3817022839640939 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3408318234246613 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3958985745011537 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3651157008968241 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3837075529901340 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3040872932589484 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3616508432498540 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3400151844008114 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3963672332930785 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3860990179675442 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3298223566172620 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3861602613346670 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3914310426823172 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3844613453570517 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3977064587310758 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3099540036616226 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3172069590223579 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3113944137887735 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3598434622551847 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3257400519586717 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3050333385741807 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3333128543767153 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3038306688413595 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3424915980272828 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3736880376096505 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3770064245161172 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3049467232561264 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3760472636868822 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3830194947451293 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3296710853969169 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3650313089191577 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3315614636843735 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 3315614636843735
# Tentando recuperar Lattes compactado 3014455019621229 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3088283916646039 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3507108402411673 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3220667484477341 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3586393906351342 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3206175501653284 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3430093143250973 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3396671810110248 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3232763649440856 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3520423980217860 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3640933143920016 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3174091970415098 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3048413552269640 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3119607617885532 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3306307963671066 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3036072748140733 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3023981476512575 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3573271229340709 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3121641433218186 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3411889340895537 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3899103016785880 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3471635328354426 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3610506987813159 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3502280745385752 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3694275013863438 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3274094150583043 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3804636209601763 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3371354927920597 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3885290977317001 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3879999437393713 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3354201079941655 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3940696773806842 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3401291327808523 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3439286540898331 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3183374722686532 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3761528968091632 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3286179619062194 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3665709730621128 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3764492083903255 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3506350682772437 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3985002218184575 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3273567257569216 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3550547627240958 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3148409163441949 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3434147810147878 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 3937511942765682 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# 4615 / 5654187. Importing id 3166701388987797.
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18976/379718440.py in <module>
#      35 cg.data_mínima_atualização_lattes = None
#      36
# ---> 37 cg.atualiza_todos_os_indicadores(começando_com = '3')
#
# ~\CNPq\Lattes\Python\Carga.py in atualiza_todos_os_indicadores(self, num_imports_skip_before_log, começando_com)
#    1063                 print(f'{num} / {linhas_totais}. Importing id {id}.\r', end="", flush=True)
#    1064
# -> 1065                 ind = Indicadores (id = id, auto_save_json_to_bd = self.auto_save_json_to_bd)
#    1066                 ind.on_conflic_update = self.on_conflic_update
#    1067                 ind.atualiza(
#
# ~\CNPq\Lattes\Python\Indicadores.py in __init__(self, id, json, filename, show_execution_time, show_sql, auto_save_json_to_bd, on_conflic_update)
#      26         self.show_sql = show_sql
#      27         self.auto_save_json_to_bd = auto_save_json_to_bd
# ---> 28         self.db = Database('CNPq', show_sql = show_sql)
#      29         self.indicadores = []
#      30         self.list_indicadores = []
#
# ~\CNPq\Lattes\Python\Database.py in __init__(self, name, show_sql)
#      34     def __init__(self, name = 'CNPq', show_sql = False):
#      35         self.params = Database.config_db_connection()
# ---> 36         self.conn = psycopg2.connect(**self.params)
#      37         self.cur = self.conn.cursor()
#      38         self.show_sql = show_sql
#
# ~\Anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     120
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#     124         conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "albertocampos.ddns.net" (200.169.188.152), port 8080 failed: Connection timed out (0x0000274C/10060)
# 	Is the server running on that host and accepting TCP/IP connections?
