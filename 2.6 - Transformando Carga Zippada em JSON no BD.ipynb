# %%
from Lattes import Lattes
# Out:
# import io, os, sys, time
# from zipfile import ZipFile
# import zeep
# import xmltodict, json, csv
# import psycopg2
# from configparser import ConfigParser
# from datetime import datetime
# import pytz
# import socket
# from Indicadores import Indicadores
# import html
# from collections import OrderedDict
# Módulos Importados

# %%
Lattes.grava_arquivo_json(max = 100)
# Out:
# Carregando lista de arquivos zip já baixados.
# Pegando lista de IDs no Banco de Dados
# Lista de IDs pega no Banco de Dados.
# Gerando lista de arquivos a transformar em JSON
# Começando importação.
# Importando id = 0000000403000690
# Arquivo compactado lido no disco.
# Unzipping file and gettinf xml and json
# retira, de cada JSON, caracteres especiais web
# XML & JSON atualizado a partir do Lattes compactado.
# Inserting xml to Postgree
# Banco de dados atualizado.
# Importando id = 0000002580990139
# Arquivo compactado lido no disco.
# Unzipping file and gettinf xml and json
# retira, de cada JSON, caracteres especiais web
# XML & JSON atualizado a partir do Lattes compactado.
# Inserting xml to Postgree
# Banco de dados atualizado.
# Importando id = 0000005794097038
# Arquivo compactado lido no disco.
# Unzipping file and gettinf xml and json
# retira, de cada JSON, caracteres especiais web
# XML & JSON atualizado a partir do Lattes compactado.
# Inserting xml to Postgree
# ...
