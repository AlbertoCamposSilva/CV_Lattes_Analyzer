# %%
from datetime import datetime

print('Início em: ', datetime.now())
print('Importações Iniciais')

from Regressao import Regressao
reg = Regressao()

print('Fim: ', datetime.now())
# Out:
# Início em:  2023-04-26 08:49:48.385977
# Importações Iniciais
# Fim:  2023-04-26 08:49:55.479977

# %%
reg.path = ''
reg.variável_dependente = 'qty_2019'
reg.variáveis_independentes = ['qty_2014', 'porcent_pagos']
reg.confianças = [0.05]
#reg.indicador = 'Artigo Publicado'
reg.ano_início = 2014
reg.best_r2 = False
reg.pareamento = False
reg.capes = False
reg.cnpq = True
reg.nenhum = True
reg.ambos = False
reg.preenche_todos_ids = False
reg.verbose = False
#reg.faz_apenas_os_indicadores = ['Conclusão de Curso de Curta Duração']

# %%
Regressao.pd = reg.pega_tabela_para_regressão()
# Out:
# Carregando indicadores na memória. Início em:  2023-04-26 08:49:55.524975
# Fim em:  2023-04-26 08:50:46.296368

# %%
reg.faz_regressões()
# Out:
# Iniciado em 2023-04-26 08:50:46.335239.
# 0/130. Fazendo: Conclusão de Doutorado.
# 1/130. 0.8% feitos. Fazendo: Conclusão de Curso de Curta Duração. Acabará em 26/04/23 08:52:22. O Último demorou: 0:00:00.436529.
# 2/130. 1.5% feitos. Fazendo: Conclusão de Graduação. Acabará em 26/04/23 08:51:54. O Último demorou: 0:00:00.305721.
# 3/130. 2.3% feitos. Fazendo: Conclusão de Mestrado. Acabará em 26/04/23 08:51:47. O Último demorou: 0:00:00.352446.
# 4/130. 3.1% feitos. Fazendo: Início de Doutorado. Acabará em 26/04/23 08:51:40. O Último demorou: 0:00:00.272004.
# 5/130. 3.8% feitos. Fazendo: Início de Curso de Curta Duração. Acabará em 26/04/23 08:51:38. O Último demorou: 0:00:00.314633.
# 6/130. 4.6% feitos. Fazendo: Início de Graduação. Acabará em 26/04/23 08:51:39. O Último demorou: 0:00:00.475893.
# 7/130. 5.4% feitos. Fazendo: Início de Mestrado. Acabará em 26/04/23 08:51:39. O Último demorou: 0:00:00.398798.
# 8/130. 6.2% feitos. Fazendo: Início de Pós-Doutorado. Acabará em 26/04/23 08:51:38. O Último demorou: 0:00:00.345320.
# 9/130. 6.9% feitos. Fazendo: Obtenção do Título de Doutorado. Acabará em 26/04/23 08:51:38. O Último demorou: 0:00:00.358499.
# 10/130. 7.7% feitos. Fazendo: Obtenção do Título de Metrado. Acabará em 26/04/23 08:51:36. O Último demorou: 0:00:00.264688.
# 11/130. 8.5% feitos. Fazendo: Trabalho em Evento. Acabará em 26/04/23 08:51:35. O Último demorou: 0:00:00.315927.
# 12/130. 9.2% feitos. Fazendo: Artigo Publicado. Acabará em 26/04/23 08:51:36. O Último demorou: 0:00:00.425279.
# 13/130. 10.0% feitos. Fazendo: Trabalho em Eventos. Acabará em 26/04/23 08:51:36. O Último demorou: 0:00:00.405262.
# 14/130. 10.8% feitos. Fazendo: Fim de Estágio. Acabará em 26/04/23 08:51:37. O Último demorou: 0:00:00.487125.
# 15/130. 11.5% feitos. Fazendo: Fim de Atividade de Pesquisa e Desenvolvimento. Acabará em 26/04/23 08:51:36. O Último demorou: 0:00:00.288111.
# 16/130. 12.3% feitos. Fazendo: Fim de Vínculo Empregatício ou Funcional. Acabará em 26/04/23 08:51:35. O Último demorou: 0:00:00.325927.
# 17/130. 13.1% feitos. Fazendo: Início de Atividade de Ensino. Acabará em 26/04/23 08:51:35. O Último demorou: 0:00:00.397000.
# 18/130. 13.8% feitos. Fazendo: Início de Estágio. Acabará em 26/04/23 08:51:36. O Último demorou: 0:00:00.388999.
# 19/130. 14.6% feitos. Fazendo: Início de Atividade de Pesquisa e Desenvolvimento. Acabará em 26/04/23 08:51:35. O Último demorou: 0:00:00.282002.
# 20/130. 15.4% feitos. Fazendo: Início de Vínculo Empregatício ou Funcional. Acabará em 26/04/23 08:51:35. O Último demorou: 0:00:00.457047.
# 21/130. 16.2% feitos. Fazendo: Apresentação de Trabalho Técnico. Acabará em 26/04/23 08:51:34. O Último demorou: 0:00:00.234999.
# 22/130. 16.9% feitos. Fazendo: Publicação de Capítulo de Livro. Acabará em 26/04/23 08:51:35. O Último demorou: 0:00:00.546000.
# 23/130. 17.7% feitos. Fazendo: Livro Publicado ou Organizado. Acabará em 26/04/23 08:51:35. O Último demorou: 0:00:00.334001.
# 24/130. 18.5% feitos. Fazendo: Outras Orientações Concluídas. Acabará em 26/04/23 08:51:35. O Último demorou: 0:00:00.277000.
# 25/130. 19.2% feitos. Fazendo: Participação em Congresso. Acabará em 26/04/23 08:51:34. O Último demorou: 0:00:00.236004.
# 26/130. 20.0% feitos. Fazendo: Participação em Seminário. Acabará em 26/04/23 08:51:34. O Último demorou: 0:00:00.362999.
# 27/130. 20.8% feitos. Fazendo: Participação em Simpósio. Acabará em 26/04/23 08:51:34. O Último demorou: 0:00:00.441754.
# 28/130. 21.5% feitos. Fazendo: Prêmio ou Título Recebido. Acabará em 26/04/23 08:51:34. O Último demorou: 0:00:00.369974.
# 29/130. 22.3% feitos. Fazendo: Conclusão de Outra Formação Complementar. Acabará em 26/04/23 08:51:35. O Último demorou: 0:00:00.488689.
# 30/130. 23.1% feitos. Fazendo: Início de Outra Formação Complementar. Acabará em 26/04/23 08:51:35. O Último demorou: 0:00:00.416916.
# 31/130. 23.8% feitos. Fazendo: Organização de Evento. Acabará em 26/04/23 08:51:35. O Último demorou: 0:00:00.383812.
# 32/130. 24.6% feitos. Fazendo: Outras Participações em Congressos. Acabará em 26/04/23 08:51:36. O Último demorou: 0:00:00.499814.
# 33/130. 25.4% feitos. Fazendo: Participação em Banca de Graduação. Acabará em 26/04/23 08:51:36. O Último demorou: 0:00:00.445160.
# 34/130. 26.2% feitos. Fazendo: Conclusão de Especialização. Acabará em 26/04/23 08:51:36. O Último demorou: 0:00:00.375728.
# 35/130. 26.9% feitos. Fazendo: Conclusão de Extensão Universitária. Acabará em 26/04/23 08:51:36. O Último demorou: 0:00:00.403927.
# 36/130. 27.7% feitos. Fazendo: Início de Especialização. Acabará em 26/04/23 08:51:37. O Último demorou: 0:00:00.719140.
# 37/130. 28.5% feitos. Fazendo: Início de Extensão Universitária. Acabará em 26/04/23 08:51:37. O Último demorou: 0:00:00.370181.
# 38/130. 29.2% feitos. Fazendo: Fim de Atividade de Ensino. Acabará em 26/04/23 08:51:37. O Último demorou: 0:00:00.411838.
# 39/130. 30.0% feitos. Fazendo: Fim de Participação em Projeto. Acabará em 26/04/23 08:51:37. O Último demorou: 0:00:00.399682.
# 40/130. 30.8% feitos. Fazendo: Fim de Projeto de Pesquisa. Acabará em 26/04/23 08:51:37. O Último demorou: 0:00:00.424108.
# 41/130. 31.5% feitos. Fazendo: Início de Participação em Projeto. Acabará em 26/04/23 08:51:37. O Último demorou: 0:00:00.486230.
# 42/130. 32.3% feitos. Fazendo: Início de Projeto de Pesquisa. Acabará em 26/04/23 08:51:38. O Último demorou: 0:00:00.621852.
# 43/130. 33.1% feitos. Fazendo: Ministério de Curso de Curta Duração. Acabará em 26/04/23 08:51:39. O Último demorou: 0:00:00.555997.
# 44/130. 33.8% feitos. Fazendo: Desenvolvimento de Material Didático ou Instrucional. Acabará em 26/04/23 08:51:38. O Último demorou: 0:00:00.320003.
# 45/130. 34.6% feitos. Fazendo: Outra produção Técnica. Acabará em 26/04/23 08:51:38. O Último demorou: 0:00:00.302115.
# 46/130. 35.4% feitos. Fazendo: Outras Participações de Bancas Julgadoras. Acabará em 26/04/23 08:51:38. O Último demorou: 0:00:00.399883.
# 47/130. 36.2% feitos. Fazendo: Participação em Encontro. Acabará em 26/04/23 08:51:38. O Último demorou: 0:00:00.369001.
# 48/130. 36.9% feitos. Fazendo: Participação em Exposição. Acabará em 26/04/23 08:51:38. O Último demorou: 0:00:00.293999.
# 49/130. 37.7% feitos. Fazendo: Publicação de Prefácio ou Posfácio. Acabará em 26/04/23 08:51:38. O Último demorou: 0:00:00.341999.
# 50/130. 38.5% feitos. Fazendo: Programa de Rádio ou TV. Acabará em 26/04/23 08:51:37. O Último demorou: 0:00:00.234999.
# 51/130. 39.2% feitos. Fazendo: Conclusão de MBA. Acabará em 26/04/23 08:51:37. O Último demorou: 0:00:00.368001.
# 52/130. 40.0% feitos. Fazendo: Início de MBA. Acabará em 26/04/23 08:51:37. O Último demorou: 0:00:00.322000.
# 53/130. 40.8% feitos. Fazendo: Fim de Atividade de Serviço Técnico-Especializado. Acabará em 26/04/23 08:51:37. O Último demorou: 0:00:00.322999.
# 54/130. 41.5% feitos. Fazendo: Início de Atividade de Serviço Técnico-Especializado. Acabará em 26/04/23 08:51:37. O Último demorou: 0:00:00.409000.
# 55/130. 42.3% feitos. Fazendo: Orientação em Andamento de Mestrado. Acabará em 26/04/23 08:51:37. O Último demorou: 0:00:00.367423.
# 56/130. 43.1% feitos. Fazendo: Orientação Concluída de Mestrado. Acabará em 26/04/23 08:51:37. O Último demorou: 0:00:00.320511.
# 57/130. 43.8% feitos. Fazendo: Participação em Banca de Exame de Qualificação. Acabará em 26/04/23 08:51:36. O Último demorou: 0:00:00.274585.
# 58/130. 44.6% feitos. Fazendo: Participação em Oficina. Acabará em 26/04/23 08:51:36. O Último demorou: 0:00:00.357481.
# 59/130. 45.4% feitos. Fazendo: Produção de Trabalho Técnico. Acabará em 26/04/23 08:51:36. O Último demorou: 0:00:00.448356.
# 60/130. 46.2% feitos. Fazendo: Mídia Social, websiteou Blog. Acabará em 26/04/23 08:51:36. O Último demorou: 0:00:00.350935.
# 61/130. 46.9% feitos. Fazendo: Participação em Banca de Aperfeiçoamento ou Especialização. Acabará em 26/04/23 08:51:36. O Último demorou: 0:00:00.371443.
# 62/130. 47.7% feitos. Fazendo: Participação em Banca de Mestrado. Acabará em 26/04/23 08:51:36. O Último demorou: 0:00:00.384401.
# 63/130. 48.5% feitos. Fazendo: Conclusão de Ensino Médio. Acabará em 26/04/23 08:51:36. O Último demorou: 0:00:00.218985.
# 64/130. 49.2% feitos. Fazendo: Início de Ensino Médio. Acabará em 26/04/23 08:51:36. O Último demorou: 0:00:00.280143.
# 65/130. 50.0% feitos. Fazendo: Artigo Aceito para Publicação. Acabará em 26/04/23 08:51:35. O Último demorou: 0:00:00.286712.
# 66/130. 50.8% feitos. Fazendo: Participação em Banca Julgadora para Concurso Público. Acabará em 26/04/23 08:51:35. O Último demorou: 0:00:00.259123.
# 67/130. 51.5% feitos. Fazendo: Orientação em Andamento de Graduação. Acabará em 26/04/23 08:51:35. O Último demorou: 0:00:00.367278.
# 68/130. 52.3% feitos. Fazendo: Produção Bibliográfica. Acabará em 26/04/23 08:51:35. O Último demorou: 0:00:00.297650.
# 69/130. 53.1% feitos. Fazendo: Participação em Banca de Doutorado. Acabará em 26/04/23 08:51:35. O Último demorou: 0:00:00.344503.
# 70/130. 53.8% feitos. Fazendo: Produção de Relatório de Pesquisa. Acabará em 26/04/23 08:51:35. O Último demorou: 0:00:00.252998.
# 71/130. 54.6% feitos. Fazendo: Conclusão de Curso Técnico/Profissionalizante. Acabará em 26/04/23 08:51:35. O Último demorou: 0:00:00.293002.
# 72/130. 55.4% feitos. Fazendo: Início de Curso Técnico/Profissionalizante. Acabará em 26/04/23 08:51:34. O Último demorou: 0:00:00.237025.
# 73/130. 56.2% feitos. Fazendo: Texto em Jornal ou Revista. Acabará em 26/04/23 08:51:34. O Último demorou: 0:00:00.341973.
# 74/130. 56.9% feitos. Fazendo: Orientação Concluída de Doutorado. Acabará em 26/04/23 08:51:34. O Último demorou: 0:00:00.320892.
# 75/130. 57.7% feitos. Fazendo: Tradução. Acabará em 26/04/23 08:51:34. O Último demorou: 0:00:00.174247.
# 76/130. 58.5% feitos. Fazendo: Produção de Artes Visuais. Acabará em 26/04/23 08:51:34. O Último demorou: 0:00:00.239113.
# 77/130. 59.2% feitos. Fazendo: Produção - Demais Trabalhos. Acabará em 26/04/23 08:51:34. O Último demorou: 0:00:00.291000.
# 78/130. 60.0% feitos. Fazendo: Produção Artística ou Cultural. Acabará em 26/04/23 08:51:33. O Último demorou: 0:00:00.196997.
# 79/130. 60.8% feitos. Fazendo: Início de Atividade de Direção ou Administração. Acabará em 26/04/23 08:51:33. O Último demorou: 0:00:00.122999.
# 80/130. 61.5% feitos. Fazendo: Fim de Extensão Universitária. Acabará em 26/04/23 08:51:32. O Último demorou: 0:00:00.130002.
# 81/130. 62.3% feitos. Fazendo: Fim de Outra Atividade Técnico/Científica. Acabará em 26/04/23 08:51:32. O Último demorou: 0:00:00.131999.
# 82/130. 63.1% feitos. Fazendo: Início de Outra Atividade Técnico/Científica. Acabará em 26/04/23 08:51:32. O Último demorou: 0:00:00.307000.
# 83/130. 63.8% feitos. Fazendo: Conclusão de Aperfeiçoamento. Acabará em 26/04/23 08:51:32. O Último demorou: 0:00:00.364182.
# 84/130. 64.6% feitos. Fazendo: Início de Aperfeiçoamento. Acabará em 26/04/23 08:51:32. O Último demorou: 0:00:00.309977.
# 85/130. 65.4% feitos. Fazendo: Orientação em Andamento de Iniciação Científica. Acabará em 26/04/23 08:51:32. O Último demorou: 0:00:00.228002.
# 86/130. 66.2% feitos. Fazendo: Conclusão de Mestrado Profissionalizante. Acabará em 26/04/23 08:51:32. O Último demorou: 0:00:00.237998.
# 87/130. 66.9% feitos. Fazendo: Início de Mestrado Profissionalizante. Acabará em 26/04/23 08:51:31. O Último demorou: 0:00:00.219000.
# 88/130. 67.7% feitos. Fazendo: Obtenção do Título de Mestrado Profissionalizante. Acabará em 26/04/23 08:51:31. O Último demorou: 0:00:00.216915.
# 89/130. 68.5% feitos. Fazendo: Fim de Participação em Conselho, Comissão ou Consultoria. Acabará em 26/04/23 08:51:31. O Último demorou: 0:00:00.325001.
# 90/130. 69.2% feitos. Fazendo: Início de Atividade de Conselho, Comissão ou Consultoria. Acabará em 26/04/23 08:51:31. O Último demorou: 0:00:00.380059.
# 91/130. 70.0% feitos. Fazendo: Produção de Carta, Mapa ou Similar. Acabará em 26/04/23 08:51:31. O Último demorou: 0:00:00.211938.
# 92/130. 70.8% feitos. Fazendo: Editoração. Acabará em 26/04/23 08:51:31. O Último demorou: 0:00:00.198997.
# 93/130. 71.5% feitos. Fazendo: Produção Técnica - Processos ou Técnicas. Acabará em 26/04/23 08:51:30. O Último demorou: 0:00:00.117012.
# 94/130. 72.3% feitos. Fazendo: Produção de Software. Acabará em 26/04/23 08:51:30. O Último demorou: 0:00:00.124991.
# 95/130. 73.1% feitos. Fazendo: Participação em Feira. Acabará em 26/04/23 08:51:30. O Último demorou: 0:00:00.115842.
# 96/130. 73.8% feitos. Fazendo: Conclusão de Pós-Doutorado. Acabará em 26/04/23 08:51:30. O Último demorou: 0:00:00.162420.
# 97/130. 74.6% feitos. Fazendo: Fim de Participação em Direção ou Administração. Acabará em 26/04/23 08:51:29. O Último demorou: 0:00:00.107689.
# 98/130. 75.4% feitos. Fazendo: Participação em Banca Julgadora para Avaliação de Cursos. Acabará em 26/04/23 08:51:29. O Último demorou: 0:00:00.134862.
# 99/130. 76.2% feitos. Fazendo: Produção Técnica - Produto Tecnológico. Acabará em 26/04/23 08:51:29. O Último demorou: 0:00:00.120964.
# 100/130. 76.9% feitos. Fazendo: Outras Orientações em Andamento. Acabará em 26/04/23 08:51:29. O Último demorou: 0:00:00.343871.
# 101/130. 77.7% feitos. Fazendo: Orientação em Andamento de Aperfeiçoamento ou Especialização. Acabará em 26/04/23 08:51:29. O Último demorou: 0:00:00.304031.
# 102/130. 78.5% feitos. Fazendo: Patente Registrada. Acabará em 26/04/23 08:51:29. O Último demorou: 0:00:00.294748.
# 103/130. 79.2% feitos. Fazendo: Desenvolvimento de Desenho Industrial. Acabará em 26/04/23 08:51:29. O Último demorou: 0:00:00.205239.
# 104/130. 80.0% feitos. Fazendo: Conclusão de Ensino Fundamental. Acabará em 26/04/23 08:51:28. O Último demorou: 0:00:00.115995.
# 105/130. 80.8% feitos. Fazendo: Início de Ensino Fundamental. Acabará em 26/04/23 08:51:28. O Último demorou: 0:00:00.115461.
# 106/130. 81.5% feitos. Fazendo: Conclusão de Residência Médica. Acabará em 26/04/23 08:51:28. O Último demorou: 0:00:00.298760.
# 107/130. 82.3% feitos. Fazendo: Início de Residência Médica. Acabará em 26/04/23 08:51:28. O Último demorou: 0:00:00.318805.
# 108/130. 83.1% feitos. Fazendo: Produção de Artes Cênicas. Acabará em 26/04/23 08:51:28. O Último demorou: 0:00:00.301608.
# 109/130. 83.8% feitos. Fazendo: Participação em Banca Julgadora para Professor Titular. Acabará em 26/04/23 08:51:28. O Último demorou: 0:00:00.263853.
# 110/130. 84.6% feitos. Fazendo: Treinamento Ministrado. Acabará em 26/04/23 08:51:28. O Último demorou: 0:00:00.331049.
# 111/130. 85.4% feitos. Fazendo: Início de Ministério de Treinamento. Acabará em 26/04/23 08:51:28. O Último demorou: 0:00:00.316826.
# 112/130. 86.2% feitos. Fazendo: Orientação em Andamento de Doutorado. Acabará em 26/04/23 08:51:28. O Último demorou: 0:00:00.216765.
# 113/130. 86.9% feitos. Fazendo: Produção  de Obra Musical. Acabará em 26/04/23 08:51:28. O Último demorou: 0:00:00.219768.
# 114/130. 87.7% feitos. Fazendo: Música. Acabará em 26/04/23 08:51:28. O Último demorou: 0:00:00.332427.
# 115/130. 88.5% feitos. Fazendo: Participação em Olimpíada. Acabará em 26/04/23 08:51:28. O Último demorou: 0:00:00.260339.
# 116/130. 89.2% feitos. Fazendo: Desenvolvimento de Marca. Acabará em 26/04/23 08:51:28. O Último demorou: 0:00:00.421311.
# 117/130. 90.0% feitos. Fazendo: Obtenção do Título de MBA. Acabará em 26/04/23 08:51:28. O Último demorou: 0:00:00.260365.
# 118/130. 90.8% feitos. Fazendo: Orientação em Andamento de Pós-Doutorado. Acabará em 26/04/23 08:51:28. O Último demorou: 0:00:00.268460.
# 119/130. 91.5% feitos. Fazendo: Participação em Banca Julgadora para Livre Docência. Acabará em 26/04/23 08:51:27. O Último demorou: 0:00:00.137008.
# 120/130. 92.3% feitos. Fazendo: Manutenção de Obra Artística. Acabará em 26/04/23 08:51:27. O Último demorou: 0:00:00.259590.
# 121/130. 93.1% feitos. Fazendo: Publicação de Partitura Musical. Acabará em 26/04/23 08:51:27. O Último demorou: 0:00:00.213298.
# 122/130. 93.8% feitos. Fazendo: Maquete. Acabará em 26/04/23 08:51:27. O Último demorou: 0:00:00.224640.
# 123/130. 94.6% feitos. Fazendo: Outras participações em Banca. Acabará em 26/04/23 08:51:27. O Último demorou: 0:00:00.215899.
# 124/130. 95.4% feitos. Fazendo: Curso de Curta Duração Realizado. Acabará em 26/04/23 08:51:27. O Último demorou: 0:00:00.233462.
# 125/130. 96.2% feitos. Fazendo: Solicitação de Cultivar Registrada. Acabará em 26/04/23 08:51:27. O Último demorou: 0:00:00.220574.
# 126/130. 96.9% feitos. Fazendo: Obtenção do Título de Livre Docência. Acabará em 26/04/23 08:51:27. O Último demorou: 0:00:00.122467.
# 127/130. 97.7% feitos. Fazendo: Orientação Concluída de Pós-Doutorado. Acabará em 26/04/23 08:51:26. O Último demorou: 0:00:00.165221.
# 128/130. 98.5% feitos. Fazendo: Solicitação de Cultivar protegida. Acabará em 26/04/23 08:51:26. O Último demorou: 0:00:00.260610.
# 129/130. 99.2% feitos. Fazendo: Desenvolvimento de Topografia de Circuito Integrado. Acabará em 26/04/23 08:51:26. O Último demorou: 0:00:00.208685.
# [{'Indicador': 'Conclusão de Doutorado',
#   'Erro': False,
#   'Prob (F-statistic)': 2.882661603582637e-10,
#   'Parâmetros': Intercept        0.981500
#   qty_2014         0.284076
#   porcent_pagos   -8.874927
#   dtype: float64,
#   'P>|t|': Intercept        0.000000e+00
#   qty_2014         4.429258e-11
#   porcent_pagos    4.451117e-01
#   dtype: float64,
#   'Standard Error': Intercept         0.002460
#   qty_2014          0.043074
#   porcent_pagos    11.622249
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000096 -0.000081      -0.159047
#   qty_2014       -0.000081  0.029497      -0.051317
#   porcent_pagos  -0.159047 -0.051317    2147.539858,
#   'Number of observations n.': 11883.0,
#   'R2 ajustado': 0.0035236126507550702,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x21401519a00>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Conclusão de Doutorado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Conclusão de Curso de Curta Duração',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept          1.420154
#   qty_2014           1.121634
#   porcent_pagos    448.432540
#   dtype: float64,
#   'P>|t|': Intercept        8.463357e-104
#   qty_2014          0.000000e+00
#   porcent_pagos     6.327706e-02
#   dtype: float64,
#   'Standard Error': Intercept          0.064856
#   qty_2014           0.005412
#   porcent_pagos    241.423600
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000194 -0.000010      -0.217860
#   qty_2014       -0.000010  0.000001       0.003582
#   porcent_pagos  -0.217860  0.003582    2681.958783,
#   'Number of observations n.': 9775.0,
#   'R2 ajustado': 0.8150140504530127,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x21401519a60>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Conclusão de Curso de Curta Duração',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Conclusão de Graduação',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept        0.006676
#   qty_2014         1.023131
#   porcent_pagos    4.723976
#   dtype: float64,
#   'P>|t|': Intercept        0.192981
#   qty_2014         0.000000
#   porcent_pagos    0.607828
#   dtype: float64,
#   'Standard Error': Intercept        0.005128
#   qty_2014         0.003932
#   porcent_pagos    9.205139
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000633 -0.000449      -0.186391
#   qty_2014       -0.000449  0.000372       0.029906
#   porcent_pagos  -0.186391  0.029906    2039.326247,
#   'Number of observations n.': 12364.0,
#   'R2 ajustado': 0.8457551809453878,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214009d0100>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Conclusão de Graduação',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Conclusão de Mestrado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept        0.240718
#   qty_2014         0.771236
#   porcent_pagos   -1.252047
#   dtype: float64,
#   'P>|t|': Intercept        0.00000
#   qty_2014         0.00000
#   porcent_pagos    0.78002
#   dtype: float64,
#   'Standard Error': Intercept        0.005551
#   qty_2014         0.005394
#   porcent_pagos    4.482807
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.003394 -0.003251      -0.197483
#   qty_2014       -0.003251  0.003206       0.030892
#   porcent_pagos  -0.197483  0.030892    2213.893541,
#   'Number of observations n.': 11655.0,
#   'R2 ajustado': 0.6368979089121535,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214009c4430>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Conclusão de Mestrado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Doutorado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept        0.051560
#   qty_2014         0.975311
#   porcent_pagos    4.572814
#   dtype: float64,
#   'P>|t|': Intercept        0.006168
#   qty_2014         0.000000
#   porcent_pagos    0.548744
#   dtype: float64,
#   'Standard Error': Intercept        0.018823
#   qty_2014         0.018649
#   porcent_pagos    7.625690
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.012342 -0.012183      -0.099538
#   qty_2014       -0.012183  0.012114      -0.047869
#   porcent_pagos  -0.099538 -0.047869    2025.649782,
#   'Number of observations n.': 12603.0,
#   'R2 ajustado': 0.1782954743434635,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214009c4970>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Início de Doutorado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Curso de Curta Duração',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept          1.425786
#   qty_2014           1.122034
#   porcent_pagos    441.139606
#   dtype: float64,
#   'P>|t|': Intercept        4.221987e-104
#   qty_2014          0.000000e+00
#   porcent_pagos     6.827130e-02
#   dtype: float64,
#   'Standard Error': Intercept          0.065016
#   qty_2014           0.005418
#   porcent_pagos    241.930659
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000194 -0.000010      -0.217777
#   qty_2014       -0.000010  0.000001       0.003586
#   porcent_pagos  -0.217777  0.003586    2680.238311,
#   'Number of observations n.': 9788.0,
#   'R2 ajustado': 0.814577943845802,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214003e5ac0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Início de Curso de Curta Duração',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Graduação',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept       -0.006818
#   qty_2014         1.043316
#   porcent_pagos    0.519969
#   dtype: float64,
#   'P>|t|': Intercept        0.224753
#   qty_2014         0.000000
#   porcent_pagos    0.960524
#   dtype: float64,
#   'Standard Error': Intercept         0.005616
#   qty_2014          0.004185
#   porcent_pagos    10.505137
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000582 -0.000398      -0.184390
#   qty_2014       -0.000398  0.000323       0.027668
#   porcent_pagos  -0.184390  0.027668    2036.775194,
#   'Number of observations n.': 12381.0,
#   'R2 ajustado': 0.8340158177001251,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214003c77c0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Início de Graduação',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Mestrado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept        0.059669
#   qty_2014         0.945964
#   porcent_pagos   -2.237431
#   dtype: float64,
#   'P>|t|': Intercept        1.427941e-45
#   qty_2014         0.000000e+00
#   porcent_pagos    4.953995e-01
#   dtype: float64,
#   'Standard Error': Intercept        0.004193
#   qty_2014         0.004057
#   porcent_pagos    3.281809
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.003611 -0.003446      -0.194795
#   qty_2014       -0.003446  0.003380       0.028546
#   porcent_pagos  -0.194795  0.028546    2212.030154,
#   'Number of observations n.': 11690.0,
#   'R2 ajustado': 0.8230702422215964,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214003fcbb0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Início de Mestrado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Pós-Doutorado',
#   'Erro': False,
#   'Prob (F-statistic)': 1.211680127131085e-08,
#   'Parâmetros': Intercept          0.847999
#   qty_2014           0.434667
#   porcent_pagos    277.348418
#   dtype: float64,
#   'P>|t|': Intercept        0.000000e+00
#   qty_2014         7.145917e-02
#   porcent_pagos    6.608223e-09
#   dtype: float64,
#   'Standard Error': Intercept         0.014647
#   qty_2014          0.241020
#   porcent_pagos    47.620144
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000617 -0.000411      -0.984390
#   qty_2014       -0.000411  0.166941       0.656260
#   porcent_pagos  -0.984390  0.656260    6516.823967,
#   'Number of observations n.': 2140.0,
#   'R2 ajustado': 0.01599529951196821,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214003c7760>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Início de Pós-Doutorado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Obtenção do Título de Doutorado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.003983351257198384,
#   'Parâmetros': Intercept         0.973558
#   qty_2014          0.276442
#   porcent_pagos   -16.325703
#   dtype: float64,
#   'P>|t|': Intercept        0.000000
#   qty_2014         0.002510
#   porcent_pagos    0.175302
#   dtype: float64,
#   'Standard Error': Intercept         0.002561
#   qty_2014          0.091452
#   porcent_pagos    12.044519
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000098 -0.000098      -0.162579
#   qty_2014       -0.000098  0.125098       0.162579
#   porcent_pagos  -0.162579  0.162579    2169.900803,
#   'Number of observations n.': 11647.0,
#   'R2 ajustado': 0.0007770455322428926,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214003ef4c0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Obtenção do Título de Doutorado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Obtenção do Título de Metrado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept        0.367220
#   qty_2014         0.646508
#   porcent_pagos    0.583352
#   dtype: float64,
#   'P>|t|': Intercept        0.000000
#   qty_2014         0.000000
#   porcent_pagos    0.898861
#   dtype: float64,
#   'Standard Error': Intercept        0.005818
#   qty_2014         0.005704
#   porcent_pagos    4.589620
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.003579 -0.003461      -0.184911
#   qty_2014       -0.003461  0.003441       0.017767
#   porcent_pagos  -0.184911  0.017767    2227.195885,
#   'Number of observations n.': 11638.0,
#   'R2 ajustado': 0.5246303148140425,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214003d46d0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Obtenção do Título de Metrado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Trabalho em Evento',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept         2.845444
#   qty_2014          1.291200
#   porcent_pagos    69.742908
#   dtype: float64,
#   'P>|t|': Intercept        6.882607e-111
#   qty_2014          0.000000e+00
#   porcent_pagos     8.844217e-01
#   dtype: float64,
#   'Standard Error': Intercept          0.125692
#   qty_2014           0.005908
#   porcent_pagos    479.762307
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept      qty_2014  porcent_pagos
#   Intercept       0.000166 -4.676281e-06      -0.182377
#   qty_2014       -0.000005  3.660221e-07       0.000366
#   porcent_pagos  -0.182377  3.661848e-04    2413.569259,
#   'Number of observations n.': 10772.0,
#   'R2 ajustado': 0.815999805446936,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214003d49a0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Trabalho em Evento',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Artigo Publicado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept           3.071206
#   qty_2014            1.447010
#   porcent_pagos    2053.329062
#   dtype: float64,
#   'P>|t|': Intercept        0.000000e+00
#   qty_2014         0.000000e+00
#   porcent_pagos    4.442233e-13
#   dtype: float64,
#   'Standard Error': Intercept          0.071201
#   qty_2014           0.010583
#   porcent_pagos    283.221832
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000136 -0.000010      -0.179555
#   qty_2014       -0.000010  0.000003       0.004225
#   porcent_pagos  -0.179555  0.004225    2155.868433,
#   'Number of observations n.': 11340.0,
#   'R2 ajustado': 0.622423511626261,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214003c16d0>,
#   'Confiança': 0.05,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Artigo Publicado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Trabalho em Eventos',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept          2.889735
#   qty_2014           1.291126
#   porcent_pagos    226.207187
#   dtype: float64,
#   'P>|t|': Intercept        7.479798e-114
#   qty_2014          0.000000e+00
#   porcent_pagos     6.369684e-01
#   dtype: float64,
#   'Standard Error': Intercept          0.125909
#   qty_2014           0.005838
#   porcent_pagos    479.298171
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept      qty_2014  porcent_pagos
#   Intercept       0.000166 -4.623341e-06      -0.181926
#   qty_2014       -0.000005  3.563371e-07       0.000375
#   porcent_pagos  -0.181926  3.749428e-04    2401.468668,
#   'Number of observations n.': 10790.0,
#   'R2 ajustado': 0.8192683795365783,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fb3e0d0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Trabalho em Eventos',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Fim de Estágio',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept         0.126903
#   qty_2014          1.026073
#   porcent_pagos    56.149692
#   dtype: float64,
#   'P>|t|': Intercept        1.002327e-08
#   qty_2014         0.000000e+00
#   porcent_pagos    4.241911e-01
#   dtype: float64,
#   'Standard Error': Intercept         0.022065
#   qty_2014          0.006726
#   porcent_pagos    70.247501
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000971 -0.000208      -0.815321
#   qty_2014       -0.000208  0.000090       0.017753
#   porcent_pagos  -0.815321  0.017753    9845.009861,
#   'Number of observations n.': 2324.0,
#   'R2 ajustado': 0.9092472064777638,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fb3e0a0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Fim de Estágio',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Fim de Atividade de Pesquisa e Desenvolvimento',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept         0.612542
#   qty_2014          0.957625
#   porcent_pagos    80.217298
#   dtype: float64,
#   'P>|t|': Intercept        1.410101e-129
#   qty_2014          0.000000e+00
#   porcent_pagos     2.824453e-01
#   dtype: float64,
#   'Standard Error': Intercept         0.023477
#   qty_2014          0.010862
#   porcent_pagos    74.611790
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000839 -0.000223      -0.735794
#   qty_2014       -0.000223  0.000179      -0.015092
#   porcent_pagos  -0.735794 -0.015092    8470.045322,
#   'Number of observations n.': 2024.0,
#   'R2 ajustado': 0.7935500350165788,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fb260a0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Fim de Atividade de Pesquisa e Desenvolvimento',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Fim de Vínculo Empregatício ou Funcional',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept          1.013633
#   qty_2014           1.189493
#   porcent_pagos    483.245188
#   dtype: float64,
#   'P>|t|': Intercept        7.180652e-107
#   qty_2014          0.000000e+00
#   porcent_pagos     7.453464e-04
#   dtype: float64,
#   'Standard Error': Intercept          0.045696
#   qty_2014           0.005342
#   porcent_pagos    143.259972
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000219 -0.000019      -0.192094
#   qty_2014       -0.000019  0.000003       0.005447
#   porcent_pagos  -0.192094  0.005447    2148.449709,
#   'Number of observations n.': 11956.0,
#   'R2 ajustado': 0.8061441969178775,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fb38490>,
#   'Confiança': 0.05,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Fim de Vínculo Empregatício ou Funcional',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Atividade de Ensino',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept           1.481353
#   qty_2014            1.228754
#   porcent_pagos    2010.152999
#   dtype: float64,
#   'P>|t|': Intercept        4.346125e-63
#   qty_2014         0.000000e+00
#   porcent_pagos    1.333754e-06
#   dtype: float64,
#   'Standard Error': Intercept          0.087332
#   qty_2014           0.007229
#   porcent_pagos    415.362585
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000258 -0.000012      -0.394554
#   qty_2014       -0.000012  0.000002       0.011807
#   porcent_pagos  -0.394554  0.011807    5829.931268,
#   'Number of observations n.': 6074.0,
#   'R2 ajustado': 0.8274266630026491,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fb4a340>,
#   'Confiança': 0.05,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Início de Atividade de Ensino',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Estágio',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept         0.120179
#   qty_2014          1.030175
#   porcent_pagos    47.709646
#   dtype: float64,
#   'P>|t|': Intercept        2.936265e-08
#   qty_2014         0.000000e+00
#   porcent_pagos    4.952932e-01
#   dtype: float64,
#   'Standard Error': Intercept         0.021602
#   qty_2014          0.006604
#   porcent_pagos    69.953721
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000925 -0.000199      -0.778438
#   qty_2014       -0.000199  0.000086       0.014923
#   porcent_pagos  -0.778438  0.014923    9702.410968,
#   'Number of observations n.': 2428.0,
#   'R2 ajustado': 0.9093112936756859,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fb43ee0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Início de Estágio',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Atividade de Pesquisa e Desenvolvimento',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept        0.531539
#   qty_2014         0.972184
#   porcent_pagos    8.273823
#   dtype: float64,
#   'P>|t|': Intercept        5.898515e-176
#   qty_2014          0.000000e+00
#   porcent_pagos     8.937759e-01
#   dtype: float64,
#   'Standard Error': Intercept         0.017920
#   qty_2014          0.008062
#   porcent_pagos    61.959558
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000465 -0.000139      -0.358526
#   qty_2014       -0.000139  0.000094      -0.022281
#   porcent_pagos  -0.358526 -0.022281    5563.278175,
#   'Number of observations n.': 4271.0,
#   'R2 ajustado': 0.7731666667508789,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fb31460>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Início de Atividade de Pesquisa e Desenvolvimento',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Vínculo Empregatício ou Funcional',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept           1.121334
#   qty_2014            1.244064
#   porcent_pagos    1777.208265
#   dtype: float64,
#   'P>|t|': Intercept        8.740018e-65
#   qty_2014         0.000000e+00
#   porcent_pagos    9.294146e-20
#   dtype: float64,
#   'Standard Error': Intercept          0.065592
#   qty_2014           0.006228
#   porcent_pagos    195.035735
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000237 -0.000018      -0.202534
#   qty_2014       -0.000018  0.000002       0.006347
#   porcent_pagos  -0.202534  0.006347    2095.574731,
#   'Number of observations n.': 12460.0,
#   'R2 ajustado': 0.7624645642108004,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fb2f1f0>,
#   'Confiança': 0.05,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Início de Vínculo Empregatício ou Funcional',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Apresentação de Trabalho Técnico',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept          2.829113
#   qty_2014           1.303311
#   porcent_pagos   -278.407957
#   dtype: float64,
#   'P>|t|': Intercept        5.738703e-165
#   qty_2014          0.000000e+00
#   porcent_pagos     4.625480e-01
#   dtype: float64,
#   'Standard Error': Intercept          0.101634
#   qty_2014           0.005936
#   porcent_pagos    378.949844
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept      qty_2014  porcent_pagos
#   Intercept       0.000163 -5.851551e-06      -0.193604
#   qty_2014       -0.000006  5.555119e-07       0.002605
#   porcent_pagos  -0.193604  2.604850e-03    2264.128065,
#   'Number of observations n.': 11241.0,
#   'R2 ajustado': 0.8118331055872727,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fb2fa90>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Apresentação de Trabalho Técnico',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Publicação de Capítulo de Livro',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept          1.649604
#   qty_2014           1.310830
#   porcent_pagos   -493.676901
#   dtype: float64,
#   'P>|t|': Intercept        3.551374e-276
#   qty_2014          0.000000e+00
#   porcent_pagos     2.007100e-02
#   dtype: float64,
#   'Standard Error': Intercept          0.044390
#   qty_2014           0.014110
#   porcent_pagos    212.284213
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000201 -0.000029      -0.295837
#   qty_2014       -0.000029  0.000020       0.013683
#   porcent_pagos  -0.295837  0.013683    4600.442980,
#   'Number of observations n.': 7044.0,
#   'R2 ajustado': 0.5517906727460384,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fb5ad30>,
#   'Confiança': 0.05,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Publicação de Capítulo de Livro',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Livro Publicado ou Organizado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept          0.935796
#   qty_2014           1.303420
#   porcent_pagos   -201.626197
#   dtype: float64,
#   'P>|t|': Intercept        2.922141e-134
#   qty_2014          0.000000e+00
#   porcent_pagos     3.877216e-01
#   dtype: float64,
#   'Standard Error': Intercept          0.036533
#   qty_2014           0.013518
#   porcent_pagos    233.404292
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000319 -0.000045      -0.638985
#   qty_2014       -0.000045  0.000044       0.048854
#   porcent_pagos  -0.638985  0.048854   13040.549750,
#   'Number of observations n.': 4059.0,
#   'R2 ajustado': 0.6972578362477665,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fa746a0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Livro Publicado ou Organizado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Outras Orientações Concluídas',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept           5.675114
#   qty_2014            1.252583
#   porcent_pagos   -2944.574741
#   dtype: float64,
#   'P>|t|': Intercept        9.503176e-193
#   qty_2014          0.000000e+00
#   porcent_pagos     2.218178e-03
#   dtype: float64,
#   'Standard Error': Intercept          0.186431
#   qty_2014           0.007084
#   porcent_pagos    962.174342
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept      qty_2014  porcent_pagos
#   Intercept       0.000175 -3.055315e-06      -0.300661
#   qty_2014       -0.000003  2.525386e-07       0.004012
#   porcent_pagos  -0.300661  4.012297e-03    4658.259129,
#   'Number of observations n.': 8059.0,
#   'R2 ajustado': 0.7979866669591656,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fa6c490>,
#   'Confiança': 0.05,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Outras Orientações Concluídas',
# ...
#   dtype: float64,
#   'Standard Error': Intercept          0.099449
#   qty_2014           0.061482
#   porcent_pagos    373.076613
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.007381 -0.002501      -8.412835
#   qty_2014       -0.002501  0.002821      -0.385802
#   porcent_pagos  -8.412835 -0.385802  103875.712925,
#   'Number of observations n.': 226.0,
#   'R2 ajustado': 0.4611585143185142,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147646a820>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Participação em Olimpíada',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Desenvolvimento de Marca',
#   'Erro': False,
#   'Prob (F-statistic)': 8.315398284967645e-71,
#   'Parâmetros': Intercept          0.568140
#   qty_2014           1.019300
#   porcent_pagos    927.379258
#   dtype: float64,
#   'P>|t|': Intercept        3.377595e-08
#   qty_2014         8.747648e-72
#   porcent_pagos    1.610631e-01
#   dtype: float64,
#   'Standard Error': Intercept          0.091047
#   qty_2014           0.011260
#   porcent_pagos    654.382362
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.017434 -0.000403     -49.217111
#   qty_2014       -0.000403  0.000267       0.982730
#   porcent_pagos -49.217111  0.982730  900597.071592,
#   'Number of observations n.': 70.0,
#   'R2 ajustado': 0.9916664413038918,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x21476461400>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Desenvolvimento de Marca',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Obtenção do Título de MBA',
#   'Erro': False,
#   'Prob (F-statistic)': 1.7255406926076966e-45,
#   'Parâmetros': Intercept        2.220446e-16
#   qty_2014         1.000000e+00
#   porcent_pagos    0.000000e+00
#   dtype: float64,
#   'P>|t|': Intercept        8.812704e-01
#   qty_2014         1.725541e-45
#   porcent_pagos             NaN
#   dtype: float64,
#   'Standard Error': Intercept        1.366772e-15
#   qty_2014         9.214777e-16
#   porcent_pagos    0.000000e+00
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       1.833333 -1.166667            0.0
#   qty_2014       -1.166667  0.833333            0.0
#   porcent_pagos   0.000000  0.000000            0.0,
#   'Number of observations n.': 5.0,
#   'R2 ajustado': 1.0,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x21476491ac0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Obtenção do Título de MBA',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Orientação em Andamento de Pós-Doutorado',
#   'Erro': True,
#   'Prob (F-statistic)': None,
#   'Parâmetros': None,
#   'P>|t|': None,
#   'Standard Error': None,
#   'Covariância entre os pasrâmetros': None,
#   'Number of observations n.': None,
#   'R2 ajustado': None,
#   'Modelo': None,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Orientação em Andamento de Pós-Doutorado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Participação em Banca Julgadora para Livre Docência',
#   'Erro': False,
#   'Prob (F-statistic)': 1.0209310937121734e-36,
#   'Parâmetros': Intercept           0.792119
#   qty_2014            1.004687
#   porcent_pagos    8484.696962
#   dtype: float64,
#   'P>|t|': Intercept        2.538783e-03
#   qty_2014         1.059883e-37
#   porcent_pagos    2.224842e-02
#   dtype: float64,
#   'Standard Error': Intercept           0.251913
#   qty_2014            0.035262
#   porcent_pagos    3619.833107
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.018620 -0.001027  -5.555314e+01
#   qty_2014       -0.001027  0.000365   3.064411e+00
#   porcent_pagos -55.553142  3.064411   3.844589e+06,
#   'Number of observations n.': 66.0,
#   'R2 ajustado': 0.925697869731568,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x21476472be0>,
#   'Confiança': 0.05,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Participação em Banca Julgadora para Livre Docência',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Manutenção de Obra Artística',
#   'Erro': False,
#   'Prob (F-statistic)': 8.100987112678477e-40,
#   'Parâmetros': Intercept          0.067342
#   qty_2014           1.040377
#   porcent_pagos   -331.589703
#   dtype: float64,
#   'P>|t|': Intercept        7.633933e-01
#   qty_2014         2.063520e-40
#   porcent_pagos    7.956525e-01
#   dtype: float64,
#   'Standard Error': Intercept           0.221610
#   qty_2014            0.008845
#   porcent_pagos    1268.647029
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                 Intercept  qty_2014  porcent_pagos
#   Intercept        0.048444 -0.000892  -1.270696e+02
#   qty_2014        -0.000892  0.000077   2.112970e+00
#   porcent_pagos -127.069571  2.112970   1.587606e+06,
#   'Number of observations n.': 32.0,
#   'R2 ajustado': 0.9978472143228302,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x21476463100>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Manutenção de Obra Artística',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Publicação de Partitura Musical',
#   'Erro': False,
#   'Prob (F-statistic)': 2.408101848125626e-12,
#   'Parâmetros': Intercept            0.261648
#   qty_2014             1.173226
#   porcent_pagos   -14053.594912
#   dtype: float64,
#   'P>|t|': Intercept        7.488634e-01
#   qty_2014         9.275293e-13
#   porcent_pagos    1.772725e-01
#   dtype: float64,
#   'Standard Error': Intercept           0.804130
#   qty_2014            0.062877
#   porcent_pagos    9984.095658
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept   qty_2014  porcent_pagos
#   Intercept       0.073516  -0.002932  -4.461606e+01
#   qty_2014       -0.002932   0.000449  -2.515217e+01
#   porcent_pagos -44.616057 -25.152167   1.133311e+07,
#   'Number of observations n.': 20.0,
#   'R2 ajustado': 0.9519777065416674,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214764676a0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Publicação de Partitura Musical',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Maquete',
#   'Erro': False,
#   'Prob (F-statistic)': 7.995689606026436e-55,
#   'Parâmetros': Intercept           0.280822
#   qty_2014            1.099898
#   porcent_pagos   -1506.512848
#   dtype: float64,
#   'P>|t|': Intercept        9.553881e-02
#   qty_2014         1.026490e-55
#   porcent_pagos    5.293927e-01
#   dtype: float64,
#   'Standard Error': Intercept           0.164493
#   qty_2014            0.007737
#   porcent_pagos    2374.479234
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.025708 -0.000271  -8.133577e+01
#   qty_2014       -0.000271  0.000057   5.116847e-01
#   porcent_pagos -81.335769  0.511685   5.356794e+06,
#   'Number of observations n.': 43.0,
#   'R2 ajustado': 0.9979282750544901,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x21474592310>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Maquete',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Outras participações em Banca',
#   'Erro': False,
#   'Prob (F-statistic)': 2.1586948735196703e-125,
#   'Parâmetros': Intercept       -6.661338e-16
#   qty_2014         1.000000e+00
#   porcent_pagos    0.000000e+00
#   dtype: float64,
#   'P>|t|': Intercept         5.757842e-01
#   qty_2014         2.158695e-125
#   porcent_pagos              NaN
#   dtype: float64,
#   'Standard Error': Intercept        1.142077e-15
#   qty_2014         1.085480e-16
#   porcent_pagos    0.000000e+00
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.203306 -0.013774            0.0
#   qty_2014       -0.013774  0.001837            0.0
#   porcent_pagos   0.000000  0.000000            0.0,
#   'Number of observations n.': 10.0,
#   'R2 ajustado': 1.0,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x21474579700>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Outras participações em Banca',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Curso de Curta Duração Realizado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept       -1.443290e-15
#   qty_2014         1.000000e+00
#   porcent_pagos    0.000000e+00
#   dtype: float64,
#   'P>|t|': Intercept        0.000274
#   qty_2014         0.000000
#   porcent_pagos         NaN
#   dtype: float64,
#   'Standard Error': Intercept        3.309370e-16
#   qty_2014         3.771377e-17
#   porcent_pagos    0.000000e+00
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.059614 -0.003534            0.0
#   qty_2014       -0.003534  0.000774            0.0
#   porcent_pagos   0.000000  0.000000            0.0,
#   'Number of observations n.': 23.0,
#   'R2 ajustado': 1.0,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147456f4f0>,
#   'Confiança': 0.05,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Curso de Curta Duração Realizado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Solicitação de Cultivar Registrada',
#   'Erro': True,
#   'Prob (F-statistic)': None,
#   'Parâmetros': None,
#   'P>|t|': None,
#   'Standard Error': None,
#   'Covariância entre os pasrâmetros': None,
#   'Number of observations n.': None,
#   'R2 ajustado': None,
#   'Modelo': None,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Solicitação de Cultivar Registrada',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Obtenção do Título de Livre Docência',
#   'Erro': True,
#   'Prob (F-statistic)': None,
#   'Parâmetros': None,
#   'P>|t|': None,
#   'Standard Error': None,
#   'Covariância entre os pasrâmetros': None,
#   'Number of observations n.': None,
#   'R2 ajustado': None,
#   'Modelo': None,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Obtenção do Título de Livre Docência',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Orientação Concluída de Pós-Doutorado',
#   'Erro': True,
#   'Prob (F-statistic)': None,
#   'Parâmetros': None,
#   'P>|t|': None,
#   'Standard Error': None,
#   'Covariância entre os pasrâmetros': None,
#   'Number of observations n.': None,
#   'R2 ajustado': None,
#   'Modelo': None,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Orientação Concluída de Pós-Doutorado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Solicitação de Cultivar protegida',
#   'Erro': False,
#   'Prob (F-statistic)': 0.049906512850594976,
#   'Parâmetros': Intercept           1.500000
#   qty_2014            1.375000
#   porcent_pagos    1643.637974
#   dtype: float64,
#   'P>|t|': Intercept        0.204833
#   qty_2014         0.033383
#   porcent_pagos    0.666667
#   dtype: float64,
#   'Standard Error': Intercept           0.500000
#   qty_2014            0.072169
#   porcent_pagos    2846.864480
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                  Intercept    qty_2014  porcent_pagos
#   Intercept         0.500000   -0.041667  -1.643638e+03
#   qty_2014         -0.041667    0.010417   1.369698e+02
#   porcent_pagos -1643.637974  136.969831   1.620927e+07,
#   'Number of observations n.': 4.0,
#   'R2 ajustado': 0.9925280199252802,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x21474569310>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Solicitação de Cultivar protegida',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Desenvolvimento de Topografia de Circuito Integrado',
#   'Erro': True,
#   'Prob (F-statistic)': None,
#   'Parâmetros': None,
#   'P>|t|': None,
#   'Standard Error': None,
#   'Covariância entre os pasrâmetros': None,
#   'Number of observations n.': None,
#   'R2 ajustado': None,
#   'Modelo': None,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Desenvolvimento de Topografia de Circuito Integrado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}}]

# %%
reg.salva_regressões_csv()

# %%
reg.lista_regressões
# Out:
# [{'Indicador': 'Conclusão de Doutorado',
#   'Erro': False,
#   'Prob (F-statistic)': 2.882661603582637e-10,
#   'Parâmetros': Intercept        0.981500
#   qty_2014         0.284076
#   porcent_pagos   -8.874927
#   dtype: float64,
#   'P>|t|': Intercept        0.000000e+00
#   qty_2014         4.429258e-11
#   porcent_pagos    4.451117e-01
#   dtype: float64,
#   'Standard Error': Intercept         0.002460
#   qty_2014          0.043074
#   porcent_pagos    11.622249
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000096 -0.000081      -0.159047
#   qty_2014       -0.000081  0.029497      -0.051317
#   porcent_pagos  -0.159047 -0.051317    2147.539858,
#   'Number of observations n.': 11883.0,
#   'R2 ajustado': 0.0035236126507550702,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x21401519a00>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Conclusão de Doutorado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Conclusão de Curso de Curta Duração',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept          1.420154
#   qty_2014           1.121634
#   porcent_pagos    448.432540
#   dtype: float64,
#   'P>|t|': Intercept        8.463357e-104
#   qty_2014          0.000000e+00
#   porcent_pagos     6.327706e-02
#   dtype: float64,
#   'Standard Error': Intercept          0.064856
#   qty_2014           0.005412
#   porcent_pagos    241.423600
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000194 -0.000010      -0.217860
#   qty_2014       -0.000010  0.000001       0.003582
#   porcent_pagos  -0.217860  0.003582    2681.958783,
#   'Number of observations n.': 9775.0,
#   'R2 ajustado': 0.8150140504530127,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x21401519a60>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Conclusão de Curso de Curta Duração',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Conclusão de Graduação',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept        0.006676
#   qty_2014         1.023131
#   porcent_pagos    4.723976
#   dtype: float64,
#   'P>|t|': Intercept        0.192981
#   qty_2014         0.000000
#   porcent_pagos    0.607828
#   dtype: float64,
#   'Standard Error': Intercept        0.005128
#   qty_2014         0.003932
#   porcent_pagos    9.205139
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000633 -0.000449      -0.186391
#   qty_2014       -0.000449  0.000372       0.029906
#   porcent_pagos  -0.186391  0.029906    2039.326247,
#   'Number of observations n.': 12364.0,
#   'R2 ajustado': 0.8457551809453878,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214009d0100>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Conclusão de Graduação',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Conclusão de Mestrado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept        0.240718
#   qty_2014         0.771236
#   porcent_pagos   -1.252047
#   dtype: float64,
#   'P>|t|': Intercept        0.00000
#   qty_2014         0.00000
#   porcent_pagos    0.78002
#   dtype: float64,
#   'Standard Error': Intercept        0.005551
#   qty_2014         0.005394
#   porcent_pagos    4.482807
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.003394 -0.003251      -0.197483
#   qty_2014       -0.003251  0.003206       0.030892
#   porcent_pagos  -0.197483  0.030892    2213.893541,
#   'Number of observations n.': 11655.0,
#   'R2 ajustado': 0.6368979089121535,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214009c4430>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Conclusão de Mestrado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Doutorado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept        0.051560
#   qty_2014         0.975311
#   porcent_pagos    4.572814
#   dtype: float64,
#   'P>|t|': Intercept        0.006168
#   qty_2014         0.000000
#   porcent_pagos    0.548744
#   dtype: float64,
#   'Standard Error': Intercept        0.018823
#   qty_2014         0.018649
#   porcent_pagos    7.625690
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.012342 -0.012183      -0.099538
#   qty_2014       -0.012183  0.012114      -0.047869
#   porcent_pagos  -0.099538 -0.047869    2025.649782,
#   'Number of observations n.': 12603.0,
#   'R2 ajustado': 0.1782954743434635,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214009c4970>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Início de Doutorado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Curso de Curta Duração',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept          1.425786
#   qty_2014           1.122034
#   porcent_pagos    441.139606
#   dtype: float64,
#   'P>|t|': Intercept        4.221987e-104
#   qty_2014          0.000000e+00
#   porcent_pagos     6.827130e-02
#   dtype: float64,
#   'Standard Error': Intercept          0.065016
#   qty_2014           0.005418
#   porcent_pagos    241.930659
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000194 -0.000010      -0.217777
#   qty_2014       -0.000010  0.000001       0.003586
#   porcent_pagos  -0.217777  0.003586    2680.238311,
#   'Number of observations n.': 9788.0,
#   'R2 ajustado': 0.814577943845802,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214003e5ac0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Início de Curso de Curta Duração',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Graduação',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept       -0.006818
#   qty_2014         1.043316
#   porcent_pagos    0.519969
#   dtype: float64,
#   'P>|t|': Intercept        0.224753
#   qty_2014         0.000000
#   porcent_pagos    0.960524
#   dtype: float64,
#   'Standard Error': Intercept         0.005616
#   qty_2014          0.004185
#   porcent_pagos    10.505137
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000582 -0.000398      -0.184390
#   qty_2014       -0.000398  0.000323       0.027668
#   porcent_pagos  -0.184390  0.027668    2036.775194,
#   'Number of observations n.': 12381.0,
#   'R2 ajustado': 0.8340158177001251,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214003c77c0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Início de Graduação',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Mestrado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept        0.059669
#   qty_2014         0.945964
#   porcent_pagos   -2.237431
#   dtype: float64,
#   'P>|t|': Intercept        1.427941e-45
#   qty_2014         0.000000e+00
#   porcent_pagos    4.953995e-01
#   dtype: float64,
#   'Standard Error': Intercept        0.004193
#   qty_2014         0.004057
#   porcent_pagos    3.281809
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.003611 -0.003446      -0.194795
#   qty_2014       -0.003446  0.003380       0.028546
#   porcent_pagos  -0.194795  0.028546    2212.030154,
#   'Number of observations n.': 11690.0,
#   'R2 ajustado': 0.8230702422215964,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214003fcbb0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Início de Mestrado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Pós-Doutorado',
#   'Erro': False,
#   'Prob (F-statistic)': 1.211680127131085e-08,
#   'Parâmetros': Intercept          0.847999
#   qty_2014           0.434667
#   porcent_pagos    277.348418
#   dtype: float64,
#   'P>|t|': Intercept        0.000000e+00
#   qty_2014         7.145917e-02
#   porcent_pagos    6.608223e-09
#   dtype: float64,
#   'Standard Error': Intercept         0.014647
#   qty_2014          0.241020
#   porcent_pagos    47.620144
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000617 -0.000411      -0.984390
#   qty_2014       -0.000411  0.166941       0.656260
#   porcent_pagos  -0.984390  0.656260    6516.823967,
#   'Number of observations n.': 2140.0,
#   'R2 ajustado': 0.01599529951196821,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214003c7760>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Início de Pós-Doutorado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Obtenção do Título de Doutorado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.003983351257198384,
#   'Parâmetros': Intercept         0.973558
#   qty_2014          0.276442
#   porcent_pagos   -16.325703
#   dtype: float64,
#   'P>|t|': Intercept        0.000000
#   qty_2014         0.002510
#   porcent_pagos    0.175302
#   dtype: float64,
#   'Standard Error': Intercept         0.002561
#   qty_2014          0.091452
#   porcent_pagos    12.044519
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000098 -0.000098      -0.162579
#   qty_2014       -0.000098  0.125098       0.162579
#   porcent_pagos  -0.162579  0.162579    2169.900803,
#   'Number of observations n.': 11647.0,
#   'R2 ajustado': 0.0007770455322428926,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214003ef4c0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Obtenção do Título de Doutorado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Obtenção do Título de Metrado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept        0.367220
#   qty_2014         0.646508
#   porcent_pagos    0.583352
#   dtype: float64,
#   'P>|t|': Intercept        0.000000
#   qty_2014         0.000000
#   porcent_pagos    0.898861
#   dtype: float64,
#   'Standard Error': Intercept        0.005818
#   qty_2014         0.005704
#   porcent_pagos    4.589620
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.003579 -0.003461      -0.184911
#   qty_2014       -0.003461  0.003441       0.017767
#   porcent_pagos  -0.184911  0.017767    2227.195885,
#   'Number of observations n.': 11638.0,
#   'R2 ajustado': 0.5246303148140425,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214003d46d0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Obtenção do Título de Metrado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Trabalho em Evento',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept         2.845444
#   qty_2014          1.291200
#   porcent_pagos    69.742908
#   dtype: float64,
#   'P>|t|': Intercept        6.882607e-111
#   qty_2014          0.000000e+00
#   porcent_pagos     8.844217e-01
#   dtype: float64,
#   'Standard Error': Intercept          0.125692
#   qty_2014           0.005908
#   porcent_pagos    479.762307
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept      qty_2014  porcent_pagos
#   Intercept       0.000166 -4.676281e-06      -0.182377
#   qty_2014       -0.000005  3.660221e-07       0.000366
#   porcent_pagos  -0.182377  3.661848e-04    2413.569259,
#   'Number of observations n.': 10772.0,
#   'R2 ajustado': 0.815999805446936,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214003d49a0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Trabalho em Evento',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Artigo Publicado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept           3.071206
#   qty_2014            1.447010
#   porcent_pagos    2053.329062
#   dtype: float64,
#   'P>|t|': Intercept        0.000000e+00
#   qty_2014         0.000000e+00
#   porcent_pagos    4.442233e-13
#   dtype: float64,
#   'Standard Error': Intercept          0.071201
#   qty_2014           0.010583
#   porcent_pagos    283.221832
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000136 -0.000010      -0.179555
#   qty_2014       -0.000010  0.000003       0.004225
#   porcent_pagos  -0.179555  0.004225    2155.868433,
#   'Number of observations n.': 11340.0,
#   'R2 ajustado': 0.622423511626261,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214003c16d0>,
#   'Confiança': 0.05,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Artigo Publicado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Trabalho em Eventos',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept          2.889735
#   qty_2014           1.291126
#   porcent_pagos    226.207187
#   dtype: float64,
#   'P>|t|': Intercept        7.479798e-114
#   qty_2014          0.000000e+00
#   porcent_pagos     6.369684e-01
#   dtype: float64,
#   'Standard Error': Intercept          0.125909
#   qty_2014           0.005838
#   porcent_pagos    479.298171
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept      qty_2014  porcent_pagos
#   Intercept       0.000166 -4.623341e-06      -0.181926
#   qty_2014       -0.000005  3.563371e-07       0.000375
#   porcent_pagos  -0.181926  3.749428e-04    2401.468668,
#   'Number of observations n.': 10790.0,
#   'R2 ajustado': 0.8192683795365783,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fb3e0d0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Trabalho em Eventos',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Fim de Estágio',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept         0.126903
#   qty_2014          1.026073
#   porcent_pagos    56.149692
#   dtype: float64,
#   'P>|t|': Intercept        1.002327e-08
#   qty_2014         0.000000e+00
#   porcent_pagos    4.241911e-01
#   dtype: float64,
#   'Standard Error': Intercept         0.022065
#   qty_2014          0.006726
#   porcent_pagos    70.247501
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000971 -0.000208      -0.815321
#   qty_2014       -0.000208  0.000090       0.017753
#   porcent_pagos  -0.815321  0.017753    9845.009861,
#   'Number of observations n.': 2324.0,
#   'R2 ajustado': 0.9092472064777638,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fb3e0a0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Fim de Estágio',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Fim de Atividade de Pesquisa e Desenvolvimento',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept         0.612542
#   qty_2014          0.957625
#   porcent_pagos    80.217298
#   dtype: float64,
#   'P>|t|': Intercept        1.410101e-129
#   qty_2014          0.000000e+00
#   porcent_pagos     2.824453e-01
#   dtype: float64,
#   'Standard Error': Intercept         0.023477
#   qty_2014          0.010862
#   porcent_pagos    74.611790
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000839 -0.000223      -0.735794
#   qty_2014       -0.000223  0.000179      -0.015092
#   porcent_pagos  -0.735794 -0.015092    8470.045322,
#   'Number of observations n.': 2024.0,
#   'R2 ajustado': 0.7935500350165788,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fb260a0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Fim de Atividade de Pesquisa e Desenvolvimento',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Fim de Vínculo Empregatício ou Funcional',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept          1.013633
#   qty_2014           1.189493
#   porcent_pagos    483.245188
#   dtype: float64,
#   'P>|t|': Intercept        7.180652e-107
#   qty_2014          0.000000e+00
#   porcent_pagos     7.453464e-04
#   dtype: float64,
#   'Standard Error': Intercept          0.045696
#   qty_2014           0.005342
#   porcent_pagos    143.259972
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000219 -0.000019      -0.192094
#   qty_2014       -0.000019  0.000003       0.005447
#   porcent_pagos  -0.192094  0.005447    2148.449709,
#   'Number of observations n.': 11956.0,
#   'R2 ajustado': 0.8061441969178775,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fb38490>,
#   'Confiança': 0.05,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Fim de Vínculo Empregatício ou Funcional',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Atividade de Ensino',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept           1.481353
#   qty_2014            1.228754
#   porcent_pagos    2010.152999
#   dtype: float64,
#   'P>|t|': Intercept        4.346125e-63
#   qty_2014         0.000000e+00
#   porcent_pagos    1.333754e-06
#   dtype: float64,
#   'Standard Error': Intercept          0.087332
#   qty_2014           0.007229
#   porcent_pagos    415.362585
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000258 -0.000012      -0.394554
#   qty_2014       -0.000012  0.000002       0.011807
#   porcent_pagos  -0.394554  0.011807    5829.931268,
#   'Number of observations n.': 6074.0,
#   'R2 ajustado': 0.8274266630026491,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fb4a340>,
#   'Confiança': 0.05,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Início de Atividade de Ensino',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Estágio',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept         0.120179
#   qty_2014          1.030175
#   porcent_pagos    47.709646
#   dtype: float64,
#   'P>|t|': Intercept        2.936265e-08
#   qty_2014         0.000000e+00
#   porcent_pagos    4.952932e-01
#   dtype: float64,
#   'Standard Error': Intercept         0.021602
#   qty_2014          0.006604
#   porcent_pagos    69.953721
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000925 -0.000199      -0.778438
#   qty_2014       -0.000199  0.000086       0.014923
#   porcent_pagos  -0.778438  0.014923    9702.410968,
#   'Number of observations n.': 2428.0,
#   'R2 ajustado': 0.9093112936756859,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fb43ee0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Início de Estágio',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Atividade de Pesquisa e Desenvolvimento',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept        0.531539
#   qty_2014         0.972184
#   porcent_pagos    8.273823
#   dtype: float64,
#   'P>|t|': Intercept        5.898515e-176
#   qty_2014          0.000000e+00
#   porcent_pagos     8.937759e-01
#   dtype: float64,
#   'Standard Error': Intercept         0.017920
#   qty_2014          0.008062
#   porcent_pagos    61.959558
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000465 -0.000139      -0.358526
#   qty_2014       -0.000139  0.000094      -0.022281
#   porcent_pagos  -0.358526 -0.022281    5563.278175,
#   'Number of observations n.': 4271.0,
#   'R2 ajustado': 0.7731666667508789,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fb31460>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Início de Atividade de Pesquisa e Desenvolvimento',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Vínculo Empregatício ou Funcional',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept           1.121334
#   qty_2014            1.244064
#   porcent_pagos    1777.208265
#   dtype: float64,
#   'P>|t|': Intercept        8.740018e-65
#   qty_2014         0.000000e+00
#   porcent_pagos    9.294146e-20
#   dtype: float64,
#   'Standard Error': Intercept          0.065592
#   qty_2014           0.006228
#   porcent_pagos    195.035735
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000237 -0.000018      -0.202534
#   qty_2014       -0.000018  0.000002       0.006347
#   porcent_pagos  -0.202534  0.006347    2095.574731,
#   'Number of observations n.': 12460.0,
#   'R2 ajustado': 0.7624645642108004,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fb2f1f0>,
#   'Confiança': 0.05,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Início de Vínculo Empregatício ou Funcional',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Apresentação de Trabalho Técnico',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept          2.829113
#   qty_2014           1.303311
#   porcent_pagos   -278.407957
#   dtype: float64,
#   'P>|t|': Intercept        5.738703e-165
#   qty_2014          0.000000e+00
#   porcent_pagos     4.625480e-01
#   dtype: float64,
#   'Standard Error': Intercept          0.101634
#   qty_2014           0.005936
#   porcent_pagos    378.949844
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept      qty_2014  porcent_pagos
#   Intercept       0.000163 -5.851551e-06      -0.193604
#   qty_2014       -0.000006  5.555119e-07       0.002605
#   porcent_pagos  -0.193604  2.604850e-03    2264.128065,
#   'Number of observations n.': 11241.0,
#   'R2 ajustado': 0.8118331055872727,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fb2fa90>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Apresentação de Trabalho Técnico',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Publicação de Capítulo de Livro',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept          1.649604
#   qty_2014           1.310830
#   porcent_pagos   -493.676901
#   dtype: float64,
#   'P>|t|': Intercept        3.551374e-276
#   qty_2014          0.000000e+00
#   porcent_pagos     2.007100e-02
#   dtype: float64,
#   'Standard Error': Intercept          0.044390
#   qty_2014           0.014110
#   porcent_pagos    212.284213
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000201 -0.000029      -0.295837
#   qty_2014       -0.000029  0.000020       0.013683
#   porcent_pagos  -0.295837  0.013683    4600.442980,
#   'Number of observations n.': 7044.0,
#   'R2 ajustado': 0.5517906727460384,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fb5ad30>,
#   'Confiança': 0.05,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Publicação de Capítulo de Livro',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Livro Publicado ou Organizado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept          0.935796
#   qty_2014           1.303420
#   porcent_pagos   -201.626197
#   dtype: float64,
#   'P>|t|': Intercept        2.922141e-134
#   qty_2014          0.000000e+00
#   porcent_pagos     3.877216e-01
#   dtype: float64,
#   'Standard Error': Intercept          0.036533
#   qty_2014           0.013518
#   porcent_pagos    233.404292
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000319 -0.000045      -0.638985
#   qty_2014       -0.000045  0.000044       0.048854
#   porcent_pagos  -0.638985  0.048854   13040.549750,
#   'Number of observations n.': 4059.0,
#   'R2 ajustado': 0.6972578362477665,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fa746a0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Livro Publicado ou Organizado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Outras Orientações Concluídas',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept           5.675114
#   qty_2014            1.252583
#   porcent_pagos   -2944.574741
#   dtype: float64,
#   'P>|t|': Intercept        9.503176e-193
#   qty_2014          0.000000e+00
#   porcent_pagos     2.218178e-03
#   dtype: float64,
#   'Standard Error': Intercept          0.186431
#   qty_2014           0.007084
#   porcent_pagos    962.174342
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept      qty_2014  porcent_pagos
#   Intercept       0.000175 -3.055315e-06      -0.300661
#   qty_2014       -0.000003  2.525386e-07       0.004012
#   porcent_pagos  -0.300661  4.012297e-03    4658.259129,
#   'Number of observations n.': 8059.0,
#   'R2 ajustado': 0.7979866669591656,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fa6c490>,
#   'Confiança': 0.05,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Outras Orientações Concluídas',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Participação em Congresso',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept          1.424805
#   qty_2014           1.179114
#   porcent_pagos    312.991972
#   dtype: float64,
#   'P>|t|': Intercept        2.798026e-200
#   qty_2014          0.000000e+00
#   porcent_pagos     7.060686e-02
#   dtype: float64,
#   'Standard Error': Intercept          0.046226
#   qty_2014           0.004558
#   porcent_pagos    173.098690
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000163 -0.000010      -0.197831
#   qty_2014       -0.000010  0.000002       0.004573
#   porcent_pagos  -0.197831  0.004573    2281.283921,
#   'Number of observations n.': 11160.0,
#   'R2 ajustado': 0.8576909240043804,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fa6c550>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Participação em Congresso',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Participação em Seminário',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept          0.638549
#   qty_2014           1.182275
#   porcent_pagos   -242.970064
#   dtype: float64,
#   'P>|t|': Intercept        2.080287e-57
#   qty_2014         0.000000e+00
#   porcent_pagos    1.285722e-01
#   dtype: float64,
#   'Standard Error': Intercept          0.039704
#   qty_2014           0.005245
#   porcent_pagos    159.859767
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000212 -0.000018      -0.263460
#   qty_2014       -0.000018  0.000004       0.009205
#   porcent_pagos  -0.263460  0.009205    3444.825271,
#   'Number of observations n.': 9082.0,
#   'R2 ajustado': 0.8493664407340771,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fa8b070>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Participação em Seminário',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Participação em Simpósio',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept         0.737676
#   qty_2014          1.119992
#   porcent_pagos    81.575252
#   dtype: float64,
#   'P>|t|': Intercept        1.957522e-156
#   qty_2014          0.000000e+00
#   porcent_pagos     4.169816e-01
#   dtype: float64,
#   'Standard Error': Intercept          0.027124
#   qty_2014           0.005602
#   porcent_pagos    100.498350
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000215 -0.000028      -0.242277
#   qty_2014       -0.000028  0.000009       0.007051
#   porcent_pagos  -0.242277  0.007051    2949.071566,
#   'Number of observations n.': 8766.0,
#   'R2 ajustado': 0.8203503973407091,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fa863d0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Participação em Simpósio',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Prêmio ou Título Recebido',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept          0.926972
#   qty_2014           1.160449
#   porcent_pagos    215.359593
#   dtype: float64,
#   'P>|t|': Intercept        1.076529e-143
#   qty_2014          0.000000e+00
#   porcent_pagos     9.963249e-02
#   dtype: float64,
#   'Standard Error': Intercept          0.035484
#   qty_2014           0.007866
#   porcent_pagos    130.770307
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000253 -0.000034      -0.306421
#   qty_2014       -0.000034  0.000012       0.017651
#   porcent_pagos  -0.306421  0.017651    3429.756608,
#   'Number of observations n.': 7078.0,
#   'R2 ajustado': 0.7556227978741479,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fa6f0a0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Prêmio ou Título Recebido',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Conclusão de Outra Formação Complementar',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept          0.620493
#   qty_2014           1.089655
#   porcent_pagos   -142.311418
#   dtype: float64,
#   'P>|t|': Intercept        2.258196e-75
#   qty_2014         0.000000e+00
#   porcent_pagos    3.379407e-01
#   dtype: float64,
#   'Standard Error': Intercept          0.033357
#   qty_2014           0.005429
#   porcent_pagos    148.502515
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000236 -0.000021      -0.326495
#   qty_2014       -0.000021  0.000006       0.006887
#   porcent_pagos  -0.326495  0.006887    4669.057622,
#   'Number of observations n.': 6797.0,
#   'R2 ajustado': 0.8558769814606103,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fa6f490>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Conclusão de Outra Formação Complementar',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Outra Formação Complementar',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept          0.608346
#   qty_2014           1.090428
#   porcent_pagos   -145.967093
#   dtype: float64,
#   'P>|t|': Intercept        3.656793e-74
#   qty_2014         0.000000e+00
#   porcent_pagos    3.199929e-01
#   dtype: float64,
#   'Standard Error': Intercept          0.032990
#   qty_2014           0.005366
#   porcent_pagos    146.767879
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000233 -0.000021      -0.321051
#   qty_2014       -0.000021  0.000006       0.006803
#   porcent_pagos  -0.321051  0.006803    4603.482580,
#   'Number of observations n.': 6923.0,
#   'R2 ajustado': 0.856673144905883,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147ed50310>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Início de Outra Formação Complementar',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Organização de Evento',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept          1.291155
#   qty_2014           1.213399
#   porcent_pagos   -110.888293
#   dtype: float64,
#   'P>|t|': Intercept        6.526783e-146
#   qty_2014          0.000000e+00
#   porcent_pagos     6.034081e-01
#   dtype: float64,
#   'Standard Error': Intercept          0.049217
#   qty_2014           0.006660
#   porcent_pagos    213.441589
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000196 -0.000015      -0.276772
#   qty_2014       -0.000015  0.000004       0.008754
#   porcent_pagos  -0.276772  0.008754    3677.808397,
#   'Number of observations n.': 8477.0,
#   'R2 ajustado': 0.7975766691671826,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147ed4b490>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Organização de Evento',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Outras Participações em Congressos',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept          0.789790
#   qty_2014           1.158787
#   porcent_pagos   -373.038264
#   dtype: float64,
#   'P>|t|': Intercept        8.782919e-61
#   qty_2014         0.000000e+00
#   porcent_pagos    4.881942e-02
#   dtype: float64,
#   'Standard Error': Intercept          0.047685
#   qty_2014           0.003808
#   porcent_pagos    189.319890
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000185 -0.000009      -0.238944
#   qty_2014       -0.000009  0.000001       0.005190
#   porcent_pagos  -0.238944  0.005190    2908.990027,
#   'Number of observations n.': 9736.0,
#   'R2 ajustado': 0.9056676240500956,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147ed38430>,
#   'Confiança': 0.05,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Outras Participações em Congressos',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Participação em Banca de Graduação',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept           5.444249
#   qty_2014            1.208923
#   porcent_pagos   -2768.188196
#   dtype: float64,
#   'P>|t|': Intercept        4.942405e-205
#   qty_2014          0.000000e+00
#   porcent_pagos     2.155162e-03
#   dtype: float64,
#   'Standard Error': Intercept          0.173050
#   qty_2014           0.006699
#   porcent_pagos    901.994768
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept      qty_2014  porcent_pagos
#   Intercept       0.000175 -3.063959e-06      -0.320555
#   qty_2014       -0.000003  2.623217e-07       0.004446
#   porcent_pagos  -0.320555  4.446128e-03    4756.081481,
#   'Number of observations n.': 8074.0,
#   'R2 ajustado': 0.8046015822049104,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147ed50130>,
#   'Confiança': 0.05,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Participação em Banca de Graduação',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Conclusão de Especialização',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept         0.238029
#   qty_2014          0.948469
#   porcent_pagos    17.381493
#   dtype: float64,
#   'P>|t|': Intercept        1.410782e-96
#   qty_2014         0.000000e+00
#   porcent_pagos    7.138187e-01
#   dtype: float64,
#   'Standard Error': Intercept         0.011202
#   qty_2014          0.006736
#   porcent_pagos    47.393294
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000561 -0.000278      -0.519587
#   qty_2014       -0.000278  0.000203       0.146586
#   porcent_pagos  -0.519587  0.146586   10046.186591,
#   'Number of observations n.': 5849.0,
#   'R2 ajustado': 0.773985381093699,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147ed54880>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Conclusão de Especialização',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Conclusão de Extensão Universitária',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept         0.353666
#   qty_2014          1.061708
#   porcent_pagos   -99.702522
#   dtype: float64,
#   'P>|t|': Intercept        7.420657e-43
#   qty_2014         0.000000e+00
#   porcent_pagos    3.628358e-01
#   dtype: float64,
#   'Standard Error': Intercept          0.025558
#   qty_2014           0.005065
#   porcent_pagos    109.557431
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000297 -0.000034      -0.365042
#   qty_2014       -0.000034  0.000012       0.008744
#   porcent_pagos  -0.365042  0.008744    5453.769093,
#   'Number of observations n.': 5685.0,
#   'R2 ajustado': 0.8855948693439482,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147ed4ac10>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Conclusão de Extensão Universitária',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Especialização',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept         0.248245
#   qty_2014          0.961676
#   porcent_pagos    37.046841
#   dtype: float64,
#   'P>|t|': Intercept        5.341120e-96
#   qty_2014         0.000000e+00
#   porcent_pagos    4.563935e-01
#   dtype: float64,
#   'Standard Error': Intercept         0.011728
#   qty_2014          0.006843
#   porcent_pagos    49.737562
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000527 -0.000251      -0.514110
#   qty_2014       -0.000251  0.000180       0.142729
#   porcent_pagos  -0.514110  0.142729    9486.661300,
#   'Number of observations n.': 6060.0,
#   'R2 ajustado': 0.7671451368770652,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147ed54550>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Início de Especialização',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Início de Extensão Universitária',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept         0.387972
#   qty_2014          1.058810
#   porcent_pagos   -84.556490
#   dtype: float64,
#   'P>|t|': Intercept        1.243950e-65
#   qty_2014         0.000000e+00
#   porcent_pagos    3.915353e-01
#   dtype: float64,
#   'Standard Error': Intercept         0.022461
#   qty_2014          0.004704
#   porcent_pagos    98.679003
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.000214 -0.000026      -0.265368
#   qty_2014       -0.000026  0.000009       0.006929
#   porcent_pagos  -0.265368  0.006929    4134.268187,
#   'Number of observations n.': 7762.0,
#   'R2 ajustado': 0.8673283397986618,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147fa6f100>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Início de Extensão Universitária',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Fim de Atividade de Ensino',
# ...
#   dtype: float64,
#   'Standard Error': Intercept          0.099449
#   qty_2014           0.061482
#   porcent_pagos    373.076613
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.007381 -0.002501      -8.412835
#   qty_2014       -0.002501  0.002821      -0.385802
#   porcent_pagos  -8.412835 -0.385802  103875.712925,
#   'Number of observations n.': 226.0,
#   'R2 ajustado': 0.4611585143185142,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147646a820>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Participação em Olimpíada',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Desenvolvimento de Marca',
#   'Erro': False,
#   'Prob (F-statistic)': 8.315398284967645e-71,
#   'Parâmetros': Intercept          0.568140
#   qty_2014           1.019300
#   porcent_pagos    927.379258
#   dtype: float64,
#   'P>|t|': Intercept        3.377595e-08
#   qty_2014         8.747648e-72
#   porcent_pagos    1.610631e-01
#   dtype: float64,
#   'Standard Error': Intercept          0.091047
#   qty_2014           0.011260
#   porcent_pagos    654.382362
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.017434 -0.000403     -49.217111
#   qty_2014       -0.000403  0.000267       0.982730
#   porcent_pagos -49.217111  0.982730  900597.071592,
#   'Number of observations n.': 70.0,
#   'R2 ajustado': 0.9916664413038918,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x21476461400>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Desenvolvimento de Marca',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Obtenção do Título de MBA',
#   'Erro': False,
#   'Prob (F-statistic)': 1.7255406926076966e-45,
#   'Parâmetros': Intercept        2.220446e-16
#   qty_2014         1.000000e+00
#   porcent_pagos    0.000000e+00
#   dtype: float64,
#   'P>|t|': Intercept        8.812704e-01
#   qty_2014         1.725541e-45
#   porcent_pagos             NaN
#   dtype: float64,
#   'Standard Error': Intercept        1.366772e-15
#   qty_2014         9.214777e-16
#   porcent_pagos    0.000000e+00
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       1.833333 -1.166667            0.0
#   qty_2014       -1.166667  0.833333            0.0
#   porcent_pagos   0.000000  0.000000            0.0,
#   'Number of observations n.': 5.0,
#   'R2 ajustado': 1.0,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x21476491ac0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Obtenção do Título de MBA',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Orientação em Andamento de Pós-Doutorado',
#   'Erro': True,
#   'Prob (F-statistic)': None,
#   'Parâmetros': None,
#   'P>|t|': None,
#   'Standard Error': None,
#   'Covariância entre os pasrâmetros': None,
#   'Number of observations n.': None,
#   'R2 ajustado': None,
#   'Modelo': None,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Orientação em Andamento de Pós-Doutorado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Participação em Banca Julgadora para Livre Docência',
#   'Erro': False,
#   'Prob (F-statistic)': 1.0209310937121734e-36,
#   'Parâmetros': Intercept           0.792119
#   qty_2014            1.004687
#   porcent_pagos    8484.696962
#   dtype: float64,
#   'P>|t|': Intercept        2.538783e-03
#   qty_2014         1.059883e-37
#   porcent_pagos    2.224842e-02
#   dtype: float64,
#   'Standard Error': Intercept           0.251913
#   qty_2014            0.035262
#   porcent_pagos    3619.833107
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.018620 -0.001027  -5.555314e+01
#   qty_2014       -0.001027  0.000365   3.064411e+00
#   porcent_pagos -55.553142  3.064411   3.844589e+06,
#   'Number of observations n.': 66.0,
#   'R2 ajustado': 0.925697869731568,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x21476472be0>,
#   'Confiança': 0.05,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Participação em Banca Julgadora para Livre Docência',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Manutenção de Obra Artística',
#   'Erro': False,
#   'Prob (F-statistic)': 8.100987112678477e-40,
#   'Parâmetros': Intercept          0.067342
#   qty_2014           1.040377
#   porcent_pagos   -331.589703
#   dtype: float64,
#   'P>|t|': Intercept        7.633933e-01
#   qty_2014         2.063520e-40
#   porcent_pagos    7.956525e-01
#   dtype: float64,
#   'Standard Error': Intercept           0.221610
#   qty_2014            0.008845
#   porcent_pagos    1268.647029
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                 Intercept  qty_2014  porcent_pagos
#   Intercept        0.048444 -0.000892  -1.270696e+02
#   qty_2014        -0.000892  0.000077   2.112970e+00
#   porcent_pagos -127.069571  2.112970   1.587606e+06,
#   'Number of observations n.': 32.0,
#   'R2 ajustado': 0.9978472143228302,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x21476463100>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Manutenção de Obra Artística',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Publicação de Partitura Musical',
#   'Erro': False,
#   'Prob (F-statistic)': 2.408101848125626e-12,
#   'Parâmetros': Intercept            0.261648
#   qty_2014             1.173226
#   porcent_pagos   -14053.594912
#   dtype: float64,
#   'P>|t|': Intercept        7.488634e-01
#   qty_2014         9.275293e-13
#   porcent_pagos    1.772725e-01
#   dtype: float64,
#   'Standard Error': Intercept           0.804130
#   qty_2014            0.062877
#   porcent_pagos    9984.095658
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept   qty_2014  porcent_pagos
#   Intercept       0.073516  -0.002932  -4.461606e+01
#   qty_2014       -0.002932   0.000449  -2.515217e+01
#   porcent_pagos -44.616057 -25.152167   1.133311e+07,
#   'Number of observations n.': 20.0,
#   'R2 ajustado': 0.9519777065416674,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x214764676a0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Publicação de Partitura Musical',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Maquete',
#   'Erro': False,
#   'Prob (F-statistic)': 7.995689606026436e-55,
#   'Parâmetros': Intercept           0.280822
#   qty_2014            1.099898
#   porcent_pagos   -1506.512848
#   dtype: float64,
#   'P>|t|': Intercept        9.553881e-02
#   qty_2014         1.026490e-55
#   porcent_pagos    5.293927e-01
#   dtype: float64,
#   'Standard Error': Intercept           0.164493
#   qty_2014            0.007737
#   porcent_pagos    2374.479234
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.025708 -0.000271  -8.133577e+01
#   qty_2014       -0.000271  0.000057   5.116847e-01
#   porcent_pagos -81.335769  0.511685   5.356794e+06,
#   'Number of observations n.': 43.0,
#   'R2 ajustado': 0.9979282750544901,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x21474592310>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Maquete',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Outras participações em Banca',
#   'Erro': False,
#   'Prob (F-statistic)': 2.1586948735196703e-125,
#   'Parâmetros': Intercept       -6.661338e-16
#   qty_2014         1.000000e+00
#   porcent_pagos    0.000000e+00
#   dtype: float64,
#   'P>|t|': Intercept         5.757842e-01
#   qty_2014         2.158695e-125
#   porcent_pagos              NaN
#   dtype: float64,
#   'Standard Error': Intercept        1.142077e-15
#   qty_2014         1.085480e-16
#   porcent_pagos    0.000000e+00
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.203306 -0.013774            0.0
#   qty_2014       -0.013774  0.001837            0.0
#   porcent_pagos   0.000000  0.000000            0.0,
#   'Number of observations n.': 10.0,
#   'R2 ajustado': 1.0,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x21474579700>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Outras participações em Banca',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Curso de Curta Duração Realizado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': Intercept       -1.443290e-15
#   qty_2014         1.000000e+00
#   porcent_pagos    0.000000e+00
#   dtype: float64,
#   'P>|t|': Intercept        0.000274
#   qty_2014         0.000000
#   porcent_pagos         NaN
#   dtype: float64,
#   'Standard Error': Intercept        3.309370e-16
#   qty_2014         3.771377e-17
#   porcent_pagos    0.000000e+00
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                Intercept  qty_2014  porcent_pagos
#   Intercept       0.059614 -0.003534            0.0
#   qty_2014       -0.003534  0.000774            0.0
#   porcent_pagos   0.000000  0.000000            0.0,
#   'Number of observations n.': 23.0,
#   'R2 ajustado': 1.0,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2147456f4f0>,
#   'Confiança': 0.05,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Curso de Curta Duração Realizado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Solicitação de Cultivar Registrada',
#   'Erro': True,
#   'Prob (F-statistic)': None,
#   'Parâmetros': None,
#   'P>|t|': None,
#   'Standard Error': None,
#   'Covariância entre os pasrâmetros': None,
#   'Number of observations n.': None,
#   'R2 ajustado': None,
#   'Modelo': None,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Solicitação de Cultivar Registrada',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Obtenção do Título de Livre Docência',
#   'Erro': True,
#   'Prob (F-statistic)': None,
#   'Parâmetros': None,
#   'P>|t|': None,
#   'Standard Error': None,
#   'Covariância entre os pasrâmetros': None,
#   'Number of observations n.': None,
#   'R2 ajustado': None,
#   'Modelo': None,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Obtenção do Título de Livre Docência',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Orientação Concluída de Pós-Doutorado',
#   'Erro': True,
#   'Prob (F-statistic)': None,
#   'Parâmetros': None,
#   'P>|t|': None,
#   'Standard Error': None,
#   'Covariância entre os pasrâmetros': None,
#   'Number of observations n.': None,
#   'R2 ajustado': None,
#   'Modelo': None,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Orientação Concluída de Pós-Doutorado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Solicitação de Cultivar protegida',
#   'Erro': False,
#   'Prob (F-statistic)': 0.049906512850594976,
#   'Parâmetros': Intercept           1.500000
#   qty_2014            1.375000
#   porcent_pagos    1643.637974
#   dtype: float64,
#   'P>|t|': Intercept        0.204833
#   qty_2014         0.033383
#   porcent_pagos    0.666667
#   dtype: float64,
#   'Standard Error': Intercept           0.500000
#   qty_2014            0.072169
#   porcent_pagos    2846.864480
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                  Intercept    qty_2014  porcent_pagos
#   Intercept         0.500000   -0.041667  -1.643638e+03
#   qty_2014         -0.041667    0.010417   1.369698e+02
#   porcent_pagos -1643.637974  136.969831   1.620927e+07,
#   'Number of observations n.': 4.0,
#   'R2 ajustado': 0.9925280199252802,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x21474569310>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Solicitação de Cultivar protegida',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}},
#  {'Indicador': 'Desenvolvimento de Topografia de Circuito Integrado',
#   'Erro': True,
#   'Prob (F-statistic)': None,
#   'Parâmetros': None,
#   'P>|t|': None,
#   'Standard Error': None,
#   'Covariância entre os pasrâmetros': None,
#   'Number of observations n.': None,
#   'R2 ajustado': None,
#   'Modelo': None,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'porcent_pagos'],
#    'confianças': [0.05],
#    'indicador': 'Desenvolvimento de Topografia de Circuito Integrado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': False,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': False,
#    'preenche_todos_ids': False,
#    'verbose': False}}]
