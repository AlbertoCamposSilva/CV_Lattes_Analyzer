# %%
from datetime import datetime

print('Início em: ', datetime.now())
print('Importações Iniciais')

from Regressao import Regressao
reg = Regressao()

print('Fim: ', datetime.now())
# Out:
# Início em:  2023-04-25 20:05:25.551222
# Importações Iniciais
# Fim:  2023-04-25 20:05:28.935191

# %%
reg.path = ''
reg.variável_dependente = 'qty_2019'
reg.variáveis_independentes = ['qty_2014', 'C(grupo)', '-1']
reg.confianças = [0.01, 0.05]
reg.indicador = 'Artigo Publicado'
reg.ano_início = 2014
reg.best_r2 = False
reg.pareamento = False
reg.capes = True
reg.cnpq = True
reg.nenhum = True
reg.ambos = True
reg.preenche_todos_ids = True
reg.drop_not_significant = False

reg.verbose = False
#reg.faz_apenas_os_indicadores = ['Conclusão de Curso de Curta Duração']

# %%
Regressao.pd = reg.pega_tabela_para_regressão()
# Out:
# Carregando indicadores na memória. Início em:  2023-04-25 20:05:28.965190
# Fim em:  2023-04-25 20:05:55.777339

# %%
reg.faz_regressões()
# Out:
# Iniciado em 2023-04-25 20:05:55.791194.
# 0/130. Fazendo: Prêmio ou Título Recebido.
# 1/130. 0.8% feitos. Fazendo: Conclusão de Doutorado. Acabará em 26/04/23 01:10:57. O Último demorou: 0:02:20.491341.
# 2/130. 1.5% feitos. Fazendo: Conclusão de Especialização. Acabará em 25/04/23 22:54:28. O Último demorou: 0:00:14.794547.
# 3/130. 2.3% feitos. Fazendo: Conclusão de Graduação. Acabará em 26/04/23 00:02:40. O Último demorou: 0:02:52.215710.
# 4/130. 3.1% feitos. Fazendo: Conclusão de Mestrado. Acabará em 25/04/23 23:05:44. O Último demorou: 0:00:04.153998.
# 5/130. 3.8% feitos. Fazendo: Início de Doutorado. Acabará em 25/04/23 22:37:51. O Último demorou: 0:00:18.662002.
# 6/130. 4.6% feitos. Fazendo: Início de Especialização. Acabará em 25/04/23 22:12:54. O Último demorou: 0:00:01.004998.
# 7/130. 5.4% feitos. Fazendo: Início de Graduação. Acabará em 25/04/23 22:40:17. O Último demorou: 0:02:27.070591.
# 8/130. 6.2% feitos. Fazendo: Início de Mestrado. Acabará em 25/04/23 22:22:06. O Último demorou: 0:00:04.102001.
# 9/130. 6.9% feitos. Fazendo: Obtenção do Título de Doutorado. Acabará em 25/04/23 22:10:41. O Último demorou: 0:00:15.445001.
# 10/130. 7.7% feitos. Fazendo: Obtenção do Título de Metrado. Acabará em 25/04/23 22:01:16. O Último demorou: 0:00:14.153163.
# 11/130. 8.5% feitos. Fazendo: Trabalho em Evento. Acabará em 25/04/23 21:53:54. O Último demorou: 0:00:15.795000.
# 12/130. 9.2% feitos. Fazendo: Artigo Publicado. Acabará em 25/04/23 21:50:35. O Último demorou: 0:00:31.455001.
# 13/130. 10.0% feitos. Fazendo: Trabalho em Eventos. Acabará em 25/04/23 21:46:28. O Último demorou: 0:00:23.616001.
# 14/130. 10.8% feitos. Fazendo: Fim de Participação em Direção ou Administração. Acabará em 25/04/23 21:44:25. O Último demorou: 0:00:33.157001.
# 15/130. 11.5% feitos. Fazendo: Fim de Atividade de Ensino. Acabará em 25/04/23 22:04:46. O Último demorou: 0:03:06.332204.
# 125/130. 96.2% feitos. Fazendo: Outras participações em Banca. Acabará em 26/04/23 01:40:48. O Último demorou: 0:04:24.253235.
# 126/130. 96.9% feitos. Fazendo: Curso de Curta Duração Realizado. Acabará em 26/04/23 01:42:35. O Último demorou: 0:04:18.961162.
# 127/130. 97.7% feitos. Fazendo: Orientação Concluída de Pós-Doutorado. Acabará em 26/04/23 01:43:49. O Último demorou: 0:03:47.405548.
# 128/130. 98.5% feitos. Fazendo: Obtenção do Título de Livre Docência. Acabará em 26/04/23 01:45:07. O Último demorou: 0:03:52.319896.
# 129/130. 99.2% feitos. Fazendo: Desenvolvimento de Topografia de Circuito Integrado. Acabará em 26/04/23 01:46:49. O Último demorou: 0:04:17.804519.
# [{'Indicador': 'Prêmio ou Título Recebido',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': C(grupo)[Ambos]     1.191844
#   C(grupo)[CAPES]     1.104001
#   C(grupo)[CNPq]      1.032455
#   C(grupo)[Nenhum]    0.937019
#   qty_2014            1.155547
#   dtype: float64,
#   'P>|t|': C(grupo)[Ambos]      6.300963e-15
#   C(grupo)[CAPES]     1.536203e-211
#   C(grupo)[CNPq]       1.249593e-67
#   C(grupo)[Nenhum]    7.105796e-164
#   qty_2014             0.000000e+00
#   dtype: float64,
#   'Standard Error': C(grupo)[Ambos]     0.152644
#   C(grupo)[CAPES]     0.034842
#   C(grupo)[CNPq]      0.059037
#   C(grupo)[Nenhum]    0.033806
#   qty_2014            0.006289
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[Ambos]  C(grupo)[CAPES]  C(grupo)[CNPq]  \
#   C(grupo)[Ambos]          0.004923         0.000028        0.000025
#   C(grupo)[CAPES]          0.000028         0.000257        0.000033
#   C(grupo)[CNPq]           0.000025         0.000033        0.000736
#   C(grupo)[Nenhum]         0.000037         0.000048        0.000044
#   qty_2014                -0.000013        -0.000017       -0.000016
#
#                     C(grupo)[Nenhum]  qty_2014
#   C(grupo)[Ambos]           0.000037 -0.000013
#   C(grupo)[CAPES]           0.000048 -0.000017
#   C(grupo)[CNPq]            0.000044 -0.000016
#   C(grupo)[Nenhum]          0.000241 -0.000023
#   qty_2014                 -0.000023  0.000008  ,
#   'Number of observations n.': 11803.0,
#   'R2 ajustado': 0.7430175664463361,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x22566661fd0>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Prêmio ou Título Recebido',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Conclusão de Doutorado',
#   'Erro': False,
#   'Prob (F-statistic)': 2.13986895039013e-26,
#   'Parâmetros': C(grupo)[Ambos]     1.060803
#   C(grupo)[CAPES]     0.995638
#   C(grupo)[CNPq]      0.989603
#   C(grupo)[Nenhum]    0.978532
#   qty_2014            0.329773
#   dtype: float64,
#   'P>|t|': C(grupo)[Ambos]     0.000000e+00
#   C(grupo)[CAPES]     0.000000e+00
#   C(grupo)[CNPq]      0.000000e+00
#   C(grupo)[Nenhum]    0.000000e+00
#   qty_2014            1.106291e-17
#   dtype: float64,
#   'Standard Error': C(grupo)[Ambos]     0.012934
#   C(grupo)[CAPES]     0.002734
#   C(grupo)[CNPq]      0.005087
#   C(grupo)[Nenhum]    0.002521
#   qty_2014            0.038479
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[Ambos]  C(grupo)[CAPES]  C(grupo)[CNPq]  \
#   C(grupo)[Ambos]      2.764111e-03     1.001665e-07    3.467499e-07
#   C(grupo)[CAPES]      1.001665e-07     1.235085e-04    2.066995e-08
#   C(grupo)[CNPq]       3.467499e-07     2.066995e-08    4.276047e-04
#   C(grupo)[Nenhum]     6.373491e-07     3.799273e-08    1.315208e-07
#   qty_2014            -2.027620e-04    -1.208676e-05   -4.184115e-05
#
#                     C(grupo)[Nenhum]  qty_2014
#   C(grupo)[Ambos]       6.373491e-07 -0.000203
#   C(grupo)[CAPES]       3.799273e-08 -0.000012
#   C(grupo)[CNPq]        1.315208e-07 -0.000042
#   C(grupo)[Nenhum]      1.050196e-04 -0.000077
#   qty_2014             -7.690679e-05  0.024467  ,
#   'Number of observations n.': 20342.0,
#   'R2 ajustado': 0.0060070257520998815,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2257d5eec40>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Conclusão de Doutorado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Conclusão de Especialização',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': C(grupo)[Ambos]     0.303896
#   C(grupo)[CAPES]     0.292641
#   C(grupo)[CNPq]      0.304724
#   C(grupo)[Nenhum]    0.273766
#   qty_2014            0.920240
#   dtype: float64,
#   'P>|t|': C(grupo)[Ambos]      3.933091e-08
#   C(grupo)[CAPES]     2.290040e-155
#   C(grupo)[CNPq]       2.132062e-46
#   C(grupo)[Nenhum]    7.501086e-149
#   qty_2014             0.000000e+00
#   dtype: float64,
#   'Standard Error': C(grupo)[Ambos]     0.055267
#   C(grupo)[CAPES]     0.010799
#   C(grupo)[CNPq]      0.021182
#   C(grupo)[Nenhum]    0.010333
#   qty_2014            0.005834
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[Ambos]  C(grupo)[CAPES]  C(grupo)[CNPq]  \
#   C(grupo)[Ambos]          0.013821         0.000146        0.000131
#   C(grupo)[CAPES]          0.000146         0.000528        0.000157
#   C(grupo)[CNPq]           0.000131         0.000157        0.002030
#   C(grupo)[Nenhum]         0.000190         0.000227        0.000203
#   qty_2014                -0.000137        -0.000164       -0.000147
#
#                     C(grupo)[Nenhum]  qty_2014
#   C(grupo)[Ambos]           0.000190 -0.000137
#   C(grupo)[CAPES]           0.000227 -0.000164
#   C(grupo)[CNPq]            0.000203 -0.000147
#   C(grupo)[Nenhum]          0.000483 -0.000213
#   qty_2014                 -0.000213  0.000154  ,
#   'Number of observations n.': 8760.0,
#   'R2 ajustado': 0.7458086053676137,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2257d5b4160>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Conclusão de Especialização',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Conclusão de Graduação',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': C(grupo)[Ambos]     0.020928
#   C(grupo)[CAPES]     0.025288
#   C(grupo)[CNPq]      0.016024
#   C(grupo)[Nenhum]    0.010444
#   qty_2014            1.019378
#   dtype: float64,
#   'P>|t|': C(grupo)[Ambos]     7.034313e-02
#   C(grupo)[CAPES]     1.075706e-08
#   C(grupo)[CNPq]      4.816908e-03
#   C(grupo)[Nenhum]    1.858069e-02
#   qty_2014            0.000000e+00
#   dtype: float64,
#   'Standard Error': C(grupo)[Ambos]     0.011564
#   C(grupo)[CAPES]     0.004421
#   C(grupo)[CNPq]      0.005684
#   C(grupo)[Nenhum]    0.004437
#   qty_2014            0.003219
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[Ambos]  C(grupo)[CAPES]  C(grupo)[CNPq]  \
#   C(grupo)[Ambos]          0.003001         0.000311        0.000307
#   C(grupo)[CAPES]          0.000311         0.000438        0.000313
#   C(grupo)[CNPq]           0.000307         0.000313        0.000725
#   C(grupo)[Nenhum]         0.000323         0.000329        0.000324
#   qty_2014                -0.000266        -0.000271       -0.000268
#
#                     C(grupo)[Nenhum]  qty_2014
#   C(grupo)[Ambos]           0.000323 -0.000266
#   C(grupo)[CAPES]           0.000329 -0.000271
#   C(grupo)[CNPq]            0.000324 -0.000268
#   C(grupo)[Nenhum]          0.000442 -0.000282
#   qty_2014                 -0.000282  0.000233  ,
#   'Number of observations n.': 20959.0,
#   'R2 ajustado': 0.8273739374556118,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x22566731160>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Conclusão de Graduação',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Conclusão de Mestrado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': C(grupo)[Ambos]     0.216770
#   C(grupo)[CAPES]     0.216098
#   C(grupo)[CNPq]      0.216733
#   C(grupo)[Nenhum]    0.222351
#   qty_2014            0.790379
#   dtype: float64,
#   'P>|t|': C(grupo)[Ambos]     1.423316e-281
#   C(grupo)[CAPES]      0.000000e+00
#   C(grupo)[CNPq]       0.000000e+00
#   C(grupo)[Nenhum]     0.000000e+00
#   qty_2014             0.000000e+00
#   dtype: float64,
#   'Standard Error': C(grupo)[Ambos]     0.005948
#   C(grupo)[CAPES]     0.004170
#   C(grupo)[CNPq]      0.004406
#   C(grupo)[Nenhum]    0.004171
#   qty_2014            0.004021
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[Ambos]  C(grupo)[CAPES]  C(grupo)[CNPq]  \
#   C(grupo)[Ambos]          0.005054         0.002321        0.002314
#   C(grupo)[CAPES]          0.002321         0.002484        0.002351
#   C(grupo)[CNPq]           0.002314         0.002351        0.002773
#   C(grupo)[Nenhum]         0.002331         0.002368        0.002361
#   qty_2014                -0.002297        -0.002334       -0.002327
#
#                     C(grupo)[Nenhum]  qty_2014
#   C(grupo)[Ambos]           0.002331 -0.002297
#   C(grupo)[CAPES]           0.002368 -0.002334
#   C(grupo)[CNPq]            0.002361 -0.002327
#   C(grupo)[Nenhum]          0.002485 -0.002344
#   qty_2014                 -0.002344  0.002310  ,
#   'Number of observations n.': 19984.0,
#   'R2 ajustado': 0.6595685988277991,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x225667313a0>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Conclusão de Mestrado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Início de Doutorado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': C(grupo)[Ambos]     0.057645
#   C(grupo)[CAPES]     0.029320
#   C(grupo)[CNPq]      0.039440
#   C(grupo)[Nenhum]    0.031979
#   qty_2014            0.993685
#   dtype: float64,
#   'P>|t|': C(grupo)[Ambos]     0.000183
#   C(grupo)[CAPES]     0.019679
#   C(grupo)[CNPq]      0.002183
#   C(grupo)[Nenhum]    0.010733
#   qty_2014            0.000000
#   dtype: float64,
#   'Standard Error': C(grupo)[Ambos]     0.015403
#   C(grupo)[CAPES]     0.012570
#   C(grupo)[CNPq]      0.012870
#   C(grupo)[Nenhum]    0.012533
#   qty_2014            0.012355
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[Ambos]  C(grupo)[CAPES]  C(grupo)[CNPq]  \
#   C(grupo)[Ambos]          0.008853         0.005967        0.005963
#   C(grupo)[CAPES]          0.005967         0.005896        0.005771
#   C(grupo)[CNPq]           0.005963         0.005771        0.006181
#   C(grupo)[Nenhum]         0.005961         0.005769        0.005765
#   qty_2014                -0.005926        -0.005735       -0.005732
#
#                     C(grupo)[Nenhum]  qty_2014
#   C(grupo)[Ambos]           0.005961 -0.005926
#   C(grupo)[CAPES]           0.005769 -0.005735
#   C(grupo)[CNPq]            0.005765 -0.005732
#   C(grupo)[Nenhum]          0.005862 -0.005730
#   qty_2014                 -0.005730  0.005696  ,
#   'Number of observations n.': 21250.0,
#   'R2 ajustado': 0.2347767008834427,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x22566740cd0>,
#   'Confiança': 0.05,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Início de Doutorado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Início de Especialização',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': C(grupo)[Ambos]     0.327839
#   C(grupo)[CAPES]     0.311764
#   C(grupo)[CNPq]      0.334245
#   C(grupo)[Nenhum]    0.292607
#   qty_2014            0.927401
#   dtype: float64,
#   'P>|t|': C(grupo)[Ambos]      8.735912e-09
#   C(grupo)[CAPES]     1.128952e-163
#   C(grupo)[CNPq]       5.834988e-52
#   C(grupo)[Nenhum]    1.513355e-155
#   qty_2014             0.000000e+00
#   dtype: float64,
#   'Standard Error': C(grupo)[Ambos]     0.056927
#   C(grupo)[CAPES]     0.011204
#   C(grupo)[CNPq]      0.021899
#   C(grupo)[Nenhum]    0.010801
#   qty_2014            0.005898
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[Ambos]  C(grupo)[CAPES]  C(grupo)[CNPq]  \
#   C(grupo)[Ambos]          0.012610         0.000132        0.000117
#   C(grupo)[CAPES]          0.000132         0.000488        0.000140
#   C(grupo)[CNPq]           0.000117         0.000140        0.001866
#   C(grupo)[Nenhum]         0.000173         0.000208        0.000183
#   qty_2014                -0.000122        -0.000147       -0.000129
#
#                     C(grupo)[Nenhum]  qty_2014
#   C(grupo)[Ambos]           0.000173 -0.000122
#   C(grupo)[CAPES]           0.000208 -0.000147
#   C(grupo)[CNPq]            0.000183 -0.000129
#   C(grupo)[Nenhum]          0.000454 -0.000192
#   qty_2014                 -0.000192  0.000135  ,
#   'Number of observations n.': 9172.0,
#   'R2 ajustado': 0.7359516589161244,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x22566930970>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Início de Especialização',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Início de Graduação',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': C(grupo)[Ambos]     0.034572
#   C(grupo)[CAPES]     0.022349
#   C(grupo)[CNPq]      0.012931
#   C(grupo)[Nenhum]    0.008188
#   qty_2014            1.030345
#   dtype: float64,
#   'P>|t|': C(grupo)[Ambos]     0.008435
#   C(grupo)[CAPES]     0.000005
#   C(grupo)[CNPq]      0.041785
#   C(grupo)[Nenhum]    0.092843
#   qty_2014            0.000000
#   dtype: float64,
#   'Standard Error': C(grupo)[Ambos]     0.013123
#   C(grupo)[CAPES]     0.004877
#   C(grupo)[CNPq]      0.006352
#   C(grupo)[Nenhum]    0.004872
#   qty_2014            0.003421
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[Ambos]  C(grupo)[CAPES]  C(grupo)[CNPq]  \
#   C(grupo)[Ambos]          0.002961         0.000280        0.000275
#   C(grupo)[CAPES]          0.000280         0.000409        0.000283
#   C(grupo)[CNPq]           0.000275         0.000283        0.000694
#   C(grupo)[Nenhum]         0.000290         0.000298        0.000293
#   qty_2014                -0.000234        -0.000241       -0.000237
#
#                     C(grupo)[Nenhum]  qty_2014
#   C(grupo)[Ambos]           0.000290 -0.000234
#   C(grupo)[CAPES]           0.000298 -0.000241
#   C(grupo)[CNPq]            0.000293 -0.000237
#   C(grupo)[Nenhum]          0.000408 -0.000249
#   qty_2014                 -0.000249  0.000201  ,
#   'Number of observations n.': 20992.0,
#   'R2 ajustado': 0.8122997075545563,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2256693a250>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Início de Graduação',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Início de Mestrado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': C(grupo)[Ambos]     0.046409
#   C(grupo)[CAPES]     0.049040
#   C(grupo)[CNPq]      0.048941
#   C(grupo)[Nenhum]    0.052263
#   qty_2014            0.953719
#   dtype: float64,
#   'P>|t|': C(grupo)[Ambos]     2.697002e-26
#   C(grupo)[CAPES]     2.525793e-56
#   C(grupo)[CNPq]      1.195754e-50
#   C(grupo)[Nenhum]    2.758446e-63
#   qty_2014            0.000000e+00
#   dtype: float64,
#   'Standard Error': C(grupo)[Ambos]     0.004368
#   C(grupo)[CAPES]     0.003092
#   C(grupo)[CNPq]      0.003261
#   C(grupo)[Nenhum]    0.003101
#   qty_2014            0.002975
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[Ambos]  C(grupo)[CAPES]  C(grupo)[CNPq]  \
#   C(grupo)[Ambos]          0.005178         0.002442        0.002436
#   C(grupo)[CAPES]          0.002442         0.002594        0.002463
#   C(grupo)[CNPq]           0.002436         0.002463        0.002885
#   C(grupo)[Nenhum]         0.002459         0.002486        0.002480
#   qty_2014                -0.002409        -0.002435       -0.002429
#
#                     C(grupo)[Nenhum]  qty_2014
#   C(grupo)[Ambos]           0.002459 -0.002409
#   C(grupo)[CAPES]           0.002486 -0.002435
#   C(grupo)[CNPq]            0.002480 -0.002429
#   C(grupo)[Nenhum]          0.002610 -0.002453
#   qty_2014                 -0.002453  0.002403  ,
#   'Number of observations n.': 20041.0,
#   'R2 ajustado': 0.8370173104298886,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x225669261f0>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Início de Mestrado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Obtenção do Título de Doutorado',
#   'Erro': False,
#   'Prob (F-statistic)': 1.6554878570065926e-11,
#   'Parâmetros': C(grupo)[Ambos]     1.043526
#   C(grupo)[CAPES]     0.989920
#   C(grupo)[CNPq]      0.980545
#   C(grupo)[Nenhum]    0.970329
#   qty_2014            0.243760
#   dtype: float64,
#   'P>|t|': C(grupo)[Ambos]     0.000000
#   C(grupo)[CAPES]     0.000000
#   C(grupo)[CNPq]      0.000000
#   C(grupo)[Nenhum]    0.000000
#   qty_2014            0.003999
#   dtype: float64,
#   'Standard Error': C(grupo)[Ambos]     0.013347
#   C(grupo)[CAPES]     0.002832
#   C(grupo)[CNPq]      0.005279
#   C(grupo)[Nenhum]    0.002629
#   qty_2014            0.084681
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[Ambos]  C(grupo)[CAPES]  C(grupo)[CNPq]  \
#   C(grupo)[Ambos]      2.763280e-03    -2.786881e-21   -1.902042e-22
#   C(grupo)[CAPES]     -2.786881e-21     1.244400e-04    1.380718e-19
#   C(grupo)[CNPq]      -1.902042e-22     1.380718e-19    4.323390e-04
#   C(grupo)[Nenhum]     2.633513e-07     1.379302e-22   -6.824402e-20
#   qty_2014            -3.072652e-04    -4.103096e-19    6.885393e-20
#
#                     C(grupo)[Nenhum]      qty_2014
#   C(grupo)[Ambos]       2.633513e-07 -3.072652e-04
#   C(grupo)[CAPES]       1.379302e-22 -4.103096e-19
#   C(grupo)[CNPq]       -6.824402e-20  6.885393e-20
#   C(grupo)[Nenhum]      1.072169e-04 -9.533318e-05
#   qty_2014             -9.533318e-05  1.112300e-01  ,
#   'Number of observations n.': 20045.0,
#   'R2 ajustado': 0.0026110810919972582,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x22566926250>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Obtenção do Título de Doutorado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Obtenção do Título de Metrado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': C(grupo)[Ambos]     0.384431
#   C(grupo)[CAPES]     0.383073
#   C(grupo)[CNPq]      0.383635
#   C(grupo)[Nenhum]    0.388903
#   qty_2014            0.626032
#   dtype: float64,
#   'P>|t|': C(grupo)[Ambos]     0.0
#   C(grupo)[CAPES]     0.0
#   C(grupo)[CNPq]      0.0
#   C(grupo)[Nenhum]    0.0
#   qty_2014            0.0
#   dtype: float64,
#   'Standard Error': C(grupo)[Ambos]     0.006368
#   C(grupo)[CAPES]     0.004484
#   C(grupo)[CNPq]      0.004742
#   C(grupo)[Nenhum]    0.004482
#   qty_2014            0.004358
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[Ambos]  C(grupo)[CAPES]  C(grupo)[CNPq]  \
#   C(grupo)[Ambos]          0.005091         0.002351        0.002348
#   C(grupo)[CAPES]          0.002351         0.002523        0.002395
#   C(grupo)[CNPq]           0.002348         0.002395        0.002822
#   C(grupo)[Nenhum]         0.002359         0.002406        0.002403
#   qty_2014                -0.002344        -0.002391       -0.002388
#
#                     C(grupo)[Nenhum]  qty_2014
#   C(grupo)[Ambos]           0.002359 -0.002344
#   C(grupo)[CAPES]           0.002406 -0.002391
#   C(grupo)[CNPq]            0.002403 -0.002388
#   C(grupo)[Nenhum]          0.002522 -0.002399
#   qty_2014                 -0.002399  0.002384  ,
#   'Number of observations n.': 19971.0,
#   'R2 ajustado': 0.5087277371210712,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2256692af40>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Obtenção do Título de Metrado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Trabalho em Evento',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': C(grupo)[Ambos]     3.869297
#   C(grupo)[CAPES]     3.227263
#   C(grupo)[CNPq]      3.164735
#   C(grupo)[Nenhum]    2.636911
#   qty_2014            1.299851
#   dtype: float64,
#   'P>|t|': C(grupo)[Ambos]      9.599341e-14
#   C(grupo)[CAPES]     6.691480e-149
#   C(grupo)[CNPq]       1.079258e-49
#   C(grupo)[Nenhum]    2.841207e-111
#   qty_2014             0.000000e+00
#   dtype: float64,
#   'Standard Error': C(grupo)[Ambos]     0.519232
#   C(grupo)[CAPES]     0.123052
#   C(grupo)[CNPq]      0.212903
#   C(grupo)[Nenhum]    0.116847
#   qty_2014            0.004577
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[Ambos]  C(grupo)[CAPES]  C(grupo)[CNPq]  \
#   C(grupo)[Ambos]          0.003033         0.000038        0.000039
#   C(grupo)[CAPES]          0.000038         0.000170        0.000037
#   C(grupo)[CNPq]           0.000039         0.000037        0.000510
#   C(grupo)[Nenhum]         0.000039         0.000037        0.000038
#   qty_2014                -0.000003        -0.000003       -0.000003
#
#                     C(grupo)[Nenhum]      qty_2014
#   C(grupo)[Ambos]           0.000039 -3.049149e-06
#   C(grupo)[CAPES]           0.000037 -2.937390e-06
#   C(grupo)[CNPq]            0.000038 -2.987519e-06
#   C(grupo)[Nenhum]          0.000154 -2.995336e-06
#   qty_2014                 -0.000003  2.356898e-07  ,
#   'Number of observations n.': 18582.0,
#   'R2 ajustado': 0.8127867045124423,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x22566934250>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Trabalho em Evento',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Artigo Publicado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': C(grupo)[Ambos]     5.153976
#   C(grupo)[CAPES]     3.919487
#   C(grupo)[CNPq]      4.199252
#   C(grupo)[Nenhum]    2.613237
#   qty_2014            1.535640
#   dtype: float64,
#   'P>|t|': C(grupo)[Ambos]      2.251338e-55
#   C(grupo)[CAPES]      0.000000e+00
#   C(grupo)[CNPq]      1.976857e-215
#   C(grupo)[Nenhum]    2.111309e-273
#   qty_2014             0.000000e+00
#   dtype: float64,
#   'Standard Error': C(grupo)[Ambos]     0.327770
#   C(grupo)[CAPES]     0.074727
#   C(grupo)[CNPq]      0.132362
#   C(grupo)[Nenhum]    0.072789
#   qty_2014            0.009169
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[Ambos]  C(grupo)[CAPES]  C(grupo)[CNPq]  \
#   C(grupo)[Ambos]          0.002770         0.000016        0.000016
#   C(grupo)[CAPES]          0.000016         0.000144        0.000016
#   C(grupo)[CNPq]           0.000016         0.000016        0.000452
#   C(grupo)[Nenhum]         0.000020         0.000021        0.000021
#   qty_2014                -0.000006        -0.000006       -0.000006
#
#                     C(grupo)[Nenhum]  qty_2014
#   C(grupo)[Ambos]           0.000020 -0.000006
#   C(grupo)[CAPES]           0.000021 -0.000006
#   C(grupo)[CNPq]            0.000021 -0.000006
#   C(grupo)[Nenhum]          0.000137 -0.000008
#   qty_2014                 -0.000008  0.000002  ,
#   'Number of observations n.': 19536.0,
#   'R2 ajustado': 0.5896424642839666,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2256693be50>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Artigo Publicado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Trabalho em Eventos',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': C(grupo)[Ambos]     4.032004
#   C(grupo)[CAPES]     3.306600
#   C(grupo)[CNPq]      3.277407
#   C(grupo)[Nenhum]    2.681159
#   qty_2014            1.299500
#   dtype: float64,
#   'P>|t|': C(grupo)[Ambos]      1.283767e-14
#   C(grupo)[CAPES]     2.500646e-154
#   C(grupo)[CNPq]       1.524426e-52
#   C(grupo)[Nenhum]    1.903115e-113
#   qty_2014             0.000000e+00
#   dtype: float64,
#   'Standard Error': C(grupo)[Ambos]     0.522708
#   C(grupo)[CAPES]     0.123771
#   C(grupo)[CNPq]      0.214167
#   C(grupo)[Nenhum]    0.117629
#   qty_2014            0.004548
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[Ambos]  C(grupo)[CAPES]  C(grupo)[CNPq]  \
#   C(grupo)[Ambos]          0.003033         0.000038        0.000039
#   C(grupo)[CAPES]          0.000038         0.000170        0.000037
#   C(grupo)[CNPq]           0.000039         0.000037        0.000509
#   C(grupo)[Nenhum]         0.000039         0.000037        0.000038
#   qty_2014                -0.000003        -0.000003       -0.000003
#
#                     C(grupo)[Nenhum]      qty_2014
#   C(grupo)[Ambos]           0.000039 -3.008164e-06
#   C(grupo)[CAPES]           0.000037 -2.899994e-06
#   C(grupo)[CNPq]            0.000038 -2.953439e-06
#   C(grupo)[Nenhum]          0.000154 -2.963881e-06
#   qty_2014                 -0.000003  2.296518e-07  ,
#   'Number of observations n.': 18617.0,
#   'R2 ajustado': 0.8143318606238358,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2256694efd0>,
#   'Confiança': 0.01,
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Trabalho em Eventos',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Fim de Participação em Direção ou Administração',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': C(grupo)[Ambos]     0.613612
#   C(grupo)[CAPES]     0.572759
#   C(grupo)[CNPq]      0.470820
#   C(grupo)[Nenhum]    0.578726
#   qty_2014            1.001772
#   dtype: float64,
#   'P>|t|': C(grupo)[Ambos]     5.107134e-02
#   C(grupo)[CAPES]     2.603586e-25
#   C(grupo)[CNPq]      3.242527e-05
#   C(grupo)[Nenhum]    5.111109e-45
#   qty_2014            0.000000e+00
#   dtype: float64,
#   'Standard Error': C(grupo)[Ambos]     0.314420
#   C(grupo)[CAPES]     0.054656
#   C(grupo)[CNPq]      0.113142
#   C(grupo)[Nenhum]    0.040504
#   qty_2014            0.010520
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[Ambos]  C(grupo)[CAPES]  C(grupo)[CNPq]  \
#   C(grupo)[Ambos]          0.038505         0.000070        0.000051
#   C(grupo)[CAPES]          0.000070         0.001164        0.000082
#   C(grupo)[CNPq]           0.000051         0.000082        0.004986
#   C(grupo)[Nenhum]         0.000090         0.000146        0.000106
#   qty_2014                -0.000043        -0.000070       -0.000051
#
#                     C(grupo)[Nenhum]  qty_2014
#   C(grupo)[Ambos]           0.000090 -0.000043
#   C(grupo)[CAPES]           0.000146 -0.000070
#   C(grupo)[CNPq]            0.000106 -0.000051
#   C(grupo)[Nenhum]          0.000639 -0.000090
#   qty_2014                 -0.000090  0.000043  ,
#   'Number of observations n.': 3401.0,
#   'R2 ajustado': 0.7299177072691582,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2257bbe9ca0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Fim de Participação em Direção ou Administração',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Fim de Atividade de Ensino',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': C(grupo)[Ambos]     2.925406
#   C(grupo)[CAPES]     2.689677
#   C(grupo)[CNPq]      2.833265
#   C(grupo)[Nenhum]    1.516644
#   qty_2014            1.226298
#   dtype: float64,
#   'P>|t|': C(grupo)[Ambos]      7.630907e-09
#   C(grupo)[CAPES]     2.506771e-137
#   C(grupo)[CNPq]       2.680041e-46
#   C(grupo)[Nenhum]     2.720256e-55
#   qty_2014             0.000000e+00
#   dtype: float64,
#   'Standard Error': C(grupo)[Ambos]     0.505912
#   C(grupo)[CAPES]     0.105800
#   C(grupo)[CNPq]      0.197095
#   C(grupo)[Nenhum]    0.096109
#   qty_2014            0.006892
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[Ambos]  C(grupo)[CAPES]  C(grupo)[CNPq]  \
#   C(grupo)[Ambos]          0.008204         0.000013        0.000010
#   C(grupo)[CAPES]          0.000013         0.000359        0.000017
#   C(grupo)[CNPq]           0.000010         0.000017        0.001245
#   C(grupo)[Nenhum]         0.000022         0.000039        0.000028
#   qty_2014                -0.000003        -0.000006       -0.000004
#
#                     C(grupo)[Nenhum]  qty_2014
#   C(grupo)[Ambos]           0.000022 -0.000003
#   C(grupo)[CAPES]           0.000039 -0.000006
#   C(grupo)[CNPq]            0.000028 -0.000004
#   C(grupo)[Nenhum]          0.000296 -0.000010
#   qty_2014                 -0.000010  0.000002  ,
# ...
#   'Parâmetros': C(grupo)[CAPES]     2.220446e-16
#   C(grupo)[Nenhum]   -4.440892e-16
#   qty_2014            1.000000e+00
#   dtype: float64,
#   'P>|t|': C(grupo)[CAPES]     9.143468e-01
#   C(grupo)[Nenhum]    8.638806e-01
#   qty_2014            2.386376e-73
#   dtype: float64,
#   'Standard Error': C(grupo)[CAPES]     1.963139e-15
#   C(grupo)[Nenhum]    2.460925e-15
#   qty_2014            1.659155e-15
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[CAPES]  C(grupo)[Nenhum]  qty_2014
#   C(grupo)[CAPES]          1.166667          1.166667 -0.833333
#   C(grupo)[Nenhum]         1.166667          1.833333 -1.166667
#   qty_2014                -0.833333         -1.166667  0.833333,
#   'Number of observations n.': 8.0,
#   'R2 ajustado': 1.0,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2257e24bf10>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Obtenção do Título de MBA',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Orientação em Andamento de Pós-Doutorado',
#   'Erro': True,
#   'Prob (F-statistic)': None,
#   'Parâmetros': None,
#   'P>|t|': None,
#   'Standard Error': None,
#   'Covariância entre os pasrâmetros': None,
#   'Number of observations n.': None,
#   'R2 ajustado': None,
#   'Modelo': None,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Orientação em Andamento de Pós-Doutorado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Participação em Banca Julgadora para Livre Docência',
#   'Erro': False,
#   'Prob (F-statistic)': 6.29056589882947e-39,
#   'Parâmetros': C(grupo)[Ambos]     1.000000
#   C(grupo)[CAPES]     1.590875
#   C(grupo)[CNPq]      3.000000
#   C(grupo)[Nenhum]    0.809426
#   qty_2014            1.000034
#   dtype: float64,
#   'P>|t|': C(grupo)[Ambos]     6.289040e-01
#   C(grupo)[CAPES]     5.281183e-04
#   C(grupo)[CNPq]      1.361407e-02
#   C(grupo)[Nenhum]    5.263812e-03
#   qty_2014            2.091760e-41
#   dtype: float64,
#   'Standard Error': C(grupo)[Ambos]     2.061647
#   C(grupo)[CAPES]     0.441280
#   C(grupo)[CNPq]      1.190292
#   C(grupo)[Nenhum]    0.282502
#   qty_2014            0.039098
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[Ambos]  C(grupo)[CAPES]  C(grupo)[CNPq]  \
#   C(grupo)[Ambos]               1.0     0.000000e+00    0.000000e+00
#   C(grupo)[CAPES]               0.0     4.581420e-02   -1.276536e-18
#   C(grupo)[CNPq]                0.0    -1.276536e-18    3.333333e-01
#   C(grupo)[Nenhum]              0.0     1.021888e-03   -4.552030e-19
#   qty_2014                      0.0    -3.596588e-04    8.678337e-19
#
#                     C(grupo)[Nenhum]      qty_2014
#   C(grupo)[Ambos]       0.000000e+00  0.000000e+00
#   C(grupo)[CAPES]       1.021888e-03 -3.596588e-04
#   C(grupo)[CNPq]       -4.552030e-19  8.678337e-19
#   C(grupo)[Nenhum]      1.877647e-02 -1.021888e-03
#   qty_2014             -1.021888e-03  3.596588e-04  ,
#   'Number of observations n.': 89.0,
#   'R2 ajustado': 0.8817054706805707,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2257e260250>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Participação em Banca Julgadora para Livre Docência',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Manutenção de Obra Artística',
#   'Erro': False,
#   'Prob (F-statistic)': 5.355448737698482e-59,
#   'Parâmetros': C(grupo)[CAPES]     0.006553
#   C(grupo)[CNPq]     -0.051569
#   C(grupo)[Nenhum]    0.087729
#   qty_2014            1.038677
#   dtype: float64,
#   'P>|t|': C(grupo)[CAPES]     9.758561e-01
#   C(grupo)[CNPq]      8.834491e-01
#   C(grupo)[Nenhum]    6.445869e-01
#   qty_2014            5.950690e-60
#   dtype: float64,
#   'Standard Error': C(grupo)[CAPES]     0.215283
#   C(grupo)[CNPq]      0.349735
#   C(grupo)[Nenhum]    0.188872
#   qty_2014            0.007416
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[CAPES]  C(grupo)[CNPq]  C(grupo)[Nenhum]  qty_2014
#   C(grupo)[CAPES]          0.063203        0.000306          0.002677 -0.000230
#   C(grupo)[CNPq]           0.000306        0.166800          0.001165 -0.000100
#   C(grupo)[Nenhum]         0.002677        0.001165          0.048647 -0.000874
#   qty_2014                -0.000230       -0.000100         -0.000874  0.000075,
#   'Number of observations n.': 48.0,
#   'R2 ajustado': 0.9977779780718913,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2257e24bc10>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Manutenção de Obra Artística',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Solicitação de Cultivar protegida',
#   'Erro': False,
#   'Prob (F-statistic)': 0.00027252575677605135,
#   'Parâmetros': C(grupo)[CAPES]     1.050505
#   C(grupo)[CNPq]      2.000000
#   C(grupo)[Nenhum]    1.404040
#   qty_2014            1.398990
#   dtype: float64,
#   'P>|t|': C(grupo)[CAPES]     0.072924
#   C(grupo)[CNPq]      0.081736
#   C(grupo)[Nenhum]    0.082181
#   qty_2014            0.000087
#   dtype: float64,
#   'Standard Error': C(grupo)[CAPES]     0.434461
#   C(grupo)[CNPq]      0.864566
#   C(grupo)[Nenhum]    0.608245
#   qty_2014            0.086892
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[CAPES]  C(grupo)[CNPq]  C(grupo)[Nenhum]  \
#   C(grupo)[CAPES]      2.525253e-01    3.248544e-18      2.020202e-02
#   C(grupo)[CNPq]       3.248544e-18    1.000000e+00      3.898253e-17
#   C(grupo)[Nenhum]     2.020202e-02    3.898253e-17      4.949495e-01
#   qty_2014            -5.050505e-03   -3.248544e-18     -4.040404e-02
#
#                         qty_2014
#   C(grupo)[CAPES]  -5.050505e-03
#   C(grupo)[CNPq]   -3.248544e-18
#   C(grupo)[Nenhum] -4.040404e-02
#   qty_2014          1.010101e-02  ,
#   'Number of observations n.': 8.0,
#   'R2 ajustado': 0.9788593000714212,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2257e257910>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Solicitação de Cultivar protegida',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Maquete',
#   'Erro': False,
#   'Prob (F-statistic)': 3.4646587660202954e-107,
#   'Parâmetros': C(grupo)[Ambos]    -0.098779
#   C(grupo)[CAPES]     0.125320
#   C(grupo)[CNPq]      0.201628
#   C(grupo)[Nenhum]    0.268453
#   qty_2014            1.098779
#   dtype: float64,
#   'P>|t|': C(grupo)[Ambos]      9.084123e-01
#   C(grupo)[CAPES]      3.244188e-01
#   C(grupo)[CNPq]       6.843805e-01
#   C(grupo)[Nenhum]     5.669236e-02
#   qty_2014            1.508956e-109
#   dtype: float64,
#   'Standard Error': C(grupo)[Ambos]     0.856083
#   C(grupo)[CAPES]     0.126437
#   C(grupo)[CNPq]      0.494320
#   C(grupo)[Nenhum]    0.138951
#   qty_2014            0.006443
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[Ambos]  C(grupo)[CAPES]  C(grupo)[CNPq]  \
#   C(grupo)[Ambos]          1.000057         0.000065        0.000076
#   C(grupo)[CAPES]          0.000065         0.021814        0.000087
#   C(grupo)[CNPq]           0.000076         0.000087        0.333434
#   C(grupo)[Nenhum]         0.000276         0.000318        0.000368
#   qty_2014                -0.000057        -0.000065       -0.000076
#
#                     C(grupo)[Nenhum]  qty_2014
#   C(grupo)[Ambos]           0.000276 -0.000057
#   C(grupo)[CAPES]           0.000318 -0.000065
#   C(grupo)[CNPq]            0.000368 -0.000076
#   C(grupo)[Nenhum]          0.026346 -0.000276
#   qty_2014                 -0.000276  0.000057  ,
#   'Number of observations n.': 90.0,
#   'R2 ajustado': 0.9970043033673878,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2257e234ca0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Maquete',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Publicação de Partitura Musical',
#   'Erro': False,
#   'Prob (F-statistic)': 3.047301009931403e-14,
#   'Parâmetros': C(grupo)[CAPES]     1.862779
#   C(grupo)[CNPq]     -2.326888
#   C(grupo)[Nenhum]    0.035016
#   qty_2014            1.194958
#   dtype: float64,
#   'P>|t|': C(grupo)[CAPES]     1.078423e-01
#   C(grupo)[CNPq]      5.015668e-01
#   C(grupo)[Nenhum]    9.772447e-01
#   qty_2014            1.978182e-15
#   dtype: float64,
#   'Standard Error': C(grupo)[CAPES]     1.126999
#   C(grupo)[CNPq]      3.424467
#   C(grupo)[Nenhum]    1.218337
#   qty_2014            0.085402
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[CAPES]  C(grupo)[CNPq]  C(grupo)[Nenhum]  qty_2014
#   C(grupo)[CAPES]          0.062301        0.016173          0.007746 -0.001115
#   C(grupo)[CNPq]           0.016173        0.575218          0.036024 -0.005187
#   C(grupo)[Nenhum]         0.007746        0.036024          0.072808 -0.002484
#   qty_2014                -0.001115       -0.005187         -0.002484  0.000358,
#   'Number of observations n.': 37.0,
#   'R2 ajustado': 0.8487074734826102,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2257e23c5e0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Publicação de Partitura Musical',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Outras participações em Banca',
#   'Erro': False,
#   'Prob (F-statistic)': 1.34372870860379e-138,
#   'Parâmetros': C(grupo)[CAPES]     1.332268e-15
#   C(grupo)[Nenhum]    3.996803e-15
#   qty_2014            1.000000e+00
#   dtype: float64,
#   'P>|t|': C(grupo)[CAPES]      6.812377e-01
#   C(grupo)[Nenhum]     4.883766e-02
#   qty_2014            3.486247e-139
#   dtype: float64,
#   'Standard Error': C(grupo)[CAPES]     3.139167e-15
#   C(grupo)[Nenhum]    1.755644e-15
#   qty_2014            1.599348e-16
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[CAPES]  C(grupo)[Nenhum]  qty_2014
#   C(grupo)[CAPES]          0.599611          0.093385 -0.012451
#   C(grupo)[Nenhum]         0.093385          0.187549 -0.011673
#   qty_2014                -0.012451         -0.011673  0.001556,
#   'Number of observations n.': 12.0,
#   'R2 ajustado': 1.0,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2257c1a99a0>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Outras participações em Banca',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Curso de Curta Duração Realizado',
#   'Erro': False,
#   'Prob (F-statistic)': 0.0,
#   'Parâmetros': C(grupo)[Ambos]     2.664535e-15
#   C(grupo)[CAPES]     5.773160e-15
#   C(grupo)[Nenhum]    3.552714e-15
#   qty_2014            1.000000e+00
#   dtype: float64,
#   'P>|t|': C(grupo)[Ambos]     0.526953
#   C(grupo)[CAPES]     0.000101
#   C(grupo)[Nenhum]    0.001134
#   qty_2014            0.000000
#   dtype: float64,
#   'Standard Error': C(grupo)[Ambos]     4.164126e-15
#   C(grupo)[CAPES]     1.295515e-15
#   C(grupo)[Nenhum]    9.904142e-16
#   qty_2014            1.085210e-16
#   dtype: float64,
#   'Covariância entre os pasrâmetros':                   C(grupo)[Ambos]  C(grupo)[CAPES]  C(grupo)[Nenhum]  qty_2014
#   C(grupo)[Ambos]          1.025063         0.014430          0.019070 -0.004177
#   C(grupo)[CAPES]          0.014430         0.099217          0.010980 -0.002405
#   C(grupo)[Nenhum]         0.019070         0.010980          0.057988 -0.003178
#   qty_2014                -0.004177        -0.002405         -0.003178  0.000696,
#   'Number of observations n.': 35.0,
#   'R2 ajustado': 1.0,
#   'Modelo': <statsmodels.regression.linear_model.OLS at 0x2257bd9d070>,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Curso de Curta Duração Realizado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Orientação Concluída de Pós-Doutorado',
#   'Erro': True,
#   'Prob (F-statistic)': None,
#   'Parâmetros': None,
#   'P>|t|': None,
#   'Standard Error': None,
#   'Covariância entre os pasrâmetros': None,
#   'Number of observations n.': None,
#   'R2 ajustado': None,
#   'Modelo': None,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Orientação Concluída de Pós-Doutorado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Obtenção do Título de Livre Docência',
#   'Erro': True,
#   'Prob (F-statistic)': None,
#   'Parâmetros': None,
#   'P>|t|': None,
#   'Standard Error': None,
#   'Covariância entre os pasrâmetros': None,
#   'Number of observations n.': None,
#   'R2 ajustado': None,
#   'Modelo': None,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Obtenção do Título de Livre Docência',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}},
#  {'Indicador': 'Desenvolvimento de Topografia de Circuito Integrado',
#   'Erro': True,
#   'Prob (F-statistic)': None,
#   'Parâmetros': None,
#   'P>|t|': None,
#   'Standard Error': None,
#   'Covariância entre os pasrâmetros': None,
#   'Number of observations n.': None,
#   'R2 ajustado': None,
#   'Modelo': None,
#   'Confiança': 'Erro',
#   'Variáveis': {'variável_dependente': 'qty_2019',
#    'variáveis_independentes': ['qty_2014', 'C(grupo)', '-1'],
#    'confianças': [0.01, 0.05],
#    'indicador': 'Desenvolvimento de Topografia de Circuito Integrado',
#    'ano_início': 2014,
#    'best_r2': False,
#    'pareamento': False,
#    'capes': True,
#    'cnpq': True,
#    'nenhum': True,
#    'ambos': True,
#    'preenche_todos_ids': True,
#    'verbose': False}}]

# %%
reg.salva_regressões_csv()
