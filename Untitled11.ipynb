# %%
from Carga import Carga
cg = Carga()
cg.atualiza_todos_os_indicadores (on_conflic_update = True, 
                                  pula_bd_indicadores = True, 
                                  pula_erros = False, 
                                  data_mínima_atualização_lattes = '2020-01-01', 
                                  de_all_lattes = True, 
                                  começando_com=[6],
                                 )
# Out:
# Carregando lista de Ids da tabela indicadores para pular
#
# Carregando lista de indicadores para importar da tabela Lattes do BD
#
# Carregando lista de indicadores para importar da tabela demanda_bruta do BD
#
# Carregando lista de indicadores para importar da tabela carga_dados_pessoais do BD
#
# Retirando ids a exluir...
# Iniciando Importação.
# Importação iniciada em 14/03/2022, 15:16:59.
# 0.1% importados.
#
# Linhas por segundo lidas (total): 5.3
# 400 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 16/03/2022, 02:26:13
#
#
# Importação iniciada em 14/03/2022, 15:16:59.
# 0.1% importados.
#
# Linhas por segundo lidas (total): 5.8
# 800 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 23:06:43
#
#
# Importação iniciada em 14/03/2022, 15:16:591.
# 0.2% importados.
#
# Linhas por segundo lidas (total): 5.5
# 1,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 16/03/2022, 00:51:56
#
#
# Importação iniciada em 14/03/2022, 15:16:595.
# 0.3% importados.
#
# Linhas por segundo lidas (total): 5.6
# 1,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 16/03/2022, 00:15:29
#
#
# Importação iniciada em 14/03/2022, 15:16:597.
# 0.3% importados.
#
# Linhas por segundo lidas (total): 5.5
# 2,000 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 16/03/2022, 01:01:04
#
#
# Importação iniciada em 14/03/2022, 15:16:595.
# 0.5% importados.
#
# Linhas por segundo lidas (total): 6.3
# 3,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 20:19:40
#
#
# Importação iniciada em 14/03/2022, 15:16:594.
# 0.9% importados.
#
# Linhas por segundo lidas (total): 7.3
# 6,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 16:21:15
#
#
# Tentando recuperar Lattes compactado 6451814562636612 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6451814562636612
# Tentando recuperar Lattes compactado 6896231481383882 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6896231481383882
# Importação iniciada em 14/03/2022, 15:16:5937.
# 1.6% importados.
#
# Linhas por segundo lidas (total): 7.4
# 10,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 15:59:10
#
#
# Tentando recuperar Lattes compactado 6274147298235846 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6274147298235846
# Tentando recuperar Lattes compactado 6902018055902515 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6902018055902515
# Tentando recuperar Lattes compactado 6486488333787702 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6486488333787702
# Importação iniciada em 14/03/2022, 15:16:5967.
# 2.4% importados.
#
# Linhas por segundo lidas (total): 7.3
# 16,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 16:03:22
#
#
# Importação iniciada em 14/03/2022, 15:16:5900.
# 2.5% importados.
#
# Linhas por segundo lidas (total): 7.3
# 16,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 15:53:36
#
#
# Importação iniciada em 14/03/2022, 15:16:5954.
# 2.8% importados.
#
# Linhas por segundo lidas (total): 7.5
# 18,400 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 15:22:13
#
#
# Importação iniciada em 14/03/2022, 15:16:5920.
# 2.8% importados.
#
# Linhas por segundo lidas (total): 7.5
# 18,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 15:13:49
#
#
# Tentando recuperar Lattes compactado 6922915451059086 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6922915451059086
# Importação iniciada em 14/03/2022, 15:16:5965.
# 3.2% importados.
#
# Linhas por segundo lidas (total): 7.7
# 21,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 14:38:56
#
#
# Importação iniciada em 14/03/2022, 15:16:5909.
# 3.2% importados.
#
# Linhas por segundo lidas (total): 7.7
# 21,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 14:35:28
#
#
# Importação iniciada em 14/03/2022, 15:16:5977.
# 3.6% importados.
#
# Linhas por segundo lidas (total): 7.3
# 24,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 15:46:12
#
#
# Importação iniciada em 14/03/2022, 15:16:5964.
# 3.7% importados.
#
# Linhas por segundo lidas (total): 7.2
# 24,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 15:52:30
#
#
# Importação iniciada em 14/03/2022, 15:16:5948.
# 3.8% importados.
#
# Linhas por segundo lidas (total): 7.2
# 25,000 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 15:52:39
#
#
# Tentando recuperar Lattes compactado 6791355916173193 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6791355916173193
# Importação iniciada em 14/03/2022, 15:16:5920.
# 3.8% importados.
#
# Linhas por segundo lidas (total): 7.2
# 25,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 15:59:21
#
#
# Importação iniciada em 14/03/2022, 15:16:5947.
# 4.0% importados.
#
# Linhas por segundo lidas (total): 7.1
# 26,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 16:10:01
#
#
# Importação iniciada em 14/03/2022, 15:16:5997.
# 4.1% importados.
#
# Linhas por segundo lidas (total): 7.1
# 27,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 16:16:58
#
#
# Importação iniciada em 14/03/2022, 15:16:5942.
# 4.1% importados.
#
# Linhas por segundo lidas (total): 7.1
# 27,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 16:17:36
#
#
# Importação iniciada em 14/03/2022, 15:16:5990.
# 4.2% importados.
#
# Linhas por segundo lidas (total): 7.1
# 27,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 16:18:21
#
#
# Importação iniciada em 14/03/2022, 15:16:5942.
# 4.4% importados.
#
# Linhas por segundo lidas (total): 7.1
# 29,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 16:19:24
#
#
# Tentando recuperar Lattes compactado 6038078738220828 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6038078738220828
# Importação iniciada em 14/03/2022, 15:16:5926.
# 4.6% importados.
#
# Linhas por segundo lidas (total): 7.0
# 30,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 16:21:46
#
#
# Importação iniciada em 14/03/2022, 15:16:5930.
# 4.7% importados.
#
# Linhas por segundo lidas (total): 7.0
# 31,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 16:21:22
#
#
# Tentando recuperar Lattes compactado 6802168308863757 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6802168308863757
# Importação iniciada em 14/03/2022, 15:16:5918.
# 4.8% importados.
#
# Linhas por segundo lidas (total): 7.1
# 31,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 16:10:56
#
#
# Importação iniciada em 14/03/2022, 15:16:5964.
# 4.8% importados.
#
# Linhas por segundo lidas (total): 7.1
# 32,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 16:07:27
#
#
# Importação iniciada em 14/03/2022, 15:16:5915.
# 4.9% importados.
#
# Linhas por segundo lidas (total): 7.1
# 32,800 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 16:01:10
#
#
# Importação iniciada em 14/03/2022, 15:16:5941.
# 5.0% importados.
#
# Linhas por segundo lidas (total): 7.1
# 33,000 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 15:56:11
#
#
# Importação iniciada em 14/03/2022, 15:16:5932.
# 5.0% importados.
#
# Linhas por segundo lidas (total): 7.1
# 33,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 15:53:52
#
#
# Tentando recuperar Lattes compactado 6761200294458747 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6761200294458747
# Importação iniciada em 14/03/2022, 15:16:5924.
# 5.3% importados.
#
# Linhas por segundo lidas (total): 7.3
# 35,000 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 15:23:32
#
#
# Tentando recuperar Lattes compactado 6087663455858216 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6087663455858216
# Importação iniciada em 14/03/2022, 15:16:5917.
# 5.3% importados.
#
# Linhas por segundo lidas (total): 7.3
# 35,300 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 15:17:41
#
#
# Importação iniciada em 14/03/2022, 15:16:5950.
# 5.4% importados.
#
# Linhas por segundo lidas (total): 7.3
# 36,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 15:10:59
#
#
# Importação iniciada em 14/03/2022, 15:16:5978.
# 5.6% importados.
#
# Linhas por segundo lidas (total): 7.4
# 37,300 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 14:52:57
#
#
# Importação iniciada em 14/03/2022, 15:16:5965.
# 5.9% importados.
#
# Linhas por segundo lidas (total): 7.5
# 39,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 14:25:06
#
#
# Importação iniciada em 14/03/2022, 15:16:5901.
# 6.0% importados.
#
# Linhas por segundo lidas (total): 7.5
# 40,000 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 14:21:30
#
#
# Tentando recuperar Lattes compactado 6635618777572037 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6635618777572037
# Importação iniciada em 14/03/2022, 15:16:5914.
# 6.3% importados.
#
# Linhas por segundo lidas (total): 7.6
# 41,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 14:05:13
#
#
# Importação iniciada em 14/03/2022, 15:16:5940.
# 6.3% importados.
#
# Linhas por segundo lidas (total): 7.6
# 42,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 14:01:07
#
#
# Importação iniciada em 14/03/2022, 15:16:5917.
# 6.3% importados.
#
# Linhas por segundo lidas (total): 7.6
# 42,300 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 14:00:03
#
#
# Importação iniciada em 14/03/2022, 15:16:5955.
# 6.4% importados.
#
# Linhas por segundo lidas (total): 7.7
# 42,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 13:53:21
#
#
# Importação iniciada em 14/03/2022, 15:16:5948.
# 6.8% importados.
#
# Linhas por segundo lidas (total): 7.8
# 45,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 13:30:31
#
#
# Importação iniciada em 14/03/2022, 15:16:5991.
# 7.2% importados.
#
# Linhas por segundo lidas (total): 7.9
# 48,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 12:59:58
#
#
# Tentando recuperar Lattes compactado 6537896193630435 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Importação iniciada em 14/03/2022, 15:16:5919.
# 7.6% importados.
#
# Linhas por segundo lidas (total): 8.0
# 50,800 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 12:37:01
#
#
# Importação iniciada em 14/03/2022, 15:16:5978.
# 7.8% importados.
#
# Linhas por segundo lidas (total): 8.1
# 51,800 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 12:27:55
#
#
# Importação iniciada em 14/03/2022, 15:16:5901.
# 7.8% importados.
#
# Linhas por segundo lidas (total): 8.1
# 52,000 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 12:26:27
#
#
# Importação iniciada em 14/03/2022, 15:16:5994.
# 8.0% importados.
#
# Linhas por segundo lidas (total): 8.1
# 53,000 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 12:15:57
#
#
# Tentando recuperar Lattes compactado 6483645173512748 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6483645173512748
# Importação iniciada em 14/03/2022, 15:16:5991.
# 8.5% importados.
#
# Linhas por segundo lidas (total): 8.2
# 56,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 11:49:51
#
#
# Importação iniciada em 14/03/2022, 15:16:5985.
# 8.5% importados.
#
# Linhas por segundo lidas (total): 8.2
# 56,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 11:48:52
#
#
# Importação iniciada em 14/03/2022, 15:16:5901.
# 8.6% importados.
#
# Linhas por segundo lidas (total): 8.3
# 57,300 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 11:46:06
#
#
# Importação iniciada em 14/03/2022, 15:16:5954.
# 8.7% importados.
#
# Linhas por segundo lidas (total): 8.3
# 57,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 11:40:54
#
#
# Importação iniciada em 14/03/2022, 15:16:5954.
# 8.7% importados.
#
# Linhas por segundo lidas (total): 8.3
# 58,300 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 11:38:07
#
#
# Importação iniciada em 14/03/2022, 15:16:5925.
# 8.8% importados.
#
# Linhas por segundo lidas (total): 8.3
# 58,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 11:33:50
#
#
# Importação iniciada em 14/03/2022, 15:16:5957.
# 9.0% importados.
#
# Linhas por segundo lidas (total): 8.3
# 60,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 11:28:09
#
#
# Importação iniciada em 14/03/2022, 15:16:5988.
# 9.1% importados.
#
# Linhas por segundo lidas (total): 8.4
# 60,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 11:24:25
#
#
# Importação iniciada em 14/03/2022, 15:16:5970.
# 9.4% importados.
#
# Linhas por segundo lidas (total): 8.4
# 62,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 11:13:20
#
#
# Importação iniciada em 14/03/2022, 15:16:5994.
# 9.5% importados.
#
# Linhas por segundo lidas (total): 8.4
# 63,000 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 11:11:12
#
#
# Tentando recuperar Lattes compactado 6389652064788897 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6389652064788897
# Tentando recuperar Lattes compactado 6923858117377379 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6923858117377379
# Importação iniciada em 14/03/2022, 15:16:5940.
# 9.6% importados.
#
# Linhas por segundo lidas (total): 8.5
# 64,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 11:02:30
#
#
# Tentando recuperar Lattes compactado 6457133891582808 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6457133891582808
# Importação iniciada em 14/03/2022, 15:16:5945.
# 9.8% importados.
#
# Linhas por segundo lidas (total): 8.5
# 65,000 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:56:27
#
#
# Importação iniciada em 14/03/2022, 15:16:5955.
# 9.8% importados.
#
# Linhas por segundo lidas (total): 8.5
# 65,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:53:01
#
#
# Importação iniciada em 14/03/2022, 15:16:5952.
# 9.9% importados.
#
# Linhas por segundo lidas (total): 8.5
# 65,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:51:52
#
#
# Importação iniciada em 14/03/2022, 15:16:5968.
# 9.9% importados.
#
# Linhas por segundo lidas (total): 8.5
# 66,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:49:13
#
#
# Importação iniciada em 14/03/2022, 15:16:5984.
# 10.1% importados.
#
# Linhas por segundo lidas (total): 8.6
# 67,000 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:44:41
#
#
# Importação iniciada em 14/03/2022, 15:16:5951.
# 10.1% importados.
#
# Linhas por segundo lidas (total): 8.6
# 67,400 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:42:49
#
#
# Importação iniciada em 14/03/2022, 15:16:5960.
# 10.3% importados.
#
# Linhas por segundo lidas (total): 8.6
# 68,400 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:36:00
#
#
# Tentando recuperar Lattes compactado 6490820114351512 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6490820114351512
# Importação iniciada em 14/03/2022, 15:16:5990.
# 10.7% importados.
#
# Linhas por segundo lidas (total): 8.7
# 71,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:16:15
#
#
# Importação iniciada em 14/03/2022, 15:16:5953.
# 10.8% importados.
#
# Linhas por segundo lidas (total): 8.7
# 71,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:16:33
#
#
# Tentando recuperar Lattes compactado 6822173410965132 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6822173410965132
# Importação iniciada em 14/03/2022, 15:16:5921.
# 11.0% importados.
#
# Linhas por segundo lidas (total): 8.7
# 73,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:07:49
#
#
# Importação iniciada em 14/03/2022, 15:16:5924.
# 11.1% importados.
#
# Linhas por segundo lidas (total): 8.7
# 74,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:05:35
#
#
# Importação iniciada em 14/03/2022, 15:16:5930.
# 11.2% importados.
#
# Linhas por segundo lidas (total): 8.8
# 74,400 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 10:03:59
#
#
# Importação iniciada em 14/03/2022, 15:16:5988.
# 11.5% importados.
#
# Linhas por segundo lidas (total): 8.8
# 76,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:53:01
#
#
# Importação iniciada em 14/03/2022, 15:16:5958.
# 11.7% importados.
#
# Linhas por segundo lidas (total): 8.8
# 78,000 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:47:21
#
#
# Tentando recuperar Lattes compactado 6898771166963131 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6898771166963131
# Importação iniciada em 14/03/2022, 15:16:5946.
# 11.9% importados.
#
# Linhas por segundo lidas (total): 8.9
# 79,400 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:41:23
#
#
# Importação iniciada em 14/03/2022, 15:16:5934.
# 12.1% importados.
#
# Linhas por segundo lidas (total): 8.9
# 80,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:37:13
#
#
# Importação iniciada em 14/03/2022, 15:16:5962.
# 12.2% importados.
#
# Linhas por segundo lidas (total): 8.9
# 81,000 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:35:32
#
#
# Importação iniciada em 14/03/2022, 15:16:5903.
# 12.6% importados.
#
# Linhas por segundo lidas (total): 8.9
# 84,000 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:25:46
#
#
# Importação iniciada em 14/03/2022, 15:16:5999.
# 12.6% importados.
#
# Linhas por segundo lidas (total): 8.9
# 84,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:26:01
#
#
# Importação iniciada em 14/03/2022, 15:16:5929.
# 12.9% importados.
#
# Linhas por segundo lidas (total): 8.9
# 85,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:21:06
#
#
# Importação iniciada em 14/03/2022, 15:16:5976.
# 12.9% importados.
#
# Linhas por segundo lidas (total): 8.9
# 85,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:20:49
#
#
# Importação iniciada em 14/03/2022, 15:16:5977.
# 13.0% importados.
#
# Linhas por segundo lidas (total): 8.9
# 86,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:19:48
#
#
# Importação iniciada em 14/03/2022, 15:16:5942.
# 13.0% importados.
#
# Linhas por segundo lidas (total): 8.9
# 86,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:18:31
#
#
# Importação iniciada em 14/03/2022, 15:16:5983.
# 13.0% importados.
#
# Linhas por segundo lidas (total): 8.9
# 86,800 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:18:34
#
#
# Importação iniciada em 14/03/2022, 15:16:5925.
# 13.2% importados.
#
# Linhas por segundo lidas (total): 8.9
# 87,800 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:15:07
#
#
# Tentando recuperar Lattes compactado 6417051760740864 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6417051760740864
# Tentando recuperar Lattes compactado 6327811258004827 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6327811258004827
# Importação iniciada em 14/03/2022, 15:16:5911.
# 13.4% importados.
#
# Linhas por segundo lidas (total): 9.0
# 89,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:09:55
#
#
# Tentando recuperar Lattes compactado 6542728197066380 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6542728197066380
# Importação iniciada em 14/03/2022, 15:16:5952.
# 13.5% importados.
#
# Linhas por segundo lidas (total): 9.0
# 89,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:08:56
#
#
# Tentando recuperar Lattes compactado 6346917355440881 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6346917355440881
# Importação iniciada em 14/03/2022, 15:16:5902.
# 13.6% importados.
#
# Linhas por segundo lidas (total): 9.0
# 90,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:04:39
#
#
# Tentando recuperar Lattes compactado 6713547734044997 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6713547734044997
# Importação iniciada em 14/03/2022, 15:16:5925.
# 13.8% importados.
#
# Linhas por segundo lidas (total): 9.0
# 91,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 09:00:23
#
#
# Tentando recuperar Lattes compactado 6806215488099677 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6806215488099677
# Tentando recuperar Lattes compactado 6689454271788168 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6689454271788168
# Importação iniciada em 14/03/2022, 15:16:5933.
# 14.0% importados.
#
# Linhas por segundo lidas (total): 9.0
# 93,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:55:52
#
#
# Tentando recuperar Lattes compactado 6579032276810875 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6579032276810875
# Tentando recuperar Lattes compactado 6471346279427305 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6471346279427305
# Importação iniciada em 14/03/2022, 15:16:5978.
# 14.1% importados.
#
# Linhas por segundo lidas (total): 9.0
# 93,800 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:53:36
#
#
# Tentando recuperar Lattes compactado 6712513683109330 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6712513683109330
# Importação iniciada em 14/03/2022, 15:16:5982.
# 14.4% importados.
#
# Linhas por segundo lidas (total): 9.1
# 96,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:45:33
#
#
# Tentando recuperar Lattes compactado 6704434991951149 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6704434991951149
# Importação iniciada em 14/03/2022, 15:16:5996.
# 14.5% importados.
#
# Linhas por segundo lidas (total): 9.1
# 96,400 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:44:26
#
#
# Tentando recuperar Lattes compactado 6225709363158791 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6225709363158791
# Tentando recuperar Lattes compactado 6927662896524628 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6927662896524628
# Tentando recuperar Lattes compactado 6140128912854333 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6140128912854333
# Importação iniciada em 14/03/2022, 15:16:5937.
# 14.9% importados.
#
# Linhas por segundo lidas (total): 9.1
# 99,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:30:40
#
#
# Importação iniciada em 14/03/2022, 15:16:59351.
# 15.0% importados.
#
# Linhas por segundo lidas (total): 9.1
# 100,000 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:30:04
#
#
# Importação iniciada em 14/03/2022, 15:16:59631.
# 15.1% importados.
#
# Linhas por segundo lidas (total): 9.1
# 100,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:29:10
#
#
# Importação iniciada em 14/03/2022, 15:16:59605.
# 15.2% importados.
#
# Linhas por segundo lidas (total): 9.1
# 101,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:27:26
#
#
# Importação iniciada em 14/03/2022, 15:16:59533.
# 15.2% importados.
#
# Linhas por segundo lidas (total): 9.1
# 101,300 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:27:29
# Importação iniciada em 14/03/2022, 15:16:59980.
# 15.2% importados.
#
# Linhas por segundo lidas (total): 9.1
# 101,400 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:28:11
#
#
# Tentando recuperar Lattes compactado 6897724436575931 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6897724436575931
# Importação iniciada em 14/03/2022, 15:16:59876.
# 15.5% importados.
#
# Linhas por segundo lidas (total): 9.2
# 103,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:23:09
#
#
# Importação iniciada em 14/03/2022, 15:16:59973.
# 15.5% importados.
#
# Linhas por segundo lidas (total): 9.1
# 103,400 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:22:53
#
#
# Importação iniciada em 14/03/2022, 15:16:59679.
# 15.6% importados.
#
# Linhas por segundo lidas (total): 9.1
# 104,000 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:25:21
#
#
# Importação iniciada em 14/03/2022, 15:16:59127.
# 15.6% importados.
#
# Linhas por segundo lidas (total): 9.1
# 104,300 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:23:47
#
#
# Importação iniciada em 14/03/2022, 15:16:59919.
# 15.8% importados.
#
# Linhas por segundo lidas (total): 9.1
# 105,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:22:30
#
#
# Importação iniciada em 14/03/2022, 15:16:59192.
# 16.1% importados.
#
# Linhas por segundo lidas (total): 9.1
# 107,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:18:33
#
#
# Importação iniciada em 14/03/2022, 15:16:59443.
# 16.3% importados.
#
# Linhas por segundo lidas (total): 9.1
# 108,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:15:37
#
#
# Importação iniciada em 14/03/2022, 15:16:59804.
# 16.4% importados.
#
# Linhas por segundo lidas (total): 9.1
# 109,400 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:14:04
#
#
# Importação iniciada em 14/03/2022, 15:16:59822.
# 16.6% importados.
#
# Linhas por segundo lidas (total): 9.1
# 110,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:11:03
#
#
# Tentando recuperar Lattes compactado 6593212763272489 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6593212763272489
# Importação iniciada em 14/03/2022, 15:16:59710.
# 16.7% importados.
#
# Linhas por segundo lidas (total): 9.1
# 111,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:09:53
#
#
# Importação iniciada em 14/03/2022, 15:16:59315.
# 16.9% importados.
#
# Linhas por segundo lidas (total): 9.1
# 112,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:06:38
#
#
# Importação iniciada em 14/03/2022, 15:16:59352.
# 17.3% importados.
#
# Linhas por segundo lidas (total): 9.2
# 115,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 08:00:58
#
#
# Tentando recuperar Lattes compactado 6589234400369618 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6589234400369618
# Tentando recuperar Lattes compactado 6333853039660564 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6333853039660564
# Importação iniciada em 14/03/2022, 15:16:59075.
# 17.9% importados.
#
# Linhas por segundo lidas (total): 9.2
# 119,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:53:11
#
#
# Tentando recuperar Lattes compactado 6437574596920803 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6437574596920803
# Importação iniciada em 14/03/2022, 15:16:59404.
# 17.9% importados.
#
# Linhas por segundo lidas (total): 9.2
# 119,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:52:55
#
#
# Importação iniciada em 14/03/2022, 15:16:59250.
# 18.0% importados.
#
# Linhas por segundo lidas (total): 9.2
# 119,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:51:43
#
#
# Tentando recuperar Lattes compactado 6104254652461901 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6104254652461901
# Importação iniciada em 14/03/2022, 15:16:59259.
# 18.1% importados.
#
# Linhas por segundo lidas (total): 9.2
# 120,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:49:36
#
#
# Importação iniciada em 14/03/2022, 15:16:59268.
# 18.2% importados.
#
# Linhas por segundo lidas (total): 9.2
# 121,300 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:49:52
#
#
# ERRRO - Lattes não está carregado. ID: 6421416314370479
# Importação iniciada em 14/03/2022, 15:16:59867.
# 18.3% importados.
#
# Linhas por segundo lidas (total): 9.2
# 121,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:48:22
#
#
# Importação iniciada em 14/03/2022, 15:16:59854.
# 18.4% importados.
#
# Linhas por segundo lidas (total): 9.2
# 122,400 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:47:02
#
#
# Importação iniciada em 14/03/2022, 15:16:59400.
# 18.5% importados.
#
# Linhas por segundo lidas (total): 9.2
# 123,000 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:45:53
#
#
# Tentando recuperar Lattes compactado 6290871397851901 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6290871397851901
# Importação iniciada em 14/03/2022, 15:16:59354.
# 18.5% importados.
#
# Linhas por segundo lidas (total): 9.2
# 123,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:45:10
#
#
# Tentando recuperar Lattes compactado 6619742653492620 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6619742653492620
# Tentando recuperar Lattes compactado 6667758239563438 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6667758239563438
# Importação iniciada em 14/03/2022, 15:16:59018.
# 19.2% importados.
#
# Linhas por segundo lidas (total): 9.2
# 127,800 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:35:13
#
#
# Importação iniciada em 14/03/2022, 15:16:59614.
# 19.3% importados.
#
# Linhas por segundo lidas (total): 9.2
# 128,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:32:58
#
#
# Importação iniciada em 14/03/2022, 15:16:59188.
# 19.4% importados.
#
# Linhas por segundo lidas (total): 9.2
# 129,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:31:38
#
#
# Importação iniciada em 14/03/2022, 15:16:59210.
# 19.5% importados.
#
# Linhas por segundo lidas (total): 9.2
# 129,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:30:08
#
#
# Tentando recuperar Lattes compactado 6196756595613511 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6196756595613511
# Importação iniciada em 14/03/2022, 15:16:59481.
# 19.7% importados.
#
# Linhas por segundo lidas (total): 9.2
# 131,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:24:51
#
#
# Importação iniciada em 14/03/2022, 15:16:59828.
# 19.8% importados.
#
# Linhas por segundo lidas (total): 9.2
# 131,800 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:23:59
#
#
# Importação iniciada em 14/03/2022, 15:16:59287.
# 19.8% importados.
#
# Linhas por segundo lidas (total): 9.2
# 131,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:23:37
#
#
# Importação iniciada em 14/03/2022, 15:16:59807.
# 19.9% importados.
#
# Linhas por segundo lidas (total): 9.2
# 132,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:21:55
#
#
# Importação iniciada em 14/03/2022, 15:16:59882.
# 19.9% importados.
#
# Linhas por segundo lidas (total): 9.2
# 132,800 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:21:31
#
#
# Importação iniciada em 14/03/2022, 15:16:59380.
# 20.0% importados.
#
# Linhas por segundo lidas (total): 9.2
# 133,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:19:43
#
#
# Tentando recuperar Lattes compactado 6144884373474638 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6144884373474638
# Importação iniciada em 14/03/2022, 15:16:59849.
# 20.1% importados.
#
# Linhas por segundo lidas (total): 9.2
# 133,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:19:21
#
#
# Importação iniciada em 14/03/2022, 15:16:59104.
# 20.1% importados.
#
# Linhas por segundo lidas (total): 9.2
# 133,800 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:18:59
#
#
# Importação iniciada em 14/03/2022, 15:16:59216.
# 20.1% importados.
#
# Linhas por segundo lidas (total): 9.2
# 134,000 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:18:37
#
#
# Importação iniciada em 14/03/2022, 15:16:59999.
# 20.1% importados.
#
# Linhas por segundo lidas (total): 9.2
# 134,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:18:03
#
#
# Importação iniciada em 14/03/2022, 15:16:59104.
# 20.2% importados.
#
# Linhas por segundo lidas (total): 9.2
# 134,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:16:11
#
#
# Importação iniciada em 14/03/2022, 15:16:59896.
# 20.3% importados.
#
# Linhas por segundo lidas (total): 9.2
# 135,000 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:16:07
#
#
# Importação iniciada em 14/03/2022, 15:16:59097.
# 20.3% importados.
#
# Linhas por segundo lidas (total): 9.2
# 135,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:14:19
#
#
# Tentando recuperar Lattes compactado 6367180971328120 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6367180971328120
# Importação iniciada em 14/03/2022, 15:16:59909.
# 20.6% importados.
#
# Linhas por segundo lidas (total): 9.3
# 137,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:09:40
#
#
# Importação iniciada em 14/03/2022, 15:16:59418.
# 20.7% importados.
#
# Linhas por segundo lidas (total): 9.3
# 138,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:08:05
#
#
# Importação iniciada em 14/03/2022, 15:16:59170.
# 20.8% importados.
#
# Linhas por segundo lidas (total): 9.3
# 138,400 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:07:14
#
#
# Tentando recuperar Lattes compactado 6781272185296428 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6781272185296428
# Importação iniciada em 14/03/2022, 15:16:59854.
# 21.1% importados.
#
# Linhas por segundo lidas (total): 9.3
# 140,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:00:43
#
#
# Importação iniciada em 14/03/2022, 15:16:59974.
# 21.1% importados.
#
# Linhas por segundo lidas (total): 9.3
# 140,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 07:00:18
#
#
# Importação iniciada em 14/03/2022, 15:16:59887.
# 21.2% importados.
#
# Linhas por segundo lidas (total): 9.3
# 141,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:59:54
#
#
# Importação iniciada em 14/03/2022, 15:16:59895.
# 21.4% importados.
#
# Linhas por segundo lidas (total): 9.3
# 142,400 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:57:35
#
#
# Tentando recuperar Lattes compactado 6032293042957901 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6032293042957901
# Importação iniciada em 14/03/2022, 15:16:59334.
# 22.1% importados.
#
# Linhas por segundo lidas (total): 9.3
# 147,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:44:31
#
#
# Importação iniciada em 14/03/2022, 15:16:59613.
# 22.1% importados.
#
# Linhas por segundo lidas (total): 9.3
# 147,300 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:44:05
#
#
# Importação iniciada em 14/03/2022, 15:16:59764.
# 22.5% importados.
#
# Linhas por segundo lidas (total): 9.3
# 149,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:38:30
#
#
# Importação iniciada em 14/03/2022, 15:16:59970.
# 22.7% importados.
#
# Linhas por segundo lidas (total): 9.3
# 151,300 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:36:38
#
#
# Importação iniciada em 14/03/2022, 15:16:59816.
# 22.8% importados.
#
# Linhas por segundo lidas (total): 9.3
# 151,800 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:35:57
#
#
# Importação iniciada em 14/03/2022, 15:16:59171.
# 22.8% importados.
#
# Linhas por segundo lidas (total): 9.3
# 152,000 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:35:41
#
#
# Tentando recuperar Lattes compactado 6884745530992482 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6884745530992482
# Tentando recuperar Lattes compactado 6961030076624118 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6961030076624118
# Tentando recuperar Lattes compactado 6734779959833794 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6734779959833794
# Tentando recuperar Lattes compactado 6694647047879401 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6694647047879401
# Importação iniciada em 14/03/2022, 15:16:59345.
# 23.4% importados.
#
# Linhas por segundo lidas (total): 9.4
# 156,300 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:25:58
#
#
# Tentando recuperar Lattes compactado 6961619370709853 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6961619370709853
# Importação iniciada em 14/03/2022, 15:16:59024.
# 23.6% importados.
#
# Linhas por segundo lidas (total): 9.4
# 157,300 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:24:36
#
#
# Importação iniciada em 14/03/2022, 15:16:59680.
# 23.7% importados.
#
# Linhas por segundo lidas (total): 9.4
# 158,000 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:23:11
#
#
# Tentando recuperar Lattes compactado 6106212487940990 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6106212487940990
# Tentando recuperar Lattes compactado 6319731383064095 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6319731383064095
# Tentando recuperar Lattes compactado 6231736059394165 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6231736059394165
# Importação iniciada em 14/03/2022, 15:16:59883.
# 24.2% importados.
#
# Linhas por segundo lidas (total): 9.4
# 161,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:13:46
#
#
# Importação iniciada em 14/03/2022, 15:16:59903.
# 24.3% importados.
#
# Linhas por segundo lidas (total): 9.4
# 161,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:12:50
#
#
# Importação iniciada em 14/03/2022, 15:16:59899.
# 24.3% importados.
#
# Linhas por segundo lidas (total): 9.4
# 162,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:12:56
#
#
# Tentando recuperar Lattes compactado 6820182173716945 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6820182173716945
# Importação iniciada em 14/03/2022, 15:16:59809.
# 24.5% importados.
#
# Linhas por segundo lidas (total): 9.4
# 163,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:08:54
#
#
# Importação iniciada em 14/03/2022, 15:16:59659.
# 24.6% importados.
#
# Linhas por segundo lidas (total): 9.4
# 164,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:07:05
#
#
# Importação iniciada em 14/03/2022, 15:16:59875.
# 24.7% importados.
#
# Linhas por segundo lidas (total): 9.4
# 164,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:06:06
#
#
# Importação iniciada em 14/03/2022, 15:16:59226.
# 24.9% importados.
#
# Linhas por segundo lidas (total): 9.4
# 166,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:02:36
#
#
# Importação iniciada em 14/03/2022, 15:16:59620.
# 25.0% importados.
#
# Linhas por segundo lidas (total): 9.4
# 166,800 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:01:47
# Importação iniciada em 14/03/2022, 15:16:59990.
# 25.1% importados.
#
# Linhas por segundo lidas (total): 9.4
# 167,400 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 06:00:16
#
#
# Tentando recuperar Lattes compactado 6765005771144306 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6765005771144306
# Tentando recuperar Lattes compactado 6236135285192982 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6236135285192982
# Tentando recuperar Lattes compactado 6350622814297571 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6350622814297571
# Importação iniciada em 14/03/2022, 15:16:59551.
# 25.3% importados.
#
# Linhas por segundo lidas (total): 9.4
# 168,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:57:21
#
#
# Tentando recuperar Lattes compactado 6344465535055889 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6344465535055889
# Importação iniciada em 14/03/2022, 15:16:59515.
# 25.4% importados.
#
# Linhas por segundo lidas (total): 9.4
# 169,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:55:52
#
#
# Importação iniciada em 14/03/2022, 15:16:59069.
# 25.5% importados.
#
# Linhas por segundo lidas (total): 9.4
# 169,800 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:54:03
#
#
# Tentando recuperar Lattes compactado 6866108677736540 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6866108677736540
# Importação iniciada em 14/03/2022, 15:16:59174.
# 25.5% importados.
#
# Linhas por segundo lidas (total): 9.4
# 170,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:52:57
#
#
# Importação iniciada em 14/03/2022, 15:16:59545.
# 25.7% importados.
#
# Linhas por segundo lidas (total): 9.5
# 171,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:49:52
#
#
# Importação iniciada em 14/03/2022, 15:16:59169.
# 26.1% importados.
#
# Linhas por segundo lidas (total): 9.5
# 173,800 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:44:32
#
#
# Importação iniciada em 14/03/2022, 15:16:59396.
# 26.2% importados.
#
# Linhas por segundo lidas (total): 9.5
# 174,400 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:43:07
#
#
# Importação iniciada em 14/03/2022, 15:16:59923.
# 26.2% importados.
#
# Linhas por segundo lidas (total): 9.5
# 174,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:42:46
#
#
# Tentando recuperar Lattes compactado 6535084620917866 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6535084620917866
# Importação iniciada em 14/03/2022, 15:16:59990.
# 26.5% importados.
#
# Linhas por segundo lidas (total): 9.5
# 176,800 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:37:47
#
#
# Importação iniciada em 14/03/2022, 15:16:59561.
# 26.6% importados.
#
# Linhas por segundo lidas (total): 9.5
# 177,300 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:36:46
#
#
# Importação iniciada em 14/03/2022, 15:16:59970.
# 26.7% importados.
#
# Linhas por segundo lidas (total): 9.5
# 177,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:35:24
#
#
# Importação iniciada em 14/03/2022, 15:16:59182.
# 26.8% importados.
#
# Linhas por segundo lidas (total): 9.5
# 178,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:32:26
#
#
# Importação iniciada em 14/03/2022, 15:16:59833.
# 26.9% importados.
#
# Linhas por segundo lidas (total): 9.5
# 179,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:31:27
#
#
# Tentando recuperar Lattes compactado 6581987204441988 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6581987204441988
# Importação iniciada em 14/03/2022, 15:16:59679.
# 27.0% importados.
#
# Linhas por segundo lidas (total): 9.5
# 179,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:30:34
#
#
# Tentando recuperar Lattes compactado 6401226972278439 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6401226972278439
# Importação iniciada em 14/03/2022, 15:16:59172.
# 27.1% importados.
#
# Linhas por segundo lidas (total): 9.5
# 180,300 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:29:48
#
#
# Importação iniciada em 14/03/2022, 15:16:59926.
# 27.1% importados.
#
# Linhas por segundo lidas (total): 9.5
# 180,800 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:29:04
#
#
# Importação iniciada em 14/03/2022, 15:16:59293.
# 27.2% importados.
#
# Linhas por segundo lidas (total): 9.5
# 181,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:27:30
#
#
# Tentando recuperar Lattes compactado 6995563539400877 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6995563539400877
# Importação iniciada em 14/03/2022, 15:16:59516.
# 27.4% importados.
#
# Linhas por segundo lidas (total): 9.5
# 182,800 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:24:57
#
#
# Tentando recuperar Lattes compactado 6237806218725841 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Importação iniciada em 14/03/2022, 15:16:59507.
# 27.6% importados.
#
# Linhas por segundo lidas (total): 9.5
# 183,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:22:50
#
#
# Importação iniciada em 14/03/2022, 15:16:59896.
# 27.9% importados.
#
# Linhas por segundo lidas (total): 9.5
# 186,000 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:19:03
#
#
# Tentando recuperar Lattes compactado 6001213918322343 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6001213918322343
# Tentando recuperar Lattes compactado 6544683048560388 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6544683048560388
# Tentando recuperar Lattes compactado 6325182964782272 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6325182964782272
# Importação iniciada em 14/03/2022, 15:16:59846.
# 28.5% importados.
#
# Linhas por segundo lidas (total): 9.5
# 190,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:10:02
#
#
# Importação iniciada em 14/03/2022, 15:16:59548.
# 28.6% importados.
#
# Linhas por segundo lidas (total): 9.5
# 190,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:08:49
#
#
# Importação iniciada em 14/03/2022, 15:16:59599.
# 28.7% importados.
#
# Linhas por segundo lidas (total): 9.5
# 191,000 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 15/03/2022, 05:07:31
#
#
# Importação iniciada em 14/03/2022, 15:16:59772.
# 28.7% importados.
#
# ...
#
#
# Importação iniciada em 14/03/2022, 15:16:59207.
# 79.6% importados.
#
# Linhas por segundo lidas (total): 10.5
# 530,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:51:56
#
#
# Tentando recuperar Lattes compactado 6076176969893498 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6076176969893498
# Importação iniciada em 14/03/2022, 15:16:59615.
# 79.9% importados.
#
# Linhas por segundo lidas (total): 10.5
# 532,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:48:29
#
#
# Importação iniciada em 14/03/2022, 15:16:59633.
# 80.0% importados.
#
# Linhas por segundo lidas (total): 10.5
# 533,000 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:48:00
#
#
# Importação iniciada em 14/03/2022, 15:16:59154.
# 80.0% importados.
#
# Linhas por segundo lidas (total): 10.5
# 533,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:47:50
#
#
# Tentando recuperar Lattes compactado 6843663908246230 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6843663908246230
# Importação iniciada em 14/03/2022, 15:16:59541.
# 80.0% importados.
#
# Linhas por segundo lidas (total): 10.5
# 533,400 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:47:21
#
#
# Importação iniciada em 14/03/2022, 15:16:59148.
# 80.1% importados.
#
# Linhas por segundo lidas (total): 10.5
# 533,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:47:01
#
#
# Importação iniciada em 14/03/2022, 15:16:59245.
# 80.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 534,300 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:45:51
#
#
# Importação iniciada em 14/03/2022, 15:16:59563.
# 80.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 536,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:42:45
#
#
# Importação iniciada em 14/03/2022, 15:16:59277.
# 80.5% importados.
#
# Linhas por segundo lidas (total): 10.6
# 536,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:41:55
#
#
# Importação iniciada em 14/03/2022, 15:16:59559.
# 80.7% importados.
#
# Linhas por segundo lidas (total): 10.6
# 537,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:40:18
#
#
# Tentando recuperar Lattes compactado 6014115645318573 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6014115645318573
# Importação iniciada em 14/03/2022, 15:16:59133.
# 80.8% importados.
#
# Linhas por segundo lidas (total): 10.6
# 538,400 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:39:12
#
#
# Importação iniciada em 14/03/2022, 15:16:59111.
# 80.8% importados.
#
# Linhas por segundo lidas (total): 10.6
# 538,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:39:03
#
#
# Importação iniciada em 14/03/2022, 15:16:59919.
# 80.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 539,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:38:08
#
#
# Importação iniciada em 14/03/2022, 15:16:59310.
# 80.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 539,400 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:37:40
#
#
# Importação iniciada em 14/03/2022, 15:16:59038.
# 81.1% importados.
#
# Linhas por segundo lidas (total): 10.6
# 540,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:35:33
#
#
# Tentando recuperar Lattes compactado 6017426289660247 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6017426289660247
# Importação iniciada em 14/03/2022, 15:16:59109.
# 81.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 541,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:34:06
#
#
# Importação iniciada em 14/03/2022, 15:16:59433.
# 81.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 541,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:33:56
#
#
# Importação iniciada em 14/03/2022, 15:16:59026.
# 81.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 542,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:32:38
#
#
# Importação iniciada em 14/03/2022, 15:16:59662.
# 81.5% importados.
#
# Linhas por segundo lidas (total): 10.6
# 543,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:31:38
#
#
# Tentando recuperar Lattes compactado 6428847753171670 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6428847753171670
# Importação iniciada em 14/03/2022, 15:16:59675.
# 81.7% importados.
#
# Linhas por segundo lidas (total): 10.6
# 544,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:29:20
#
#
# Tentando recuperar Lattes compactado 6121786012697141 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6121786012697141
# Tentando recuperar Lattes compactado 6441049147434861 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6441049147434861
# Tentando recuperar Lattes compactado 6340196816023092 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6340196816023092
# Importação iniciada em 14/03/2022, 15:16:59866.
# 81.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 545,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:27:23
#
#
# Importação iniciada em 14/03/2022, 15:16:59733.
# 81.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 545,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:27:03
#
#
# Importação iniciada em 14/03/2022, 15:16:59350.
# 82.0% importados.
#
# Linhas por segundo lidas (total): 10.6
# 546,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:25:55
#
#
# Importação iniciada em 14/03/2022, 15:16:59993.
# 82.0% importados.
#
# Linhas por segundo lidas (total): 10.6
# 546,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:25:45
#
#
# Importação iniciada em 14/03/2022, 15:16:59968.
# 82.1% importados.
#
# Linhas por segundo lidas (total): 10.6
# 547,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:24:30
#
#
# Importação iniciada em 14/03/2022, 15:16:59210.
# 82.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 547,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:24:21
#
#
# Tentando recuperar Lattes compactado 6846032384955894 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6846032384955894
# Importação iniciada em 14/03/2022, 15:16:59406.
# 82.5% importados.
#
# Linhas por segundo lidas (total): 10.6
# 549,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:20:37
#
#
# Importação iniciada em 14/03/2022, 15:16:59659.
# 82.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 550,300 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:19:59
#
#
# Importação iniciada em 14/03/2022, 15:16:59972.
# 82.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 550,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:19:30
#
#
# Importação iniciada em 14/03/2022, 15:16:59588.
# 82.7% importados.
#
# Linhas por segundo lidas (total): 10.6
# 550,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:19:02
#
#
# Importação iniciada em 14/03/2022, 15:16:59814.
# 83.0% importados.
#
# Linhas por segundo lidas (total): 10.6
# 553,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:14:53
#
#
# Importação iniciada em 14/03/2022, 15:16:59869.
# 83.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 555,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:12:10
#
#
# Tentando recuperar Lattes compactado 6567352496620616 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6567352496620616
# Importação iniciada em 14/03/2022, 15:16:59496.
# 83.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 556,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:10:33
#
#
# Tentando recuperar Lattes compactado 6034171117285716 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6034171117285716
# Tentando recuperar Lattes compactado 6710764374904235 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6710764374904235
# Importação iniciada em 14/03/2022, 15:16:59128.
# 83.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 557,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:08:31
#
#
# Tentando recuperar Lattes compactado 6434313456070592 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6434313456070592
# Importação iniciada em 14/03/2022, 15:16:59533.
# 83.8% importados.
#
# Linhas por segundo lidas (total): 10.6
# 558,800 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:06:26
#
#
# Importação iniciada em 14/03/2022, 15:16:59102.
# 83.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 558,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:06:18
#
#
# Importação iniciada em 14/03/2022, 15:16:59780.
# 83.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 559,300 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:05:40
#
#
# Tentando recuperar Lattes compactado 6296090894516999 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6296090894516999
# Importação iniciada em 14/03/2022, 15:16:59722.
# 84.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 560,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:03:06
#
#
# Importação iniciada em 14/03/2022, 15:16:59649.
# 84.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 561,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:02:37
#
#
# Importação iniciada em 14/03/2022, 15:16:59892.
# 84.4% importados.
#
# Linhas por segundo lidas (total): 10.6
# 562,400 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 18:00:44
#
#
# Tentando recuperar Lattes compactado 6737069787698007 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6737069787698007
# Importação iniciada em 14/03/2022, 15:16:59078.
# 84.5% importados.
#
# Linhas por segundo lidas (total): 10.6
# 563,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 17:59:27
#
#
# Importação iniciada em 14/03/2022, 15:16:59683.
# 84.7% importados.
#
# Linhas por segundo lidas (total): 10.6
# 564,300 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 17:57:43
#
#
# Tentando recuperar Lattes compactado 6393300780049282 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6393300780049282
# Importação iniciada em 14/03/2022, 15:16:59813.
# 84.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 565,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 17:55:30
#
#
# Importação iniciada em 14/03/2022, 15:16:59238.
# 85.0% importados.
#
# Linhas por segundo lidas (total): 10.6
# 566,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 17:54:13
#
#
# Importação iniciada em 14/03/2022, 15:16:59400.
# 85.1% importados.
#
# Linhas por segundo lidas (total): 10.6
# 567,200 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 17:53:07
#
#
# Tentando recuperar Lattes compactado 6624636053688856 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6624636053688856
# Importação iniciada em 14/03/2022, 15:16:59376.
# 85.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 567,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 17:52:21
#
#
# Tentando recuperar Lattes compactado 6831170493512800 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6831170493512800
# Importação iniciada em 14/03/2022, 15:16:59356.
# 85.3% importados.
#
# Linhas por segundo lidas (total): 10.6
# 568,300 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 17:51:25
#
#
# Importação iniciada em 14/03/2022, 15:16:59348.
# 85.5% importados.
#
# Linhas por segundo lidas (total): 10.6
# 569,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 17:49:13
#
#
# Importação iniciada em 14/03/2022, 15:16:59358.
# 85.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 570,400 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 17:48:05
#
#
# Importação iniciada em 14/03/2022, 15:16:59965.
# 85.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 570,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 17:47:55
#
#
# Importação iniciada em 14/03/2022, 15:16:59322.
# 85.7% importados.
#
# Linhas por segundo lidas (total): 10.6
# 570,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 17:47:17
#
#
# Tentando recuperar Lattes compactado 6070243075070641 via SOAP
# Erro 1: "Mais de um curriculo atende ao criterio informado!".
# ERRRO - Lattes não está carregado. ID: 6070243075070641
# Importação iniciada em 14/03/2022, 15:16:59599.
# 85.7% importados.
#
# Linhas por segundo lidas (total): 10.6
# 571,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 17:46:58
#
#
# Importação iniciada em 14/03/2022, 15:16:59928.
# 85.9% importados.
#
# Linhas por segundo lidas (total): 10.6
# 572,500 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 17:44:44
#
#
# Tentando recuperar Lattes compactado 6100010694016363 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6100010694016363
# Tentando recuperar Lattes compactado 6630375904580369 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6630375904580369
# Importação iniciada em 14/03/2022, 15:16:59517.
# 86.2% importados.
#
# Linhas por segundo lidas (total): 10.6
# 574,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 17:41:22
#
#
# Importação iniciada em 14/03/2022, 15:16:59728.
# 86.5% importados.
#
# Linhas por segundo lidas (total): 10.6
# 576,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 17:38:01
#
#
# Importação iniciada em 14/03/2022, 15:16:59556.
# 86.5% importados.
#
# Linhas por segundo lidas (total): 10.6
# 576,800 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 17:37:52
#
#
# Tentando recuperar Lattes compactado 6081693026493955 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6081693026493955
# Importação iniciada em 14/03/2022, 15:16:59041.
# 86.8% importados.
#
# Linhas por segundo lidas (total): 10.6
# 578,600 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 17:35:01
# Importação iniciada em 14/03/2022, 15:16:59808.
# 87.0% importados.
#
# Linhas por segundo lidas (total): 10.6
# 579,700 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 17:33:16
#
#
# Tentando recuperar Lattes compactado 6016973292621471 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6016973292621471
# Importação iniciada em 14/03/2022, 15:16:59638.
# 87.5% importados.
#
# Linhas por segundo lidas (total): 10.6
# 582,900 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 17:28:10
#
#
# Tentando recuperar Lattes compactado 6062943862511241 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 6062943862511241
# Importação iniciada em 14/03/2022, 15:16:59085.
# 87.6% importados.
#
# Linhas por segundo lidas (total): 10.6
# 584,100 de 666,540
# Acabará em:
#     Cálculo considerando desde o início: 14/03/2022, 17:26:15
#
#
# 584642 / 666540. Importing id 6287876695214362.
