# %%
from Regressao import Regressao

# %%
reg = Regressao()

# %%
dir(reg)
# Out:
# ['CA',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'chamada',
#  'data_atualização',
#  'db',
#  'est2',
#  'faz_regressoes',
#  'fit',
#  'gera_sql',
#  'get_parâmetros',
#  'get_pd',
#  'grava_resultados',
#  'include',
#  'já_feita',
#  'lista_cas',
#  'lista_chamadas',
#  'lista_indicadores',
#  'lista_programas',
#  'média_investimento',
#  'path',
#  'pega_lista_cas',
#  'pega_lista_chamadas',
#  'pega_lista_indicadores',
#  'pega_lista_programas',
#  'programa',
#  'select_CA',
#  'select_chamada',
#  'select_programa',
#  'select_área',
#  'tipo_indicador',
#  'total_investido',
#  'área']

# %%
reg.chamada = 'UNIVERSAL 2016 - FAIXA A'
reg.programa = 'PROGRAMA BASICO DE EDUCACAO'
reg.tipo_indicador = '@ANO-DO-ARTIGO ARTIGO-PUBLICADO '

# %%
reg.get_pd(chamada = reg.chamada)

# %%
reg.pd[['qty_i','qty_f','pgtos']].to_excel('d:/test.xlsx')

# %%
dir(reg.est2)
# Out:
# ['HC0_se',
#  'HC1_se',
#  'HC2_se',
#  'HC3_se',
#  '_HCCM',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slotnames__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abat_diagonal',
#  '_cache',
#  '_data_attr',
#  '_data_in_cache',
#  '_get_robustcov_results',
#  '_is_nested',
#  '_use_t',
#  '_wexog_singular_values',
#  'aic',
#  'bic',
#  'bse',
#  'centered_tss',
#  'compare_f_test',
#  'compare_lm_test',
#  'compare_lr_test',
#  'condition_number',
#  'conf_int',
#  'conf_int_el',
#  'cov_HC0',
#  'cov_HC1',
#  'cov_HC2',
#  'cov_HC3',
#  'cov_kwds',
#  'cov_params',
#  'cov_type',
#  'df_model',
#  'df_resid',
#  'diagn',
#  'eigenvals',
#  'el_test',
#  'ess',
#  'f_pvalue',
#  'f_test',
#  'fittedvalues',
#  'fvalue',
#  'get_influence',
#  'get_prediction',
#  'get_robustcov_results',
#  'initialize',
#  'k_constant',
#  'llf',
#  'load',
#  'model',
#  'mse_model',
#  'mse_resid',
#  'mse_total',
#  'nobs',
#  'normalized_cov_params',
#  'outlier_test',
#  'params',
#  'predict',
#  'pvalues',
#  'remove_data',
#  'resid',
#  'resid_pearson',
#  'rsquared',
#  'rsquared_adj',
#  'save',
#  'scale',
#  'ssr',
#  'summary',
#  'summary2',
#  't_test',
#  't_test_pairwise',
#  'tvalues',
#  'uncentered_tss',
#  'use_t',
#  'wald_test',
#  'wald_test_terms',
#  'wresid']

# %%
reg.est2.params
# Out:
# const    7.470208
# pgtos    0.000253
# qty_i    1.516480
# dtype: float64

# %%
reg.pd.pgtos.sum() * reg.est2.params.pgtos
# Out:
# 573.439379149968

# %%
reg.pd
# Out:
#                    id                              tipo  qty_i  qty_f  \
# 0      76991033733054  @ANO-DO-ARTIGO ARTIGO-PUBLICADO    16.0   23.0
# 1      78830840463434  @ANO-DO-ARTIGO ARTIGO-PUBLICADO    14.0   34.0
# 2     130140163490918  @ANO-DO-ARTIGO ARTIGO-PUBLICADO     0.0    7.0
# 3     146898361391391  @ANO-DO-ARTIGO ARTIGO-PUBLICADO     5.0   18.0
# 4     171195237052575  @ANO-DO-ARTIGO ARTIGO-PUBLICADO     4.0   14.0
# ..                ...                               ...    ...    ...
# 414  9871036913331484  @ANO-DO-ARTIGO ARTIGO-PUBLICADO    16.0   23.0
# 415  9873499914963340  @ANO-DO-ARTIGO ARTIGO-PUBLICADO     4.0   14.0
# 416  9900433024242592  @ANO-DO-ARTIGO ARTIGO-PUBLICADO     5.0   21.0
# 417  9916149503779411  @ANO-DO-ARTIGO ARTIGO-PUBLICADO     2.0    8.0
# 418  9999217523842385  @ANO-DO-ARTIGO ARTIGO-PUBLICADO    10.0   25.0
#
#        pgtos                   chamada                     programa
# 0        0.0  UNIVERSAL 2016 - FAIXA A  PROGRAMA BASICO DE EDUCACAO
# 1        0.0  UNIVERSAL 2016 - FAIXA A  PROGRAMA BASICO DE EDUCACAO
# 2        0.0  UNIVERSAL 2016 - FAIXA A  PROGRAMA BASICO DE EDUCACAO
# 3    29500.0  UNIVERSAL 2016 - FAIXA A  PROGRAMA BASICO DE EDUCACAO
# 4        0.0  UNIVERSAL 2016 - FAIXA A  PROGRAMA BASICO DE EDUCACAO
# ..       ...                       ...                          ...
# 414      0.0  UNIVERSAL 2016 - FAIXA A  PROGRAMA BASICO DE EDUCACAO
# 415  22990.0  UNIVERSAL 2016 - FAIXA A  PROGRAMA BASICO DE EDUCACAO
# 416      0.0  UNIVERSAL 2016 - FAIXA A  PROGRAMA BASICO DE EDUCACAO
# 417      0.0  UNIVERSAL 2016 - FAIXA A  PROGRAMA BASICO DE EDUCACAO
# 418      0.0  UNIVERSAL 2016 - FAIXA A  PROGRAMA BASICO DE EDUCACAO
#
# [419 rows x 7 columns]
