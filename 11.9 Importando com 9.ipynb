# %%
from Carga import Carga
cg = Carga()


#Origens
cg.de_hd = False
cg.de_all_lattes = True
cg.de_bd_demanda_bruta = False
cg.de_dados_pessoais = False

#Exceções
cg.pular_indicadores = False
cg.pular_palavras_chave = False
cg.pular_areas_conhecimento = False
cg.pular_publicações = True
cg.pular_dados_gerais=False
cg.pular_vinculos = False
cg.pular_erros = False
cg.pular_jsons = False

#Importações
cg.on_conflic_update = True
cg.importar_indicadores = True
cg.importar_palavras_chave = True
cg.importar_areas_conhecimento = True
cg.importar_publicações = True
cg.importar_dados_gerais=True
cg.importar_vinculos = True


#Outras Configurações
cg.on_conflic_update = True
cg.auto_save_json_to_bd = True
cg.pegar_lista_de_importação_de_arquivo = False
cg.data_mínima_atualização_lattes = None

cg.atualiza_todos_os_indicadores(começando_com = '9')
# Out:
# Carregando lista de indicadores para importar da tabela all_lattes do BD
#
# Carregando lista de Ids da tabela publicacoes para pular
#
# Retirando ids a exluir...
# Salvando o arquivo com a lista no disco.
# Iniciando Importação.
# Tentando recuperar Lattes compactado 9075466730503261 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 9075466730503261
# Tentando recuperar Lattes compactado 9928428184447914 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 9928428184447914
# Tentando recuperar Lattes compactado 9880245448434500 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 9880245448434500
# Tentando recuperar Lattes compactado 9991219718192167 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 9991219718192167
# Tentando recuperar Lattes compactado 9652281613769892 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 9652281613769892
# Tentando recuperar Lattes compactado 9829650405981482 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 9829650405981482
# Tentando recuperar Lattes compactado 9792895722139605 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 9792895722139605
# Tentando recuperar Lattes compactado 9248725305836949 via SOAP
# Erro 1: "Nenhum curriculo encontrado!".
# ERRRO - Lattes não está carregado. ID: 9248725305836949
# Tentando recuperar Lattes compactado 9837848355462864 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 9898325592023122 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 9940011915891326 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 9589932892407771 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 9745399025820854 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 9934614676969472 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 9867516825474600 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 9890608481265987 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 9711474158511671 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 9589048540204651 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 9786324780888792 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 9400519334564977 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 9259539240507255 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 9637694737801798 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 9137096372256400 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 9044528552461898 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# Tentando recuperar Lattes compactado 9489678352611654 via SOAP
# Lattes compactado recuperado via SOAP
# Lattes salvo no disco.
# 8062 / 5654187. Importing id 9039182932747194.
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16828/2261324006.py in <module>
#      35 cg.data_mínima_atualização_lattes = None
#      36
# ---> 37 cg.atualiza_todos_os_indicadores(começando_com = '9')
#
# ~\CNPq\Lattes\Python\Carga.py in atualiza_todos_os_indicadores(self, num_imports_skip_before_log, começando_com)
#    1065                 ind = Indicadores (id = id, auto_save_json_to_bd = self.auto_save_json_to_bd)
#    1066                 ind.on_conflic_update = self.on_conflic_update
# -> 1067                 ind.atualiza(
#    1068                             indicadores = self.importar_indicadores,
#    1069                             palavras_chave = self.importar_palavras_chave,
#
# ~\CNPq\Lattes\Python\Indicadores.py in wrap(*args, **kw)
#      63         def wrap(*args, **kw):
#      64             if args[0].show_execution_time: ts = datetime.now()
# ---> 65             result = f(*args, **kw)
#      66             if args[0].show_execution_time:
#      67                 te = datetime.now()
#
# ~\CNPq\Lattes\Python\Indicadores.py in atualiza(self, indicadores, palavras_chave, areas_conhecimento, publicações, dados_gerais, vinculos)
#     494                 return False
#     495             else:
# --> 496                 self.salva_indicadores_no_bd()
#     497         if palavras_chave:
#     498             if not self.get_palavras_chave():
#
# ~\CNPq\Lattes\Python\Indicadores.py in wrap(*args, **kw)
#      63         def wrap(*args, **kw):
#      64             if args[0].show_execution_time: ts = datetime.now()
# ---> 65             result = f(*args, **kw)
#      66             if args[0].show_execution_time:
#      67                 te = datetime.now()
#
# ~\CNPq\Lattes\Python\Indicadores.py in salva_indicadores_no_bd(self)
#     144             sql = self.db.cursor.mogrify(sql, [self.id])
#     145             if self.show_sql: print (sql)
# --> 146             self.db.execute(sql)
#     147         else:
#     148             if self.show_sql: print (sql)
#
# ~\CNPq\Lattes\Python\Database.py in execute(self, sql, params)
#      84         if self.show_sql:
#      85             print(sql_to_execute)
# ---> 86         self.cursor.execute(sql_to_execute)
#      87         self.commit()
#      88         self.close()
#
# OperationalError: server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
