# %%
from Lattes import Lattes
# Out:
# import io, os, sys, time
# from zipfile import ZipFile
# import zeep
# import xmltodict, json, csv
# import psycopg2
# from configparser import ConfigParser
# from datetime import datetime
# import pytz
# import socket
# from Indicadores import Indicadores
# import html
# from collections import OrderedDict
# Módulos Importados

# %%
lattes = Lattes(id='6421416314370479')

# %%
lattes.get_zip_from_SOAP()
# Out:
# Erro 1: "Mais de um curriculo atende ao criterio informado!"
# False

# %%
lattes.save_zip_to_disk()
# Out:
# ERRO ao gravar arquivo zippado no disco.

# %%
lattes.get_xml()
# Out:
# False

# %%
lattes.insert_json()
# Out:
# Inserting 6421416314370479 JSON in BD.
# Inserting xml to Postgree
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12992/2071018594.py in <module>
# ----> 1 lattes.insert_json()
#
# ~\CNPq\Lattes\Python\Lattes.py in insert_json(self)
#     384         data = (self.id,
#     385                 json.dumps(self.json),
# --> 386                 self.dt_atualizacao.strftime('%Y-%m-%dT%H:%M:%S.%f'))
#     387         # print("Data tuple: ", data)
#     388         conn = None
#
# AttributeError: 'NoneType' object has no attribute 'strftime'

# %%
lista_ids = Lattes.get_bd_lista_ids()
# Out:
# Lista de IDs pega no Banco de Dados.

# %%
print(lista_ids)
# Out:
# [('0000000403000690',), ('0000002580990139',), ('0000005794097038',), ('0000010326417697',), ('0000021871668960',), ('0000025215704147',), ('0000027477345359',), ('0000030343117448',), ('0000031952686226',), ('0000042224250076',), ('0000045877979820',), ('0009227120124459',), ('0011193162263188',), ('0022323935509908',), ('0025691356734276',), ('0027107749225989',), ('0028525989491756',), ('0029364286971436',), ('0029796450556482',), ('0030588569394521',), ('0030781854104755',), ('0038082635312850',), ('0039577792859830',), ('0051857773510069',), ('0060936280167664',), ('0061583098515492',), ('0064662007370722',), ('0067723908804482',), ('0068750820270643',), ('0069465581458412',), ('0070007776971984',), ('0071825108081700',), ('0071959846758799',), ('0072237405511009',), ('0073316808677174',), ('0075424036193583',), ('0078281412810444',), ('0080510047126688',), ('0084119879119569',), ('0084343165067528',), ('0085761434221379',), ('0088251730114521',), ('0095112297501455',), ('010386
# ...

# %%
print(Lattes.bd_lista_ids)
# Out:
# [('0000000403000690',), ('0000002580990139',), ('0000005794097038',), ('0000010326417697',), ('0000021871668960',), ('0000025215704147',), ('0000027477345359',), ('0000030343117448',), ('0000031952686226',), ('0000042224250076',), ('0000045877979820',), ('0009227120124459',), ('0011193162263188',), ('0022323935509908',), ('0025691356734276',), ('0027107749225989',), ('0028525989491756',), ('0029364286971436',), ('0029796450556482',), ('0030588569394521',), ('0030781854104755',), ('0038082635312850',), ('0039577792859830',), ('0051857773510069',), ('0060936280167664',), ('0061583098515492',), ('0064662007370722',), ('0067723908804482',), ('0068750820270643',), ('0069465581458412',), ('0070007776971984',), ('0071825108081700',), ('0071959846758799',), ('0072237405511009',), ('0073316808677174',), ('0075424036193583',), ('0078281412810444',), ('0080510047126688',), ('0084119879119569',), ('0084343165067528',), ('0085761434221379',), ('0088251730114521',), ('0095112297501455',), ('010386
# ...

# %%
arquivos = [id for id in lista_ids if id not in Lattes.bd_lista_ids]
print(arquivos)
# Out:
# []
